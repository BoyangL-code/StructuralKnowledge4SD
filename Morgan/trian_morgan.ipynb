# %%
# -*- coding: utf-8 -*-
import os
import re
import glob
import json
import numpy as np
import pandas as pd

import optuna
import xgboost as xgb
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import roc_auc_score, average_precision_score

# =========================
# 0) 配置
# =========================
RANDOM_SEED = 42
N_TRIALS = 30
N_SPLITS = 5
THRESH = 0.5

# 直接读取你已生成的 Morgan 特征文件（xlsx）
FEATURE_FILE_GLOB = "./Malodors_transformed_MORGAN_features*.xlsx"
# 如果你的文件名不同，改成你的，例如：
# FEATURE_FILE_GLOB = "./Malodors_transformed_MORGAN_features.xlsx"

# 固定参数（Optuna 只搜索部分超参）
BASE_XGB_PARAMS = dict(
    objective="binary:logistic",
    eval_metric="logloss",
    tree_method="hist",
    n_jobs=-1,
    random_state=RANDOM_SEED,
    verbosity=0,
    multi_strategy="multi_output_tree",
)

# =========================
# 1) 版本检查
# =========================
def _ver_tuple(v: str):
    parts = re.split(r"[.+-]", v.strip())
    nums = []
    for p in parts[:3]:
        try:
            nums.append(int(p))
        except Exception:
            nums.append(0)
    while len(nums) < 3:
        nums.append(0)
    return tuple(nums)

def check_xgb_version():
    v = _ver_tuple(xgb.__version__)
    if v < (1, 6, 0):
        raise RuntimeError(f"xgboost=={xgb.__version__} 太旧：multi-label 需要 >=1.6")
    if "multi_strategy" in BASE_XGB_PARAMS and v < (2, 0, 0):
        raise RuntimeError(
            f"xgboost=={xgb.__version__} 不支持 multi_output_tree（需要>=2.0）。"
            f"升级或删掉 multi_strategy。"
        )

# =========================
# 2) 读取 transformed Morgan 特征文件 & 自动识别列
# =========================
def find_feature_file(pattern: str):
    cands = sorted(glob.glob(pattern))
    if not cands:
        raise FileNotFoundError(
            f"找不到 Morgan 特征文件：{pattern}\n"
            f"请确认你保存的 xlsx 文件名，或修改 FEATURE_FILE_GLOB。"
        )
    return cands[-1]

def find_smiles_col(df: pd.DataFrame):
    cand = [c for c in df.columns if isinstance(c, str) and "smiles" in c.lower()]
    if not cand:
        return None
    for p in ["Canonical SMILES", "canonical_smiles", "SMILES", "smiles"]:
        for c in cand:
            if c.lower() == p.lower():
                return c
    return cand[0]

def is_binary_01_series(s: pd.Series) -> bool:
    if s.dtype == bool:
        return True
    if not np.issubdtype(s.dtype, np.number):
        return False
    vals = pd.unique(s.dropna())
    if len(vals) == 0:
        return False
    return set(vals).issubset({0, 1})

def infer_feature_cols_morgan(df: pd.DataFrame):
    """
    兼容两种常见 Morgan 保存方式：
    A) 列名是 morgan_0...morgan_2047 / fp_ / bit_
    B) 列名是纯数字 0...2047（Excel 读入后可能变成 int）
    """
    # A) 前缀形式
    morgan_cols = []
    for prefix in ["morgan_", "fp_", "ecfp_", "mfp_", "bit_"]:
        morgan_cols.extend([c for c in df.columns if isinstance(c, str) and c.startswith(prefix)])

    if morgan_cols:
        # 保持原顺序
        return list(morgan_cols)

    # B) 纯数字列
    num_cols = []
    for c in df.columns:
        if isinstance(c, (int, np.integer)):
            num_cols.append(c)
        elif isinstance(c, str) and c.isdigit():
            num_cols.append(c)

    if num_cols:
        # 尽量按数值排序
        def keyf(x):
            try:
                return int(x)
            except Exception:
                return 10**18
        return sorted(num_cols, key=keyf)

    raise ValueError(
        "未找到 Morgan 特征列。\n"
        "请确保：Morgan 列名为 morgan_/fp_/bit_ 前缀，或列名为 0..2047 的纯数字。"
    )

def infer_label_cols(df: pd.DataFrame, smiles_col: str, feature_cols: list):
    exclude = set(feature_cols)
    if smiles_col is not None:
        exclude.add(smiles_col)

    label_cols = []
    for c in df.columns:
        if c in exclude:
            continue
        if is_binary_01_series(df[c]):
            label_cols.append(c)

    if not label_cols:
        raise ValueError("未识别到标签列（0/1）。请确认文件中仍包含 138 个标签列。")

    return label_cols

def load_Xy_from_transformed_morgan(xlsx_path: str):
    df = pd.read_excel(xlsx_path)

    smiles_col = find_smiles_col(df)
    feature_cols = infer_feature_cols_morgan(df)
    label_cols = infer_label_cols(df, smiles_col, feature_cols)

    X = df[feature_cols].fillna(0).astype(np.float32).values
    y = df[label_cols].fillna(0).astype(int).values

    if X.shape[0] != y.shape[0]:
        raise ValueError("X 和 y 行数不一致，请检查文件。")

    return X, y, feature_cols, label_cols, df

# =========================
# 3) 指标（macro）
# =========================
def multilabel_macro_metrics(y_true, y_prob, thresh=0.5):
    y_true = np.asarray(y_true).astype(int)
    y_prob = np.asarray(y_prob).astype(float)
    y_pred = (y_prob >= thresh).astype(int)

    L = y_true.shape[1]
    accs, precs, recs, specs = [], [], [], []
    aurocs, auprcs = [], []

    for k in range(L):
        yt = y_true[:, k]
        yp = y_pred[:, k]
        ys = y_prob[:, k]

        tp = int(np.sum((yt == 1) & (yp == 1)))
        tn = int(np.sum((yt == 0) & (yp == 0)))
        fp = int(np.sum((yt == 0) & (yp == 1)))
        fn = int(np.sum((yt == 1) & (yp == 0)))
        n = len(yt)

        accs.append((tp + tn) / n if n else np.nan)
        precs.append(tp / (tp + fp) if (tp + fp) else np.nan)
        recs.append(tp / (tp + fn) if (tp + fn) else np.nan)
        specs.append(tn / (tn + fp) if (tn + fp) else np.nan)

        if len(np.unique(yt)) == 2:
            aurocs.append(roc_auc_score(yt, ys))
            auprcs.append(average_precision_score(yt, ys))
        else:
            aurocs.append(np.nan)
            auprcs.append(np.nan)

    def nanmean(x):
        return float(np.nanmean(np.asarray(x, dtype=float)))

    return {
        "Accuracy_macro": nanmean(accs),
        "Precision_macro": nanmean(precs),
        "Recall_macro": nanmean(recs),
        "Specificity_macro": nanmean(specs),
        "AUROC_macro": nanmean(aurocs),
        "AUPRC_macro": nanmean(auprcs),
        "AUROC_valid_labels": int(np.sum(~np.isnan(aurocs))),
        "AUPRC_valid_labels": int(np.sum(~np.isnan(auprcs))),
        "n_labels": int(L),
    }

def extract_positive_proba(p, n_labels: int):
    if isinstance(p, list):
        return np.vstack([pi[:, 1] for pi in p]).T.astype(np.float32)

    p = np.asarray(p)
    if p.ndim == 3 and p.shape[-1] == 2:
        return p[:, :, 1].astype(np.float32)
    if p.ndim == 2:
        if p.shape[1] == 2 and n_labels == 1:
            return p[:, 1:2].astype(np.float32)
        return p.astype(np.float32)
    raise ValueError(f"无法解析 predict_proba 输出形状: {p.shape}")

# =========================
# 4) 近似分层 5 折：用 label cardinality 分层
# =========================
def make_stratify_target(y: np.ndarray, n_bins: int = 10):
    card = y.sum(axis=1).astype(int)
    uniq = np.unique(card)
    if len(uniq) <= 15:
        return card
    r = pd.Series(card).rank(method="average").values
    bins = pd.qcut(r, q=min(n_bins, len(np.unique(r))), labels=False, duplicates="drop")
    return np.asarray(bins, dtype=int)

def build_folds(X, y, n_splits=5, seed=42):
    strat_y = make_stratify_target(y)
    skf = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=seed)
    return list(skf.split(X, strat_y))

# =========================
# 5) 5 折 CV 评估
# =========================
def cv_eval_one_paramset(X, y, folds, params, thresh=0.5):
    n_labels = y.shape[1]
    fold_metrics = []

    for fold_id, (tr_idx, va_idx) in enumerate(folds, start=1):
        X_tr, X_va = X[tr_idx], X[va_idx]
        y_tr, y_va = y[tr_idx], y[va_idx]

        clf = xgb.XGBClassifier(**params)
        clf.fit(X_tr, y_tr)

        p = clf.predict_proba(X_va)
        y_prob = extract_positive_proba(p, n_labels=n_labels)

        m = multilabel_macro_metrics(y_va, y_prob, thresh=thresh)
        fold_metrics.append(m)

    keys = list(fold_metrics[0].keys())
    mean_metrics = {}
    for k in keys:
        vals = [fm[k] for fm in fold_metrics]
        if isinstance(vals[0], float):
            mean_metrics[k] = float(np.nanmean(vals))
        else:
            mean_metrics[k] = vals[-1]
    return mean_metrics

# =========================
# 6) Optuna 超参空间
# =========================
def build_trial_params(trial: optuna.Trial):
    params = dict(BASE_XGB_PARAMS)
    params.update({
        "n_estimators": trial.suggest_int("n_estimators", 300, 1200),
        "max_depth": trial.suggest_int("max_depth", 3, 10),
        "learning_rate": trial.suggest_float("learning_rate", 0.01, 0.2, log=True),
        "subsample": trial.suggest_float("subsample", 0.6, 1.0),
        "colsample_bytree": trial.suggest_float("colsample_bytree", 0.6, 1.0),
        "min_child_weight": trial.suggest_float("min_child_weight", 0.5, 10.0, log=True),
        "reg_lambda": trial.suggest_float("reg_lambda", 1e-3, 20.0, log=True),
        "reg_alpha": trial.suggest_float("reg_alpha", 1e-8, 5.0, log=True),
        "gamma": trial.suggest_float("gamma", 0.0, 5.0),
    })
    return params

# =========================
# 7) 主流程：读Morgan特征 -> 固定folds -> Optuna(30) -> 输出+保存
# =========================
def main():
    check_xgb_version()

    feature_file = find_feature_file(FEATURE_FILE_GLOB)
    print("[INFO] Using transformed Morgan feature file:", feature_file)

    X, y, feat_cols, label_cols, df_all = load_Xy_from_transformed_morgan(feature_file)
    print(f"[INFO] X shape={X.shape} (features={len(feat_cols)}) | y shape={y.shape} (labels={len(label_cols)})")

    folds = build_folds(X, y, n_splits=N_SPLITS, seed=RANDOM_SEED)
    print(f"[INFO] Prepared fixed {N_SPLITS}-fold splits for all trials.")

    def objective(trial: optuna.Trial):
        params = build_trial_params(trial)
        mean_metrics = cv_eval_one_paramset(X, y, folds, params, thresh=THRESH)

        score = mean_metrics["AUPRC_macro"]  # PRAUC
        print(
            f"\n[TRIAL {trial.number:02d}] score(AUPRC_macro)={score:.6f} | "
            f"AUROC={mean_metrics['AUROC_macro']:.6f} | "
            f"Acc={mean_metrics['Accuracy_macro']:.6f} | "
            f"P={mean_metrics['Precision_macro']:.6f} | "
            f"R={mean_metrics['Recall_macro']:.6f} | "
            f"Spec={mean_metrics['Specificity_macro']:.6f}"
        )

        for k, v in mean_metrics.items():
            trial.set_user_attr(k, v)

        return score

    study = optuna.create_study(
        direction="maximize",
        sampler=optuna.samplers.TPESampler(seed=RANDOM_SEED),
    )
    study.optimize(objective, n_trials=N_TRIALS, show_progress_bar=True)

    print("\n================ BEST =================")
    print("Best trial:", study.best_trial.number)
    print("Best AUPRC_macro:", study.best_value)
    print("Best params:")
    print(json.dumps(study.best_params, indent=2, ensure_ascii=False))

    rows = []
    for t in study.trials:
        if t.value is None:
            continue
        row = {"trial": t.number, "AUPRC_macro": t.value, **t.params}
        row.update({k: v for k, v in t.user_attrs.items() if k.endswith("_macro")})
        rows.append(row)

    res_df = pd.DataFrame(rows).sort_values("AUPRC_macro", ascending=False)
    out_csv = "./optuna_singlemodel_MORGAN_30trials_5fold_results.csv"
    res_df.to_csv(out_csv, index=False, encoding="utf-8-sig")
    print("[SAVED]", out_csv)

if __name__ == "__main__":
    main()
# Out:
# [INFO] Using transformed Morgan feature file: ./Malodors_transformed_MORGAN_features.xlsx
# [I 2026-01-07 22:36:11,493] A new study created in memory with name: no-name-9f03ca58-ca16-439f-bf1d-034ffd32bf72
# [INFO] X shape=(4952, 2048) (features=2048) | y shape=(4952, 138) (labels=138)
# [INFO] Prepared fixed 5-fold splits for all trials.
#   0%|          | 0/30 [00:00<?, ?it/s]
# [TRIAL 00] score(AUPRC_macro)=0.296136 | AUROC=0.858934 | Acc=0.971812 | P=0.461775 | R=0.178823 | Spec=0.991886
# [I 2026-01-08 01:13:30,676] Trial 0 finished with value: 0.29613556536383034 and parameters: {'n_estimators': 637, 'max_depth': 10, 'learning_rate': 0.08960785365368121, 'subsample': 0.8394633936788146, 'colsample_bytree': 0.6624074561769746, 'min_child_weight': 0.7978542347074177, 'reg_lambda': 0.0017775399007348214, 'reg_alpha': 0.3426417745118369, 'gamma': 3.005575058716044}. Best is trial 0 with value: 0.29613556536383034.
#
# [TRIAL 01] score(AUPRC_macro)=0.304476 | AUROC=0.856937 | Acc=0.972390 | P=0.480987 | R=0.171790 | Spec=0.992860
# [I 2026-01-08 02:07:50,674] Trial 1 finished with value: 0.30447617275127564 and parameters: {'n_estimators': 937, 'max_depth': 3, 'learning_rate': 0.18276027831785724, 'subsample': 0.9329770563201687, 'colsample_bytree': 0.6849356442713105, 'min_child_weight': 0.8620446097910766, 'reg_lambda': 0.006149337057087106, 'reg_alpha': 4.4319427891510175e-06, 'gamma': 2.6237821581611893}. Best is trial 1 with value: 0.30447617275127564.
#
# [TRIAL 02] score(AUPRC_macro)=0.298779 | AUROC=0.856985 | Acc=0.972552 | P=0.532873 | R=0.146040 | Spec=0.993816
# [I 2026-01-08 03:44:35,533] Trial 2 finished with value: 0.29877932772844257 and parameters: {'n_estimators': 689, 'max_depth': 5, 'learning_rate': 0.06252287916406217, 'subsample': 0.6557975442608167, 'colsample_bytree': 0.7168578594140873, 'min_child_weight': 1.498365454855079, 'reg_lambda': 0.09153152164233955, 'reg_alpha': 0.06764288719681069, 'gamma': 0.9983689107917987}. Best is trial 1 with value: 0.30447617275127564.
#
# [TRIAL 03] score(AUPRC_macro)=0.264499 | AUROC=0.852456 | Acc=0.971571 | P=0.744173 | R=0.041713 | Spec=0.997404
# [I 2026-01-08 05:51:48,907] Trial 3 finished with value: 0.2644989521742057 and parameters: {'n_estimators': 763, 'max_depth': 7, 'learning_rate': 0.011492999300221412, 'subsample': 0.8430179407605753, 'colsample_bytree': 0.6682096494749166, 'min_child_weight': 0.6075808513336687, 'reg_lambda': 12.055498078944888, 'reg_alpha': 2.5119100929409792, 'gamma': 4.041986740582305}. Best is trial 1 with value: 0.30447617275127564.
#
# [TRIAL 04] score(AUPRC_macro)=0.294262 | AUROC=0.858343 | Acc=0.972593 | P=0.661466 | R=0.094632 | Spec=0.995854
# [I 2026-01-08 06:34:09,456] Trial 4 finished with value: 0.29426189878771075 and parameters: {'n_estimators': 574, 'max_depth': 3, 'learning_rate': 0.07766184280392888, 'subsample': 0.7760609974958406, 'colsample_bytree': 0.6488152939379115, 'min_child_weight': 2.2039920190846214, 'reg_lambda': 0.001405743424794793, 'reg_alpha': 0.8131129951713353, 'gamma': 1.2938999080000846}. Best is trial 1 with value: 0.30447617275127564.
#
# [TRIAL 05] score(AUPRC_macro)=0.272978 | AUROC=0.846704 | Acc=0.972315 | P=0.669133 | R=0.074269 | Spec=0.995979
# [I 2026-01-08 08:25:42,272] Trial 5 finished with value: 0.2729776742846842 and parameters: {'n_estimators': 896, 'max_depth': 5, 'learning_rate': 0.04749239763680407, 'subsample': 0.8186841117373118, 'colsample_bytree': 0.6739417822102108, 'min_child_weight': 9.129115219600122, 'reg_lambda': 2.1570962503558295, 'reg_alpha': 1.4882404753442915, 'gamma': 4.474136752138244}. Best is trial 1 with value: 0.30447617275127564.

# %%
import pandas as pd

df_trials = study.trials_dataframe(attrs=("number", "value", "params", "user_attrs", "state"))
df_trials.to_csv("optuna_trials_dump.csv", index=False, encoding="utf-8-sig")
print("saved: optuna_trials_dump.csv")

# %%
# -*- coding: utf-8 -*-
import os
import re
import glob
import json
import warnings
import numpy as np
import pandas as pd

import optuna
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import roc_auc_score, average_precision_score
from sklearn.multioutput import MultiOutputClassifier

# =========================
# 0) 全局：尽量屏蔽警告 + LightGBM 日志
# =========================
os.environ["PYTHONWARNINGS"] = "ignore"
warnings.filterwarnings("ignore", category=UserWarning)
warnings.filterwarnings("ignore", category=FutureWarning)
warnings.filterwarnings("ignore", category=RuntimeWarning)

try:
    import lightgbm as lgb
except Exception as e:
    raise RuntimeError(
        "未检测到 lightgbm。请先安装：pip install lightgbm\n"
        f"原始错误：{repr(e)}"
    )

# =========================
# 1) 配置
# =========================
RANDOM_SEED = 42
N_TRIALS = 30
N_SPLITS = 5
THRESH = 0.5

# 直接读取你已生成的 Morgan 特征文件（xlsx）
FEATURE_FILE_GLOB = "./Malodors_transformed_MORGAN_features.xlsx"

# 固定参数（Optuna 只搜索部分超参）
# 关键：verbosity=-1 关闭 LightGBM 输出
BASE_LGB_PARAMS = dict(
    objective="binary",
    boosting_type="gbdt",
    n_jobs=-1,
    random_state=RANDOM_SEED,
    verbosity=-1,  # 关闭 LightGBM 日志（重要）
)

# =========================
# 2) 读取 transformed Morgan 特征文件 & 自动识别列
# =========================
def find_feature_file(pattern: str):
    cands = sorted(glob.glob(pattern))
    if not cands:
        raise FileNotFoundError(
            f"找不到 Morgan 特征文件：{pattern}\n"
            f"请确认你保存的 xlsx 文件名，或修改 FEATURE_FILE_GLOB。"
        )
    return cands[-1]

def find_smiles_col(df: pd.DataFrame):
    cand = [c for c in df.columns if isinstance(c, str) and "smiles" in c.lower()]
    if not cand:
        return None
    for p in ["Canonical SMILES", "canonical_smiles", "SMILES", "smiles"]:
        for c in cand:
            if c.lower() == p.lower():
                return c
    return cand[0]

def is_binary_01_series(s: pd.Series) -> bool:
    if s.dtype == bool:
        return True
    if not np.issubdtype(s.dtype, np.number):
        return False
    vals = pd.unique(s.dropna())
    if len(vals) == 0:
        return False
    return set(vals).issubset({0, 1})

def infer_feature_cols_morgan(df: pd.DataFrame):
    """
    兼容两种常见 Morgan 保存方式：
    A) 列名是 morgan_0... / fp_ / bit_
    B) 列名是纯数字 0...2047（Excel 读入后可能变成 int）
    """
    morgan_cols = []
    for prefix in ["morgan_", "fp_", "ecfp_", "mfp_", "bit_"]:
        morgan_cols.extend([c for c in df.columns if isinstance(c, str) and c.startswith(prefix)])
    if morgan_cols:
        return list(morgan_cols)

    num_cols = []
    for c in df.columns:
        if isinstance(c, (int, np.integer)):
            num_cols.append(c)
        elif isinstance(c, str) and c.isdigit():
            num_cols.append(c)

    if num_cols:
        def keyf(x):
            try:
                return int(x)
            except Exception:
                return 10**18
        return sorted(num_cols, key=keyf)

    raise ValueError(
        "未找到 Morgan 特征列。\n"
        "请确保：Morgan 列名为 morgan_/fp_/bit_ 前缀，或列名为 0..2047 的纯数字。"
    )

def infer_label_cols(df: pd.DataFrame, smiles_col: str, feature_cols: list):
    exclude = set(feature_cols)
    if smiles_col is not None:
        exclude.add(smiles_col)

    label_cols = []
    for c in df.columns:
        if c in exclude:
            continue
        if is_binary_01_series(df[c]):
            label_cols.append(c)

    if not label_cols:
        raise ValueError("未识别到标签列（0/1）。请确认文件中仍包含 138 个标签列。")
    return label_cols

def load_Xy_from_transformed_morgan(xlsx_path: str):
    df = pd.read_excel(xlsx_path)

    smiles_col = find_smiles_col(df)
    feature_cols = infer_feature_cols_morgan(df)
    label_cols = infer_label_cols(df, smiles_col, feature_cols)

    X = df[feature_cols].fillna(0).astype(np.float32).values
    y = df[label_cols].fillna(0).astype(int).values

    if X.shape[0] != y.shape[0]:
        raise ValueError("X 和 y 行数不一致，请检查文件。")

    return X, y, feature_cols, label_cols, df

# =========================
# 3) 指标（macro）
# =========================
def multilabel_macro_metrics(y_true, y_prob, thresh=0.5):
    y_true = np.asarray(y_true).astype(int)
    y_prob = np.asarray(y_prob).astype(float)
    y_pred = (y_prob >= thresh).astype(int)

    L = y_true.shape[1]
    accs, precs, recs, specs = [], [], [], []
    aurocs, auprcs = [], []

    for k in range(L):
        yt = y_true[:, k]
        yp = y_pred[:, k]
        ys = y_prob[:, k]

        tp = int(np.sum((yt == 1) & (yp == 1)))
        tn = int(np.sum((yt == 0) & (yp == 0)))
        fp = int(np.sum((yt == 0) & (yp == 1)))
        fn = int(np.sum((yt == 1) & (yp == 0)))
        n = len(yt)

        accs.append((tp + tn) / n if n else np.nan)
        precs.append(tp / (tp + fp) if (tp + fp) else np.nan)
        recs.append(tp / (tp + fn) if (tp + fn) else np.nan)
        specs.append(tn / (tn + fp) if (tn + fp) else np.nan)

        if len(np.unique(yt)) == 2:
            aurocs.append(roc_auc_score(yt, ys))
            auprcs.append(average_precision_score(yt, ys))
        else:
            aurocs.append(np.nan)
            auprcs.append(np.nan)

    def nanmean(x):
        return float(np.nanmean(np.asarray(x, dtype=float)))

    return {
        "Accuracy_macro": nanmean(accs),
        "Precision_macro": nanmean(precs),
        "Recall_macro": nanmean(recs),
        "Specificity_macro": nanmean(specs),
        "AUROC_macro": nanmean(aurocs),
        "AUPRC_macro": nanmean(auprcs),
        "AUROC_valid_labels": int(np.sum(~np.isnan(aurocs))),
        "AUPRC_valid_labels": int(np.sum(~np.isnan(auprcs))),
        "n_labels": int(L),
    }

def extract_positive_proba(p, n_labels: int):
    # MultiOutputClassifier.predict_proba -> list，长度=labels，每个是 (n,2)
    if isinstance(p, list):
        return np.vstack([pi[:, 1] for pi in p]).T.astype(np.float32)

    p = np.asarray(p)
    if p.ndim == 3 and p.shape[-1] == 2:
        return p[:, :, 1].astype(np.float32)
    if p.ndim == 2:
        if p.shape[1] == 2 and n_labels == 1:
            return p[:, 1:2].astype(np.float32)
        return p.astype(np.float32)
    raise ValueError(f"无法解析 predict_proba 输出形状: {p.shape}")

# =========================
# 4) 近似分层 5 折：用 label cardinality 分层
# =========================
def make_stratify_target(y: np.ndarray, n_bins: int = 10):
    card = y.sum(axis=1).astype(int)
    uniq = np.unique(card)
    if len(uniq) <= 15:
        return card
    r = pd.Series(card).rank(method="average").values
    bins = pd.qcut(r, q=min(n_bins, len(np.unique(r))), labels=False, duplicates="drop")
    return np.asarray(bins, dtype=int)

def build_folds(X, y, n_splits=5, seed=42):
    strat_y = make_stratify_target(y)
    skf = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=seed)
    return list(skf.split(X, strat_y))

# =========================
# 5) 5 折 CV 评估（LightGBM + MultiOutput）
# =========================
def cv_eval_one_paramset(X, y, folds, params, thresh=0.5):
    n_labels = y.shape[1]
    fold_metrics = []

    for fold_id, (tr_idx, va_idx) in enumerate(folds, start=1):
        X_tr, X_va = X[tr_idx], X[va_idx]
        y_tr, y_va = y[tr_idx], y[va_idx]

        base_est = lgb.LGBMClassifier(**params)
        # 每个标签一个 LGBM；n_jobs=1 避免“外层并行 + 内层线程”导致爆核
        clf = MultiOutputClassifier(base_est, n_jobs=1)

        clf.fit(X_tr, y_tr)

        p = clf.predict_proba(X_va)
        y_prob = extract_positive_proba(p, n_labels=n_labels)

        m = multilabel_macro_metrics(y_va, y_prob, thresh=thresh)
        fold_metrics.append(m)

    keys = list(fold_metrics[0].keys())
    mean_metrics = {}
    for k in keys:
        vals = [fm[k] for fm in fold_metrics]
        if isinstance(vals[0], float):
            mean_metrics[k] = float(np.nanmean(vals))
        else:
            mean_metrics[k] = vals[-1]
    return mean_metrics

# =========================
# 6) Optuna 超参空间（LightGBM）
# =========================
def build_trial_params(trial: optuna.Trial):
    params = dict(BASE_LGB_PARAMS)
    params.update({
        "n_estimators": trial.suggest_int("n_estimators", 300, 2000),
        "learning_rate": trial.suggest_float("learning_rate", 0.01, 0.2, log=True),

        "num_leaves": trial.suggest_int("num_leaves", 31, 255),
        "max_depth": trial.suggest_int("max_depth", -1, 20),  # -1 表示不限制
        "min_child_samples": trial.suggest_int("min_child_samples", 5, 80),

        "subsample": trial.suggest_float("subsample", 0.6, 1.0),
        "colsample_bytree": trial.suggest_float("colsample_bytree", 0.6, 1.0),

        "reg_lambda": trial.suggest_float("reg_lambda", 1e-3, 50.0, log=True),
        "reg_alpha": trial.suggest_float("reg_alpha", 1e-8, 10.0, log=True),

        "min_split_gain": trial.suggest_float("min_split_gain", 0.0, 5.0),  # 类似 gamma
    })
    return params

# =========================
# 7) 主流程：读Morgan特征 -> 固定folds -> Optuna(30) -> 输出+保存
# =========================
def main():
    feature_file = find_feature_file(FEATURE_FILE_GLOB)
    print("[INFO] Using transformed Morgan feature file:", feature_file)

    X, y, feat_cols, label_cols, df_all = load_Xy_from_transformed_morgan(feature_file)
    print(f"[INFO] X shape={X.shape} (features={len(feat_cols)}) | y shape={y.shape} (labels={len(label_cols)})")

    folds = build_folds(X, y, n_splits=N_SPLITS, seed=RANDOM_SEED)
    print(f"[INFO] Prepared fixed {N_SPLITS}-fold splits for all trials.")

    def objective(trial: optuna.Trial):
        params = build_trial_params(trial)
        mean_metrics = cv_eval_one_paramset(X, y, folds, params, thresh=THRESH)

        score = mean_metrics["AUPRC_macro"]  # PRAUC
        print(
            f"\n[TRIAL {trial.number:02d}] score(AUPRC_macro)={score:.6f} | "
            f"AUROC={mean_metrics['AUROC_macro']:.6f} | "
            f"Acc={mean_metrics['Accuracy_macro']:.6f} | "
            f"P={mean_metrics['Precision_macro']:.6f} | "
            f"R={mean_metrics['Recall_macro']:.6f} | "
            f"Spec={mean_metrics['Specificity_macro']:.6f}"
        )

        for k, v in mean_metrics.items():
            trial.set_user_attr(k, v)

        return score

    study = optuna.create_study(
        direction="maximize",
        sampler=optuna.samplers.TPESampler(seed=RANDOM_SEED),
    )
    study.optimize(objective, n_trials=N_TRIALS, show_progress_bar=True)

    print("\n================ BEST =================")
    print("Best trial:", study.best_trial.number)
    print("Best AUPRC_macro:", study.best_value)
    print("Best params:")
    print(json.dumps(study.best_params, indent=2, ensure_ascii=False))

    rows = []
    for t in study.trials:
        if t.value is None:
            continue
        row = {"trial": t.number, "AUPRC_macro": t.value, **t.params}
        row.update({k: v for k, v in t.user_attrs.items() if k.endswith("_macro")})
        rows.append(row)

    res_df = pd.DataFrame(rows).sort_values("AUPRC_macro", ascending=False)
    out_csv = "./optuna_singlemodel_LIGHTGBM_30trials_5fold_results.csv"
    res_df.to_csv(out_csv, index=False, encoding="utf-8-sig")
    print("[SAVED]", out_csv)

if __name__ == "__main__":
    main()
# Out:
# [INFO] Using transformed Morgan feature file: ./Malodors_transformed_MORGAN_features.xlsx
# [I 2026-01-03 16:13:15,152] A new study created in memory with name: no-name-d6aaff5f-d010-42cd-b64a-ee68cc7e43c1
# [INFO] X shape=(5023, 2048) (features=2048) | y shape=(5023, 138) (labels=138)
# [INFO] Prepared fixed 5-fold splits for all trials.
#   0%|          | 0/30 [00:00<?, ?it/s]
# [TRIAL 00] score(AUPRC_macro)=0.209434 | AUROC=0.805336 | Acc=0.971264 | P=0.750099 | R=0.034539 | Spec=0.997422
# [I 2026-01-03 16:19:41,741] Trial 0 finished with value: 0.2094338447325812 and parameters: {'n_estimators': 937, 'learning_rate': 0.17254716573280354, 'num_leaves': 195, 'max_depth': 12, 'min_child_samples': 16, 'subsample': 0.662397808134481, 'colsample_bytree': 0.6232334448672797, 'reg_lambda': 11.752647960576219, 'reg_alpha': 0.002570603566117598, 'min_split_gain': 3.540362888980227}. Best is trial 0 with value: 0.2094338447325812.
#
# [TRIAL 01] score(AUPRC_macro)=0.282328 | AUROC=0.842020 | Acc=0.972417 | P=0.611812 | R=0.108021 | Spec=0.995834
# [I 2026-01-03 16:21:40,983] Trial 1 finished with value: 0.28232794906544095 and parameters: {'n_estimators': 335, 'learning_rate': 0.18276027831785724, 'num_leaves': 218, 'max_depth': 3, 'min_child_samples': 18, 'subsample': 0.6733618039413735, 'colsample_bytree': 0.7216968971838151, 'reg_lambda': 0.2922905212920093, 'reg_alpha': 7.71800699380605e-05, 'min_split_gain': 1.4561457009902097}. Best is trial 1 with value: 0.28232794906544095.
#
# [TRIAL 02] score(AUPRC_macro)=0.298052 | AUROC=0.848942 | Acc=0.972396 | P=0.526118 | R=0.142523 | Spec=0.994401
# [I 2026-01-03 16:27:51,623] Trial 2 finished with value: 0.2980515157535898 and parameters: {'n_estimators': 1340, 'learning_rate': 0.01518747922672247, 'num_leaves': 96, 'max_depth': 7, 'min_child_samples': 39, 'subsample': 0.9140703845572055, 'colsample_bytree': 0.6798695128633439, 'reg_lambda': 0.2608388046560993, 'reg_alpha': 0.0021465011216654484, 'min_split_gain': 0.23225206359998862}. Best is trial 2 with value: 0.2980515157535898.
#
# [TRIAL 03] score(AUPRC_macro)=0.262933 | AUROC=0.836052 | Acc=0.971628 | P=0.692584 | R=0.055146 | Spec=0.997008
# [I 2026-01-03 16:30:14,365] Trial 3 finished with value: 0.2629332062130205 and parameters: {'n_estimators': 1333, 'learning_rate': 0.016666983286066417, 'num_leaves': 45, 'max_depth': 19, 'min_child_samples': 78, 'subsample': 0.9233589392465844, 'colsample_bytree': 0.7218455076693483, 'reg_lambda': 0.002877122371623787, 'reg_alpha': 0.014391207615728067, 'min_split_gain': 2.2007624686980067}. Best is trial 2 with value: 0.2980515157535898.
#
# [TRIAL 04] score(AUPRC_macro)=0.298925 | AUROC=0.845458 | Acc=0.972717 | P=0.636122 | R=0.109213 | Spec=0.995691
# [I 2026-01-03 16:32:23,561] Trial 4 finished with value: 0.2989246330745864 and parameters: {'n_estimators': 507, 'learning_rate': 0.04407984038169244, 'num_leaves': 38, 'max_depth': 19, 'min_child_samples': 24, 'subsample': 0.8650089137415928, 'colsample_bytree': 0.7246844304357644, 'reg_lambda': 0.2778331300797557, 'reg_alpha': 0.0008325158565947976, 'min_split_gain': 0.9242722776276352}. Best is trial 4 with value: 0.2989246330745864.
#
# [TRIAL 05] score(AUPRC_macro)=0.281844 | AUROC=0.841727 | Acc=0.972317 | P=0.687527 | R=0.085776 | Spec=0.996493
# [I 2026-01-03 16:37:43,641] Trial 5 finished with value: 0.2818442050256768 and parameters: {'n_estimators': 1949, 'learning_rate': 0.10196967939171485, 'num_leaves': 242, 'max_depth': 18, 'min_child_samples': 50, 'subsample': 0.9687496940092467, 'colsample_bytree': 0.6353970008207678, 'reg_lambda': 0.008335230071817131, 'reg_alpha': 2.5529693461039728e-08, 'min_split_gain': 1.6266516538163218}. Best is trial 4 with value: 0.2989246330745864.
#
# [TRIAL 06] score(AUPRC_macro)=0.216206 | AUROC=0.805758 | Acc=0.971068 | P=0.736905 | R=0.029866 | Spec=0.997725
# [I 2026-01-03 16:41:15,475] Trial 6 finished with value: 0.21620610351039155 and parameters: {'n_estimators': 961, 'learning_rate': 0.022544116997360492, 'num_leaves': 217, 'max_depth': 6, 'min_child_samples': 26, 'subsample': 0.8170784332632994, 'colsample_bytree': 0.6563696899899051, 'reg_lambda': 5.881655048861897, 'reg_alpha': 4.6876566400928895e-08, 'min_split_gain': 4.9344346830025865}. Best is trial 4 with value: 0.2989246330745864.
#
# [TRIAL 07] score(AUPRC_macro)=0.290638 | AUROC=0.847603 | Acc=0.972440 | P=0.637335 | R=0.108508 | Spec=0.995744
# [I 2026-01-03 16:45:18,279] Trial 7 finished with value: 0.29063784683924904 and parameters: {'n_estimators': 1613, 'learning_rate': 0.018135730867783396, 'num_leaves': 32, 'max_depth': 16, 'min_child_samples': 58, 'subsample': 0.8916028672163949, 'colsample_bytree': 0.9085081386743783, 'reg_lambda': 0.0022280944532589255, 'reg_alpha': 1.683416412018213e-05, 'min_split_gain': 0.5793452976256486}. Best is trial 4 with value: 0.2989246330745864.
#
# [TRIAL 08] score(AUPRC_macro)=0.252750 | AUROC=0.824209 | Acc=0.971948 | P=0.746512 | R=0.056959 | Spec=0.997065
# [I 2026-01-03 16:49:14,443] Trial 8 finished with value: 0.25275019423787404 and parameters: {'n_estimators': 1768, 'learning_rate': 0.06470376604234768, 'num_leaves': 105, 'max_depth': 0, 'min_child_samples': 28, 'subsample': 0.7300733288106989, 'colsample_bytree': 0.8918424713352255, 'reg_lambda': 0.9905204218383901, 'reg_alpha': 0.9658611176861268, 'min_split_gain': 2.3610746258097466}. Best is trial 4 with value: 0.2989246330745864.
#
# [TRIAL 09] score(AUPRC_macro)=0.287215 | AUROC=0.847547 | Acc=0.972339 | P=0.623391 | R=0.107960 | Spec=0.995681
# [I 2026-01-03 16:50:56,826] Trial 9 finished with value: 0.287214714575172 and parameters: {'n_estimators': 503, 'learning_rate': 0.08471354625326555, 'num_leaves': 202, 'max_depth': 11, 'min_child_samples': 63, 'subsample': 0.7975182385457563, 'colsample_bytree': 0.8090931317527976, 'reg_lambda': 0.10209451747520762, 'reg_alpha': 1.6934490731313353e-08, 'min_split_gain': 0.5394571349665223}. Best is trial 4 with value: 0.2989246330745864.
#
# [TRIAL 10] score(AUPRC_macro)=0.213118 | AUROC=0.795953 | Acc=0.971224 | P=0.751661 | R=0.034197 | Spec=0.997677
# [I 2026-01-03 16:54:18,065] Trial 10 finished with value: 0.21311778304214163 and parameters: {'n_estimators': 653, 'learning_rate': 0.04128697297312279, 'num_leaves': 147, 'max_depth': 14, 'min_child_samples': 6, 'subsample': 0.8163775632702192, 'colsample_bytree': 0.983908298378168, 'reg_lambda': 0.03379534397108484, 'reg_alpha': 3.3316309468938505, 'min_split_gain': 3.6920277236251042}. Best is trial 4 with value: 0.2989246330745864.
#
# [TRIAL 11] score(AUPRC_macro)=0.297818 | AUROC=0.850994 | Acc=0.972417 | P=0.524492 | R=0.146018 | Spec=0.994620
# [I 2026-01-03 17:03:31,823] Trial 11 finished with value: 0.29781844305710653 and parameters: {'n_estimators': 1264, 'learning_rate': 0.010272842363526024, 'num_leaves': 88, 'max_depth': 7, 'min_child_samples': 38, 'subsample': 0.88180962139586, 'colsample_bytree': 0.7389917503278137, 'reg_lambda': 1.507231417469703, 'reg_alpha': 0.027019779735714396, 'min_split_gain': 0.03670622408491764}. Best is trial 4 with value: 0.2989246330745864.
#
# [TRIAL 12] score(AUPRC_macro)=0.220072 | AUROC=0.813471 | Acc=0.971508 | P=0.744239 | R=0.040444 | Spec=0.997105
# [I 2026-01-03 17:07:08,180] Trial 12 finished with value: 0.22007188715665663 and parameters: {'n_estimators': 1503, 'learning_rate': 0.0315300520298409, 'num_leaves': 84, 'max_depth': 8, 'min_child_samples': 39, 'subsample': 0.9914385491497694, 'colsample_bytree': 0.7925153971864091, 'reg_lambda': 47.89076853424982, 'reg_alpha': 3.0027540878413585e-06, 'min_split_gain': 0.9506756250895875}. Best is trial 4 with value: 0.2989246330745864.
#
# [TRIAL 13] score(AUPRC_macro)=0.295185 | AUROC=0.847475 | Acc=0.972319 | P=0.568849 | R=0.128102 | Spec=0.995872
# [I 2026-01-03 17:12:48,276] Trial 13 finished with value: 0.2951852662132431 and parameters: {'n_estimators': 993, 'learning_rate': 0.010444406415184166, 'num_leaves': 139, 'max_depth': 4, 'min_child_samples': 32, 'subsample': 0.8578694741072342, 'colsample_bytree': 0.6782204589759935, 'reg_lambda': 0.05083762407403203, 'reg_alpha': 0.0028198498393717567, 'min_split_gain': 0.01751880554040286}. Best is trial 4 with value: 0.2989246330745864.
#
# [TRIAL 14] score(AUPRC_macro)=0.283604 | AUROC=0.843782 | Acc=0.972324 | P=0.687714 | R=0.084062 | Spec=0.996385
# [I 2026-01-03 17:14:52,366] Trial 14 finished with value: 0.28360394361641267 and parameters: {'n_estimators': 726, 'learning_rate': 0.049091725244760645, 'num_leaves': 61, 'max_depth': 10, 'min_child_samples': 50, 'subsample': 0.9383133750822349, 'colsample_bytree': 0.7901530268661332, 'reg_lambda': 0.43069286056305955, 'reg_alpha': 0.0004236629819025505, 'min_split_gain': 1.271403048985379}. Best is trial 4 with value: 0.2989246330745864.
#
# [TRIAL 15] score(AUPRC_macro)=0.281502 | AUROC=0.832894 | Acc=0.972446 | P=0.727739 | R=0.079085 | Spec=0.996951
# [I 2026-01-03 17:26:50,828] Trial 15 finished with value: 0.28150157959055216 and parameters: {'n_estimators': 1147, 'learning_rate': 0.026942848563453147, 'num_leaves': 127, 'max_depth': 20, 'min_child_samples': 5, 'subsample': 0.7471642719061846, 'colsample_bytree': 0.6006549219376077, 'reg_lambda': 0.01622242063515459, 'reg_alpha': 0.07476985772132953, 'min_split_gain': 3.1191680193668962}. Best is trial 4 with value: 0.2989246330745864.
#
# [TRIAL 16] score(AUPRC_macro)=0.289998 | AUROC=0.839505 | Acc=0.972486 | P=0.688637 | R=0.086735 | Spec=0.996461
# [I 2026-01-03 17:28:43,149] Trial 16 finished with value: 0.28999836019765557 and parameters: {'n_estimators': 301, 'learning_rate': 0.03967237750605707, 'num_leaves': 64, 'max_depth': -1, 'min_child_samples': 18, 'subsample': 0.609478164602333, 'colsample_bytree': 0.6852224778895979, 'reg_lambda': 0.1438364744608722, 'reg_alpha': 1.0845062115979571e-06, 'min_split_gain': 1.974087544936252}. Best is trial 4 with value: 0.2989246330745864.
#
# [TRIAL 17] score(AUPRC_macro)=0.282726 | AUROC=0.843073 | Acc=0.972399 | P=0.700421 | R=0.080992 | Spec=0.996276
# [I 2026-01-03 17:31:26,343] Trial 17 finished with value: 0.282725848779307 and parameters: {'n_estimators': 736, 'learning_rate': 0.014987251349884136, 'num_leaves': 166, 'max_depth': 13, 'min_child_samples': 47, 'subsample': 0.9153884787798737, 'colsample_bytree': 0.8416634198004798, 'reg_lambda': 2.5358207357631524, 'reg_alpha': 0.30170776649870923, 'min_split_gain': 0.7035424264598704}. Best is trial 4 with value: 0.2989246330745864.
#
# [TRIAL 18] score(AUPRC_macro)=0.258246 | AUROC=0.831436 | Acc=0.971778 | P=0.724534 | R=0.058329 | Spec=0.997010
# [I 2026-01-03 17:33:45,845] Trial 18 finished with value: 0.2582461932137617 and parameters: {'n_estimators': 1448, 'learning_rate': 0.10903567711615332, 'num_leaves': 110, 'max_depth': 16, 'min_child_samples': 62, 'subsample': 0.8544624028080892, 'colsample_bytree': 0.7546609557466136, 'reg_lambda': 0.5373804046176045, 'reg_alpha': 0.00039957667456266854, 'min_split_gain': 2.7171428616208355}. Best is trial 4 with value: 0.2989246330745864.
#
# [TRIAL 19] score(AUPRC_macro)=0.291069 | AUROC=0.847615 | Acc=0.972398 | P=0.633741 | R=0.101971 | Spec=0.995988
# [I 2026-01-03 17:36:33,108] Trial 19 finished with value: 0.2910690822930523 and parameters: {'n_estimators': 1158, 'learning_rate': 0.050124499073911845, 'num_leaves': 64, 'max_depth': 3, 'min_child_samples': 34, 'subsample': 0.7750887431972865, 'colsample_bytree': 0.6991295320977609, 'reg_lambda': 0.10787604280683159, 'reg_alpha': 2.1578855507902905e-05, 'min_split_gain': 0.9751182906733957}. Best is trial 4 with value: 0.2989246330745864.
#
# [TRIAL 20] score(AUPRC_macro)=0.298459 | AUROC=0.849990 | Acc=0.972671 | P=0.624390 | R=0.108041 | Spec=0.995257
# [I 2026-01-03 17:40:49,020] Trial 20 finished with value: 0.2984587511845424 and parameters: {'n_estimators': 1627, 'learning_rate': 0.06771593175292405, 'num_leaves': 85, 'max_depth': 9, 'min_child_samples': 23, 'subsample': 0.9641951514768756, 'colsample_bytree': 0.76320346282282, 'reg_lambda': 3.774401339460368, 'reg_alpha': 0.002732044889740839, 'min_split_gain': 0.36740870491421207}. Best is trial 4 with value: 0.2989246330745864.
#
# [TRIAL 21] score(AUPRC_macro)=0.294098 | AUROC=0.849577 | Acc=0.972669 | P=0.660120 | R=0.102428 | Spec=0.995388
# [I 2026-01-03 17:45:39,989] Trial 21 finished with value: 0.29409803823159886 and parameters: {'n_estimators': 1781, 'learning_rate': 0.06973198368518387, 'num_leaves': 84, 'max_depth': 8, 'min_child_samples': 23, 'subsample': 0.9674665938181195, 'colsample_bytree': 0.7643926412734383, 'reg_lambda': 10.37473599513754, 'reg_alpha': 0.004680250864060313, 'min_split_gain': 0.2447949671614199}. Best is trial 4 with value: 0.2989246330745864.
#
# [TRIAL 22] score(AUPRC_macro)=0.210487 | AUROC=0.809728 | Acc=0.971395 | P=0.737856 | R=0.037621 | Spec=0.997201
# [I 2026-01-03 17:50:20,690] Trial 22 finished with value: 0.21048724472339803 and parameters: {'n_estimators': 1624, 'learning_rate': 0.13410737297462638, 'num_leaves': 107, 'max_depth': 5, 'min_child_samples': 13, 'subsample': 0.9478852826905244, 'colsample_bytree': 0.8198626169348787, 'reg_lambda': 49.68371142684821, 'reg_alpha': 0.000285536170412002, 'min_split_gain': 1.1224884340878218}. Best is trial 4 with value: 0.2989246330745864.
#
# [TRIAL 23] score(AUPRC_macro)=0.294382 | AUROC=0.847390 | Acc=0.972637 | P=0.650403 | R=0.099942 | Spec=0.995611
# [I 2026-01-03 17:53:59,717] Trial 23 finished with value: 0.29438188834994017 and parameters: {'n_estimators': 1370, 'learning_rate': 0.06848720506512604, 'num_leaves': 45, 'max_depth': 8, 'min_child_samples': 26, 'subsample': 0.9995601290304088, 'colsample_bytree': 0.8625354373632149, 'reg_lambda': 2.794137651221629, 'reg_alpha': 0.13544165422428853, 'min_split_gain': 0.47791416165623934}. Best is trial 4 with value: 0.2989246330745864.
#
# [TRIAL 24] score(AUPRC_macro)=0.283737 | AUROC=0.841913 | Acc=0.972278 | P=0.703278 | R=0.077393 | Spec=0.996484
# [I 2026-01-03 17:58:07,105] Trial 24 finished with value: 0.2837372430270095 and parameters: {'n_estimators': 1996, 'learning_rate': 0.03338370654460342, 'num_leaves': 82, 'max_depth': 15, 'min_child_samples': 42, 'subsample': 0.8851077253776742, 'colsample_bytree': 0.7632492907781473, 'reg_lambda': 0.7682468490388812, 'reg_alpha': 0.0013036516891994472, 'min_split_gain': 1.4911441233197196}. Best is trial 4 with value: 0.2989246330745864.
#
# [TRIAL 25] score(AUPRC_macro)=0.281547 | AUROC=0.839395 | Acc=0.972334 | P=0.718997 | R=0.078406 | Spec=0.996646
# [I 2026-01-03 18:01:19,080] Trial 25 finished with value: 0.2815468448754391 and parameters: {'n_estimators': 1202, 'learning_rate': 0.05632138544073541, 'num_leaves': 34, 'max_depth': 10, 'min_child_samples': 32, 'subsample': 0.8417130174182256, 'colsample_bytree': 0.7042135804372701, 'reg_lambda': 0.25949567612982627, 'reg_alpha': 0.00923691419458277, 'min_split_gain': 1.934389432015264}. Best is trial 4 with value: 0.2989246330745864.
#
# [TRIAL 26] score(AUPRC_macro)=0.285686 | AUROC=0.843225 | Acc=0.972218 | P=0.534471 | R=0.116563 | Spec=0.995762
# [I 2026-01-03 18:08:12,988] Trial 26 finished with value: 0.28568559630232715 and parameters: {'n_estimators': 1609, 'learning_rate': 0.021037376357848223, 'num_leaves': 60, 'max_depth': 2, 'min_child_samples': 11, 'subsample': 0.911886120600996, 'colsample_bytree': 0.666885772747332, 'reg_lambda': 0.05523783120182743, 'reg_alpha': 6.913763076049864e-05, 'min_split_gain': 0.8280284503286858}. Best is trial 4 with value: 0.2989246330745864.
#
# [TRIAL 27] score(AUPRC_macro)=0.297673 | AUROC=0.850228 | Acc=0.972695 | P=0.635015 | R=0.108491 | Spec=0.995261
# [I 2026-01-03 18:12:20,078] Trial 27 finished with value: 0.2976730142830514 and parameters: {'n_estimators': 1802, 'learning_rate': 0.09041611196792894, 'num_leaves': 127, 'max_depth': 12, 'min_child_samples': 23, 'subsample': 0.9648678157786647, 'colsample_bytree': 0.7342885040178554, 'reg_lambda': 4.6307262464510925, 'reg_alpha': 0.044945518040990874, 'min_split_gain': 0.3308146046691094}. Best is trial 4 with value: 0.2989246330745864.
#
# [TRIAL 28] score(AUPRC_macro)=0.249466 | AUROC=0.824914 | Acc=0.971617 | P=0.703042 | R=0.061069 | Spec=0.997038
# [I 2026-01-03 18:15:18,666] Trial 28 finished with value: 0.2494663150295851 and parameters: {'n_estimators': 1065, 'learning_rate': 0.13093051319481808, 'num_leaves': 164, 'max_depth': 6, 'min_child_samples': 45, 'subsample': 0.8898552839349908, 'colsample_bytree': 0.649243736700827, 'reg_lambda': 0.01217722923076294, 'reg_alpha': 0.0008382770322142795, 'min_split_gain': 4.274628776972462}. Best is trial 4 with value: 0.2989246330745864.
#
# [TRIAL 29] score(AUPRC_macro)=0.283844 | AUROC=0.846031 | Acc=0.972521 | P=0.697923 | R=0.081685 | Spec=0.996043
# [I 2026-01-03 18:25:30,344] Trial 29 finished with value: 0.2838438835609327 and parameters: {'n_estimators': 860, 'learning_rate': 0.01345789251302373, 'num_leaves': 96, 'max_depth': 12, 'min_child_samples': 20, 'subsample': 0.9375294674881187, 'colsample_bytree': 0.6005721148950148, 'reg_lambda': 22.77117075536535, 'reg_alpha': 1.4331820360727482e-06, 'min_split_gain': 0.2408116739422908}. Best is trial 4 with value: 0.2989246330745864.
#
# ================ BEST =================
# Best trial: 4
# Best AUPRC_macro: 0.2989246330745864
# Best params:
# {
#   "n_estimators": 507,
#   "learning_rate": 0.04407984038169244,
#   "num_leaves": 38,
#   "max_depth": 19,
#   "min_child_samples": 24,
#   "subsample": 0.8650089137415928,
#   "colsample_bytree": 0.7246844304357644,
#   "reg_lambda": 0.2778331300797557,
#   "reg_alpha": 0.0008325158565947976,
#   "min_split_gain": 0.9242722776276352
# }
# [SAVED] ./optuna_singlemodel_LIGHTGBM_30trials_5fold_results.csv

# %%
# -*- coding: utf-8 -*-
import os
import re
import glob
import json
import warnings
import numpy as np
import pandas as pd

import optuna
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import roc_auc_score, average_precision_score
from sklearn.ensemble import RandomForestClassifier

# =========================
# 0) 配置 & 尽量屏蔽警告
# =========================
RANDOM_SEED = 42
N_TRIALS = 30
N_SPLITS = 5
THRESH = 0.5

os.environ["PYTHONWARNINGS"] = "ignore"
warnings.filterwarnings("ignore", category=UserWarning)
warnings.filterwarnings("ignore", category=FutureWarning)
warnings.filterwarnings("ignore", category=RuntimeWarning)

# 直接读取你已生成的 Morgan 特征文件（xlsx）
FEATURE_FILE_GLOB = "./Malodors_transformed_MORGAN_features*.xlsx"

# RandomForest 固定参数（Optuna 只搜索部分超参）
BASE_RF_PARAMS = dict(
    n_jobs=-1,
    random_state=RANDOM_SEED,
)

# =========================
# 1) 读取 transformed Morgan 特征文件 & 自动识别列
# =========================
def find_feature_file(pattern: str):
    cands = sorted(glob.glob(pattern))
    if not cands:
        raise FileNotFoundError(
            f"找不到 Morgan 特征文件：{pattern}\n"
            f"请确认你保存的 xlsx 文件名，或修改 FEATURE_FILE_GLOB。"
        )
    return cands[-1]

def find_smiles_col(df: pd.DataFrame):
    cand = [c for c in df.columns if isinstance(c, str) and "smiles" in c.lower()]
    if not cand:
        return None
    for p in ["Canonical SMILES", "canonical_smiles", "SMILES", "smiles"]:
        for c in cand:
            if c.lower() == p.lower():
                return c
    return cand[0]

def is_binary_01_series(s: pd.Series) -> bool:
    if s.dtype == bool:
        return True
    if not np.issubdtype(s.dtype, np.number):
        return False
    vals = pd.unique(s.dropna())
    if len(vals) == 0:
        return False
    return set(vals).issubset({0, 1})

def infer_feature_cols_morgan(df: pd.DataFrame):
    """
    兼容两种常见 Morgan 保存方式：
    A) 列名是 morgan_0...morgan_2047 / fp_ / bit_
    B) 列名是纯数字 0...2047（Excel 读入后可能变成 int）
    """
    # A) 前缀形式
    morgan_cols = []
    for prefix in ["morgan_", "fp_", "ecfp_", "mfp_", "bit_"]:
        morgan_cols.extend([c for c in df.columns if isinstance(c, str) and c.startswith(prefix)])
    if morgan_cols:
        return list(morgan_cols)

    # B) 纯数字列
    num_cols = []
    for c in df.columns:
        if isinstance(c, (int, np.integer)):
            num_cols.append(c)
        elif isinstance(c, str) and c.isdigit():
            num_cols.append(c)

    if num_cols:
        def keyf(x):
            try:
                return int(x)
            except Exception:
                return 10**18
        return sorted(num_cols, key=keyf)

    raise ValueError(
        "未找到 Morgan 特征列。\n"
        "请确保：Morgan 列名为 morgan_/fp_/bit_ 前缀，或列名为 0..2047 的纯数字。"
    )

def infer_label_cols(df: pd.DataFrame, smiles_col: str, feature_cols: list):
    exclude = set(feature_cols)
    if smiles_col is not None:
        exclude.add(smiles_col)

    label_cols = []
    for c in df.columns:
        if c in exclude:
            continue
        if is_binary_01_series(df[c]):
            label_cols.append(c)

    if not label_cols:
        raise ValueError("未识别到标签列（0/1）。请确认文件中仍包含 138 个标签列。")
    return label_cols

def load_Xy_from_transformed_morgan(xlsx_path: str):
    df = pd.read_excel(xlsx_path)

    smiles_col = find_smiles_col(df)
    feature_cols = infer_feature_cols_morgan(df)
    label_cols = infer_label_cols(df, smiles_col, feature_cols)

    X = df[feature_cols].fillna(0).astype(np.float32).values
    y = df[label_cols].fillna(0).astype(int).values

    if X.shape[0] != y.shape[0]:
        raise ValueError("X 和 y 行数不一致，请检查文件。")

    return X, y, feature_cols, label_cols, df

# =========================
# 2) 指标（macro）
# =========================
def multilabel_macro_metrics(y_true, y_prob, thresh=0.5):
    y_true = np.asarray(y_true).astype(int)
    y_prob = np.asarray(y_prob).astype(float)
    y_pred = (y_prob >= thresh).astype(int)

    L = y_true.shape[1]
    accs, precs, recs, specs = [], [], [], []
    aurocs, auprcs = [], []

    for k in range(L):
        yt = y_true[:, k]
        yp = y_pred[:, k]
        ys = y_prob[:, k]

        tp = int(np.sum((yt == 1) & (yp == 1)))
        tn = int(np.sum((yt == 0) & (yp == 0)))
        fp = int(np.sum((yt == 0) & (yp == 1)))
        fn = int(np.sum((yt == 1) & (yp == 0)))
        n = len(yt)

        accs.append((tp + tn) / n if n else np.nan)
        precs.append(tp / (tp + fp) if (tp + fp) else np.nan)
        recs.append(tp / (tp + fn) if (tp + fn) else np.nan)
        specs.append(tn / (tn + fp) if (tn + fp) else np.nan)

        if len(np.unique(yt)) == 2:
            aurocs.append(roc_auc_score(yt, ys))
            auprcs.append(average_precision_score(yt, ys))
        else:
            aurocs.append(np.nan)
            auprcs.append(np.nan)

    def nanmean(x):
        return float(np.nanmean(np.asarray(x, dtype=float)))

    return {
        "Accuracy_macro": nanmean(accs),
        "Precision_macro": nanmean(precs),
        "Recall_macro": nanmean(recs),
        "Specificity_macro": nanmean(specs),
        "AUROC_macro": nanmean(aurocs),
        "AUPRC_macro": nanmean(auprcs),
        "AUROC_valid_labels": int(np.sum(~np.isnan(aurocs))),
        "AUPRC_valid_labels": int(np.sum(~np.isnan(auprcs))),
        "n_labels": int(L),
    }

def extract_positive_proba(p, n_labels: int, classes_list=None):
    """
    兼容：
    - multi-output RF 的 predict_proba: list，长度=labels，每个 (n, n_classes_k)
    - 处理某标签在该 fold 训练集里只有单类 => (n,1)
    """
    if isinstance(p, list):
        out = np.zeros((p[0].shape[0], n_labels), dtype=np.float32)
        for k in range(n_labels):
            pk = p[k]
            if pk.ndim != 2:
                raise ValueError(f"predict_proba[{k}] 形状异常: {pk.shape}")

            if pk.shape[1] == 2:
                # 取 class==1 的那一列更稳（避免 classes_ 顺序不是 [0,1]）
                if classes_list is not None and len(classes_list) == n_labels:
                    cls = list(classes_list[k])
                    if 1 in cls:
                        j = cls.index(1)
                        out[:, k] = pk[:, j].astype(np.float32)
                    else:
                        out[:, k] = 0.0
                else:
                    out[:, k] = pk[:, 1].astype(np.float32)

            elif pk.shape[1] == 1:
                # 只有单一类别：若该类别是 1 => 概率恒为1；若是 0 => 概率恒为0
                if classes_list is not None and len(classes_list) == n_labels:
                    only_cls = int(list(classes_list[k])[0])
                    out[:, k] = 1.0 if only_cls == 1 else 0.0
                else:
                    # 兜底：默认认为是 class 0
                    out[:, k] = 0.0
            else:
                raise ValueError(f"predict_proba[{k}] 类别数异常: {pk.shape[1]}")
        return out

    # 非 list 情况（一般不会出现在 multi-output RF）
    p = np.asarray(p)
    if p.ndim == 3 and p.shape[-1] == 2:
        return p[:, :, 1].astype(np.float32)
    if p.ndim == 2:
        if p.shape[1] == 2 and n_labels == 1:
            return p[:, 1:2].astype(np.float32)
        return p.astype(np.float32)
    raise ValueError(f"无法解析 predict_proba 输出形状: {p.shape}")

# =========================
# 3) 近似分层 5 折：用 label cardinality 分层
# =========================
def make_stratify_target(y: np.ndarray, n_bins: int = 10):
    card = y.sum(axis=1).astype(int)
    uniq = np.unique(card)
    if len(uniq) <= 15:
        return card
    r = pd.Series(card).rank(method="average").values
    bins = pd.qcut(r, q=min(n_bins, len(np.unique(r))), labels=False, duplicates="drop")
    return np.asarray(bins, dtype=int)

def build_folds(X, y, n_splits=5, seed=42):
    strat_y = make_stratify_target(y)
    skf = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=seed)
    return list(skf.split(X, strat_y))

# =========================
# 4) 5 折 CV 评估（RF）
# =========================
def cv_eval_one_paramset(X, y, folds, params, thresh=0.5):
    n_labels = y.shape[1]
    fold_metrics = []

    for fold_id, (tr_idx, va_idx) in enumerate(folds, start=1):
        X_tr, X_va = X[tr_idx], X[va_idx]
        y_tr, y_va = y[tr_idx], y[va_idx]

        clf = RandomForestClassifier(**params)
        clf.fit(X_tr, y_tr)

        p = clf.predict_proba(X_va)  # list(length=L)
        y_prob = extract_positive_proba(p, n_labels=n_labels, classes_list=getattr(clf, "classes_", None))

        m = multilabel_macro_metrics(y_va, y_prob, thresh=thresh)
        fold_metrics.append(m)

    keys = list(fold_metrics[0].keys())
    mean_metrics = {}
    for k in keys:
        vals = [fm[k] for fm in fold_metrics]
        if isinstance(vals[0], float):
            mean_metrics[k] = float(np.nanmean(vals))
        else:
            mean_metrics[k] = vals[-1]
    return mean_metrics

# =========================
# 5) Optuna 超参空间（RF）
# =========================
def build_trial_params(trial: optuna.Trial):
    params = dict(BASE_RF_PARAMS)

    max_depth_raw = trial.suggest_int("max_depth", 0, 40)  # 0 表示 None
    max_depth = None if max_depth_raw == 0 else max_depth_raw

    params.update({
        "n_estimators": trial.suggest_int("n_estimators", 300, 1500),
        "max_depth": max_depth,
        "max_features": trial.suggest_categorical("max_features", ["sqrt", "log2", 0.3, 0.5, 0.8, 1.0]),
        "min_samples_split": trial.suggest_int("min_samples_split", 2, 20),
        "min_samples_leaf": trial.suggest_int("min_samples_leaf", 1, 10),
        "bootstrap": trial.suggest_categorical("bootstrap", [True, False]),
        "criterion": trial.suggest_categorical("criterion", ["gini", "entropy", "log_loss"]),
    })
    return params

# =========================
# 6) 主流程：读Morgan特征 -> 固定folds -> Optuna(30) -> 输出+保存
# =========================
def main():
    feature_file = find_feature_file(FEATURE_FILE_GLOB)
    print("[INFO] Using transformed Morgan feature file:", feature_file)

    X, y, feat_cols, label_cols, df_all = load_Xy_from_transformed_morgan(feature_file)
    print(f"[INFO] X shape={X.shape} (features={len(feat_cols)}) | y shape={y.shape} (labels={len(label_cols)})")

    folds = build_folds(X, y, n_splits=N_SPLITS, seed=RANDOM_SEED)
    print(f"[INFO] Prepared fixed {N_SPLITS}-fold splits for all trials.")

    def objective(trial: optuna.Trial):
        params = build_trial_params(trial)
        mean_metrics = cv_eval_one_paramset(X, y, folds, params, thresh=THRESH)

        score = mean_metrics["AUPRC_macro"]  # PRAUC
        print(
            f"\n[TRIAL {trial.number:02d}] score(AUPRC_macro)={score:.6f} | "
            f"AUROC={mean_metrics['AUROC_macro']:.6f} | "
            f"Acc={mean_metrics['Accuracy_macro']:.6f} | "
            f"P={mean_metrics['Precision_macro']:.6f} | "
            f"R={mean_metrics['Recall_macro']:.6f} | "
            f"Spec={mean_metrics['Specificity_macro']:.6f}"
        )

        for k, v in mean_metrics.items():
            trial.set_user_attr(k, v)

        return score

    study = optuna.create_study(
        direction="maximize",
        sampler=optuna.samplers.TPESampler(seed=RANDOM_SEED),
    )
    study.optimize(objective, n_trials=N_TRIALS, show_progress_bar=True)

    print("\n================ BEST =================")
    print("Best trial:", study.best_trial.number)
    print("Best AUPRC_macro:", study.best_value)
    print("Best params:")
    print(json.dumps(study.best_params, indent=2, ensure_ascii=False))

    rows = []
    for t in study.trials:
        if t.value is None:
            continue
        row = {"trial": t.number, "AUPRC_macro": t.value, **t.params}
        row.update({k: v for k, v in t.user_attrs.items() if k.endswith("_macro")})
        rows.append(row)

    res_df = pd.DataFrame(rows).sort_values("AUPRC_macro", ascending=False)
    out_csv = "./optuna_singlemodel_RF_30trials_5fold_results.csv"
    res_df.to_csv(out_csv, index=False, encoding="utf-8-sig")
    print("[SAVED]", out_csv)

if __name__ == "__main__":
    main()
# Out:
# [INFO] Using transformed Morgan feature file: ./Malodors_transformed_MORGAN_features.xlsx
# [I 2026-01-03 18:40:00,583] A new study created in memory with name: no-name-327cc882-7a78-4d55-9d18-839cbaa955ba
# [INFO] X shape=(5023, 2048) (features=2048) | y shape=(5023, 138) (labels=138)
# [INFO] Prepared fixed 5-fold splits for all trials.
#   0%|          | 0/30 [00:00<?, ?it/s]
# [TRIAL 00] score(AUPRC_macro)=0.190562 | AUROC=0.741706 | Acc=0.970034 | P=0.479547 | R=0.102519 | Spec=0.993047
# [I 2026-01-03 18:46:54,063] Trial 0 finished with value: 0.1905621001241606 and parameters: {'max_depth': 15, 'n_estimators': 1441, 'max_features': 1.0, 'min_samples_split': 13, 'min_samples_leaf': 8, 'bootstrap': False, 'criterion': 'gini'}. Best is trial 0 with value: 0.1905621001241606.
#
# [TRIAL 01] score(AUPRC_macro)=0.256340 | AUROC=0.845928 | Acc=0.970613 | P=0.739051 | R=0.028970 | Spec=0.998251
# [I 2026-01-03 18:48:34,554] Trial 1 finished with value: 0.2563401834650317 and parameters: {'max_depth': 7, 'n_estimators': 665, 'max_features': 0.5, 'min_samples_split': 8, 'min_samples_leaf': 5, 'bootstrap': True, 'criterion': 'entropy'}. Best is trial 1 with value: 0.2563401834650317.
#
# [TRIAL 02] score(AUPRC_macro)=0.285020 | AUROC=0.848870 | Acc=0.972148 | P=0.706575 | R=0.071628 | Spec=0.996761
# [I 2026-01-03 18:49:55,653] Trial 2 finished with value: 0.2850195683506137 and parameters: {'max_depth': 24, 'n_estimators': 504, 'max_features': 0.3, 'min_samples_split': 15, 'min_samples_leaf': 5, 'bootstrap': False, 'criterion': 'entropy'}. Best is trial 2 with value: 0.2850195683506137.
#
# [TRIAL 03] score(AUPRC_macro)=0.278156 | AUROC=0.851469 | Acc=0.971672 | P=0.730160 | R=0.051864 | Spec=0.997351
# [I 2026-01-03 18:51:31,579] Trial 3 finished with value: 0.2781556085255117 and parameters: {'max_depth': 27, 'n_estimators': 674, 'max_features': 0.5, 'min_samples_split': 19, 'min_samples_leaf': 6, 'bootstrap': True, 'criterion': 'log_loss'}. Best is trial 2 with value: 0.2850195683506137.
#
# [TRIAL 04] score(AUPRC_macro)=0.268084 | AUROC=0.853359 | Acc=0.969426 | P=0.868372 | R=0.008539 | Spec=0.999152
# [I 2026-01-03 18:52:43,226] Trial 4 finished with value: 0.2680841293202073 and parameters: {'max_depth': 15, 'n_estimators': 625, 'max_features': 'sqrt', 'min_samples_split': 3, 'min_samples_leaf': 10, 'bootstrap': True, 'criterion': 'entropy'}. Best is trial 2 with value: 0.2850195683506137.
#
# [TRIAL 05] score(AUPRC_macro)=0.278827 | AUROC=0.838624 | Acc=0.972179 | P=0.602949 | R=0.099963 | Spec=0.995417
# [I 2026-01-03 18:56:40,848] Trial 5 finished with value: 0.2788274576774197 and parameters: {'max_depth': 29, 'n_estimators': 1226, 'max_features': 0.5, 'min_samples_split': 3, 'min_samples_leaf': 4, 'bootstrap': False, 'criterion': 'entropy'}. Best is trial 2 with value: 0.2850195683506137.
#
# [TRIAL 06] score(AUPRC_macro)=0.199571 | AUROC=0.817428 | Acc=0.969265 | P=0.764574 | R=0.008311 | Spec=0.999129
# [I 2026-01-03 18:59:15,974] Trial 6 finished with value: 0.1995705507466363 and parameters: {'max_depth': 4, 'n_estimators': 1156, 'max_features': 0.3, 'min_samples_split': 2, 'min_samples_leaf': 2, 'bootstrap': False, 'criterion': 'log_loss'}. Best is trial 2 with value: 0.2850195683506137.
#
# [TRIAL 07] score(AUPRC_macro)=0.269248 | AUROC=0.844701 | Acc=0.971512 | P=0.697029 | R=0.056204 | Spec=0.997161
# [I 2026-01-03 19:01:40,943] Trial 7 finished with value: 0.26924812520899194 and parameters: {'max_depth': 10, 'n_estimators': 792, 'max_features': 1.0, 'min_samples_split': 17, 'min_samples_leaf': 7, 'bootstrap': True, 'criterion': 'entropy'}. Best is trial 2 with value: 0.2850195683506137.
#
# [TRIAL 08] score(AUPRC_macro)=0.277635 | AUROC=0.844527 | Acc=0.971877 | P=0.672530 | R=0.069138 | Spec=0.996621
# [I 2026-01-03 19:05:56,188] Trial 8 finished with value: 0.2776350409043011 and parameters: {'max_depth': 33, 'n_estimators': 1376, 'max_features': 1.0, 'min_samples_split': 2, 'min_samples_leaf': 6, 'bootstrap': True, 'criterion': 'log_loss'}. Best is trial 2 with value: 0.2850195683506137.
#
# [TRIAL 09] score(AUPRC_macro)=0.274059 | AUROC=0.847430 | Acc=0.971983 | P=0.662830 | R=0.075359 | Spec=0.996870
# [I 2026-01-03 19:08:20,990] Trial 9 finished with value: 0.274059010499414 and parameters: {'max_depth': 13, 'n_estimators': 923, 'max_features': 0.3, 'min_samples_split': 7, 'min_samples_leaf': 3, 'bootstrap': False, 'criterion': 'gini'}. Best is trial 2 with value: 0.2850195683506137.
#
# [TRIAL 10] score(AUPRC_macro)=0.264438 | AUROC=0.825921 | Acc=0.971662 | P=0.538767 | R=0.103453 | Spec=0.994629
# [I 2026-01-03 19:10:36,457] Trial 10 finished with value: 0.26443768315889493 and parameters: {'max_depth': 39, 'n_estimators': 307, 'max_features': 0.8, 'min_samples_split': 14, 'min_samples_leaf': 1, 'bootstrap': False, 'criterion': 'entropy'}. Best is trial 2 with value: 0.2850195683506137.
#
# [TRIAL 11] score(AUPRC_macro)=0.286700 | AUROC=0.858013 | Acc=0.969021 | P=0.908594 | R=0.006216 | Spec=0.999505
# [I 2026-01-03 19:11:17,300] Trial 11 finished with value: 0.2866997738843679 and parameters: {'max_depth': 25, 'n_estimators': 343, 'max_features': 'log2', 'min_samples_split': 9, 'min_samples_leaf': 4, 'bootstrap': False, 'criterion': 'entropy'}. Best is trial 11 with value: 0.2866997738843679.
#
# [TRIAL 12] score(AUPRC_macro)=0.283657 | AUROC=0.856665 | Acc=0.968739 | P=0.919913 | R=0.005082 | Spec=0.999566
# [I 2026-01-03 19:11:54,303] Trial 12 finished with value: 0.2836574663997428 and parameters: {'max_depth': 21, 'n_estimators': 314, 'max_features': 'log2', 'min_samples_split': 10, 'min_samples_leaf': 4, 'bootstrap': False, 'criterion': 'entropy'}. Best is trial 11 with value: 0.2866997738843679.
#
# [TRIAL 13] score(AUPRC_macro)=0.285922 | AUROC=0.857545 | Acc=0.968708 | P=0.918188 | R=0.004932 | Spec=0.999575
# [I 2026-01-03 19:12:48,958] Trial 13 finished with value: 0.28592151444500624 and parameters: {'max_depth': 21, 'n_estimators': 479, 'max_features': 'log2', 'min_samples_split': 15, 'min_samples_leaf': 4, 'bootstrap': False, 'criterion': 'entropy'}. Best is trial 11 with value: 0.2866997738843679.
#
# [TRIAL 14] score(AUPRC_macro)=0.287393 | AUROC=0.858488 | Acc=0.968790 | P=0.908948 | R=0.005197 | Spec=0.999592
# [I 2026-01-03 19:13:41,193] Trial 14 finished with value: 0.28739278351894804 and parameters: {'max_depth': 20, 'n_estimators': 445, 'max_features': 'log2', 'min_samples_split': 11, 'min_samples_leaf': 3, 'bootstrap': False, 'criterion': 'entropy'}. Best is trial 14 with value: 0.28739278351894804.
#
# [TRIAL 15] score(AUPRC_macro)=0.289515 | AUROC=0.859182 | Acc=0.971268 | P=0.792819 | R=0.033124 | Spec=0.998424
# [I 2026-01-03 19:14:40,619] Trial 15 finished with value: 0.2895149510262658 and parameters: {'max_depth': 38, 'n_estimators': 471, 'max_features': 'log2', 'min_samples_split': 10, 'min_samples_leaf': 1, 'bootstrap': False, 'criterion': 'gini'}. Best is trial 15 with value: 0.2895149510262658.
#
# [TRIAL 16] score(AUPRC_macro)=0.292025 | AUROC=0.860571 | Acc=0.971257 | P=0.802537 | R=0.031229 | Spec=0.998454
# [I 2026-01-03 19:16:34,160] Trial 16 finished with value: 0.29202499989345343 and parameters: {'max_depth': 39, 'n_estimators': 930, 'max_features': 'log2', 'min_samples_split': 12, 'min_samples_leaf': 1, 'bootstrap': False, 'criterion': 'gini'}. Best is trial 16 with value: 0.29202499989345343.
#
# [TRIAL 17] score(AUPRC_macro)=0.292696 | AUROC=0.860681 | Acc=0.971257 | P=0.807021 | R=0.031091 | Spec=0.998457
# [I 2026-01-03 19:18:36,172] Trial 17 finished with value: 0.29269598829725824 and parameters: {'max_depth': 39, 'n_estimators': 974, 'max_features': 'log2', 'min_samples_split': 12, 'min_samples_leaf': 1, 'bootstrap': False, 'criterion': 'gini'}. Best is trial 17 with value: 0.29269598829725824.
#
# [TRIAL 18] score(AUPRC_macro)=0.304803 | AUROC=0.865615 | Acc=0.971874 | P=0.787865 | R=0.045033 | Spec=0.997884
# [I 2026-01-03 19:26:37,643] Trial 18 finished with value: 0.30480266598139133 and parameters: {'max_depth': 34, 'n_estimators': 997, 'max_features': 'sqrt', 'min_samples_split': 6, 'min_samples_leaf': 2, 'bootstrap': False, 'criterion': 'gini'}. Best is trial 18 with value: 0.30480266598139133.
#
# [TRIAL 19] score(AUPRC_macro)=0.304727 | AUROC=0.866048 | Acc=0.971854 | P=0.789277 | R=0.044708 | Spec=0.997910
# [I 2026-01-03 19:35:37,233] Trial 19 finished with value: 0.30472720306416645 and parameters: {'max_depth': 33, 'n_estimators': 1082, 'max_features': 'sqrt', 'min_samples_split': 6, 'min_samples_leaf': 2, 'bootstrap': False, 'criterion': 'gini'}. Best is trial 18 with value: 0.30480266598139133.
#
# [TRIAL 20] score(AUPRC_macro)=0.303348 | AUROC=0.865864 | Acc=0.971863 | P=0.780154 | R=0.045136 | Spec=0.997888
# [I 2026-01-03 19:44:50,147] Trial 20 finished with value: 0.303348355797343 and parameters: {'max_depth': 32, 'n_estimators': 1106, 'max_features': 'sqrt', 'min_samples_split': 5, 'min_samples_leaf': 2, 'bootstrap': False, 'criterion': 'gini'}. Best is trial 18 with value: 0.30480266598139133.
#
# [TRIAL 21] score(AUPRC_macro)=0.303963 | AUROC=0.865854 | Acc=0.971884 | P=0.796007 | R=0.045544 | Spec=0.997917
# [I 2026-01-03 19:53:51,693] Trial 21 finished with value: 0.3039633319529341 and parameters: {'max_depth': 32, 'n_estimators': 1084, 'max_features': 'sqrt', 'min_samples_split': 6, 'min_samples_leaf': 2, 'bootstrap': False, 'criterion': 'gini'}. Best is trial 18 with value: 0.30480266598139133.
#
# [TRIAL 22] score(AUPRC_macro)=0.304553 | AUROC=0.865447 | Acc=0.971880 | P=0.787946 | R=0.045639 | Spec=0.997855
# [I 2026-01-03 20:02:29,904] Trial 22 finished with value: 0.3045527249700507 and parameters: {'max_depth': 34, 'n_estimators': 1038, 'max_features': 'sqrt', 'min_samples_split': 5, 'min_samples_leaf': 2, 'bootstrap': False, 'criterion': 'gini'}. Best is trial 18 with value: 0.30480266598139133.
#
# [TRIAL 23] score(AUPRC_macro)=0.305641 | AUROC=0.866786 | Acc=0.971397 | P=0.823152 | R=0.032331 | Spec=0.998260
# [I 2026-01-03 20:13:06,520] Trial 23 finished with value: 0.3056411534297122 and parameters: {'max_depth': 35, 'n_estimators': 1280, 'max_features': 'sqrt', 'min_samples_split': 5, 'min_samples_leaf': 3, 'bootstrap': False, 'criterion': 'gini'}. Best is trial 23 with value: 0.3056411534297122.
#
# [TRIAL 24] score(AUPRC_macro)=0.305299 | AUROC=0.866630 | Acc=0.971395 | P=0.825224 | R=0.032360 | Spec=0.998247
# [I 2026-01-03 20:23:48,462] Trial 24 finished with value: 0.3052990679856028 and parameters: {'max_depth': 36, 'n_estimators': 1291, 'max_features': 'sqrt', 'min_samples_split': 5, 'min_samples_leaf': 3, 'bootstrap': False, 'criterion': 'gini'}. Best is trial 23 with value: 0.3056411534297122.
#
# [TRIAL 25] score(AUPRC_macro)=0.304808 | AUROC=0.866309 | Acc=0.971352 | P=0.828396 | R=0.031617 | Spec=0.998299
# [I 2026-01-03 20:34:28,445] Trial 25 finished with value: 0.3048078439843813 and parameters: {'max_depth': 29, 'n_estimators': 1287, 'max_features': 'sqrt', 'min_samples_split': 4, 'min_samples_leaf': 3, 'bootstrap': False, 'criterion': 'gini'}. Best is trial 23 with value: 0.3056411534297122.
#
# [TRIAL 26] score(AUPRC_macro)=0.301046 | AUROC=0.865338 | Acc=0.970850 | P=0.832503 | R=0.021757 | Spec=0.998516
# [I 2026-01-03 20:45:26,778] Trial 26 finished with value: 0.3010462195518558 and parameters: {'max_depth': 36, 'n_estimators': 1322, 'max_features': 'sqrt', 'min_samples_split': 4, 'min_samples_leaf': 3, 'bootstrap': True, 'criterion': 'gini'}. Best is trial 23 with value: 0.3056411534297122.
#
# [TRIAL 27] score(AUPRC_macro)=0.259457 | AUROC=0.818401 | Acc=0.971408 | P=0.484280 | R=0.123086 | Spec=0.993507
# [I 2026-01-03 20:53:54,076] Trial 27 finished with value: 0.2594567282485114 and parameters: {'max_depth': 28, 'n_estimators': 1500, 'max_features': 0.8, 'min_samples_split': 8, 'min_samples_leaf': 3, 'bootstrap': False, 'criterion': 'gini'}. Best is trial 23 with value: 0.3056411534297122.
#
# [TRIAL 28] score(AUPRC_macro)=0.298869 | AUROC=0.865849 | Acc=0.970726 | P=0.837987 | R=0.019818 | Spec=0.998607
# [I 2026-01-03 21:04:08,209] Trial 28 finished with value: 0.298869464777001 and parameters: {'max_depth': 30, 'n_estimators': 1238, 'max_features': 'sqrt', 'min_samples_split': 4, 'min_samples_leaf': 5, 'bootstrap': False, 'criterion': 'gini'}. Best is trial 23 with value: 0.3056411534297122.
#
# [TRIAL 29] score(AUPRC_macro)=0.292173 | AUROC=0.864295 | Acc=0.970384 | P=0.862985 | R=0.014616 | Spec=0.998743
# [I 2026-01-03 21:15:34,152] Trial 29 finished with value: 0.29217294533561483 and parameters: {'max_depth': 36, 'n_estimators': 1387, 'max_features': 'sqrt', 'min_samples_split': 8, 'min_samples_leaf': 7, 'bootstrap': False, 'criterion': 'gini'}. Best is trial 23 with value: 0.3056411534297122.
#
# ================ BEST =================
# Best trial: 23
# Best AUPRC_macro: 0.3056411534297122
# Best params:
# {
#   "max_depth": 35,
#   "n_estimators": 1280,
#   "max_features": "sqrt",
#   "min_samples_split": 5,
#   "min_samples_leaf": 3,
#   "bootstrap": false,
#   "criterion": "gini"
# }
# [SAVED] ./optuna_singlemodel_RF_30trials_5fold_results.csv
