# %%
# -*- coding: utf-8 -*-
import os
import re
import glob
import json
import numpy as np
import pandas as pd

import optuna
import xgboost as xgb
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import roc_auc_score, average_precision_score

# =========================
# 0) 配置
# =========================
RANDOM_SEED = 42
N_TRIALS = 30
N_SPLITS = 5
THRESH = 0.5

# 直接读取你已生成的特征文件（xlsx）
FEATURE_FILE_GLOB = "./Malodors_Morgan_features.xlsx"
# 如果你的文件名不同，改成你的，例如：
# FEATURE_FILE_GLOB = "./Malodors_transformed_MORGAN_features.xlsx"

# 固定参数：Optuna 只搜索部分超参
BASE_XGB_PARAMS = dict(
    objective="binary:logistic",
    eval_metric="logloss",
    tree_method="hist",
    n_jobs=-1,
    random_state=RANDOM_SEED,
    verbosity=0,
    multi_strategy="multi_output_tree",
)


# =========================
# 1) XGBoost 版本检查
# =========================
def _ver_tuple(v: str):
    parts = re.split(r"[.+-]", v.strip())
    nums = []

    for p in parts[:3]:
        try:
            nums.append(int(p))
        except Exception:
            nums.append(0)

    while len(nums) < 3:
        nums.append(0)

    return tuple(nums)


def check_xgb_version():
    v = _ver_tuple(xgb.__version__)

    if v < (1, 6, 0):
        raise RuntimeError(
            f"xgboost=={xgb.__version__} 太旧：multi-label 需要 >=1.6"
        )

    if "multi_strategy" in BASE_XGB_PARAMS and v < (2, 0, 0):
        raise RuntimeError(
            f"xgboost=={xgb.__version__} 不支持 multi_output_tree，需要 >=2.0。\n"
            f"请升级 xgboost，或删除 BASE_XGB_PARAMS 中的 multi_strategy。"
        )


# =========================
# 2) 读取特征文件 & 按固定列位置划分 SMILES / y / X
# =========================
def find_feature_file(pattern: str):
    cands = sorted(glob.glob(pattern))

    if not cands:
        raise FileNotFoundError(
            f"找不到特征文件：{pattern}\n"
            f"请确认 xlsx 文件名，或修改 FEATURE_FILE_GLOB。"
        )

    return cands[-1]


def load_Xy_from_feature_file(xlsx_path: str):
    """
    固定数据格式：
    第 1 列：SMILES
    第 2-25 列：24 个 y 标签
    第 26 列及之后：X 特征列

    说明：
    - 不再通过 0/1 自动判断 y 标签列；
    - 避免 Morgan bit、Rule、FG、StructKG 等 0/1 或数值特征被误识别为标签；
    - 适用于当前 24 标签任务。
    """
    df = pd.read_excel(xlsx_path)

    if df.shape[1] < 26:
        raise ValueError(
            f"当前文件列数为 {df.shape[1]}，不足以按“1列SMILES + 24列标签 + 特征列”划分。"
        )

    # 固定列位置
    smiles_col = df.columns[0]
    label_cols = list(df.columns[1:25])
    feature_cols = list(df.columns[25:])

    if len(label_cols) != 24:
        raise ValueError(
            f"标签列数量应为 24，但当前识别为 {len(label_cols)}。"
        )

    if len(feature_cols) == 0:
        raise ValueError(
            "未识别到特征列。请确认第 26 列之后为 X 特征。"
        )

    # y 标签转为 0/1 整数
    y_df = df[label_cols].copy()
    y_df = y_df.apply(pd.to_numeric, errors="coerce").fillna(0).astype(int)

    # 检查 y 标签是否为 0/1
    invalid_label_cols = []
    for c in label_cols:
        vals = set(pd.unique(y_df[c].dropna()))
        if not vals.issubset({0, 1}):
            invalid_label_cols.append(c)

    if invalid_label_cols:
        raise ValueError(
            "以下标签列不是标准 0/1 标签，请检查数据：\n"
            + "\n".join(map(str, invalid_label_cols))
        )

    # X 特征转为数值
    X_df = df[feature_cols].copy()
    X_df = X_df.apply(pd.to_numeric, errors="coerce").fillna(0)

    X = X_df.astype(np.float32).values
    y = y_df.values.astype(int)

    if X.shape[0] != y.shape[0]:
        raise ValueError("X 和 y 行数不一致，请检查文件。")

    print("[INFO] Column split mode: fixed-position")
    print(f"[INFO] SMILES column: {smiles_col}")
    print(f"[INFO] Label columns: columns 2-25, n={len(label_cols)}")
    print(f"[INFO] Feature columns: columns 26-end, n={len(feature_cols)}")

    print("\n[INFO] Label columns:")
    for i, c in enumerate(label_cols, start=1):
        print(f"  y{i:02d}: {c}")

    return X, y, feature_cols, label_cols, df


# =========================
# 3) 指标：macro
# =========================
def multilabel_macro_metrics(y_true, y_prob, thresh=0.5):
    y_true = np.asarray(y_true).astype(int)
    y_prob = np.asarray(y_prob).astype(float)
    y_pred = (y_prob >= thresh).astype(int)

    L = y_true.shape[1]
    accs, precs, recs, specs = [], [], [], []
    aurocs, auprcs = [], []

    for k in range(L):
        yt = y_true[:, k]
        yp = y_pred[:, k]
        ys = y_prob[:, k]

        tp = int(np.sum((yt == 1) & (yp == 1)))
        tn = int(np.sum((yt == 0) & (yp == 0)))
        fp = int(np.sum((yt == 0) & (yp == 1)))
        fn = int(np.sum((yt == 1) & (yp == 0)))
        n = len(yt)

        accs.append((tp + tn) / n if n else np.nan)
        precs.append(tp / (tp + fp) if (tp + fp) else np.nan)
        recs.append(tp / (tp + fn) if (tp + fn) else np.nan)
        specs.append(tn / (tn + fp) if (tn + fp) else np.nan)

        if len(np.unique(yt)) == 2:
            aurocs.append(roc_auc_score(yt, ys))
            auprcs.append(average_precision_score(yt, ys))
        else:
            aurocs.append(np.nan)
            auprcs.append(np.nan)

    def nanmean(x):
        return float(np.nanmean(np.asarray(x, dtype=float)))

    return {
        "Accuracy_macro": nanmean(accs),
        "Precision_macro": nanmean(precs),
        "Recall_macro": nanmean(recs),
        "Specificity_macro": nanmean(specs),
        "AUROC_macro": nanmean(aurocs),
        "AUPRC_macro": nanmean(auprcs),
        "AUROC_valid_labels": int(np.sum(~np.isnan(aurocs))),
        "AUPRC_valid_labels": int(np.sum(~np.isnan(auprcs))),
        "n_labels": int(L),
    }


def extract_positive_proba(p, n_labels: int):
    """
    兼容 XGBoost 多标签输出：

    常见情况：
    - multi_output_tree 下 predict_proba 通常返回形状为 (n_samples, n_labels)
    - 某些版本或设置下可能返回 list 或 3D array
    """
    if isinstance(p, list):
        out = np.zeros((p[0].shape[0], n_labels), dtype=np.float32)

        for k in range(n_labels):
            pk = p[k]

            if pk.ndim != 2:
                raise ValueError(f"predict_proba[{k}] 形状异常: {pk.shape}")

            if pk.shape[1] == 2:
                out[:, k] = pk[:, 1].astype(np.float32)
            elif pk.shape[1] == 1:
                out[:, k] = pk[:, 0].astype(np.float32)
            else:
                raise ValueError(
                    f"predict_proba[{k}] 类别数异常: {pk.shape[1]}"
                )

        return out

    p = np.asarray(p)

    if p.ndim == 3 and p.shape[-1] == 2:
        return p[:, :, 1].astype(np.float32)

    if p.ndim == 2:
        if p.shape[1] == 2 and n_labels == 1:
            return p[:, 1:2].astype(np.float32)

        if p.shape[1] == n_labels:
            return p.astype(np.float32)

        raise ValueError(
            f"predict_proba 输出为二维，但列数 {p.shape[1]} 与标签数 {n_labels} 不一致。"
        )

    raise ValueError(f"无法解析 predict_proba 输出形状: {p.shape}")


# =========================
# 4) 近似分层 5 折：用 label cardinality 分层
# =========================
def make_stratify_target(y: np.ndarray, n_bins: int = 10):
    """
    多标签任务中没有直接的 StratifiedKFold。
    这里使用每个样本的标签数量 label cardinality 做近似分层。
    """
    card = y.sum(axis=1).astype(int)
    uniq = np.unique(card)

    if len(uniq) <= 15:
        return card

    r = pd.Series(card).rank(method="average").values
    bins = pd.qcut(
        r,
        q=min(n_bins, len(np.unique(r))),
        labels=False,
        duplicates="drop"
    )

    return np.asarray(bins, dtype=int)


def build_folds(X, y, n_splits=5, seed=42):
    strat_y = make_stratify_target(y)

    skf = StratifiedKFold(
        n_splits=n_splits,
        shuffle=True,
        random_state=seed
    )

    return list(skf.split(X, strat_y))


# =========================
# 5) 5 折 CV 评估
# =========================
def cv_eval_one_paramset(X, y, folds, params, thresh=0.5):
    n_labels = y.shape[1]
    fold_metrics = []

    for fold_id, (tr_idx, va_idx) in enumerate(folds, start=1):
        X_tr, X_va = X[tr_idx], X[va_idx]
        y_tr, y_va = y[tr_idx], y[va_idx]

        clf = xgb.XGBClassifier(**params)
        clf.fit(X_tr, y_tr)

        p = clf.predict_proba(X_va)
        y_prob = extract_positive_proba(p, n_labels=n_labels)

        m = multilabel_macro_metrics(y_va, y_prob, thresh=thresh)
        fold_metrics.append(m)

        print(
            f"    [FOLD {fold_id}] "
            f"AUPRC={m['AUPRC_macro']:.6f} | "
            f"AUROC={m['AUROC_macro']:.6f} | "
            f"Acc={m['Accuracy_macro']:.6f} | "
            f"P={m['Precision_macro']:.6f} | "
            f"R={m['Recall_macro']:.6f} | "
            f"Spec={m['Specificity_macro']:.6f}"
        )

    keys = list(fold_metrics[0].keys())
    mean_metrics = {}

    for k in keys:
        vals = [fm[k] for fm in fold_metrics]

        if isinstance(vals[0], float):
            mean_metrics[k] = float(np.nanmean(vals))
        else:
            mean_metrics[k] = vals[-1]

    return mean_metrics


# =========================
# 6) Optuna 超参空间
# =========================
def build_trial_params(trial: optuna.Trial):
    params = dict(BASE_XGB_PARAMS)

    params.update({
        "n_estimators": trial.suggest_int("n_estimators", 300, 1200),
        "max_depth": trial.suggest_int("max_depth", 3, 10),
        "learning_rate": trial.suggest_float("learning_rate", 0.01, 0.2, log=True),
        "subsample": trial.suggest_float("subsample", 0.6, 1.0),
        "colsample_bytree": trial.suggest_float("colsample_bytree", 0.6, 1.0),
        "min_child_weight": trial.suggest_float("min_child_weight", 0.5, 10.0, log=True),
        "reg_lambda": trial.suggest_float("reg_lambda", 1e-3, 20.0, log=True),
        "reg_alpha": trial.suggest_float("reg_alpha", 1e-8, 5.0, log=True),
        "gamma": trial.suggest_float("gamma", 0.0, 5.0),
    })

    return params


# =========================
# 7) 主流程：读特征 -> 固定 folds -> Optuna -> 输出保存
# =========================
def main():
    check_xgb_version()

    feature_file = find_feature_file(FEATURE_FILE_GLOB)
    print("[INFO] Using feature file:", feature_file)

    X, y, feat_cols, label_cols, df_all = load_Xy_from_feature_file(feature_file)

    print(
        f"\n[INFO] X shape={X.shape} "
        f"(features={len(feat_cols)}) | "
        f"y shape={y.shape} "
        f"(labels={len(label_cols)})"
    )

    folds = build_folds(X, y, n_splits=N_SPLITS, seed=RANDOM_SEED)
    print(f"[INFO] Prepared fixed {N_SPLITS}-fold splits for all trials.")

    def objective(trial: optuna.Trial):
        params = build_trial_params(trial)

        print("\n" + "=" * 80)
        print(f"[TRIAL {trial.number:02d}] params:")
        print(json.dumps(params, indent=2, ensure_ascii=False, default=str))

        mean_metrics = cv_eval_one_paramset(
            X,
            y,
            folds,
            params,
            thresh=THRESH
        )

        score = mean_metrics["AUPRC_macro"]

        print(
            f"\n[TRIAL {trial.number:02d}] "
            f"score(AUPRC_macro)={score:.6f} | "
            f"AUROC={mean_metrics['AUROC_macro']:.6f} | "
            f"Acc={mean_metrics['Accuracy_macro']:.6f} | "
            f"P={mean_metrics['Precision_macro']:.6f} | "
            f"R={mean_metrics['Recall_macro']:.6f} | "
            f"Spec={mean_metrics['Specificity_macro']:.6f}"
        )

        for k, v in mean_metrics.items():
            trial.set_user_attr(k, v)

        return score

    study = optuna.create_study(
        direction="maximize",
        sampler=optuna.samplers.TPESampler(seed=RANDOM_SEED),
    )

    study.optimize(
        objective,
        n_trials=N_TRIALS,
        show_progress_bar=True
    )

    print("\n================ BEST =================")
    print("Best trial:", study.best_trial.number)
    print("Best AUPRC_macro:", study.best_value)
    print("Best params:")
    print(json.dumps(study.best_params, indent=2, ensure_ascii=False))

    rows = []

    for t in study.trials:
        if t.value is None:
            continue

        row = {
            "trial": t.number,
            "AUPRC_macro": t.value,
            **t.params
        }

        row.update({
            k: v for k, v in t.user_attrs.items()
            if k.endswith("_macro")
        })

        rows.append(row)

    res_df = pd.DataFrame(rows).sort_values(
        "AUPRC_macro",
        ascending=False
    )

    out_csv = "./optuna_singlemodel_XGB_30trials_5fold_results.csv"
    res_df.to_csv(out_csv, index=False, encoding="utf-8-sig")
    print("[SAVED]", out_csv)

    # 额外保存标签列和特征列，便于后续核查
    label_out = "./used_label_columns_24.csv"
    feature_out = "./used_feature_columns.csv"

    pd.DataFrame({"label_col": label_cols}).to_csv(
        label_out,
        index=False,
        encoding="utf-8-sig"
    )

    pd.DataFrame({"feature_col": feat_cols}).to_csv(
        feature_out,
        index=False,
        encoding="utf-8-sig"
    )

    print("[SAVED]", label_out)
    print("[SAVED]", feature_out)


if __name__ == "__main__":
    main()
# Out:
# [INFO] Using feature file: ./Malodors_Morgan_features.xlsx
# /root/miniconda3/lib/python3.12/site-packages/sklearn/model_selection/_split.py:813: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# [I 2026-05-07 16:04:29,526] A new study created in memory with name: no-name-31af7943-271d-469b-a494-549d49236337
# [INFO] Column split mode: fixed-position
# [INFO] SMILES column: Canonical_SMILES
# [INFO] Label columns: columns 2-25, n=24
# [INFO] Feature columns: columns 26-end, n=2048
#
# [INFO] Label columns:
#   y01: alcoholic
#   y02: aldehydic
#   y03: almond
#   y04: aromatic
#   y05: burnt
#   y06: cabbage
#   y07: cheesy
#   y08: cherry
#   y09: chocolate
#   y10: ethereal
#   y11: fishy
#   y12: fruity
#   y13: garlic
#   y14: gassy
#   y15: green
#   y16: ketonic
#   y17: musty
#   y18: pungent
#   y19: sharp
#   y20: solvent
#   y21: sour
#   y22: sulfurous
#   y23: sweaty
#   y24: sweet
#
# [INFO] X shape=(3756, 2048) (features=2048) | y shape=(3756, 24) (labels=24)
# [INFO] Prepared fixed 5-fold splits for all trials.
#   0%|          | 0/30 [00:00<?, ?it/s]
# ================================================================================
# [TRIAL 00] params:
# {
#   "objective": "binary:logistic",
#   "eval_metric": "logloss",
#   "tree_method": "hist",
#   "n_jobs": -1,
#   "random_state": 42,
#   "verbosity": 0,
#   "multi_strategy": "multi_output_tree",
#   "n_estimators": 637,
#   "max_depth": 10,
#   "learning_rate": 0.08960785365368121,
#   "subsample": 0.8394633936788146,
#   "colsample_bytree": 0.6624074561769746,
#   "min_child_weight": 0.7978542347074177,
#   "reg_lambda": 0.0017775399007348214,
#   "reg_alpha": 0.3426417745118369,
#   "gamma": 3.005575058716044
# }
#     [FOLD 1] AUPRC=0.379849 | AUROC=0.846748 | Acc=0.939772 | P=0.549043 | R=0.265961 | Spec=0.969059
#     [FOLD 2] AUPRC=0.358379 | AUROC=0.854859 | Acc=0.939969 | P=0.470998 | R=0.239026 | Spec=0.971839
#     [FOLD 3] AUPRC=0.386761 | AUROC=0.842785 | Acc=0.943964 | P=0.593286 | R=0.276704 | Spec=0.970938
#     [FOLD 4] AUPRC=0.389123 | AUROC=0.849988 | Acc=0.939248 | P=0.559746 | R=0.251299 | Spec=0.967392
#     [FOLD 5] AUPRC=0.378837 | AUROC=0.843923 | Acc=0.942410 | P=0.516850 | R=0.266552 | Spec=0.970653
#
# [TRIAL 00] score(AUPRC_macro)=0.378590 | AUROC=0.847661 | Acc=0.941072 | P=0.537985 | R=0.259908 | Spec=0.969976
# [I 2026-05-07 16:08:38,955] Trial 0 finished with value: 0.37858959535624637 and parameters: {'n_estimators': 637, 'max_depth': 10, 'learning_rate': 0.08960785365368121, 'subsample': 0.8394633936788146, 'colsample_bytree': 0.6624074561769746, 'min_child_weight': 0.7978542347074177, 'reg_lambda': 0.0017775399007348214, 'reg_alpha': 0.3426417745118369, 'gamma': 3.005575058716044}. Best is trial 0 with value: 0.37858959535624637.
#
# ================================================================================
# [TRIAL 01] params:
# {
#   "objective": "binary:logistic",
#   "eval_metric": "logloss",
#   "tree_method": "hist",
#   "n_jobs": -1,
#   "random_state": 42,
#   "verbosity": 0,
#   "multi_strategy": "multi_output_tree",
#   "n_estimators": 937,
#   "max_depth": 3,
#   "learning_rate": 0.18276027831785724,
#   "subsample": 0.9329770563201687,
#   "colsample_bytree": 0.6849356442713105,
#   "min_child_weight": 0.8620446097910766,
#   "reg_lambda": 0.006149337057087106,
#   "reg_alpha": 4.4319427891510175e-06,
#   "gamma": 2.6237821581611893
# }
#     [FOLD 1] AUPRC=0.379548 | AUROC=0.849093 | Acc=0.940381 | P=0.499364 | R=0.255225 | Spec=0.968880
#     [FOLD 2] AUPRC=0.345933 | AUROC=0.853808 | Acc=0.938915 | P=0.499013 | R=0.228810 | Spec=0.970510
#     [FOLD 3] AUPRC=0.386713 | AUROC=0.838777 | Acc=0.942577 | P=0.555019 | R=0.270632 | Spec=0.969853
#     [FOLD 4] AUPRC=0.392056 | AUROC=0.846118 | Acc=0.938526 | P=0.561803 | R=0.251695 | Spec=0.966758
#     [FOLD 5] AUPRC=0.365535 | AUROC=0.840926 | Acc=0.940690 | P=0.427292 | R=0.236005 | Spec=0.968467
#
# [TRIAL 01] score(AUPRC_macro)=0.373957 | AUROC=0.845744 | Acc=0.940218 | P=0.508498 | R=0.248473 | Spec=0.968894
# [I 2026-05-07 16:10:16,822] Trial 1 finished with value: 0.37395698249433507 and parameters: {'n_estimators': 937, 'max_depth': 3, 'learning_rate': 0.18276027831785724, 'subsample': 0.9329770563201687, 'colsample_bytree': 0.6849356442713105, 'min_child_weight': 0.8620446097910766, 'reg_lambda': 0.006149337057087106, 'reg_alpha': 4.4319427891510175e-06, 'gamma': 2.6237821581611893}. Best is trial 0 with value: 0.37858959535624637.
#
# ================================================================================
# [TRIAL 02] params:
# {
#   "objective": "binary:logistic",
#   "eval_metric": "logloss",
#   "tree_method": "hist",
#   "n_jobs": -1,
#   "random_state": 42,
#   "verbosity": 0,
#   "multi_strategy": "multi_output_tree",
#   "n_estimators": 689,
#   "max_depth": 5,
#   "learning_rate": 0.06252287916406217,
#   "subsample": 0.6557975442608167,
#   "colsample_bytree": 0.7168578594140873,
#   "min_child_weight": 1.498365454855079,
#   "reg_lambda": 0.09153152164233955,
#   "reg_alpha": 0.06764288719681069,
#   "gamma": 0.9983689107917987
# }
#     [FOLD 1] AUPRC=0.359613 | AUROC=0.839315 | Acc=0.940049 | P=0.586490 | R=0.226186 | Spec=0.970613
#     [FOLD 2] AUPRC=0.349435 | AUROC=0.843859 | Acc=0.940135 | P=0.423463 | R=0.197254 | Spec=0.973385
#     [FOLD 3] AUPRC=0.381256 | AUROC=0.840353 | Acc=0.943686 | P=0.607054 | R=0.241185 | Spec=0.971862
#     [FOLD 4] AUPRC=0.371414 | AUROC=0.841841 | Acc=0.938970 | P=0.582870 | R=0.230829 | Spec=0.969238
#     [FOLD 5] AUPRC=0.373670 | AUROC=0.837166 | Acc=0.941689 | P=0.542317 | R=0.228449 | Spec=0.970826
#
# [TRIAL 02] score(AUPRC_macro)=0.367078 | AUROC=0.840507 | Acc=0.940906 | P=0.548439 | R=0.224780 | Spec=0.971185
# [I 2026-05-07 16:13:39,720] Trial 2 finished with value: 0.36707750045049403 and parameters: {'n_estimators': 689, 'max_depth': 5, 'learning_rate': 0.06252287916406217, 'subsample': 0.6557975442608167, 'colsample_bytree': 0.7168578594140873, 'min_child_weight': 1.498365454855079, 'reg_lambda': 0.09153152164233955, 'reg_alpha': 0.06764288719681069, 'gamma': 0.9983689107917987}. Best is trial 0 with value: 0.37858959535624637.
#
# ================================================================================
# [TRIAL 03] params:
# {
#   "objective": "binary:logistic",
#   "eval_metric": "logloss",
#   "tree_method": "hist",
#   "n_jobs": -1,
#   "random_state": 42,
#   "verbosity": 0,
#   "multi_strategy": "multi_output_tree",
#   "n_estimators": 763,
#   "max_depth": 7,
#   "learning_rate": 0.011492999300221412,
#   "subsample": 0.8430179407605753,
#   "colsample_bytree": 0.6682096494749166,
#   "min_child_weight": 0.6075808513336687,
#   "reg_lambda": 12.055498078944888,
#   "reg_alpha": 2.5119100929409792,
#   "gamma": 4.041986740582305
# }
#     [FOLD 1] AUPRC=0.355373 | AUROC=0.849411 | Acc=0.940769 | P=0.756922 | R=0.137823 | Spec=0.979318
#     [FOLD 2] AUPRC=0.358337 | AUROC=0.856883 | Acc=0.939525 | P=0.717533 | R=0.126845 | Spec=0.981221
#     [FOLD 3] AUPRC=0.359158 | AUROC=0.832517 | Acc=0.941411 | P=0.753573 | R=0.141018 | Spec=0.980144
#     [FOLD 4] AUPRC=0.350503 | AUROC=0.831551 | Acc=0.938415 | P=0.738434 | R=0.137456 | Spec=0.978349
#     [FOLD 5] AUPRC=0.361388 | AUROC=0.822835 | Acc=0.939525 | P=0.765619 | R=0.124100 | Spec=0.978237
#
# [TRIAL 03] score(AUPRC_macro)=0.356952 | AUROC=0.838640 | Acc=0.939929 | P=0.746416 | R=0.133448 | Spec=0.979454
# [I 2026-05-07 16:17:57,913] Trial 3 finished with value: 0.3569516312094876 and parameters: {'n_estimators': 763, 'max_depth': 7, 'learning_rate': 0.011492999300221412, 'subsample': 0.8430179407605753, 'colsample_bytree': 0.6682096494749166, 'min_child_weight': 0.6075808513336687, 'reg_lambda': 12.055498078944888, 'reg_alpha': 2.5119100929409792, 'gamma': 4.041986740582305}. Best is trial 0 with value: 0.37858959535624637.
#
# ================================================================================
# [TRIAL 04] params:
# {
#   "objective": "binary:logistic",
#   "eval_metric": "logloss",
#   "tree_method": "hist",
#   "n_jobs": -1,
#   "random_state": 42,
#   "verbosity": 0,
#   "multi_strategy": "multi_output_tree",
#   "n_estimators": 574,
#   "max_depth": 3,
#   "learning_rate": 0.07766184280392888,
#   "subsample": 0.7760609974958406,
#   "colsample_bytree": 0.6488152939379115,
#   "min_child_weight": 2.2039920190846214,
#   "reg_lambda": 0.001405743424794793,
#   "reg_alpha": 0.8131129951713353,
#   "gamma": 1.2938999080000846
# }
#     [FOLD 1] AUPRC=0.355258 | AUROC=0.850535 | Acc=0.941656 | P=0.667294 | R=0.184916 | Spec=0.975112
#     [FOLD 2] AUPRC=0.343139 | AUROC=0.854270 | Acc=0.941245 | P=0.577706 | R=0.178221 | Spec=0.977717
#     [FOLD 3] AUPRC=0.380038 | AUROC=0.847268 | Acc=0.942521 | P=0.582518 | R=0.184775 | Spec=0.975302
#     [FOLD 4] AUPRC=0.385330 | AUROC=0.848104 | Acc=0.939969 | P=0.714960 | R=0.183297 | Spec=0.975008
#     [FOLD 5] AUPRC=0.373909 | AUROC=0.845227 | Acc=0.944130 | P=0.707070 | R=0.183732 | Spec=0.977208
#
# [TRIAL 04] score(AUPRC_macro)=0.367535 | AUROC=0.849081 | Acc=0.941904 | P=0.649910 | R=0.182988 | Spec=0.976069
# [I 2026-05-07 16:19:17,566] Trial 4 finished with value: 0.36753514437129664 and parameters: {'n_estimators': 574, 'max_depth': 3, 'learning_rate': 0.07766184280392888, 'subsample': 0.7760609974958406, 'colsample_bytree': 0.6488152939379115, 'min_child_weight': 2.2039920190846214, 'reg_lambda': 0.001405743424794793, 'reg_alpha': 0.8131129951713353, 'gamma': 1.2938999080000846}. Best is trial 0 with value: 0.37858959535624637.
#
# ================================================================================
# [TRIAL 05] params:
# {
#   "objective": "binary:logistic",
#   "eval_metric": "logloss",
#   "tree_method": "hist",
#   "n_jobs": -1,
#   "random_state": 42,
#   "verbosity": 0,
#   "multi_strategy": "multi_output_tree",
#   "n_estimators": 896,
#   "max_depth": 5,
#   "learning_rate": 0.04749239763680407,
#   "subsample": 0.8186841117373118,
#   "colsample_bytree": 0.6739417822102108,
#   "min_child_weight": 9.129115219600122,
#   "reg_lambda": 2.1570962503558295,
#   "reg_alpha": 1.4882404753442915,
#   "gamma": 4.474136752138244
# }
#     [FOLD 1] AUPRC=0.352305 | AUROC=0.846982 | Acc=0.940824 | P=0.743690 | R=0.166971 | Spec=0.976386
#     [FOLD 2] AUPRC=0.348608 | AUROC=0.853440 | Acc=0.940468 | P=0.508894 | R=0.152108 | Spec=0.978551
#     [FOLD 3] AUPRC=0.367684 | AUROC=0.837080 | Acc=0.941578 | P=0.635126 | R=0.161824 | Spec=0.977620
#     [FOLD 4] AUPRC=0.364198 | AUROC=0.837957 | Acc=0.938693 | P=0.727983 | R=0.163415 | Spec=0.974854
#     [FOLD 5] AUPRC=0.363727 | AUROC=0.833434 | Acc=0.941911 | P=0.671495 | R=0.156749 | Spec=0.976307
#
# [TRIAL 05] score(AUPRC_macro)=0.359304 | AUROC=0.841779 | Acc=0.940695 | P=0.657438 | R=0.160213 | Spec=0.976744
# [I 2026-05-07 16:21:56,272] Trial 5 finished with value: 0.3593044003752629 and parameters: {'n_estimators': 896, 'max_depth': 5, 'learning_rate': 0.04749239763680407, 'subsample': 0.8186841117373118, 'colsample_bytree': 0.6739417822102108, 'min_child_weight': 9.129115219600122, 'reg_lambda': 2.1570962503558295, 'reg_alpha': 1.4882404753442915, 'gamma': 4.474136752138244}. Best is trial 0 with value: 0.37858959535624637.
#
# ================================================================================
# [TRIAL 06] params:
# {
#   "objective": "binary:logistic",
#   "eval_metric": "logloss",
#   "tree_method": "hist",
#   "n_jobs": -1,
#   "random_state": 42,
#   "verbosity": 0,
#   "multi_strategy": "multi_output_tree",
#   "n_estimators": 838,
#   "max_depth": 10,
#   "learning_rate": 0.01303561122512888,
#   "subsample": 0.6783931449676581,
#   "colsample_bytree": 0.6180909155642152,
#   "min_child_weight": 1.3250568853729487,
#   "reg_lambda": 0.0469583341176048,
#   "reg_alpha": 2.293280024184598e-06,
#   "gamma": 4.143687545759647
# }
#     [FOLD 1] AUPRC=0.378061 | AUROC=0.851842 | Acc=0.942099 | P=0.666791 | R=0.227904 | Spec=0.973926
#     [FOLD 2] AUPRC=0.370939 | AUROC=0.851497 | Acc=0.941578 | P=0.513005 | R=0.197009 | Spec=0.975766
#     [FOLD 3] AUPRC=0.401665 | AUROC=0.849471 | Acc=0.944186 | P=0.597997 | R=0.234588 | Spec=0.974399
#     [FOLD 4] AUPRC=0.389493 | AUROC=0.847869 | Acc=0.940468 | P=0.621358 | R=0.219817 | Spec=0.972832
#     [FOLD 5] AUPRC=0.389737 | AUROC=0.844987 | Acc=0.943853 | P=0.552211 | R=0.218190 | Spec=0.974775
#
# [TRIAL 06] score(AUPRC_macro)=0.385979 | AUROC=0.849133 | Acc=0.942437 | P=0.590272 | R=0.219502 | Spec=0.974340
# [I 2026-05-07 16:34:22,407] Trial 6 finished with value: 0.3859790363053871 and parameters: {'n_estimators': 838, 'max_depth': 10, 'learning_rate': 0.01303561122512888, 'subsample': 0.6783931449676581, 'colsample_bytree': 0.6180909155642152, 'min_child_weight': 1.3250568853729487, 'reg_lambda': 0.0469583341176048, 'reg_alpha': 2.293280024184598e-06, 'gamma': 4.143687545759647}. Best is trial 6 with value: 0.3859790363053871.
#
# ================================================================================
# [TRIAL 07] params:
# {
#   "objective": "binary:logistic",
#   "eval_metric": "logloss",
#   "tree_method": "hist",
#   "n_jobs": -1,
#   "random_state": 42,
#   "verbosity": 0,
#   "multi_strategy": "multi_output_tree",
#   "n_estimators": 621,
#   "max_depth": 5,
#   "learning_rate": 0.05082341959721458,
#   "subsample": 0.6563696899899051,
#   "colsample_bytree": 0.9208787923016158,
#   "min_child_weight": 0.6251188975400557,
#   "reg_lambda": 17.564278579581362,
#   "reg_alpha": 0.05220764268782494,
#   "gamma": 0.993578407670862
# }
#     [FOLD 1] AUPRC=0.369653 | AUROC=0.857244 | Acc=0.941988 | P=0.721646 | R=0.178510 | Spec=0.975911
#     [FOLD 2] AUPRC=0.366540 | AUROC=0.863146 | Acc=0.941356 | P=0.641386 | R=0.170597 | Spec=0.978407
#     [FOLD 3] AUPRC=0.382835 | AUROC=0.848030 | Acc=0.942188 | P=0.589422 | R=0.170120 | Spec=0.976243
#     [FOLD 4] AUPRC=0.381550 | AUROC=0.846672 | Acc=0.939359 | P=0.697369 | R=0.177565 | Spec=0.973808
#     [FOLD 5] AUPRC=0.385422 | AUROC=0.845109 | Acc=0.943631 | P=0.763426 | R=0.178311 | Spec=0.976829
#
# [TRIAL 07] score(AUPRC_macro)=0.377200 | AUROC=0.852040 | Acc=0.941704 | P=0.682650 | R=0.175021 | Spec=0.976240
# [I 2026-05-07 16:37:26,471] Trial 7 finished with value: 0.3771999260444108 and parameters: {'n_estimators': 621, 'max_depth': 5, 'learning_rate': 0.05082341959721458, 'subsample': 0.6563696899899051, 'colsample_bytree': 0.9208787923016158, 'min_child_weight': 0.6251188975400557, 'reg_lambda': 17.564278579581362, 'reg_alpha': 0.05220764268782494, 'gamma': 0.993578407670862}. Best is trial 6 with value: 0.3859790363053871.
#
# ================================================================================
# [TRIAL 08] params:
# {
#   "objective": "binary:logistic",
#   "eval_metric": "logloss",
#   "tree_method": "hist",
#   "n_jobs": -1,
#   "random_state": 42,
#   "verbosity": 0,
#   "multi_strategy": "multi_output_tree",
#   "n_estimators": 304,
#   "max_depth": 9,
#   "learning_rate": 0.08310795711416077,
#   "subsample": 0.8916028672163949,
#   "colsample_bytree": 0.9085081386743783,
#   "min_child_weight": 0.6241720498669826,
#   "reg_lambda": 0.034815437009482725,
#   "reg_alpha": 1.0184541290289273e-07,
#   "gamma": 4.315517129377968
# }
#     [FOLD 1] AUPRC=0.386731 | AUROC=0.852729 | Acc=0.940658 | P=0.514290 | R=0.243047 | Spec=0.970839
#     [FOLD 2] AUPRC=0.357716 | AUROC=0.851924 | Acc=0.939913 | P=0.493095 | R=0.218064 | Spec=0.972310
#     [FOLD 3] AUPRC=0.405638 | AUROC=0.845478 | Acc=0.944407 | P=0.585233 | R=0.295043 | Spec=0.972211
#     [FOLD 4] AUPRC=0.396016 | AUROC=0.853078 | Acc=0.940024 | P=0.546019 | R=0.255336 | Spec=0.970325
#     [FOLD 5] AUPRC=0.379720 | AUROC=0.839691 | Acc=0.942410 | P=0.453262 | R=0.255517 | Spec=0.971452
#
# [TRIAL 08] score(AUPRC_macro)=0.385164 | AUROC=0.848580 | Acc=0.941483 | P=0.518380 | R=0.253401 | Spec=0.971427
# [I 2026-05-07 16:40:10,010] Trial 8 finished with value: 0.3851642280990296 and parameters: {'n_estimators': 304, 'max_depth': 9, 'learning_rate': 0.08310795711416077, 'subsample': 0.8916028672163949, 'colsample_bytree': 0.9085081386743783, 'min_child_weight': 0.6241720498669826, 'reg_lambda': 0.034815437009482725, 'reg_alpha': 1.0184541290289273e-07, 'gamma': 4.315517129377968}. Best is trial 6 with value: 0.3859790363053871.
#
# ================================================================================
# [TRIAL 09] params:
# {
#   "objective": "binary:logistic",
#   "eval_metric": "logloss",
#   "tree_method": "hist",
#   "n_jobs": -1,
#   "random_state": 42,
#   "verbosity": 0,
#   "multi_strategy": "multi_output_tree",
#   "n_estimators": 861,
#   "max_depth": 5,
#   "learning_rate": 0.012097379927033842,
#   "subsample": 0.7243929286862649,
#   "colsample_bytree": 0.7300733288106989,
#   "min_child_weight": 4.448458336296337,
#   "reg_lambda": 0.5522729957780633,
#   "reg_alpha": 0.5222002015831414,
#   "gamma": 2.3610746258097466
# }
#     [FOLD 1] AUPRC=0.356967 | AUROC=0.853149 | Acc=0.941656 | P=0.766379 | R=0.171544 | Spec=0.977441
#     [FOLD 2] AUPRC=0.350427 | AUROC=0.854617 | Acc=0.939858 | P=0.605835 | R=0.153322 | Spec=0.978895
#     [FOLD 3] AUPRC=0.367710 | AUROC=0.839580 | Acc=0.942466 | P=0.643920 | R=0.164969 | Spec=0.978404
#     [FOLD 4] AUPRC=0.366742 | AUROC=0.836168 | Acc=0.939359 | P=0.685233 | R=0.158836 | Spec=0.976265
#     [FOLD 5] AUPRC=0.372403 | AUROC=0.833585 | Acc=0.942854 | P=0.718705 | R=0.162759 | Spec=0.977946
#
# [TRIAL 09] score(AUPRC_macro)=0.362850 | AUROC=0.843420 | Acc=0.941238 | P=0.684015 | R=0.162286 | Spec=0.977790
# [I 2026-05-07 16:44:19,440] Trial 9 finished with value: 0.3628499448606459 and parameters: {'n_estimators': 861, 'max_depth': 5, 'learning_rate': 0.012097379927033842, 'subsample': 0.7243929286862649, 'colsample_bytree': 0.7300733288106989, 'min_child_weight': 4.448458336296337, 'reg_lambda': 0.5522729957780633, 'reg_alpha': 0.5222002015831414, 'gamma': 2.3610746258097466}. Best is trial 6 with value: 0.3859790363053871.
#
# ================================================================================
# [TRIAL 10] params:
# {
#   "objective": "binary:logistic",
#   "eval_metric": "logloss",
#   "tree_method": "hist",
#   "n_jobs": -1,
#   "random_state": 42,
#   "verbosity": 0,
#   "multi_strategy": "multi_output_tree",
#   "n_estimators": 1159,
#   "max_depth": 8,
#   "learning_rate": 0.02120936045478828,
#   "subsample": 0.6071847502459279,
#   "colsample_bytree": 0.8262452362725613,
#   "min_child_weight": 1.4778843806130162,
#   "reg_lambda": 0.014168088907480319,
#   "reg_alpha": 2.5937967187312596e-05,
#   "gamma": 3.3446220352955045
# }
#     [FOLD 1] AUPRC=0.374014 | AUROC=0.844668 | Acc=0.939883 | P=0.585018 | R=0.234396 | Spec=0.970093
#     [FOLD 2] AUPRC=0.355266 | AUROC=0.842577 | Acc=0.939969 | P=0.432266 | R=0.203163 | Spec=0.972797
#     [FOLD 3] AUPRC=0.390525 | AUROC=0.839728 | Acc=0.943520 | P=0.604271 | R=0.253557 | Spec=0.971781
#     [FOLD 4] AUPRC=0.376501 | AUROC=0.839060 | Acc=0.940135 | P=0.571530 | R=0.230884 | Spec=0.970175
#     [FOLD 5] AUPRC=0.370289 | AUROC=0.836296 | Acc=0.941911 | P=0.507457 | R=0.218881 | Spec=0.971652
#
# [TRIAL 10] score(AUPRC_macro)=0.373319 | AUROC=0.840466 | Acc=0.941083 | P=0.540108 | R=0.228176 | Spec=0.971300
# [I 2026-05-07 16:55:19,282] Trial 10 finished with value: 0.37331879567500686 and parameters: {'n_estimators': 1159, 'max_depth': 8, 'learning_rate': 0.02120936045478828, 'subsample': 0.6071847502459279, 'colsample_bytree': 0.8262452362725613, 'min_child_weight': 1.4778843806130162, 'reg_lambda': 0.014168088907480319, 'reg_alpha': 2.5937967187312596e-05, 'gamma': 3.3446220352955045}. Best is trial 6 with value: 0.3859790363053871.
#
# ================================================================================
# [TRIAL 11] params:
# {
#   "objective": "binary:logistic",
#   "eval_metric": "logloss",
#   "tree_method": "hist",
#   "n_jobs": -1,
#   "random_state": 42,
#   "verbosity": 0,
#   "multi_strategy": "multi_output_tree",
#   "n_estimators": 306,
#   "max_depth": 10,
#   "learning_rate": 0.02567081087626854,
#   "subsample": 0.9732335194426311,
#   "colsample_bytree": 0.9748633637110227,
#   "min_child_weight": 1.2469100666073158,
#   "reg_lambda": 0.05256657291432167,
#   "reg_alpha": 1.4042918934900348e-08,
#   "gamma": 4.991961519082388
# }
#     [FOLD 1] AUPRC=0.392082 | AUROC=0.854445 | Acc=0.940824 | P=0.635409 | R=0.215620 | Spec=0.973001
#     [FOLD 2] AUPRC=0.374394 | AUROC=0.855816 | Acc=0.942077 | P=0.517814 | R=0.202541 | Spec=0.975812
#     [FOLD 3] AUPRC=0.407054 | AUROC=0.854188 | Acc=0.944629 | P=0.708440 | R=0.236908 | Spec=0.975280
#     [FOLD 4] AUPRC=0.403789 | AUROC=0.849475 | Acc=0.940468 | P=0.650641 | R=0.237771 | Spec=0.971744
#     [FOLD 5] AUPRC=0.402082 | AUROC=0.845407 | Acc=0.943242 | P=0.528097 | R=0.226685 | Spec=0.974439
#
# [TRIAL 11] score(AUPRC_macro)=0.395880 | AUROC=0.851866 | Acc=0.942248 | P=0.608080 | R=0.223905 | Spec=0.974055
# [I 2026-05-07 16:59:52,080] Trial 11 finished with value: 0.3958801449708104 and parameters: {'n_estimators': 306, 'max_depth': 10, 'learning_rate': 0.02567081087626854, 'subsample': 0.9732335194426311, 'colsample_bytree': 0.9748633637110227, 'min_child_weight': 1.2469100666073158, 'reg_lambda': 0.05256657291432167, 'reg_alpha': 1.4042918934900348e-08, 'gamma': 4.991961519082388}. Best is trial 11 with value: 0.3958801449708104.
#
# ================================================================================
# [TRIAL 12] params:
# {
#   "objective": "binary:logistic",
#   "eval_metric": "logloss",
#   "tree_method": "hist",
#   "n_jobs": -1,
#   "random_state": 42,
#   "verbosity": 0,
#   "multi_strategy": "multi_output_tree",
#   "n_estimators": 314,
#   "max_depth": 10,
#   "learning_rate": 0.02454989860396554,
#   "subsample": 0.9867601240041175,
#   "colsample_bytree": 0.9978853691332172,
#   "min_child_weight": 1.3368334126711403,
#   "reg_lambda": 0.2955001088989606,
#   "reg_alpha": 1.959578228249567e-08,
#   "gamma": 4.9566801520194055
# }
#     [FOLD 1] AUPRC=0.386941 | AUROC=0.852285 | Acc=0.941102 | P=0.653773 | R=0.221597 | Spec=0.973026
#     [FOLD 2] AUPRC=0.375949 | AUROC=0.856121 | Acc=0.941522 | P=0.485798 | R=0.196897 | Spec=0.975834
#     [FOLD 3] AUPRC=0.401727 | AUROC=0.851597 | Acc=0.944075 | P=0.682085 | R=0.237258 | Spec=0.974638
#     [FOLD 4] AUPRC=0.403624 | AUROC=0.848205 | Acc=0.940413 | P=0.669610 | R=0.225202 | Spec=0.972195
#     [FOLD 5] AUPRC=0.408052 | AUROC=0.845443 | Acc=0.943409 | P=0.568871 | R=0.212964 | Spec=0.974995
#
# [TRIAL 12] score(AUPRC_macro)=0.395258 | AUROC=0.850730 | Acc=0.942104 | P=0.612028 | R=0.218784 | Spec=0.974138
# [I 2026-05-07 17:04:39,821] Trial 12 finished with value: 0.39525841576494253 and parameters: {'n_estimators': 314, 'max_depth': 10, 'learning_rate': 0.02454989860396554, 'subsample': 0.9867601240041175, 'colsample_bytree': 0.9978853691332172, 'min_child_weight': 1.3368334126711403, 'reg_lambda': 0.2955001088989606, 'reg_alpha': 1.959578228249567e-08, 'gamma': 4.9566801520194055}. Best is trial 11 with value: 0.3958801449708104.
#
# ================================================================================
# [TRIAL 13] params:
# {
#   "objective": "binary:logistic",
#   "eval_metric": "logloss",
#   "tree_method": "hist",
#   "n_jobs": -1,
#   "random_state": 42,
#   "verbosity": 0,
#   "multi_strategy": "multi_output_tree",
#   "n_estimators": 316,
#   "max_depth": 9,
#   "learning_rate": 0.026794506480027357,
#   "subsample": 0.9997449754566206,
#   "colsample_bytree": 0.9943311582387746,
#   "min_child_weight": 3.1373621157982865,
#   "reg_lambda": 0.3285454464523439,
#   "reg_alpha": 1.708423628613354e-08,
#   "gamma": 4.9901290709394335
# }
#     [FOLD 1] AUPRC=0.381198 | AUROC=0.848493 | Acc=0.941434 | P=0.702722 | R=0.194051 | Spec=0.975445
#     [FOLD 2] AUPRC=0.360975 | AUROC=0.855631 | Acc=0.940135 | P=0.561525 | R=0.187403 | Spec=0.975740
#     [FOLD 3] AUPRC=0.395983 | AUROC=0.849176 | Acc=0.944130 | P=0.632996 | R=0.207684 | Spec=0.977139
#     [FOLD 4] AUPRC=0.375650 | AUROC=0.845205 | Acc=0.939359 | P=0.650068 | R=0.196513 | Spec=0.972585
#     [FOLD 5] AUPRC=0.393216 | AUROC=0.842789 | Acc=0.944130 | P=0.633093 | R=0.208473 | Spec=0.977345
#
# [TRIAL 13] score(AUPRC_macro)=0.381404 | AUROC=0.848259 | Acc=0.941838 | P=0.636081 | R=0.198825 | Spec=0.975651
# [I 2026-05-07 17:07:53,948] Trial 13 finished with value: 0.3814043115964393 and parameters: {'n_estimators': 316, 'max_depth': 9, 'learning_rate': 0.026794506480027357, 'subsample': 0.9997449754566206, 'colsample_bytree': 0.9943311582387746, 'min_child_weight': 3.1373621157982865, 'reg_lambda': 0.3285454464523439, 'reg_alpha': 1.708423628613354e-08, 'gamma': 4.9901290709394335}. Best is trial 11 with value: 0.3958801449708104.
#
# ================================================================================
# [TRIAL 14] params:
# {
#   "objective": "binary:logistic",
#   "eval_metric": "logloss",
#   "tree_method": "hist",
#   "n_jobs": -1,
#   "random_state": 42,
#   "verbosity": 0,
#   "multi_strategy": "multi_output_tree",
#   "n_estimators": 445,
#   "max_depth": 8,
#   "learning_rate": 0.03048135367065171,
#   "subsample": 0.9984067957444854,
#   "colsample_bytree": 0.999789368911463,
#   "min_child_weight": 1.080549657407865,
#   "reg_lambda": 1.0356019628611641,
#   "reg_alpha": 0.0009239851891071016,
#   "gamma": 4.7756131651200615
# }
#     [FOLD 1] AUPRC=0.390158 | AUROC=0.856029 | Acc=0.940824 | P=0.679900 | R=0.216741 | Spec=0.973464
#     [FOLD 2] AUPRC=0.378827 | AUROC=0.858970 | Acc=0.941744 | P=0.524102 | R=0.204292 | Spec=0.976096
#     [FOLD 3] AUPRC=0.405845 | AUROC=0.853231 | Acc=0.944518 | P=0.664782 | R=0.241234 | Spec=0.974750
#     [FOLD 4] AUPRC=0.399186 | AUROC=0.847709 | Acc=0.941300 | P=0.639901 | R=0.223758 | Spec=0.972695
#     [FOLD 5] AUPRC=0.402226 | AUROC=0.849407 | Acc=0.943520 | P=0.600420 | R=0.224226 | Spec=0.974761
#
# [TRIAL 14] score(AUPRC_macro)=0.395248 | AUROC=0.853069 | Acc=0.942381 | P=0.621821 | R=0.222050 | Spec=0.974353
# [I 2026-05-07 17:11:24,514] Trial 14 finished with value: 0.39524843296345075 and parameters: {'n_estimators': 445, 'max_depth': 8, 'learning_rate': 0.03048135367065171, 'subsample': 0.9984067957444854, 'colsample_bytree': 0.999789368911463, 'min_child_weight': 1.080549657407865, 'reg_lambda': 1.0356019628611641, 'reg_alpha': 0.0009239851891071016, 'gamma': 4.7756131651200615}. Best is trial 11 with value: 0.3958801449708104.
#
# ================================================================================
# [TRIAL 15] params:
# {
#   "objective": "binary:logistic",
#   "eval_metric": "logloss",
#   "tree_method": "hist",
#   "n_jobs": -1,
#   "random_state": 42,
#   "verbosity": 0,
#   "multi_strategy": "multi_output_tree",
#   "n_estimators": 471,
#   "max_depth": 10,
#   "learning_rate": 0.018748612143601875,
#   "subsample": 0.9407328365449625,
#   "colsample_bytree": 0.9258360514720573,
#   "min_child_weight": 2.2593490054065106,
#   "reg_lambda": 0.2415392988659889,
#   "reg_alpha": 1.0605009015749573e-08,
#   "gamma": 3.8470209237636586
# }
#     [FOLD 1] AUPRC=0.382255 | AUROC=0.853634 | Acc=0.941822 | P=0.616309 | R=0.211460 | Spec=0.974616
#     [FOLD 2] AUPRC=0.368626 | AUROC=0.853879 | Acc=0.940968 | P=0.500665 | R=0.195690 | Spec=0.975208
#     [FOLD 3] AUPRC=0.399215 | AUROC=0.849808 | Acc=0.943908 | P=0.661731 | R=0.231785 | Spec=0.975089
#     [FOLD 4] AUPRC=0.392309 | AUROC=0.851316 | Acc=0.939747 | P=0.636144 | R=0.215075 | Spec=0.971669
#     [FOLD 5] AUPRC=0.384077 | AUROC=0.843755 | Acc=0.944851 | P=0.617265 | R=0.216733 | Spec=0.975681
#
# [TRIAL 15] score(AUPRC_macro)=0.385296 | AUROC=0.850479 | Acc=0.942259 | P=0.606423 | R=0.214149 | Spec=0.974453
# [I 2026-05-07 17:18:00,217] Trial 15 finished with value: 0.3852963174931025 and parameters: {'n_estimators': 471, 'max_depth': 10, 'learning_rate': 0.018748612143601875, 'subsample': 0.9407328365449625, 'colsample_bytree': 0.9258360514720573, 'min_child_weight': 2.2593490054065106, 'reg_lambda': 0.2415392988659889, 'reg_alpha': 1.0605009015749573e-08, 'gamma': 3.8470209237636586}. Best is trial 11 with value: 0.3958801449708104.
#
# ================================================================================
# [TRIAL 16] params:
# {
#   "objective": "binary:logistic",
#   "eval_metric": "logloss",
#   "tree_method": "hist",
#   "n_jobs": -1,
#   "random_state": 42,
#   "verbosity": 0,
#   "multi_strategy": "multi_output_tree",
#   "n_estimators": 431,
#   "max_depth": 9,
#   "learning_rate": 0.03653540677297512,
#   "subsample": 0.9349228961551378,
#   "colsample_bytree": 0.8517314664119262,
#   "min_child_weight": 2.3460579849079886,
#   "reg_lambda": 2.655963324975414,
#   "reg_alpha": 3.2347594895094473e-07,
#   "gamma": 0.06589607190461733
# }
#     [FOLD 1] AUPRC=0.385455 | AUROC=0.851451 | Acc=0.940603 | P=0.554264 | R=0.213031 | Spec=0.971875
#     [FOLD 2] AUPRC=0.367419 | AUROC=0.855054 | Acc=0.941134 | P=0.541459 | R=0.202633 | Spec=0.974361
#     [FOLD 3] AUPRC=0.399429 | AUROC=0.851457 | Acc=0.944130 | P=0.681597 | R=0.236249 | Spec=0.973756
#     [FOLD 4] AUPRC=0.397299 | AUROC=0.849258 | Acc=0.940024 | P=0.682495 | R=0.231385 | Spec=0.970777
#     [FOLD 5] AUPRC=0.392431 | AUROC=0.841864 | Acc=0.943853 | P=0.579313 | R=0.219675 | Spec=0.973525
#
# [TRIAL 16] score(AUPRC_macro)=0.388407 | AUROC=0.849817 | Acc=0.941949 | P=0.607826 | R=0.220595 | Spec=0.972859
# [I 2026-05-07 17:27:46,317] Trial 16 finished with value: 0.3884066174935613 and parameters: {'n_estimators': 431, 'max_depth': 9, 'learning_rate': 0.03653540677297512, 'subsample': 0.9349228961551378, 'colsample_bytree': 0.8517314664119262, 'min_child_weight': 2.3460579849079886, 'reg_lambda': 2.655963324975414, 'reg_alpha': 3.2347594895094473e-07, 'gamma': 0.06589607190461733}. Best is trial 11 with value: 0.3958801449708104.
#
# ================================================================================
# [TRIAL 17] params:
# {
#   "objective": "binary:logistic",
#   "eval_metric": "logloss",
#   "tree_method": "hist",
#   "n_jobs": -1,
#   "random_state": 42,
#   "verbosity": 0,
#   "multi_strategy": "multi_output_tree",
#   "n_estimators": 516,
#   "max_depth": 7,
#   "learning_rate": 0.01830617664909081,
#   "subsample": 0.8954582514940983,
#   "colsample_bytree": 0.9612381377327339,
#   "min_child_weight": 5.044173409237846,
#   "reg_lambda": 0.10793806342203977,
#   "reg_alpha": 0.00034828131066813264,
#   "gamma": 3.5091356706473498
# }
#     [FOLD 1] AUPRC=0.369319 | AUROC=0.854056 | Acc=0.941988 | P=0.659845 | R=0.185693 | Spec=0.976800
#     [FOLD 2] AUPRC=0.362318 | AUROC=0.856642 | Acc=0.940024 | P=0.592857 | R=0.162400 | Spec=0.977617
#     [FOLD 3] AUPRC=0.381919 | AUROC=0.840276 | Acc=0.942022 | P=0.541911 | R=0.169882 | Spec=0.976881
#     [FOLD 4] AUPRC=0.374793 | AUROC=0.840374 | Acc=0.939969 | P=0.709511 | R=0.181705 | Spec=0.974484
#     [FOLD 5] AUPRC=0.379615 | AUROC=0.834752 | Acc=0.943464 | P=0.629228 | R=0.191076 | Spec=0.976299
#
# [TRIAL 17] score(AUPRC_macro)=0.373593 | AUROC=0.845220 | Acc=0.941493 | P=0.626670 | R=0.178151 | Spec=0.976416
# [I 2026-05-07 17:31:34,847] Trial 17 finished with value: 0.37359301782439597 and parameters: {'n_estimators': 516, 'max_depth': 7, 'learning_rate': 0.01830617664909081, 'subsample': 0.8954582514940983, 'colsample_bytree': 0.9612381377327339, 'min_child_weight': 5.044173409237846, 'reg_lambda': 0.10793806342203977, 'reg_alpha': 0.00034828131066813264, 'gamma': 3.5091356706473498}. Best is trial 11 with value: 0.3958801449708104.
#
# ================================================================================
# [TRIAL 18] params:
# {
#   "objective": "binary:logistic",
#   "eval_metric": "logloss",
#   "tree_method": "hist",
#   "n_jobs": -1,
#   "random_state": 42,
#   "verbosity": 0,
#   "multi_strategy": "multi_output_tree",
#   "n_estimators": 382,
#   "max_depth": 8,
#   "learning_rate": 0.026128449853797624,
#   "subsample": 0.9692417844390309,
#   "colsample_bytree": 0.8799942704006583,
#   "min_child_weight": 1.172545322380691,
#   "reg_lambda": 0.008269783500035634,
#   "reg_alpha": 1.374793161147017e-07,
#   "gamma": 1.9964732415940314
# }
#     [FOLD 1] AUPRC=0.385589 | AUROC=0.856065 | Acc=0.941323 | P=0.597378 | R=0.229234 | Spec=0.972960
#     [FOLD 2] AUPRC=0.368327 | AUROC=0.854920 | Acc=0.942688 | P=0.514330 | R=0.208341 | Spec=0.977191
#     [FOLD 3] AUPRC=0.399410 | AUROC=0.851387 | Acc=0.944463 | P=0.683959 | R=0.245907 | Spec=0.974250
#     [FOLD 4] AUPRC=0.405395 | AUROC=0.851552 | Acc=0.941578 | P=0.670006 | R=0.233720 | Spec=0.973250
#     [FOLD 5] AUPRC=0.398779 | AUROC=0.851384 | Acc=0.942854 | P=0.557702 | R=0.229017 | Spec=0.973862
#
# [TRIAL 18] score(AUPRC_macro)=0.391500 | AUROC=0.853062 | Acc=0.942581 | P=0.604675 | R=0.229244 | Spec=0.974303
# [I 2026-05-07 17:35:54,894] Trial 18 finished with value: 0.3915000383866843 and parameters: {'n_estimators': 382, 'max_depth': 8, 'learning_rate': 0.026128449853797624, 'subsample': 0.9692417844390309, 'colsample_bytree': 0.8799942704006583, 'min_child_weight': 1.172545322380691, 'reg_lambda': 0.008269783500035634, 'reg_alpha': 1.374793161147017e-07, 'gamma': 1.9964732415940314}. Best is trial 11 with value: 0.3958801449708104.
#
# ================================================================================
# [TRIAL 19] params:
# {
#   "objective": "binary:logistic",
#   "eval_metric": "logloss",
#   "tree_method": "hist",
#   "n_jobs": -1,
#   "random_state": 42,
#   "verbosity": 0,
#   "multi_strategy": "multi_output_tree",
#   "n_estimators": 1026,
#   "max_depth": 10,
#   "learning_rate": 0.13939811999819263,
#   "subsample": 0.8841970179104862,
#   "colsample_bytree": 0.764088169035724,
#   "min_child_weight": 1.7558803279686024,
#   "reg_lambda": 0.01934006617009238,
#   "reg_alpha": 0.0039029897289188063,
#   "gamma": 4.913165676406196
# }
#     [FOLD 1] AUPRC=0.386311 | AUROC=0.845848 | Acc=0.940160 | P=0.595820 | R=0.246089 | Spec=0.969564
#     [FOLD 2] AUPRC=0.370246 | AUROC=0.846798 | Acc=0.940191 | P=0.401841 | R=0.217291 | Spec=0.972886
#     [FOLD 3] AUPRC=0.379269 | AUROC=0.839436 | Acc=0.943908 | P=0.517252 | R=0.273017 | Spec=0.971669
#     [FOLD 4] AUPRC=0.388993 | AUROC=0.840641 | Acc=0.940579 | P=0.581226 | R=0.257296 | Spec=0.969262
#     [FOLD 5] AUPRC=0.365400 | AUROC=0.836058 | Acc=0.942798 | P=0.513446 | R=0.247395 | Spec=0.971277
#
# [TRIAL 19] score(AUPRC_macro)=0.378044 | AUROC=0.841756 | Acc=0.941527 | P=0.521917 | R=0.248217 | Spec=0.970932
# [I 2026-05-07 17:38:45,256] Trial 19 finished with value: 0.37804359113080005 and parameters: {'n_estimators': 1026, 'max_depth': 10, 'learning_rate': 0.13939811999819263, 'subsample': 0.8841970179104862, 'colsample_bytree': 0.764088169035724, 'min_child_weight': 1.7558803279686024, 'reg_lambda': 0.01934006617009238, 'reg_alpha': 0.0039029897289188063, 'gamma': 4.913165676406196}. Best is trial 11 with value: 0.3958801449708104.
#
# ================================================================================
# [TRIAL 20] params:
# {
#   "objective": "binary:logistic",
#   "eval_metric": "logloss",
#   "tree_method": "hist",
#   "n_jobs": -1,
#   "random_state": 42,
#   "verbosity": 0,
#   "multi_strategy": "multi_output_tree",
#   "n_estimators": 376,
#   "max_depth": 6,
#   "learning_rate": 0.03847926256643271,
#   "subsample": 0.7649909107919399,
#   "colsample_bytree": 0.9539435857285904,
#   "min_child_weight": 0.9337788982827928,
#   "reg_lambda": 5.309314647179563,
#   "reg_alpha": 2.253079742753112e-05,
#   "gamma": 3.5835953820045923
# }
#     [FOLD 1] AUPRC=0.380987 | AUROC=0.852896 | Acc=0.941489 | P=0.649098 | R=0.187270 | Spec=0.975362
#     [FOLD 2] AUPRC=0.364157 | AUROC=0.862237 | Acc=0.941190 | P=0.571212 | R=0.178672 | Spec=0.977831
#     [FOLD 3] AUPRC=0.392563 | AUROC=0.851557 | Acc=0.944296 | P=0.672283 | R=0.200231 | Spec=0.977406
#     [FOLD 4] AUPRC=0.387054 | AUROC=0.847996 | Acc=0.940135 | P=0.742340 | R=0.184246 | Spec=0.974266
#     [FOLD 5] AUPRC=0.391560 | AUROC=0.847051 | Acc=0.943353 | P=0.709727 | R=0.184668 | Spec=0.976450
#
# [TRIAL 20] score(AUPRC_macro)=0.383264 | AUROC=0.852347 | Acc=0.942093 | P=0.668932 | R=0.187018 | Spec=0.976263
# [I 2026-05-07 17:40:58,849] Trial 20 finished with value: 0.38326445599184844 and parameters: {'n_estimators': 376, 'max_depth': 6, 'learning_rate': 0.03847926256643271, 'subsample': 0.7649909107919399, 'colsample_bytree': 0.9539435857285904, 'min_child_weight': 0.9337788982827928, 'reg_lambda': 5.309314647179563, 'reg_alpha': 2.253079742753112e-05, 'gamma': 3.5835953820045923}. Best is trial 11 with value: 0.3958801449708104.
#
# ================================================================================
# [TRIAL 21] params:
# {
#   "objective": "binary:logistic",
#   "eval_metric": "logloss",
#   "tree_method": "hist",
#   "n_jobs": -1,
#   "random_state": 42,
#   "verbosity": 0,
#   "multi_strategy": "multi_output_tree",
#   "n_estimators": 517,
#   "max_depth": 8,
#   "learning_rate": 0.03177228176607785,
#   "subsample": 0.9960831961151186,
#   "colsample_bytree": 0.99767408384934,
#   "min_child_weight": 1.1108801228578953,
#   "reg_lambda": 0.628019565369673,
#   "reg_alpha": 0.0013632921693974133,
#   "gamma": 4.766850801201148
# }
#     [FOLD 1] AUPRC=0.390513 | AUROC=0.854521 | Acc=0.941268 | P=0.640978 | R=0.222206 | Spec=0.973389
#     [FOLD 2] AUPRC=0.374969 | AUROC=0.858458 | Acc=0.941855 | P=0.534102 | R=0.205949 | Spec=0.976446
#     [FOLD 3] AUPRC=0.402250 | AUROC=0.853109 | Acc=0.944629 | P=0.669378 | R=0.245396 | Spec=0.974867
#     [FOLD 4] AUPRC=0.402348 | AUROC=0.849683 | Acc=0.940968 | P=0.650127 | R=0.229411 | Spec=0.972937
#     [FOLD 5] AUPRC=0.402073 | AUROC=0.849860 | Acc=0.943242 | P=0.612876 | R=0.223422 | Spec=0.974517
#
# [TRIAL 21] score(AUPRC_macro)=0.394430 | AUROC=0.853126 | Acc=0.942392 | P=0.621492 | R=0.225277 | Spec=0.974431
# [I 2026-05-07 17:44:53,960] Trial 21 finished with value: 0.3944304392690059 and parameters: {'n_estimators': 517, 'max_depth': 8, 'learning_rate': 0.03177228176607785, 'subsample': 0.9960831961151186, 'colsample_bytree': 0.99767408384934, 'min_child_weight': 1.1108801228578953, 'reg_lambda': 0.628019565369673, 'reg_alpha': 0.0013632921693974133, 'gamma': 4.766850801201148}. Best is trial 11 with value: 0.3958801449708104.
#
# ================================================================================
# [TRIAL 22] params:
# {
#   "objective": "binary:logistic",
#   "eval_metric": "logloss",
#   "tree_method": "hist",
#   "n_jobs": -1,
#   "random_state": 42,
#   "verbosity": 0,
#   "multi_strategy": "multi_output_tree",
#   "n_estimators": 397,
#   "max_depth": 9,
#   "learning_rate": 0.01568001200576774,
#   "subsample": 0.9540403305438755,
#   "colsample_bytree": 0.9673050570336588,
#   "min_child_weight": 1.8389296637350332,
#   "reg_lambda": 1.162966243093593,
#   "reg_alpha": 8.252948285968884e-07,
#   "gamma": 4.541705333012385
# }
#     [FOLD 1] AUPRC=0.384411 | AUROC=0.852233 | Acc=0.941379 | P=0.696089 | R=0.196962 | Spec=0.975034
#     [FOLD 2] AUPRC=0.374922 | AUROC=0.855982 | Acc=0.941190 | P=0.553785 | R=0.182871 | Spec=0.977536
#     [FOLD 3] AUPRC=0.395770 | AUROC=0.849188 | Acc=0.943964 | P=0.673816 | R=0.206199 | Spec=0.977542
#     [FOLD 4] AUPRC=0.387515 | AUROC=0.849155 | Acc=0.940080 | P=0.645541 | R=0.188504 | Spec=0.973492
#     [FOLD 5] AUPRC=0.394458 | AUROC=0.839561 | Acc=0.943298 | P=0.627651 | R=0.207802 | Spec=0.976305
#
# [TRIAL 22] score(AUPRC_macro)=0.387415 | AUROC=0.849224 | Acc=0.941982 | P=0.639377 | R=0.196468 | Spec=0.975982
# [I 2026-05-07 17:50:21,602] Trial 22 finished with value: 0.38741535229178015 and parameters: {'n_estimators': 397, 'max_depth': 9, 'learning_rate': 0.01568001200576774, 'subsample': 0.9540403305438755, 'colsample_bytree': 0.9673050570336588, 'min_child_weight': 1.8389296637350332, 'reg_lambda': 1.162966243093593, 'reg_alpha': 8.252948285968884e-07, 'gamma': 4.541705333012385}. Best is trial 11 with value: 0.3958801449708104.
#
# ================================================================================
# [TRIAL 23] params:
# {
#   "objective": "binary:logistic",
#   "eval_metric": "logloss",
#   "tree_method": "hist",
#   "n_jobs": -1,
#   "random_state": 42,
#   "verbosity": 0,
#   "multi_strategy": "multi_output_tree",
#   "n_estimators": 325,
#   "max_depth": 8,
#   "learning_rate": 0.02425317120935874,
#   "subsample": 0.9789397807476168,
#   "colsample_bytree": 0.8830840730066526,
#   "min_child_weight": 1.0703705694996188,
#   "reg_lambda": 0.16486435797775392,
#   "reg_alpha": 5.099983103104849e-05,
#   "gamma": 4.463793201875562
# }
#     [FOLD 1] AUPRC=0.389800 | AUROC=0.858281 | Acc=0.941545 | P=0.623248 | R=0.214434 | Spec=0.974108
#     [FOLD 2] AUPRC=0.369473 | AUROC=0.859152 | Acc=0.941190 | P=0.547197 | R=0.189113 | Spec=0.977121
#     [FOLD 3] AUPRC=0.406886 | AUROC=0.853463 | Acc=0.944407 | P=0.668066 | R=0.234275 | Spec=0.976042
#     [FOLD 4] AUPRC=0.400040 | AUROC=0.850864 | Acc=0.940191 | P=0.659752 | R=0.218532 | Spec=0.972850
#     [FOLD 5] AUPRC=0.406906 | AUROC=0.848606 | Acc=0.943353 | P=0.584404 | R=0.212011 | Spec=0.975975
#
# [TRIAL 23] score(AUPRC_macro)=0.394621 | AUROC=0.854073 | Acc=0.942137 | P=0.616534 | R=0.213673 | Spec=0.975219
# [I 2026-05-07 17:53:49,951] Trial 23 finished with value: 0.3946211584322597 and parameters: {'n_estimators': 325, 'max_depth': 8, 'learning_rate': 0.02425317120935874, 'subsample': 0.9789397807476168, 'colsample_bytree': 0.8830840730066526, 'min_child_weight': 1.0703705694996188, 'reg_lambda': 0.16486435797775392, 'reg_alpha': 5.099983103104849e-05, 'gamma': 4.463793201875562}. Best is trial 11 with value: 0.3958801449708104.
#
# ================================================================================
# [TRIAL 24] params:
# {
#   "objective": "binary:logistic",
#   "eval_metric": "logloss",
#   "tree_method": "hist",
#   "n_jobs": -1,
#   "random_state": 42,
#   "verbosity": 0,
#   "multi_strategy": "multi_output_tree",
#   "n_estimators": 472,
#   "max_depth": 9,
#   "learning_rate": 0.03173634651134353,
#   "subsample": 0.9234170576833637,
#   "colsample_bytree": 0.9981331860597691,
#   "min_child_weight": 3.3339118345899283,
#   "reg_lambda": 0.6463290546387064,
#   "reg_alpha": 4.274050634780337e-08,
#   "gamma": 4.935376534702555
# }
#     [FOLD 1] AUPRC=0.379822 | AUROC=0.849446 | Acc=0.941988 | P=0.654061 | R=0.200237 | Spec=0.974613
#     [FOLD 2] AUPRC=0.360316 | AUROC=0.854560 | Acc=0.940912 | P=0.552846 | R=0.184981 | Spec=0.976059
#     [FOLD 3] AUPRC=0.392927 | AUROC=0.846615 | Acc=0.943797 | P=0.664421 | R=0.215508 | Spec=0.975856
#     [FOLD 4] AUPRC=0.378877 | AUROC=0.847214 | Acc=0.940413 | P=0.648971 | R=0.199720 | Spec=0.972937
#     [FOLD 5] AUPRC=0.384928 | AUROC=0.842727 | Acc=0.944407 | P=0.612484 | R=0.208853 | Spec=0.975694
#
# [TRIAL 24] score(AUPRC_macro)=0.379374 | AUROC=0.848112 | Acc=0.942304 | P=0.626557 | R=0.201860 | Spec=0.975032
# [I 2026-05-07 17:57:51,174] Trial 24 finished with value: 0.37937413831021244 and parameters: {'n_estimators': 472, 'max_depth': 9, 'learning_rate': 0.03173634651134353, 'subsample': 0.9234170576833637, 'colsample_bytree': 0.9981331860597691, 'min_child_weight': 3.3339118345899283, 'reg_lambda': 0.6463290546387064, 'reg_alpha': 4.274050634780337e-08, 'gamma': 4.935376534702555}. Best is trial 11 with value: 0.3958801449708104.
#
# ================================================================================
# [TRIAL 25] params:
# {
#   "objective": "binary:logistic",
#   "eval_metric": "logloss",
#   "tree_method": "hist",
#   "n_jobs": -1,
#   "random_state": 42,
#   "verbosity": 0,
#   "multi_strategy": "multi_output_tree",
#   "n_estimators": 554,
#   "max_depth": 10,
#   "learning_rate": 0.016487337592334242,
#   "subsample": 0.966470221226457,
#   "colsample_bytree": 0.9508508638890715,
#   "min_child_weight": 0.5038898791720519,
#   "reg_lambda": 0.05379411257185619,
#   "reg_alpha": 0.0031004778230525657,
#   "gamma": 3.7946626315010414
# }
#     [FOLD 1] AUPRC=0.394834 | AUROC=0.863312 | Acc=0.940160 | P=0.548774 | R=0.231361 | Spec=0.971914
#     [FOLD 2] AUPRC=0.369892 | AUROC=0.862811 | Acc=0.941245 | P=0.500113 | R=0.212094 | Spec=0.974909
#     [FOLD 3] AUPRC=0.408543 | AUROC=0.849495 | Acc=0.944796 | P=0.691259 | R=0.260721 | Spec=0.974019
#     [FOLD 4] AUPRC=0.402046 | AUROC=0.853595 | Acc=0.940635 | P=0.628313 | R=0.257278 | Spec=0.970660
#     [FOLD 5] AUPRC=0.391074 | AUROC=0.849845 | Acc=0.942410 | P=0.480798 | R=0.239571 | Spec=0.973013
#
# [TRIAL 25] score(AUPRC_macro)=0.393278 | AUROC=0.855812 | Acc=0.941849 | P=0.569851 | R=0.240205 | Spec=0.972903
# [I 2026-05-07 18:08:04,739] Trial 25 finished with value: 0.393277959986265 and parameters: {'n_estimators': 554, 'max_depth': 10, 'learning_rate': 0.016487337592334242, 'subsample': 0.966470221226457, 'colsample_bytree': 0.9508508638890715, 'min_child_weight': 0.5038898791720519, 'reg_lambda': 0.05379411257185619, 'reg_alpha': 0.0031004778230525657, 'gamma': 3.7946626315010414}. Best is trial 11 with value: 0.3958801449708104.
#
# ================================================================================
# [TRIAL 26] params:
# {
#   "objective": "binary:logistic",
#   "eval_metric": "logloss",
#   "tree_method": "hist",
#   "n_jobs": -1,
#   "random_state": 42,
#   "verbosity": 0,
#   "multi_strategy": "multi_output_tree",
#   "n_estimators": 439,
#   "max_depth": 7,
#   "learning_rate": 0.04216377257298697,
#   "subsample": 0.9044864806656665,
#   "colsample_bytree": 0.8073119087982856,
#   "min_child_weight": 0.7955240922680049,
#   "reg_lambda": 2.271454128184116,
#   "reg_alpha": 0.0004310551660237596,
#   "gamma": 3.0529691892605886
# }
#     [FOLD 1] AUPRC=0.392950 | AUROC=0.856439 | Acc=0.941489 | P=0.671691 | R=0.217991 | Spec=0.973156
#     [FOLD 2] AUPRC=0.376348 | AUROC=0.860436 | Acc=0.941855 | P=0.494244 | R=0.195576 | Spec=0.976728
#     [FOLD 3] AUPRC=0.403521 | AUROC=0.852935 | Acc=0.944296 | P=0.638999 | R=0.234380 | Spec=0.974665
#     [FOLD 4] AUPRC=0.403374 | AUROC=0.851387 | Acc=0.940524 | P=0.600025 | R=0.228207 | Spec=0.972078
#     [FOLD 5] AUPRC=0.399766 | AUROC=0.852200 | Acc=0.943353 | P=0.577297 | R=0.205418 | Spec=0.974496
#
# [TRIAL 26] score(AUPRC_macro)=0.395192 | AUROC=0.854679 | Acc=0.942304 | P=0.596451 | R=0.216315 | Spec=0.974224
# [I 2026-05-07 18:11:06,366] Trial 26 finished with value: 0.39519177773176445 and parameters: {'n_estimators': 439, 'max_depth': 7, 'learning_rate': 0.04216377257298697, 'subsample': 0.9044864806656665, 'colsample_bytree': 0.8073119087982856, 'min_child_weight': 0.7955240922680049, 'reg_lambda': 2.271454128184116, 'reg_alpha': 0.0004310551660237596, 'gamma': 3.0529691892605886}. Best is trial 11 with value: 0.3958801449708104.
#
# ================================================================================
# [TRIAL 27] params:
# {
#   "objective": "binary:logistic",
#   "eval_metric": "logloss",
#   "tree_method": "hist",
#   "n_jobs": -1,
#   "random_state": 42,
#   "verbosity": 0,
#   "multi_strategy": "multi_output_tree",
#   "n_estimators": 355,
#   "max_depth": 9,
#   "learning_rate": 0.030424282796330426,
#   "subsample": 0.8671713014234984,
#   "colsample_bytree": 0.8912101550266425,
#   "min_child_weight": 1.7001555365163998,
#   "reg_lambda": 0.2457068838104057,
#   "reg_alpha": 5.027130366125299e-06,
#   "gamma": 4.630690612206038
# }
#     [FOLD 1] AUPRC=0.381198 | AUROC=0.848478 | Acc=0.940935 | P=0.640405 | R=0.214565 | Spec=0.973226
#     [FOLD 2] AUPRC=0.366100 | AUROC=0.851682 | Acc=0.941300 | P=0.517538 | R=0.201822 | Spec=0.975406
#     [FOLD 3] AUPRC=0.401357 | AUROC=0.848188 | Acc=0.943298 | P=0.606933 | R=0.234151 | Spec=0.974152
#     [FOLD 4] AUPRC=0.397544 | AUROC=0.850330 | Acc=0.940413 | P=0.657109 | R=0.223116 | Spec=0.972361
#     [FOLD 5] AUPRC=0.395528 | AUROC=0.843696 | Acc=0.943797 | P=0.565440 | R=0.211426 | Spec=0.975256
#
# [TRIAL 27] score(AUPRC_macro)=0.388345 | AUROC=0.848475 | Acc=0.941949 | P=0.597485 | R=0.217016 | Spec=0.974080
# [I 2026-05-07 18:14:53,314] Trial 27 finished with value: 0.3883454498058784 and parameters: {'n_estimators': 355, 'max_depth': 9, 'learning_rate': 0.030424282796330426, 'subsample': 0.8671713014234984, 'colsample_bytree': 0.8912101550266425, 'min_child_weight': 1.7001555365163998, 'reg_lambda': 0.2457068838104057, 'reg_alpha': 5.027130366125299e-06, 'gamma': 4.630690612206038}. Best is trial 11 with value: 0.3958801449708104.
#
# ================================================================================
# [TRIAL 28] params:
# {
#   "objective": "binary:logistic",
#   "eval_metric": "logloss",
#   "tree_method": "hist",
#   "n_jobs": -1,
#   "random_state": 42,
#   "verbosity": 0,
#   "multi_strategy": "multi_output_tree",
#   "n_estimators": 305,
#   "max_depth": 6,
#   "learning_rate": 0.021950999007515883,
#   "subsample": 0.9808273321681361,
#   "colsample_bytree": 0.9384639364567751,
#   "min_child_weight": 1.2942503008408657,
#   "reg_lambda": 1.441945030227182,
#   "reg_alpha": 0.013554636682826459,
#   "gamma": 4.11346060715257
# }
#     [FOLD 1] AUPRC=0.381678 | AUROC=0.855476 | Acc=0.940935 | P=0.643675 | R=0.183513 | Spec=0.976533
#     [FOLD 2] AUPRC=0.368130 | AUROC=0.860925 | Acc=0.939858 | P=0.600819 | R=0.171270 | Spec=0.977650
#     [FOLD 3] AUPRC=0.393497 | AUROC=0.850379 | Acc=0.943298 | P=0.719050 | R=0.192349 | Spec=0.978460
#     [FOLD 4] AUPRC=0.391479 | AUROC=0.844944 | Acc=0.940024 | P=0.718536 | R=0.175389 | Spec=0.976059
#     [FOLD 5] AUPRC=0.392580 | AUROC=0.846578 | Acc=0.942854 | P=0.769494 | R=0.182049 | Spec=0.977522
#
# [TRIAL 28] score(AUPRC_macro)=0.385473 | AUROC=0.851661 | Acc=0.941394 | P=0.690315 | R=0.180914 | Spec=0.977245
# [I 2026-05-07 18:16:45,460] Trial 28 finished with value: 0.3854727654061196 and parameters: {'n_estimators': 305, 'max_depth': 6, 'learning_rate': 0.021950999007515883, 'subsample': 0.9808273321681361, 'colsample_bytree': 0.9384639364567751, 'min_child_weight': 1.2942503008408657, 'reg_lambda': 1.441945030227182, 'reg_alpha': 0.013554636682826459, 'gamma': 4.11346060715257}. Best is trial 11 with value: 0.3958801449708104.
#
# ================================================================================
# [TRIAL 29] params:
# {
#   "objective": "binary:logistic",
#   "eval_metric": "logloss",
#   "tree_method": "hist",
#   "n_jobs": -1,
#   "random_state": 42,
#   "verbosity": 0,
#   "multi_strategy": "multi_output_tree",
#   "n_estimators": 699,
#   "max_depth": 10,
#   "learning_rate": 0.06655562284149769,
#   "subsample": 0.9160920505690429,
#   "colsample_bytree": 0.9674525778879886,
#   "min_child_weight": 0.8128514702023292,
#   "reg_lambda": 6.7323045313147,
#   "reg_alpha": 8.089452897792233e-05,
#   "gamma": 3.00120582375693
# }
#     [FOLD 1] AUPRC=0.387547 | AUROC=0.850561 | Acc=0.940658 | P=0.657581 | R=0.228866 | Spec=0.970989
#     [FOLD 2] AUPRC=0.364686 | AUROC=0.856237 | Acc=0.940579 | P=0.462630 | R=0.200103 | Spec=0.974344
#     [FOLD 3] AUPRC=0.403507 | AUROC=0.850913 | Acc=0.944740 | P=0.622821 | R=0.252829 | Spec=0.974034
#     [FOLD 4] AUPRC=0.392357 | AUROC=0.851842 | Acc=0.940191 | P=0.634687 | R=0.237567 | Spec=0.970601
#     [FOLD 5] AUPRC=0.399247 | AUROC=0.850592 | Acc=0.943076 | P=0.582716 | R=0.224783 | Spec=0.973046
#
# [TRIAL 29] score(AUPRC_macro)=0.389469 | AUROC=0.852029 | Acc=0.941849 | P=0.592087 | R=0.228830 | Spec=0.972603
# [I 2026-05-07 18:21:52,074] Trial 29 finished with value: 0.3894689472709209 and parameters: {'n_estimators': 699, 'max_depth': 10, 'learning_rate': 0.06655562284149769, 'subsample': 0.9160920505690429, 'colsample_bytree': 0.9674525778879886, 'min_child_weight': 0.8128514702023292, 'reg_lambda': 6.7323045313147, 'reg_alpha': 8.089452897792233e-05, 'gamma': 3.00120582375693}. Best is trial 11 with value: 0.3958801449708104.
#
# ================ BEST =================
# Best trial: 11
# Best AUPRC_macro: 0.3958801449708104
# Best params:
# {
#   "n_estimators": 306,
#   "max_depth": 10,
#   "learning_rate": 0.02567081087626854,
#   "subsample": 0.9732335194426311,
#   "colsample_bytree": 0.9748633637110227,
#   "min_child_weight": 1.2469100666073158,
#   "reg_lambda": 0.05256657291432167,
#   "reg_alpha": 1.4042918934900348e-08,
#   "gamma": 4.991961519082388
# }
# [SAVED] ./optuna_singlemodel_XGB_30trials_5fold_results.csv
# [SAVED] ./used_label_columns_24.csv
# [SAVED] ./used_feature_columns.csv

# %%
# -*- coding: utf-8 -*-
import os
import glob
import json
import warnings
import numpy as np
import pandas as pd

import optuna
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import roc_auc_score, average_precision_score
from sklearn.multioutput import MultiOutputClassifier

# =========================
# 0) 全局：尽量屏蔽警告 + LightGBM 日志
# =========================
os.environ["PYTHONWARNINGS"] = "ignore"
warnings.filterwarnings("ignore", category=UserWarning)
warnings.filterwarnings("ignore", category=FutureWarning)
warnings.filterwarnings("ignore", category=RuntimeWarning)

try:
    import lightgbm as lgb
except Exception as e:
    raise RuntimeError(
        "未检测到 lightgbm。请先安装：pip install lightgbm\n"
        f"原始错误：{repr(e)}"
    )

# =========================
# 1) 配置
# =========================
RANDOM_SEED = 42
N_TRIALS = 30
N_SPLITS = 5
THRESH = 0.5

# 直接读取你已生成的特征文件
FEATURE_FILE_GLOB = "./Malodors_Morgan_features.xlsx"

# 固定参数：Optuna 只搜索部分超参
BASE_LGB_PARAMS = dict(
    objective="binary",
    boosting_type="gbdt",
    n_jobs=-1,
    random_state=RANDOM_SEED,
    verbosity=-1,
)


# =========================
# 2) 读取特征文件 & 按固定列位置划分 SMILES / y / X
# =========================
def find_feature_file(pattern: str):
    cands = sorted(glob.glob(pattern))

    if not cands:
        raise FileNotFoundError(
            f"找不到特征文件：{pattern}\n"
            f"请确认 xlsx 文件名，或修改 FEATURE_FILE_GLOB。"
        )

    return cands[-1]


def load_Xy_from_feature_file(xlsx_path: str):
    """
    固定数据格式：
    第 1 列：SMILES
    第 2-25 列：24 个 y 标签
    第 26 列及之后：X 特征列

    说明：
    - 不再通过 0/1 自动判断 y 标签列；
    - 避免 Rule、FG、Morgan、StructKG 等 0/1 或数值特征被误识别为标签；
    - 适用于当前 24 标签任务。
    """
    df = pd.read_excel(xlsx_path)

    if df.shape[1] < 26:
        raise ValueError(
            f"当前文件列数为 {df.shape[1]}，不足以按“1列SMILES + 24列标签 + 特征列”划分。"
        )

    # 固定列位置
    smiles_col = df.columns[0]
    label_cols = list(df.columns[1:25])
    feature_cols = list(df.columns[25:])

    if len(label_cols) != 24:
        raise ValueError(
            f"标签列数量应为 24，但当前识别为 {len(label_cols)}。"
        )

    if len(feature_cols) == 0:
        raise ValueError(
            "未识别到特征列。请确认第 26 列之后为 X 特征。"
        )

    # y 标签转为 0/1 整数
    y_df = df[label_cols].copy()
    y_df = y_df.apply(pd.to_numeric, errors="coerce").fillna(0).astype(int)

    # 检查 y 标签是否为 0/1
    invalid_label_cols = []
    for c in label_cols:
        vals = set(pd.unique(y_df[c].dropna()))
        if not vals.issubset({0, 1}):
            invalid_label_cols.append(c)

    if invalid_label_cols:
        raise ValueError(
            "以下标签列不是标准 0/1 标签，请检查数据：\n"
            + "\n".join(map(str, invalid_label_cols))
        )

    # X 特征转为数值
    X_df = df[feature_cols].copy()
    X_df = X_df.apply(pd.to_numeric, errors="coerce").fillna(0)

    X = X_df.astype(np.float32).values
    y = y_df.values.astype(int)

    if X.shape[0] != y.shape[0]:
        raise ValueError("X 和 y 行数不一致，请检查文件。")

    print("[INFO] Column split mode: fixed-position")
    print(f"[INFO] SMILES column: {smiles_col}")
    print(f"[INFO] Label columns: columns 2-25, n={len(label_cols)}")
    print(f"[INFO] Feature columns: columns 26-end, n={len(feature_cols)}")

    print("\n[INFO] Label columns:")
    for i, c in enumerate(label_cols, start=1):
        print(f"  y{i:02d}: {c}")

    return X, y, feature_cols, label_cols, df


# =========================
# 3) 指标：macro
# =========================
def multilabel_macro_metrics(y_true, y_prob, thresh=0.5):
    y_true = np.asarray(y_true).astype(int)
    y_prob = np.asarray(y_prob).astype(float)
    y_pred = (y_prob >= thresh).astype(int)

    L = y_true.shape[1]
    accs, precs, recs, specs = [], [], [], []
    aurocs, auprcs = [], []

    for k in range(L):
        yt = y_true[:, k]
        yp = y_pred[:, k]
        ys = y_prob[:, k]

        tp = int(np.sum((yt == 1) & (yp == 1)))
        tn = int(np.sum((yt == 0) & (yp == 0)))
        fp = int(np.sum((yt == 0) & (yp == 1)))
        fn = int(np.sum((yt == 1) & (yp == 0)))
        n = len(yt)

        accs.append((tp + tn) / n if n else np.nan)
        precs.append(tp / (tp + fp) if (tp + fp) else np.nan)
        recs.append(tp / (tp + fn) if (tp + fn) else np.nan)
        specs.append(tn / (tn + fp) if (tn + fp) else np.nan)

        if len(np.unique(yt)) == 2:
            aurocs.append(roc_auc_score(yt, ys))
            auprcs.append(average_precision_score(yt, ys))
        else:
            aurocs.append(np.nan)
            auprcs.append(np.nan)

    def nanmean(x):
        return float(np.nanmean(np.asarray(x, dtype=float)))

    return {
        "Accuracy_macro": nanmean(accs),
        "Precision_macro": nanmean(precs),
        "Recall_macro": nanmean(recs),
        "Specificity_macro": nanmean(specs),
        "AUROC_macro": nanmean(aurocs),
        "AUPRC_macro": nanmean(auprcs),
        "AUROC_valid_labels": int(np.sum(~np.isnan(aurocs))),
        "AUPRC_valid_labels": int(np.sum(~np.isnan(auprcs))),
        "n_labels": int(L),
    }


def extract_positive_proba(p, n_labels: int):
    """
    MultiOutputClassifier.predict_proba 通常返回 list：
    list 长度 = 标签数，每个元素形状为 (n_samples, n_classes)。

    注意：
    - 若某个 fold 中某个标签训练集只有单类，LightGBM 可能只返回 1 列；
    - 这里做了兼容，避免 pi[:, 1] 越界。
    """
    if isinstance(p, list):
        out = np.zeros((p[0].shape[0], n_labels), dtype=np.float32)

        for k in range(n_labels):
            pk = p[k]

            if pk.ndim != 2:
                raise ValueError(f"predict_proba[{k}] 形状异常: {pk.shape}")

            if pk.shape[1] == 2:
                out[:, k] = pk[:, 1].astype(np.float32)
            elif pk.shape[1] == 1:
                # 无法从 predict_proba 本身判断该单类是 0 还是 1；
                # 这里兜底使用该列概率。通常极少发生。
                out[:, k] = pk[:, 0].astype(np.float32)
            else:
                raise ValueError(
                    f"predict_proba[{k}] 类别数异常: {pk.shape[1]}"
                )

        return out

    p = np.asarray(p)

    if p.ndim == 3 and p.shape[-1] == 2:
        return p[:, :, 1].astype(np.float32)

    if p.ndim == 2:
        if p.shape[1] == 2 and n_labels == 1:
            return p[:, 1:2].astype(np.float32)

        if p.shape[1] == n_labels:
            return p.astype(np.float32)

        raise ValueError(
            f"predict_proba 输出为二维，但列数 {p.shape[1]} 与标签数 {n_labels} 不一致。"
        )

    raise ValueError(f"无法解析 predict_proba 输出形状: {p.shape}")


# =========================
# 4) 近似分层 5 折：用 label cardinality 分层
# =========================
def make_stratify_target(y: np.ndarray, n_bins: int = 10):
    """
    多标签任务中没有直接的 StratifiedKFold。
    这里使用每个样本的标签数量 label cardinality 做近似分层。
    """
    card = y.sum(axis=1).astype(int)
    uniq = np.unique(card)

    if len(uniq) <= 15:
        return card

    r = pd.Series(card).rank(method="average").values
    bins = pd.qcut(
        r,
        q=min(n_bins, len(np.unique(r))),
        labels=False,
        duplicates="drop"
    )

    return np.asarray(bins, dtype=int)


def build_folds(X, y, n_splits=5, seed=42):
    strat_y = make_stratify_target(y)

    skf = StratifiedKFold(
        n_splits=n_splits,
        shuffle=True,
        random_state=seed
    )

    return list(skf.split(X, strat_y))


# =========================
# 5) 5 折 CV 评估：LightGBM + MultiOutput
# =========================
def cv_eval_one_paramset(X, y, folds, params, thresh=0.5):
    n_labels = y.shape[1]
    fold_metrics = []

    for fold_id, (tr_idx, va_idx) in enumerate(folds, start=1):
        X_tr, X_va = X[tr_idx], X[va_idx]
        y_tr, y_va = y[tr_idx], y[va_idx]

        base_est = lgb.LGBMClassifier(**params)

        # 每个标签一个 LGBM；
        # n_jobs=1 避免“外层并行 + 内层线程”导致线程过载
        clf = MultiOutputClassifier(base_est, n_jobs=1)

        clf.fit(X_tr, y_tr)

        p = clf.predict_proba(X_va)
        y_prob = extract_positive_proba(p, n_labels=n_labels)

        m = multilabel_macro_metrics(y_va, y_prob, thresh=thresh)
        fold_metrics.append(m)

        print(
            f"    [FOLD {fold_id}] "
            f"AUPRC={m['AUPRC_macro']:.6f} | "
            f"AUROC={m['AUROC_macro']:.6f} | "
            f"Acc={m['Accuracy_macro']:.6f} | "
            f"P={m['Precision_macro']:.6f} | "
            f"R={m['Recall_macro']:.6f} | "
            f"Spec={m['Specificity_macro']:.6f}"
        )

    keys = list(fold_metrics[0].keys())
    mean_metrics = {}

    for k in keys:
        vals = [fm[k] for fm in fold_metrics]

        if isinstance(vals[0], float):
            mean_metrics[k] = float(np.nanmean(vals))
        else:
            mean_metrics[k] = vals[-1]

    return mean_metrics


# =========================
# 6) Optuna 超参空间：LightGBM
# =========================
def build_trial_params(trial: optuna.Trial):
    params = dict(BASE_LGB_PARAMS)

    params.update({
        "n_estimators": trial.suggest_int("n_estimators", 300, 2000),
        "learning_rate": trial.suggest_float("learning_rate", 0.01, 0.2, log=True),

        "num_leaves": trial.suggest_int("num_leaves", 31, 255),
        "max_depth": trial.suggest_int("max_depth", -1, 20),
        "min_child_samples": trial.suggest_int("min_child_samples", 5, 80),

        "subsample": trial.suggest_float("subsample", 0.6, 1.0),
        "colsample_bytree": trial.suggest_float("colsample_bytree", 0.6, 1.0),

        "reg_lambda": trial.suggest_float("reg_lambda", 1e-3, 50.0, log=True),
        "reg_alpha": trial.suggest_float("reg_alpha", 1e-8, 10.0, log=True),

        "min_split_gain": trial.suggest_float("min_split_gain", 0.0, 5.0),
    })

    return params


# =========================
# 7) 主流程：读特征 -> 固定 folds -> Optuna -> 输出保存
# =========================
def main():
    feature_file = find_feature_file(FEATURE_FILE_GLOB)
    print("[INFO] Using feature file:", feature_file)

    X, y, feat_cols, label_cols, df_all = load_Xy_from_feature_file(feature_file)

    print(
        f"\n[INFO] X shape={X.shape} "
        f"(features={len(feat_cols)}) | "
        f"y shape={y.shape} "
        f"(labels={len(label_cols)})"
    )

    folds = build_folds(X, y, n_splits=N_SPLITS, seed=RANDOM_SEED)
    print(f"[INFO] Prepared fixed {N_SPLITS}-fold splits for all trials.")

    def objective(trial: optuna.Trial):
        params = build_trial_params(trial)

        print("\n" + "=" * 80)
        print(f"[TRIAL {trial.number:02d}] params:")
        print(json.dumps(params, indent=2, ensure_ascii=False, default=str))

        mean_metrics = cv_eval_one_paramset(
            X,
            y,
            folds,
            params,
            thresh=THRESH
        )

        score = mean_metrics["AUPRC_macro"]

        print(
            f"\n[TRIAL {trial.number:02d}] "
            f"score(AUPRC_macro)={score:.6f} | "
            f"AUROC={mean_metrics['AUROC_macro']:.6f} | "
            f"Acc={mean_metrics['Accuracy_macro']:.6f} | "
            f"P={mean_metrics['Precision_macro']:.6f} | "
            f"R={mean_metrics['Recall_macro']:.6f} | "
            f"Spec={mean_metrics['Specificity_macro']:.6f}"
        )

        for k, v in mean_metrics.items():
            trial.set_user_attr(k, v)

        return score

    study = optuna.create_study(
        direction="maximize",
        sampler=optuna.samplers.TPESampler(seed=RANDOM_SEED),
    )

    study.optimize(
        objective,
        n_trials=N_TRIALS,
        show_progress_bar=True
    )

    print("\n================ BEST =================")
    print("Best trial:", study.best_trial.number)
    print("Best AUPRC_macro:", study.best_value)
    print("Best params:")
    print(json.dumps(study.best_params, indent=2, ensure_ascii=False))

    rows = []

    for t in study.trials:
        if t.value is None:
            continue

        row = {
            "trial": t.number,
            "AUPRC_macro": t.value,
            **t.params
        }

        row.update({
            k: v for k, v in t.user_attrs.items()
            if k.endswith("_macro")
        })

        rows.append(row)

    res_df = pd.DataFrame(rows).sort_values(
        "AUPRC_macro",
        ascending=False
    )

    out_csv = "./optuna_singlemodel_LIGHTGBM_30trials_5fold_results.csv"
    res_df.to_csv(out_csv, index=False, encoding="utf-8-sig")
    print("[SAVED]", out_csv)

    # 额外保存标签列和特征列，便于核查
    label_out = "./used_label_columns_24.csv"
    feature_out = "./used_feature_columns.csv"

    pd.DataFrame({"label_col": label_cols}).to_csv(
        label_out,
        index=False,
        encoding="utf-8-sig"
    )

    pd.DataFrame({"feature_col": feat_cols}).to_csv(
        feature_out,
        index=False,
        encoding="utf-8-sig"
    )

    print("[SAVED]", label_out)
    print("[SAVED]", feature_out)


if __name__ == "__main__":
    main()
# Out:
# [INFO] Using feature file: ./Malodors_Morgan_features.xlsx
# [I 2026-05-07 19:14:28,902] A new study created in memory with name: no-name-9ec49bff-4901-499b-b3c5-0f18656f586a
# [INFO] Column split mode: fixed-position
# [INFO] SMILES column: Canonical_SMILES
# [INFO] Label columns: columns 2-25, n=24
# [INFO] Feature columns: columns 26-end, n=2048
#
# [INFO] Label columns:
#   y01: alcoholic
#   y02: aldehydic
#   y03: almond
#   y04: aromatic
#   y05: burnt
#   y06: cabbage
#   y07: cheesy
#   y08: cherry
#   y09: chocolate
#   y10: ethereal
#   y11: fishy
#   y12: fruity
#   y13: garlic
#   y14: gassy
#   y15: green
#   y16: ketonic
#   y17: musty
#   y18: pungent
#   y19: sharp
#   y20: solvent
#   y21: sour
#   y22: sulfurous
#   y23: sweaty
#   y24: sweet
#
# [INFO] X shape=(3756, 2048) (features=2048) | y shape=(3756, 24) (labels=24)
# [INFO] Prepared fixed 5-fold splits for all trials.
#   0%|          | 0/30 [00:00<?, ?it/s]
# ================================================================================
# [TRIAL 00] params:
# {
#   "objective": "binary",
#   "boosting_type": "gbdt",
#   "n_jobs": -1,
#   "random_state": 42,
#   "verbosity": -1,
#   "n_estimators": 937,
#   "learning_rate": 0.17254716573280354,
#   "num_leaves": 195,
#   "max_depth": 12,
#   "min_child_samples": 16,
#   "subsample": 0.662397808134481,
#   "colsample_bytree": 0.6232334448672797,
#   "reg_lambda": 11.752647960576219,
#   "reg_alpha": 0.002570603566117598,
#   "min_split_gain": 3.540362888980227
# }
#     [FOLD 1] AUPRC=0.303657 | AUROC=0.813775 | Acc=0.940658 | P=0.816530 | R=0.133226 | Spec=0.981138
#     [FOLD 2] AUPRC=0.300337 | AUROC=0.821801 | Acc=0.938915 | P=0.782291 | R=0.115133 | Spec=0.982328
#     [FOLD 3] AUPRC=0.302616 | AUROC=0.810207 | Acc=0.940579 | P=0.749991 | R=0.125598 | Spec=0.980626
#     [FOLD 4] AUPRC=0.288256 | AUROC=0.804300 | Acc=0.937028 | P=0.673089 | R=0.113283 | Spec=0.979904
#     [FOLD 5] AUPRC=0.298795 | AUROC=0.806231 | Acc=0.939192 | P=0.844479 | R=0.114006 | Spec=0.979079
#
# [TRIAL 00] score(AUPRC_macro)=0.298732 | AUROC=0.811263 | Acc=0.939275 | P=0.773276 | R=0.120249 | Spec=0.980615
# [I 2026-05-07 19:14:59,882] Trial 0 finished with value: 0.2987322774107371 and parameters: {'n_estimators': 937, 'learning_rate': 0.17254716573280354, 'num_leaves': 195, 'max_depth': 12, 'min_child_samples': 16, 'subsample': 0.662397808134481, 'colsample_bytree': 0.6232334448672797, 'reg_lambda': 11.752647960576219, 'reg_alpha': 0.002570603566117598, 'min_split_gain': 3.540362888980227}. Best is trial 0 with value: 0.2987322774107371.
#
# ================================================================================
# [TRIAL 01] params:
# {
#   "objective": "binary",
#   "boosting_type": "gbdt",
#   "n_jobs": -1,
#   "random_state": 42,
#   "verbosity": -1,
#   "n_estimators": 335,
#   "learning_rate": 0.18276027831785724,
#   "num_leaves": 218,
#   "max_depth": 3,
#   "min_child_samples": 18,
#   "subsample": 0.6733618039413735,
#   "colsample_bytree": 0.7216968971838151,
#   "reg_lambda": 0.2922905212920093,
#   "reg_alpha": 7.71800699380605e-05,
#   "min_split_gain": 1.4561457009902097
# }
#     [FOLD 1] AUPRC=0.359397 | AUROC=0.839137 | Acc=0.940547 | P=0.646686 | R=0.173279 | Spec=0.978233
#     [FOLD 2] AUPRC=0.357367 | AUROC=0.851633 | Acc=0.940635 | P=0.680663 | R=0.171985 | Spec=0.980466
#     [FOLD 3] AUPRC=0.360381 | AUROC=0.834490 | Acc=0.943686 | P=0.643256 | R=0.183740 | Spec=0.979717
#     [FOLD 4] AUPRC=0.370064 | AUROC=0.835025 | Acc=0.940357 | P=0.667381 | R=0.187018 | Spec=0.976710
#     [FOLD 5] AUPRC=0.338413 | AUROC=0.832004 | Acc=0.942688 | P=0.682266 | R=0.163943 | Spec=0.978633
#
# [TRIAL 01] score(AUPRC_macro)=0.357125 | AUROC=0.838458 | Acc=0.941583 | P=0.664050 | R=0.175993 | Spec=0.978752
# [I 2026-05-07 19:15:10,875] Trial 1 finished with value: 0.35712450391318634 and parameters: {'n_estimators': 335, 'learning_rate': 0.18276027831785724, 'num_leaves': 218, 'max_depth': 3, 'min_child_samples': 18, 'subsample': 0.6733618039413735, 'colsample_bytree': 0.7216968971838151, 'reg_lambda': 0.2922905212920093, 'reg_alpha': 7.71800699380605e-05, 'min_split_gain': 1.4561457009902097}. Best is trial 1 with value: 0.35712450391318634.
#
# ================================================================================
# [TRIAL 02] params:
# {
#   "objective": "binary",
#   "boosting_type": "gbdt",
#   "n_jobs": -1,
#   "random_state": 42,
#   "verbosity": -1,
#   "n_estimators": 1340,
#   "learning_rate": 0.01518747922672247,
#   "num_leaves": 96,
#   "max_depth": 7,
#   "min_child_samples": 39,
#   "subsample": 0.9140703845572055,
#   "colsample_bytree": 0.6798695128633439,
#   "reg_lambda": 0.2608388046560993,
#   "reg_alpha": 0.0021465011216654484,
#   "min_split_gain": 0.23225206359998862
# }
#     [FOLD 1] AUPRC=0.369873 | AUROC=0.843926 | Acc=0.941268 | P=0.589524 | R=0.219598 | Spec=0.975357
#     [FOLD 2] AUPRC=0.353513 | AUROC=0.851524 | Acc=0.940468 | P=0.530392 | R=0.188057 | Spec=0.976715
#     [FOLD 3] AUPRC=0.375530 | AUROC=0.841145 | Acc=0.942521 | P=0.581718 | R=0.215118 | Spec=0.975219
#     [FOLD 4] AUPRC=0.390514 | AUROC=0.843812 | Acc=0.940024 | P=0.718402 | R=0.224633 | Spec=0.972478
#     [FOLD 5] AUPRC=0.362905 | AUROC=0.833793 | Acc=0.942798 | P=0.623352 | R=0.205751 | Spec=0.975564
#
# [TRIAL 02] score(AUPRC_macro)=0.370467 | AUROC=0.842840 | Acc=0.941416 | P=0.608677 | R=0.210631 | Spec=0.975067
# [I 2026-05-07 19:15:53,348] Trial 2 finished with value: 0.3704670428648337 and parameters: {'n_estimators': 1340, 'learning_rate': 0.01518747922672247, 'num_leaves': 96, 'max_depth': 7, 'min_child_samples': 39, 'subsample': 0.9140703845572055, 'colsample_bytree': 0.6798695128633439, 'reg_lambda': 0.2608388046560993, 'reg_alpha': 0.0021465011216654484, 'min_split_gain': 0.23225206359998862}. Best is trial 2 with value: 0.3704670428648337.
#
# ================================================================================
# [TRIAL 03] params:
# {
#   "objective": "binary",
#   "boosting_type": "gbdt",
#   "n_jobs": -1,
#   "random_state": 42,
#   "verbosity": -1,
#   "n_estimators": 1333,
#   "learning_rate": 0.016666983286066417,
#   "num_leaves": 45,
#   "max_depth": 19,
#   "min_child_samples": 78,
#   "subsample": 0.9233589392465844,
#   "colsample_bytree": 0.7218455076693483,
#   "reg_lambda": 0.002877122371623787,
#   "reg_alpha": 0.014391207615728067,
#   "min_split_gain": 2.2007624686980067
# }
#     [FOLD 1] AUPRC=0.317614 | AUROC=0.828588 | Acc=0.940769 | P=0.730788 | R=0.145393 | Spec=0.980062
#     [FOLD 2] AUPRC=0.314119 | AUROC=0.838440 | Acc=0.939359 | P=0.686943 | R=0.129060 | Spec=0.982069
#     [FOLD 3] AUPRC=0.342391 | AUROC=0.831223 | Acc=0.940912 | P=0.754771 | R=0.145286 | Spec=0.980624
#     [FOLD 4] AUPRC=0.335673 | AUROC=0.820406 | Acc=0.938249 | P=0.832014 | R=0.142753 | Spec=0.978634
#     [FOLD 5] AUPRC=0.329961 | AUROC=0.824355 | Acc=0.939525 | P=0.791502 | R=0.138727 | Spec=0.978207
#
# [TRIAL 03] score(AUPRC_macro)=0.327952 | AUROC=0.828602 | Acc=0.939763 | P=0.759203 | R=0.140244 | Spec=0.979919
# [I 2026-05-07 19:16:12,708] Trial 3 finished with value: 0.3279516469086973 and parameters: {'n_estimators': 1333, 'learning_rate': 0.016666983286066417, 'num_leaves': 45, 'max_depth': 19, 'min_child_samples': 78, 'subsample': 0.9233589392465844, 'colsample_bytree': 0.7218455076693483, 'reg_lambda': 0.002877122371623787, 'reg_alpha': 0.014391207615728067, 'min_split_gain': 2.2007624686980067}. Best is trial 2 with value: 0.3704670428648337.
#
# ================================================================================
# [TRIAL 04] params:
# {
#   "objective": "binary",
#   "boosting_type": "gbdt",
#   "n_jobs": -1,
#   "random_state": 42,
#   "verbosity": -1,
#   "n_estimators": 507,
#   "learning_rate": 0.04407984038169244,
#   "num_leaves": 38,
#   "max_depth": 19,
#   "min_child_samples": 24,
#   "subsample": 0.8650089137415928,
#   "colsample_bytree": 0.7246844304357644,
#   "reg_lambda": 0.2778331300797557,
#   "reg_alpha": 0.0008325158565947976,
#   "min_split_gain": 0.9242722776276352
# }
#     [FOLD 1] AUPRC=0.366285 | AUROC=0.845391 | Acc=0.940991 | P=0.622522 | R=0.166383 | Spec=0.977841
#     [FOLD 2] AUPRC=0.368956 | AUROC=0.850991 | Acc=0.940746 | P=0.592054 | R=0.168267 | Spec=0.978626
#     [FOLD 3] AUPRC=0.379246 | AUROC=0.839875 | Acc=0.943131 | P=0.657631 | R=0.188494 | Spec=0.977480
#     [FOLD 4] AUPRC=0.382417 | AUROC=0.841519 | Acc=0.939747 | P=0.726478 | R=0.192476 | Spec=0.974173
#     [FOLD 5] AUPRC=0.355974 | AUROC=0.837234 | Acc=0.942798 | P=0.719994 | R=0.180742 | Spec=0.977641
#
# [TRIAL 04] score(AUPRC_macro)=0.370576 | AUROC=0.843002 | Acc=0.941483 | P=0.663736 | R=0.179272 | Spec=0.977152
# [I 2026-05-07 19:16:25,925] Trial 4 finished with value: 0.3705755181940193 and parameters: {'n_estimators': 507, 'learning_rate': 0.04407984038169244, 'num_leaves': 38, 'max_depth': 19, 'min_child_samples': 24, 'subsample': 0.8650089137415928, 'colsample_bytree': 0.7246844304357644, 'reg_lambda': 0.2778331300797557, 'reg_alpha': 0.0008325158565947976, 'min_split_gain': 0.9242722776276352}. Best is trial 4 with value: 0.3705755181940193.
#
# ================================================================================
# [TRIAL 05] params:
# {
#   "objective": "binary",
#   "boosting_type": "gbdt",
#   "n_jobs": -1,
#   "random_state": 42,
#   "verbosity": -1,
#   "n_estimators": 1949,
#   "learning_rate": 0.10196967939171485,
#   "num_leaves": 242,
#   "max_depth": 18,
#   "min_child_samples": 50,
#   "subsample": 0.9687496940092467,
#   "colsample_bytree": 0.6353970008207678,
#   "reg_lambda": 0.008335230071817131,
#   "reg_alpha": 2.5529693461039728e-08,
#   "min_split_gain": 1.6266516538163218
# }
#     [FOLD 1] AUPRC=0.327231 | AUROC=0.832155 | Acc=0.940437 | P=0.767609 | R=0.155422 | Spec=0.978170
#     [FOLD 2] AUPRC=0.345340 | AUROC=0.849076 | Acc=0.940024 | P=0.659238 | R=0.143623 | Spec=0.981069
#     [FOLD 3] AUPRC=0.350537 | AUROC=0.833917 | Acc=0.941190 | P=0.782797 | R=0.149352 | Spec=0.979674
#     [FOLD 4] AUPRC=0.361887 | AUROC=0.829010 | Acc=0.938804 | P=0.863229 | R=0.158799 | Spec=0.978170
#     [FOLD 5] AUPRC=0.346144 | AUROC=0.828898 | Acc=0.939858 | P=0.710187 | R=0.140953 | Spec=0.977845
#
# [TRIAL 05] score(AUPRC_macro)=0.346228 | AUROC=0.834611 | Acc=0.940062 | P=0.756612 | R=0.149630 | Spec=0.978986
# [I 2026-05-07 19:16:58,805] Trial 5 finished with value: 0.3462277823355272 and parameters: {'n_estimators': 1949, 'learning_rate': 0.10196967939171485, 'num_leaves': 242, 'max_depth': 18, 'min_child_samples': 50, 'subsample': 0.9687496940092467, 'colsample_bytree': 0.6353970008207678, 'reg_lambda': 0.008335230071817131, 'reg_alpha': 2.5529693461039728e-08, 'min_split_gain': 1.6266516538163218}. Best is trial 4 with value: 0.3705755181940193.
#
# ================================================================================
# [TRIAL 06] params:
# {
#   "objective": "binary",
#   "boosting_type": "gbdt",
#   "n_jobs": -1,
#   "random_state": 42,
#   "verbosity": -1,
#   "n_estimators": 961,
#   "learning_rate": 0.022544116997360492,
#   "num_leaves": 217,
#   "max_depth": 6,
#   "min_child_samples": 26,
#   "subsample": 0.8170784332632994,
#   "colsample_bytree": 0.6563696899899051,
#   "reg_lambda": 5.881655048861897,
#   "reg_alpha": 4.6876566400928895e-08,
#   "min_split_gain": 4.9344346830025865
# }
#     [FOLD 1] AUPRC=0.296748 | AUROC=0.812176 | Acc=0.939993 | P=0.786600 | R=0.112795 | Spec=0.982587
#     [FOLD 2] AUPRC=0.302505 | AUROC=0.822792 | Acc=0.938194 | P=0.693231 | R=0.096098 | Spec=0.984481
#     [FOLD 3] AUPRC=0.304721 | AUROC=0.808743 | Acc=0.939969 | P=0.769538 | R=0.113188 | Spec=0.982281
#     [FOLD 4] AUPRC=0.299949 | AUROC=0.804382 | Acc=0.936806 | P=0.812262 | R=0.105518 | Spec=0.980814
#     [FOLD 5] AUPRC=0.294140 | AUROC=0.806289 | Acc=0.938582 | P=0.820358 | R=0.102031 | Spec=0.980587
#
# [TRIAL 06] score(AUPRC_macro)=0.299612 | AUROC=0.810876 | Acc=0.938709 | P=0.776398 | R=0.105926 | Spec=0.982150
# [I 2026-05-07 19:17:17,075] Trial 6 finished with value: 0.29961246021119825 and parameters: {'n_estimators': 961, 'learning_rate': 0.022544116997360492, 'num_leaves': 217, 'max_depth': 6, 'min_child_samples': 26, 'subsample': 0.8170784332632994, 'colsample_bytree': 0.6563696899899051, 'reg_lambda': 5.881655048861897, 'reg_alpha': 4.6876566400928895e-08, 'min_split_gain': 4.9344346830025865}. Best is trial 4 with value: 0.3705755181940193.
#
# ================================================================================
# [TRIAL 07] params:
# {
#   "objective": "binary",
#   "boosting_type": "gbdt",
#   "n_jobs": -1,
#   "random_state": 42,
#   "verbosity": -1,
#   "n_estimators": 1613,
#   "learning_rate": 0.018135730867783396,
#   "num_leaves": 32,
#   "max_depth": 16,
#   "min_child_samples": 58,
#   "subsample": 0.8916028672163949,
#   "colsample_bytree": 0.9085081386743783,
#   "reg_lambda": 0.0022280944532589255,
#   "reg_alpha": 1.683416412018213e-05,
#   "min_split_gain": 0.5793452976256486
# }
#     [FOLD 1] AUPRC=0.347619 | AUROC=0.837154 | Acc=0.940547 | P=0.611007 | R=0.169608 | Spec=0.976821
#     [FOLD 2] AUPRC=0.346129 | AUROC=0.847943 | Acc=0.940024 | P=0.592663 | R=0.161264 | Spec=0.978491
#     [FOLD 3] AUPRC=0.359759 | AUROC=0.839034 | Acc=0.940857 | P=0.644585 | R=0.179411 | Spec=0.976913
#     [FOLD 4] AUPRC=0.368484 | AUROC=0.833858 | Acc=0.938859 | P=0.662497 | R=0.177332 | Spec=0.975535
#     [FOLD 5] AUPRC=0.355205 | AUROC=0.834331 | Acc=0.940635 | P=0.673065 | R=0.165121 | Spec=0.976628
#
# [TRIAL 07] score(AUPRC_macro)=0.355439 | AUROC=0.838464 | Acc=0.940184 | P=0.636763 | R=0.170547 | Spec=0.976878
# [I 2026-05-07 19:17:39,297] Trial 7 finished with value: 0.3554391414939953 and parameters: {'n_estimators': 1613, 'learning_rate': 0.018135730867783396, 'num_leaves': 32, 'max_depth': 16, 'min_child_samples': 58, 'subsample': 0.8916028672163949, 'colsample_bytree': 0.9085081386743783, 'reg_lambda': 0.0022280944532589255, 'reg_alpha': 1.683416412018213e-05, 'min_split_gain': 0.5793452976256486}. Best is trial 4 with value: 0.3705755181940193.
#
# ================================================================================
# [TRIAL 08] params:
# {
#   "objective": "binary",
#   "boosting_type": "gbdt",
#   "n_jobs": -1,
#   "random_state": 42,
#   "verbosity": -1,
#   "n_estimators": 1768,
#   "learning_rate": 0.06470376604234768,
#   "num_leaves": 105,
#   "max_depth": 0,
#   "min_child_samples": 28,
#   "subsample": 0.7300733288106989,
#   "colsample_bytree": 0.8918424713352255,
#   "reg_lambda": 0.9905204218383901,
#   "reg_alpha": 0.9658611176861268,
#   "min_split_gain": 2.3610746258097466
# }
#     [FOLD 1] AUPRC=0.318174 | AUROC=0.826221 | Acc=0.940492 | P=0.759748 | R=0.138798 | Spec=0.980126
#     [FOLD 2] AUPRC=0.325785 | AUROC=0.827606 | Acc=0.940191 | P=0.734199 | R=0.140736 | Spec=0.982107
#     [FOLD 3] AUPRC=0.329808 | AUROC=0.822740 | Acc=0.941300 | P=0.767192 | R=0.140149 | Spec=0.980422
#     [FOLD 4] AUPRC=0.330699 | AUROC=0.822862 | Acc=0.937417 | P=0.789148 | R=0.123019 | Spec=0.978311
#     [FOLD 5] AUPRC=0.317948 | AUROC=0.817418 | Acc=0.940135 | P=0.778397 | R=0.127541 | Spec=0.978635
#
# [TRIAL 08] score(AUPRC_macro)=0.324483 | AUROC=0.823369 | Acc=0.939907 | P=0.765737 | R=0.134049 | Spec=0.979920
# [I 2026-05-07 19:18:01,079] Trial 8 finished with value: 0.32448279629532395 and parameters: {'n_estimators': 1768, 'learning_rate': 0.06470376604234768, 'num_leaves': 105, 'max_depth': 0, 'min_child_samples': 28, 'subsample': 0.7300733288106989, 'colsample_bytree': 0.8918424713352255, 'reg_lambda': 0.9905204218383901, 'reg_alpha': 0.9658611176861268, 'min_split_gain': 2.3610746258097466}. Best is trial 4 with value: 0.3705755181940193.
#
# ================================================================================
# [TRIAL 09] params:
# {
#   "objective": "binary",
#   "boosting_type": "gbdt",
#   "n_jobs": -1,
#   "random_state": 42,
#   "verbosity": -1,
#   "n_estimators": 503,
#   "learning_rate": 0.08471354625326555,
#   "num_leaves": 202,
#   "max_depth": 11,
#   "min_child_samples": 63,
#   "subsample": 0.7975182385457563,
#   "colsample_bytree": 0.8090931317527976,
#   "reg_lambda": 0.10209451747520762,
#   "reg_alpha": 1.6934490731313353e-08,
#   "min_split_gain": 0.5394571349665223
# }
#     [FOLD 1] AUPRC=0.348353 | AUROC=0.837403 | Acc=0.940049 | P=0.639036 | R=0.168419 | Spec=0.976076
#     [FOLD 2] AUPRC=0.338221 | AUROC=0.851430 | Acc=0.939636 | P=0.533731 | R=0.155542 | Spec=0.977736
#     [FOLD 3] AUPRC=0.364735 | AUROC=0.838255 | Acc=0.941134 | P=0.679505 | R=0.173297 | Spec=0.977381
#     [FOLD 4] AUPRC=0.365909 | AUROC=0.833583 | Acc=0.938415 | P=0.590262 | R=0.184140 | Spec=0.974149
#     [FOLD 5] AUPRC=0.350776 | AUROC=0.834812 | Acc=0.940635 | P=0.611221 | R=0.168565 | Spec=0.976271
#
# [TRIAL 09] score(AUPRC_macro)=0.353599 | AUROC=0.839096 | Acc=0.939974 | P=0.610751 | R=0.169992 | Spec=0.976323
# [I 2026-05-07 19:18:12,007] Trial 9 finished with value: 0.35359872174612894 and parameters: {'n_estimators': 503, 'learning_rate': 0.08471354625326555, 'num_leaves': 202, 'max_depth': 11, 'min_child_samples': 63, 'subsample': 0.7975182385457563, 'colsample_bytree': 0.8090931317527976, 'reg_lambda': 0.10209451747520762, 'reg_alpha': 1.6934490731313353e-08, 'min_split_gain': 0.5394571349665223}. Best is trial 4 with value: 0.3705755181940193.
#
# ================================================================================
# [TRIAL 10] params:
# {
#   "objective": "binary",
#   "boosting_type": "gbdt",
#   "n_jobs": -1,
#   "random_state": 42,
#   "verbosity": -1,
#   "n_estimators": 653,
#   "learning_rate": 0.04128697297312279,
#   "num_leaves": 147,
#   "max_depth": 14,
#   "min_child_samples": 6,
#   "subsample": 0.8163775632702192,
#   "colsample_bytree": 0.983908298378168,
#   "reg_lambda": 0.03379534397108484,
#   "reg_alpha": 3.3316309468938505,
#   "min_split_gain": 3.6920277236251042
# }
#     [FOLD 1] AUPRC=0.288663 | AUROC=0.802603 | Acc=0.939993 | P=0.838902 | R=0.118592 | Spec=0.982335
#     [FOLD 2] AUPRC=0.293895 | AUROC=0.807928 | Acc=0.938748 | P=0.751588 | R=0.112321 | Spec=0.983742
#     [FOLD 3] AUPRC=0.302491 | AUROC=0.800827 | Acc=0.940080 | P=0.786866 | R=0.111271 | Spec=0.982789
#     [FOLD 4] AUPRC=0.297614 | AUROC=0.792913 | Acc=0.936252 | P=0.756977 | R=0.113282 | Spec=0.979654
#     [FOLD 5] AUPRC=0.282966 | AUROC=0.789642 | Acc=0.938970 | P=0.843096 | R=0.105106 | Spec=0.980528
#
# [TRIAL 10] score(AUPRC_macro)=0.293126 | AUROC=0.798783 | Acc=0.938809 | P=0.795486 | R=0.112114 | Spec=0.981810
# [I 2026-05-07 19:18:31,228] Trial 10 finished with value: 0.2931259106090914 and parameters: {'n_estimators': 653, 'learning_rate': 0.04128697297312279, 'num_leaves': 147, 'max_depth': 14, 'min_child_samples': 6, 'subsample': 0.8163775632702192, 'colsample_bytree': 0.983908298378168, 'reg_lambda': 0.03379534397108484, 'reg_alpha': 3.3316309468938505, 'min_split_gain': 3.6920277236251042}. Best is trial 4 with value: 0.3705755181940193.
#
# ================================================================================
# [TRIAL 11] params:
# {
#   "objective": "binary",
#   "boosting_type": "gbdt",
#   "n_jobs": -1,
#   "random_state": 42,
#   "verbosity": -1,
#   "n_estimators": 1264,
#   "learning_rate": 0.010272842363526024,
#   "num_leaves": 88,
#   "max_depth": 7,
#   "min_child_samples": 38,
#   "subsample": 0.88180962139586,
#   "colsample_bytree": 0.7389917503278137,
#   "reg_lambda": 1.507231417469703,
#   "reg_alpha": 0.027019779735714396,
#   "min_split_gain": 0.03670622408491764
# }
#     [FOLD 1] AUPRC=0.378706 | AUROC=0.845885 | Acc=0.941212 | P=0.609560 | R=0.227773 | Spec=0.974481
#     [FOLD 2] AUPRC=0.353371 | AUROC=0.849499 | Acc=0.940968 | P=0.472341 | R=0.191366 | Spec=0.977173
#     [FOLD 3] AUPRC=0.382306 | AUROC=0.842832 | Acc=0.942299 | P=0.572929 | R=0.223139 | Spec=0.974984
#     [FOLD 4] AUPRC=0.385632 | AUROC=0.846351 | Acc=0.939636 | P=0.621430 | R=0.230697 | Spec=0.972085
#     [FOLD 5] AUPRC=0.367923 | AUROC=0.839908 | Acc=0.942022 | P=0.572450 | R=0.215016 | Spec=0.974495
#
# [TRIAL 11] score(AUPRC_macro)=0.373588 | AUROC=0.844895 | Acc=0.941227 | P=0.569742 | R=0.217598 | Spec=0.974643
# [I 2026-05-07 19:19:52,603] Trial 11 finished with value: 0.37358782449583144 and parameters: {'n_estimators': 1264, 'learning_rate': 0.010272842363526024, 'num_leaves': 88, 'max_depth': 7, 'min_child_samples': 38, 'subsample': 0.88180962139586, 'colsample_bytree': 0.7389917503278137, 'reg_lambda': 1.507231417469703, 'reg_alpha': 0.027019779735714396, 'min_split_gain': 0.03670622408491764}. Best is trial 11 with value: 0.37358782449583144.
#
# ================================================================================
# [TRIAL 12] params:
# {
#   "objective": "binary",
#   "boosting_type": "gbdt",
#   "n_jobs": -1,
#   "random_state": 42,
#   "verbosity": -1,
#   "n_estimators": 858,
#   "learning_rate": 0.01038511485188037,
#   "num_leaves": 73,
#   "max_depth": 7,
#   "min_child_samples": 42,
#   "subsample": 0.9931791398704514,
#   "colsample_bytree": 0.7830926587418234,
#   "reg_lambda": 2.215962141079502,
#   "reg_alpha": 0.28705712109400183,
#   "min_split_gain": 0.016551504565429198
# }
#     [FOLD 1] AUPRC=0.375072 | AUROC=0.846187 | Acc=0.940769 | P=0.606339 | R=0.209467 | Spec=0.974649
#     [FOLD 2] AUPRC=0.359165 | AUROC=0.853914 | Acc=0.939692 | P=0.532676 | R=0.181088 | Spec=0.976730
#     [FOLD 3] AUPRC=0.382834 | AUROC=0.845637 | Acc=0.941411 | P=0.577628 | R=0.192137 | Spec=0.976371
#     [FOLD 4] AUPRC=0.380003 | AUROC=0.844826 | Acc=0.938804 | P=0.607645 | R=0.199866 | Spec=0.973636
#     [FOLD 5] AUPRC=0.369659 | AUROC=0.845029 | Acc=0.942022 | P=0.632662 | R=0.194022 | Spec=0.976751
#
# [TRIAL 12] score(AUPRC_macro)=0.373347 | AUROC=0.847118 | Acc=0.940540 | P=0.591390 | R=0.195316 | Spec=0.975627
# [I 2026-05-07 19:20:51,355] Trial 12 finished with value: 0.37334659821368255 and parameters: {'n_estimators': 858, 'learning_rate': 0.01038511485188037, 'num_leaves': 73, 'max_depth': 7, 'min_child_samples': 42, 'subsample': 0.9931791398704514, 'colsample_bytree': 0.7830926587418234, 'reg_lambda': 2.215962141079502, 'reg_alpha': 0.28705712109400183, 'min_split_gain': 0.016551504565429198}. Best is trial 11 with value: 0.37358782449583144.
#
# ================================================================================
# [TRIAL 13] params:
# {
#   "objective": "binary",
#   "boosting_type": "gbdt",
#   "n_jobs": -1,
#   "random_state": 42,
#   "verbosity": -1,
#   "n_estimators": 1045,
#   "learning_rate": 0.010136284547794212,
#   "num_leaves": 86,
#   "max_depth": 8,
#   "min_child_samples": 39,
#   "subsample": 0.999515774191902,
#   "colsample_bytree": 0.8184200828646883,
#   "reg_lambda": 2.344862431497,
#   "reg_alpha": 0.16036783824922757,
#   "min_split_gain": 0.008279365666262343
# }
#     [FOLD 1] AUPRC=0.382178 | AUROC=0.847125 | Acc=0.940824 | P=0.594211 | R=0.221058 | Spec=0.974084
#     [FOLD 2] AUPRC=0.355958 | AUROC=0.849418 | Acc=0.940468 | P=0.535200 | R=0.192187 | Spec=0.976502
#     [FOLD 3] AUPRC=0.386448 | AUROC=0.845632 | Acc=0.941911 | P=0.568058 | R=0.212408 | Spec=0.974816
#     [FOLD 4] AUPRC=0.387743 | AUROC=0.847409 | Acc=0.939248 | P=0.659590 | R=0.219303 | Spec=0.972348
#     [FOLD 5] AUPRC=0.369586 | AUROC=0.842866 | Acc=0.941855 | P=0.609206 | R=0.217296 | Spec=0.975075
#
# [TRIAL 13] score(AUPRC_macro)=0.376383 | AUROC=0.846490 | Acc=0.940861 | P=0.593253 | R=0.212451 | Spec=0.974565
# [I 2026-05-07 19:22:06,269] Trial 13 finished with value: 0.37638265456774866 and parameters: {'n_estimators': 1045, 'learning_rate': 0.010136284547794212, 'num_leaves': 86, 'max_depth': 8, 'min_child_samples': 39, 'subsample': 0.999515774191902, 'colsample_bytree': 0.8184200828646883, 'reg_lambda': 2.344862431497, 'reg_alpha': 0.16036783824922757, 'min_split_gain': 0.008279365666262343}. Best is trial 13 with value: 0.37638265456774866.
#
# ================================================================================
# [TRIAL 14] params:
# {
#   "objective": "binary",
#   "boosting_type": "gbdt",
#   "n_jobs": -1,
#   "random_state": 42,
#   "verbosity": -1,
#   "n_estimators": 1208,
#   "learning_rate": 0.010615002992039876,
#   "num_leaves": 140,
#   "max_depth": 3,
#   "min_child_samples": 39,
#   "subsample": 0.9518854644540856,
#   "colsample_bytree": 0.8209966024533897,
#   "reg_lambda": 35.8566705453666,
#   "reg_alpha": 0.03890836201731729,
#   "min_split_gain": 1.3145482105778155
# }
#     [FOLD 1] AUPRC=0.308978 | AUROC=0.823173 | Acc=0.940326 | P=0.809361 | R=0.127893 | Spec=0.980687
#     [FOLD 2] AUPRC=0.304327 | AUROC=0.819254 | Acc=0.938582 | P=0.713020 | R=0.119501 | Spec=0.981465
#     [FOLD 3] AUPRC=0.305517 | AUROC=0.815319 | Acc=0.940968 | P=0.756241 | R=0.130679 | Spec=0.980260
#     [FOLD 4] AUPRC=0.294930 | AUROC=0.807906 | Acc=0.938027 | P=0.702172 | R=0.127779 | Spec=0.979463
#     [FOLD 5] AUPRC=0.296948 | AUROC=0.807809 | Acc=0.938804 | P=0.837580 | R=0.112867 | Spec=0.977669
#
# [TRIAL 14] score(AUPRC_macro)=0.302140 | AUROC=0.814692 | Acc=0.939341 | P=0.763675 | R=0.123744 | Spec=0.979909
# [I 2026-05-07 19:22:31,939] Trial 14 finished with value: 0.3021401252071903 and parameters: {'n_estimators': 1208, 'learning_rate': 0.010615002992039876, 'num_leaves': 140, 'max_depth': 3, 'min_child_samples': 39, 'subsample': 0.9518854644540856, 'colsample_bytree': 0.8209966024533897, 'reg_lambda': 35.8566705453666, 'reg_alpha': 0.03890836201731729, 'min_split_gain': 1.3145482105778155}. Best is trial 13 with value: 0.37638265456774866.
#
# ================================================================================
# [TRIAL 15] params:
# {
#   "objective": "binary",
#   "boosting_type": "gbdt",
#   "n_jobs": -1,
#   "random_state": 42,
#   "verbosity": -1,
#   "n_estimators": 1528,
#   "learning_rate": 0.027921177606118185,
#   "num_leaves": 132,
#   "max_depth": 9,
#   "min_child_samples": 53,
#   "subsample": 0.8557873865083512,
#   "colsample_bytree": 0.8893891830023913,
#   "reg_lambda": 1.527590485046901,
#   "reg_alpha": 0.07602311011709978,
#   "min_split_gain": 0.056735346470968416
# }
#     [FOLD 1] AUPRC=0.361133 | AUROC=0.839480 | Acc=0.938996 | P=0.548231 | R=0.206883 | Spec=0.973095
#     [FOLD 2] AUPRC=0.352278 | AUROC=0.847269 | Acc=0.939470 | P=0.403089 | R=0.185192 | Spec=0.974939
#     [FOLD 3] AUPRC=0.378000 | AUROC=0.840627 | Acc=0.941467 | P=0.558911 | R=0.218271 | Spec=0.973658
#     [FOLD 4] AUPRC=0.376250 | AUROC=0.839354 | Acc=0.939525 | P=0.664338 | R=0.226614 | Spec=0.970685
#     [FOLD 5] AUPRC=0.361543 | AUROC=0.838450 | Acc=0.941356 | P=0.548280 | R=0.217951 | Spec=0.973537
#
# [TRIAL 15] score(AUPRC_macro)=0.365841 | AUROC=0.841036 | Acc=0.940163 | P=0.544570 | R=0.210982 | Spec=0.973183
# [I 2026-05-07 19:23:17,263] Trial 15 finished with value: 0.3658408134389488 and parameters: {'n_estimators': 1528, 'learning_rate': 0.027921177606118185, 'num_leaves': 132, 'max_depth': 9, 'min_child_samples': 53, 'subsample': 0.8557873865083512, 'colsample_bytree': 0.8893891830023913, 'reg_lambda': 1.527590485046901, 'reg_alpha': 0.07602311011709978, 'min_split_gain': 0.056735346470968416}. Best is trial 13 with value: 0.37638265456774866.
#
# ================================================================================
# [TRIAL 16] params:
# {
#   "objective": "binary",
#   "boosting_type": "gbdt",
#   "n_jobs": -1,
#   "random_state": 42,
#   "verbosity": -1,
#   "n_estimators": 1115,
#   "learning_rate": 0.030581042909244193,
#   "num_leaves": 73,
#   "max_depth": 4,
#   "min_child_samples": 71,
#   "subsample": 0.609478164602333,
#   "colsample_bytree": 0.7730852421324665,
#   "reg_lambda": 5.069430553224879,
#   "reg_alpha": 9.613124918409422,
#   "min_split_gain": 3.1370991330748375
# }
#     [FOLD 1] AUPRC=0.242217 | AUROC=0.745860 | Acc=0.938497 | P=0.737057 | R=0.089820 | Spec=0.982835
#     [FOLD 2] AUPRC=0.238105 | AUROC=0.760887 | Acc=0.937306 | P=0.742033 | R=0.087033 | Spec=0.984103
#     [FOLD 3] AUPRC=0.235381 | AUROC=0.734878 | Acc=0.938693 | P=0.754037 | R=0.085185 | Spec=0.983909
#     [FOLD 4] AUPRC=0.239081 | AUROC=0.738609 | Acc=0.933700 | P=0.693847 | R=0.078075 | Spec=0.980369
#     [FOLD 5] AUPRC=0.235795 | AUROC=0.727982 | Acc=0.937028 | P=0.722229 | R=0.082654 | Spec=0.980216
#
# [TRIAL 16] score(AUPRC_macro)=0.238116 | AUROC=0.741643 | Acc=0.937045 | P=0.729841 | R=0.084553 | Spec=0.982286
# [I 2026-05-07 19:23:31,145] Trial 16 finished with value: 0.23811583918741192 and parameters: {'n_estimators': 1115, 'learning_rate': 0.030581042909244193, 'num_leaves': 73, 'max_depth': 4, 'min_child_samples': 71, 'subsample': 0.609478164602333, 'colsample_bytree': 0.7730852421324665, 'reg_lambda': 5.069430553224879, 'reg_alpha': 9.613124918409422, 'min_split_gain': 3.1370991330748375}. Best is trial 13 with value: 0.37638265456774866.
#
# ================================================================================
# [TRIAL 17] params:
# {
#   "objective": "binary",
#   "boosting_type": "gbdt",
#   "n_jobs": -1,
#   "random_state": 42,
#   "verbosity": -1,
#   "n_estimators": 736,
#   "learning_rate": 0.014449369873367413,
#   "num_leaves": 166,
#   "max_depth": 0,
#   "min_child_samples": 33,
#   "subsample": 0.7531459884455247,
#   "colsample_bytree": 0.8416634198004798,
#   "reg_lambda": 33.221913420148894,
#   "reg_alpha": 7.938090375917386e-07,
#   "min_split_gain": 1.1171436441726101
# }
#     [FOLD 1] AUPRC=0.315794 | AUROC=0.826303 | Acc=0.940326 | P=0.743619 | R=0.137342 | Spec=0.978988
#     [FOLD 2] AUPRC=0.319188 | AUROC=0.821874 | Acc=0.939303 | P=0.696029 | R=0.129146 | Spec=0.981066
#     [FOLD 3] AUPRC=0.317489 | AUROC=0.819252 | Acc=0.940801 | P=0.776397 | R=0.139592 | Spec=0.978751
#     [FOLD 4] AUPRC=0.306862 | AUROC=0.814320 | Acc=0.938249 | P=0.749276 | R=0.137105 | Spec=0.977887
#     [FOLD 5] AUPRC=0.306475 | AUROC=0.810773 | Acc=0.939802 | P=0.728745 | R=0.122834 | Spec=0.977453
#
# [TRIAL 17] score(AUPRC_macro)=0.313162 | AUROC=0.818504 | Acc=0.939696 | P=0.738813 | R=0.133204 | Spec=0.978829
# [I 2026-05-07 19:23:52,832] Trial 17 finished with value: 0.31316155464796486 and parameters: {'n_estimators': 736, 'learning_rate': 0.014449369873367413, 'num_leaves': 166, 'max_depth': 0, 'min_child_samples': 33, 'subsample': 0.7531459884455247, 'colsample_bytree': 0.8416634198004798, 'reg_lambda': 33.221913420148894, 'reg_alpha': 7.938090375917386e-07, 'min_split_gain': 1.1171436441726101}. Best is trial 13 with value: 0.37638265456774866.
#
# ================================================================================
# [TRIAL 18] params:
# {
#   "objective": "binary",
#   "boosting_type": "gbdt",
#   "n_jobs": -1,
#   "random_state": 42,
#   "verbosity": -1,
#   "n_estimators": 1118,
#   "learning_rate": 0.010060927133553738,
#   "num_leaves": 106,
#   "max_depth": 9,
#   "min_child_samples": 48,
#   "subsample": 0.9948668735382384,
#   "colsample_bytree": 0.7640453501990042,
#   "reg_lambda": 0.9390987001523136,
#   "reg_alpha": 0.010281092734903045,
#   "min_split_gain": 1.7143164298881695
# }
#     [FOLD 1] AUPRC=0.330421 | AUROC=0.830960 | Acc=0.940935 | P=0.752825 | R=0.153597 | Spec=0.979883
#     [FOLD 2] AUPRC=0.340455 | AUROC=0.841825 | Acc=0.940468 | P=0.740376 | R=0.137804 | Spec=0.982567
#     [FOLD 3] AUPRC=0.353748 | AUROC=0.833275 | Acc=0.941300 | P=0.756933 | R=0.142855 | Spec=0.980086
#     [FOLD 4] AUPRC=0.351630 | AUROC=0.832201 | Acc=0.938637 | P=0.829752 | R=0.149070 | Spec=0.979010
#     [FOLD 5] AUPRC=0.339918 | AUROC=0.826471 | Acc=0.940579 | P=0.818571 | R=0.143398 | Spec=0.978641
#
# [TRIAL 18] score(AUPRC_macro)=0.343234 | AUROC=0.832946 | Acc=0.940384 | P=0.779691 | R=0.145345 | Spec=0.980037
# [I 2026-05-07 19:24:16,962] Trial 18 finished with value: 0.3432344219836878 and parameters: {'n_estimators': 1118, 'learning_rate': 0.010060927133553738, 'num_leaves': 106, 'max_depth': 9, 'min_child_samples': 48, 'subsample': 0.9948668735382384, 'colsample_bytree': 0.7640453501990042, 'reg_lambda': 0.9390987001523136, 'reg_alpha': 0.010281092734903045, 'min_split_gain': 1.7143164298881695}. Best is trial 13 with value: 0.37638265456774866.
#
# ================================================================================
# [TRIAL 19] params:
# {
#   "objective": "binary",
#   "boosting_type": "gbdt",
#   "n_jobs": -1,
#   "random_state": 42,
#   "verbosity": -1,
#   "n_estimators": 1419,
#   "learning_rate": 0.021495308600491165,
#   "num_leaves": 64,
#   "max_depth": 12,
#   "min_child_samples": 35,
#   "subsample": 0.9354348266823663,
#   "colsample_bytree": 0.8498813604674549,
#   "reg_lambda": 0.05050657990214898,
#   "reg_alpha": 0.38023080600284087,
#   "min_split_gain": 0.6896060497059809
# }
#     [FOLD 1] AUPRC=0.361761 | AUROC=0.839039 | Acc=0.941434 | P=0.692119 | R=0.172219 | Spec=0.977262
#     [FOLD 2] AUPRC=0.349769 | AUROC=0.844261 | Acc=0.940912 | P=0.559797 | R=0.160759 | Spec=0.979802
#     [FOLD 3] AUPRC=0.361655 | AUROC=0.842376 | Acc=0.941800 | P=0.687831 | R=0.167662 | Spec=0.977056
#     [FOLD 4] AUPRC=0.378236 | AUROC=0.841479 | Acc=0.938582 | P=0.739709 | R=0.186504 | Spec=0.974528
#     [FOLD 5] AUPRC=0.357955 | AUROC=0.832969 | Acc=0.941245 | P=0.688434 | R=0.169499 | Spec=0.976484
#
# [TRIAL 19] score(AUPRC_macro)=0.361875 | AUROC=0.840025 | Acc=0.940795 | P=0.673578 | R=0.171329 | Spec=0.977026
# [I 2026-05-07 19:24:42,364] Trial 19 finished with value: 0.36187546741126136 and parameters: {'n_estimators': 1419, 'learning_rate': 0.021495308600491165, 'num_leaves': 64, 'max_depth': 12, 'min_child_samples': 35, 'subsample': 0.9354348266823663, 'colsample_bytree': 0.8498813604674549, 'reg_lambda': 0.05050657990214898, 'reg_alpha': 0.38023080600284087, 'min_split_gain': 0.6896060497059809}. Best is trial 13 with value: 0.37638265456774866.
#
# ================================================================================
# [TRIAL 20] params:
# {
#   "objective": "binary",
#   "boosting_type": "gbdt",
#   "n_jobs": -1,
#   "random_state": 42,
#   "verbosity": -1,
#   "n_estimators": 1700,
#   "learning_rate": 0.013612614564341284,
#   "num_leaves": 91,
#   "max_depth": 5,
#   "min_child_samples": 64,
#   "subsample": 0.8615446184152367,
#   "colsample_bytree": 0.98435084677316,
#   "reg_lambda": 13.447512261114895,
#   "reg_alpha": 0.00010494543807024175,
#   "min_split_gain": 4.848024319125552
# }
#     [FOLD 1] AUPRC=0.270970 | AUROC=0.798904 | Acc=0.938220 | P=0.725340 | R=0.091943 | Spec=0.981911
#     [FOLD 2] AUPRC=0.265719 | AUROC=0.808114 | Acc=0.938083 | P=0.735558 | R=0.090183 | Spec=0.983937
#     [FOLD 3] AUPRC=0.273035 | AUROC=0.795392 | Acc=0.939081 | P=0.741017 | R=0.091024 | Spec=0.981825
#     [FOLD 4] AUPRC=0.263917 | AUROC=0.788580 | Acc=0.935253 | P=0.698332 | R=0.089906 | Spec=0.980106
#     [FOLD 5] AUPRC=0.270661 | AUROC=0.790972 | Acc=0.937250 | P=0.707232 | R=0.086888 | Spec=0.979212
#
# [TRIAL 20] score(AUPRC_macro)=0.268860 | AUROC=0.796392 | Acc=0.937577 | P=0.721496 | R=0.089989 | Spec=0.981398
# [I 2026-05-07 19:25:03,086] Trial 20 finished with value: 0.26886047233206656 and parameters: {'n_estimators': 1700, 'learning_rate': 0.013612614564341284, 'num_leaves': 91, 'max_depth': 5, 'min_child_samples': 64, 'subsample': 0.8615446184152367, 'colsample_bytree': 0.98435084677316, 'reg_lambda': 13.447512261114895, 'reg_alpha': 0.00010494543807024175, 'min_split_gain': 4.848024319125552}. Best is trial 13 with value: 0.37638265456774866.
#
# ================================================================================
# [TRIAL 21] params:
# {
#   "objective": "binary",
#   "boosting_type": "gbdt",
#   "n_jobs": -1,
#   "random_state": 42,
#   "verbosity": -1,
#   "n_estimators": 908,
#   "learning_rate": 0.011412521526555334,
#   "num_leaves": 68,
#   "max_depth": 8,
#   "min_child_samples": 43,
#   "subsample": 0.9989879313923895,
#   "colsample_bytree": 0.7687511993658322,
#   "reg_lambda": 2.5041926027149812,
#   "reg_alpha": 0.15887068527225723,
#   "min_split_gain": 0.04922174424631101
# }
#     [FOLD 1] AUPRC=0.371674 | AUROC=0.845261 | Acc=0.940714 | P=0.608025 | R=0.208281 | Spec=0.974581
#     [FOLD 2] AUPRC=0.358968 | AUROC=0.852065 | Acc=0.940413 | P=0.540230 | R=0.184754 | Spec=0.976744
#     [FOLD 3] AUPRC=0.386443 | AUROC=0.844735 | Acc=0.941578 | P=0.533020 | R=0.201924 | Spec=0.975017
#     [FOLD 4] AUPRC=0.385338 | AUROC=0.845099 | Acc=0.939192 | P=0.651330 | R=0.209458 | Spec=0.972584
#     [FOLD 5] AUPRC=0.364725 | AUROC=0.842908 | Acc=0.942355 | P=0.594827 | R=0.206889 | Spec=0.975806
#
# [TRIAL 21] score(AUPRC_macro)=0.373429 | AUROC=0.846014 | Acc=0.940850 | P=0.585486 | R=0.202261 | Spec=0.974946
# [I 2026-05-07 19:26:06,978] Trial 21 finished with value: 0.3734294491548388 and parameters: {'n_estimators': 908, 'learning_rate': 0.011412521526555334, 'num_leaves': 68, 'max_depth': 8, 'min_child_samples': 43, 'subsample': 0.9989879313923895, 'colsample_bytree': 0.7687511993658322, 'reg_lambda': 2.5041926027149812, 'reg_alpha': 0.15887068527225723, 'min_split_gain': 0.04922174424631101}. Best is trial 13 with value: 0.37638265456774866.
#
# ================================================================================
# [TRIAL 22] params:
# {
#   "objective": "binary",
#   "boosting_type": "gbdt",
#   "n_jobs": -1,
#   "random_state": 42,
#   "verbosity": -1,
#   "n_estimators": 1197,
#   "learning_rate": 0.012895152719222012,
#   "num_leaves": 63,
#   "max_depth": 9,
#   "min_child_samples": 46,
#   "subsample": 0.9684648237401063,
#   "colsample_bytree": 0.7527998447162596,
#   "reg_lambda": 3.7797714858084217,
#   "reg_alpha": 0.08800640743625325,
#   "min_split_gain": 0.4879398100272049
# }
#     [FOLD 1] AUPRC=0.345730 | AUROC=0.837432 | Acc=0.941046 | P=0.729788 | R=0.172960 | Spec=0.976566
#     [FOLD 2] AUPRC=0.353498 | AUROC=0.847791 | Acc=0.940302 | P=0.697351 | R=0.157897 | Spec=0.978709
#     [FOLD 3] AUPRC=0.365958 | AUROC=0.841175 | Acc=0.941689 | P=0.753944 | R=0.175145 | Spec=0.976618
#     [FOLD 4] AUPRC=0.367293 | AUROC=0.839796 | Acc=0.938748 | P=0.799162 | R=0.174759 | Spec=0.975024
#     [FOLD 5] AUPRC=0.353686 | AUROC=0.832680 | Acc=0.941300 | P=0.669623 | R=0.156402 | Spec=0.977225
#
# [TRIAL 22] score(AUPRC_macro)=0.357233 | AUROC=0.839775 | Acc=0.940617 | P=0.729973 | R=0.167433 | Spec=0.976829
# [I 2026-05-07 19:26:42,822] Trial 22 finished with value: 0.35723287321219466 and parameters: {'n_estimators': 1197, 'learning_rate': 0.012895152719222012, 'num_leaves': 63, 'max_depth': 9, 'min_child_samples': 46, 'subsample': 0.9684648237401063, 'colsample_bytree': 0.7527998447162596, 'reg_lambda': 3.7797714858084217, 'reg_alpha': 0.08800640743625325, 'min_split_gain': 0.4879398100272049}. Best is trial 13 with value: 0.37638265456774866.
#
# ================================================================================
# [TRIAL 23] params:
# {
#   "objective": "binary",
#   "boosting_type": "gbdt",
#   "n_jobs": -1,
#   "random_state": 42,
#   "verbosity": -1,
#   "n_estimators": 1039,
#   "learning_rate": 0.019160216250491264,
#   "num_leaves": 117,
#   "max_depth": 7,
#   "min_child_samples": 34,
#   "subsample": 0.9994142129780654,
#   "colsample_bytree": 0.7059565224241247,
#   "reg_lambda": 0.6824434347841384,
#   "reg_alpha": 0.9650035038231141,
#   "min_split_gain": 0.9226919608387776
# }
#     [FOLD 1] AUPRC=0.333642 | AUROC=0.830902 | Acc=0.941212 | P=0.754635 | R=0.161735 | Spec=0.978329
#     [FOLD 2] AUPRC=0.353975 | AUROC=0.843317 | Acc=0.941467 | P=0.789821 | R=0.153460 | Spec=0.981676
#     [FOLD 3] AUPRC=0.355505 | AUROC=0.836048 | Acc=0.941245 | P=0.758450 | R=0.145703 | Spec=0.979078
#     [FOLD 4] AUPRC=0.363461 | AUROC=0.837313 | Acc=0.937861 | P=0.753424 | R=0.153904 | Spec=0.976563
#     [FOLD 5] AUPRC=0.347911 | AUROC=0.828852 | Acc=0.940413 | P=0.833587 | R=0.149705 | Spec=0.977655
#
# [TRIAL 23] score(AUPRC_macro)=0.350899 | AUROC=0.835286 | Acc=0.940440 | P=0.777983 | R=0.152902 | Spec=0.978660
# [I 2026-05-07 19:27:04,799] Trial 23 finished with value: 0.35089864306068635 and parameters: {'n_estimators': 1039, 'learning_rate': 0.019160216250491264, 'num_leaves': 117, 'max_depth': 7, 'min_child_samples': 34, 'subsample': 0.9994142129780654, 'colsample_bytree': 0.7059565224241247, 'reg_lambda': 0.6824434347841384, 'reg_alpha': 0.9650035038231141, 'min_split_gain': 0.9226919608387776}. Best is trial 13 with value: 0.37638265456774866.
#
# ================================================================================
# [TRIAL 24] params:
# {
#   "objective": "binary",
#   "boosting_type": "gbdt",
#   "n_jobs": -1,
#   "random_state": 42,
#   "verbosity": -1,
#   "n_estimators": 797,
#   "learning_rate": 0.02631017853054883,
#   "num_leaves": 78,
#   "max_depth": 10,
#   "min_child_samples": 57,
#   "subsample": 0.8960785942371853,
#   "colsample_bytree": 0.8630826230398995,
#   "reg_lambda": 12.046027046660202,
#   "reg_alpha": 0.00969553246325887,
#   "min_split_gain": 0.26850878888867663
# }
#     [FOLD 1] AUPRC=0.344298 | AUROC=0.841146 | Acc=0.939993 | P=0.692985 | R=0.162750 | Spec=0.975633
#     [FOLD 2] AUPRC=0.340660 | AUROC=0.844311 | Acc=0.939192 | P=0.496156 | R=0.150206 | Spec=0.977648
#     [FOLD 3] AUPRC=0.373147 | AUROC=0.839655 | Acc=0.940579 | P=0.703061 | R=0.167181 | Spec=0.976947
#     [FOLD 4] AUPRC=0.359163 | AUROC=0.838569 | Acc=0.938526 | P=0.740391 | R=0.168741 | Spec=0.974376
#     [FOLD 5] AUPRC=0.359748 | AUROC=0.835965 | Acc=0.941245 | P=0.730586 | R=0.156891 | Spec=0.976234
#
# [TRIAL 24] score(AUPRC_macro)=0.355403 | AUROC=0.839929 | Acc=0.939907 | P=0.672636 | R=0.161154 | Spec=0.976168
# [I 2026-05-07 19:27:28,477] Trial 24 finished with value: 0.35540341987682694 and parameters: {'n_estimators': 797, 'learning_rate': 0.02631017853054883, 'num_leaves': 78, 'max_depth': 10, 'min_child_samples': 57, 'subsample': 0.8960785942371853, 'colsample_bytree': 0.8630826230398995, 'reg_lambda': 12.046027046660202, 'reg_alpha': 0.00969553246325887, 'min_split_gain': 0.26850878888867663}. Best is trial 13 with value: 0.37638265456774866.
#
# ================================================================================
# [TRIAL 25] params:
# {
#   "objective": "binary",
#   "boosting_type": "gbdt",
#   "n_jobs": -1,
#   "random_state": 42,
#   "verbosity": -1,
#   "n_estimators": 1282,
#   "learning_rate": 0.012511052131487581,
#   "num_leaves": 55,
#   "max_depth": 14,
#   "min_child_samples": 45,
#   "subsample": 0.9595226003967243,
#   "colsample_bytree": 0.9331270398923089,
#   "reg_lambda": 2.636145994342891,
#   "reg_alpha": 0.1716484798173885,
#   "min_split_gain": 2.061695052729005
# }
#     [FOLD 1] AUPRC=0.320284 | AUROC=0.826496 | Acc=0.940658 | P=0.761996 | R=0.136722 | Spec=0.980089
#     [FOLD 2] AUPRC=0.330979 | AUROC=0.833331 | Acc=0.939747 | P=0.778182 | R=0.135707 | Spec=0.981918
#     [FOLD 3] AUPRC=0.334837 | AUROC=0.827676 | Acc=0.941079 | P=0.756178 | R=0.139129 | Spec=0.980417
#     [FOLD 4] AUPRC=0.332086 | AUROC=0.823134 | Acc=0.938249 | P=0.812065 | R=0.144628 | Spec=0.978496
#     [FOLD 5] AUPRC=0.323866 | AUROC=0.818817 | Acc=0.939636 | P=0.823349 | R=0.128763 | Spec=0.978066
#
# [TRIAL 25] score(AUPRC_macro)=0.328410 | AUROC=0.825891 | Acc=0.939874 | P=0.786354 | R=0.136990 | Spec=0.979797
# [I 2026-05-07 19:27:50,488] Trial 25 finished with value: 0.3284102775106629 and parameters: {'n_estimators': 1282, 'learning_rate': 0.012511052131487581, 'num_leaves': 55, 'max_depth': 14, 'min_child_samples': 45, 'subsample': 0.9595226003967243, 'colsample_bytree': 0.9331270398923089, 'reg_lambda': 2.636145994342891, 'reg_alpha': 0.1716484798173885, 'min_split_gain': 2.061695052729005}. Best is trial 13 with value: 0.37638265456774866.
#
# ================================================================================
# [TRIAL 26] params:
# {
#   "objective": "binary",
#   "boosting_type": "gbdt",
#   "n_jobs": -1,
#   "random_state": 42,
#   "verbosity": -1,
#   "n_estimators": 986,
#   "learning_rate": 0.036866446184889066,
#   "num_leaves": 88,
#   "max_depth": 1,
#   "min_child_samples": 21,
#   "subsample": 0.8906669308739337,
#   "colsample_bytree": 0.8010887640229132,
#   "reg_lambda": 0.5438279740338109,
#   "reg_alpha": 1.915391620817656,
#   "min_split_gain": 0.9415591917176228
# }
#     [FOLD 1] AUPRC=0.313950 | AUROC=0.826880 | Acc=0.939772 | P=0.759698 | R=0.132960 | Spec=0.980072
#     [FOLD 2] AUPRC=0.332596 | AUROC=0.840551 | Acc=0.939581 | P=0.617938 | R=0.131525 | Spec=0.983104
#     [FOLD 3] AUPRC=0.332875 | AUROC=0.827029 | Acc=0.940968 | P=0.738346 | R=0.139740 | Spec=0.980108
#     [FOLD 4] AUPRC=0.328404 | AUROC=0.827032 | Acc=0.938859 | P=0.762037 | R=0.132226 | Spec=0.979651
#     [FOLD 5] AUPRC=0.317246 | AUROC=0.818343 | Acc=0.940413 | P=0.797768 | R=0.135390 | Spec=0.979353
#
# [TRIAL 26] score(AUPRC_macro)=0.325014 | AUROC=0.827967 | Acc=0.939918 | P=0.735157 | R=0.134368 | Spec=0.980457
# [I 2026-05-07 19:28:08,169] Trial 26 finished with value: 0.3250142645068742 and parameters: {'n_estimators': 986, 'learning_rate': 0.036866446184889066, 'num_leaves': 88, 'max_depth': 1, 'min_child_samples': 21, 'subsample': 0.8906669308739337, 'colsample_bytree': 0.8010887640229132, 'reg_lambda': 0.5438279740338109, 'reg_alpha': 1.915391620817656, 'min_split_gain': 0.9415591917176228}. Best is trial 13 with value: 0.37638265456774866.
#
# ================================================================================
# [TRIAL 27] params:
# {
#   "objective": "binary",
#   "boosting_type": "gbdt",
#   "n_jobs": -1,
#   "random_state": 42,
#   "verbosity": -1,
#   "n_estimators": 565,
#   "learning_rate": 0.058095113612954746,
#   "num_leaves": 123,
#   "max_depth": 8,
#   "min_child_samples": 32,
#   "subsample": 0.9393848020446602,
#   "colsample_bytree": 0.7457090728091004,
#   "reg_lambda": 0.1362617846438644,
#   "reg_alpha": 0.02473551584715785,
#   "min_split_gain": 3.00120582375693
# }
#     [FOLD 1] AUPRC=0.330964 | AUROC=0.824460 | Acc=0.940714 | P=0.797984 | R=0.143463 | Spec=0.980720
#     [FOLD 2] AUPRC=0.353151 | AUROC=0.840058 | Acc=0.940746 | P=0.756992 | R=0.151397 | Spec=0.982354
#     [FOLD 3] AUPRC=0.338615 | AUROC=0.829113 | Acc=0.940857 | P=0.741961 | R=0.136568 | Spec=0.980907
#     [FOLD 4] AUPRC=0.345712 | AUROC=0.825738 | Acc=0.938027 | P=0.761716 | R=0.138867 | Spec=0.979078
#     [FOLD 5] AUPRC=0.331085 | AUROC=0.819110 | Acc=0.940579 | P=0.844447 | R=0.140747 | Spec=0.978147
#
# [TRIAL 27] score(AUPRC_macro)=0.339905 | AUROC=0.827696 | Acc=0.940184 | P=0.780620 | R=0.142209 | Spec=0.980241
# [I 2026-05-07 19:28:19,715] Trial 27 finished with value: 0.3399052821379253 and parameters: {'n_estimators': 565, 'learning_rate': 0.058095113612954746, 'num_leaves': 123, 'max_depth': 8, 'min_child_samples': 32, 'subsample': 0.9393848020446602, 'colsample_bytree': 0.7457090728091004, 'reg_lambda': 0.1362617846438644, 'reg_alpha': 0.02473551584715785, 'min_split_gain': 3.00120582375693}. Best is trial 13 with value: 0.37638265456774866.
#
# ================================================================================
# [TRIAL 28] params:
# {
#   "objective": "binary",
#   "boosting_type": "gbdt",
#   "n_jobs": -1,
#   "random_state": 42,
#   "verbosity": -1,
#   "n_estimators": 890,
#   "learning_rate": 0.012194357183268707,
#   "num_leaves": 52,
#   "max_depth": 5,
#   "min_child_samples": 11,
#   "subsample": 0.7781680396745365,
#   "colsample_bytree": 0.6958197457314187,
#   "reg_lambda": 6.282795224078963,
#   "reg_alpha": 0.003007627424981929,
#   "min_split_gain": 4.274628776972462
# }
#     [FOLD 1] AUPRC=0.305252 | AUROC=0.815837 | Acc=0.940991 | P=0.849327 | R=0.127191 | Spec=0.982485
#     [FOLD 2] AUPRC=0.314381 | AUROC=0.824045 | Acc=0.938915 | P=0.775762 | R=0.108277 | Spec=0.984038
#     [FOLD 3] AUPRC=0.311547 | AUROC=0.813771 | Acc=0.940302 | P=0.794998 | R=0.114505 | Spec=0.982283
#     [FOLD 4] AUPRC=0.305887 | AUROC=0.806661 | Acc=0.936917 | P=0.809437 | R=0.108172 | Spec=0.980748
#     [FOLD 5] AUPRC=0.298095 | AUROC=0.808325 | Acc=0.938970 | P=0.841283 | R=0.106491 | Spec=0.979982
#
# [TRIAL 28] score(AUPRC_macro)=0.307033 | AUROC=0.813728 | Acc=0.939219 | P=0.814161 | R=0.112927 | Spec=0.981907
# [I 2026-05-07 19:28:42,425] Trial 28 finished with value: 0.3070325602869941 and parameters: {'n_estimators': 890, 'learning_rate': 0.012194357183268707, 'num_leaves': 52, 'max_depth': 5, 'min_child_samples': 11, 'subsample': 0.7781680396745365, 'colsample_bytree': 0.6958197457314187, 'reg_lambda': 6.282795224078963, 'reg_alpha': 0.003007627424981929, 'min_split_gain': 4.274628776972462}. Best is trial 13 with value: 0.37638265456774866.
#
# ================================================================================
# [TRIAL 29] params:
# {
#   "objective": "binary",
#   "boosting_type": "gbdt",
#   "n_jobs": -1,
#   "random_state": 42,
#   "verbosity": -1,
#   "n_estimators": 1422,
#   "learning_rate": 0.016236972731924884,
#   "num_leaves": 172,
#   "max_depth": 13,
#   "min_child_samples": 41,
#   "subsample": 0.6972947731222421,
#   "colsample_bytree": 0.6066353473015387,
#   "reg_lambda": 18.829855828376054,
#   "reg_alpha": 0.0006186677478754244,
#   "min_split_gain": 0.3593190220090755
# }
#     [FOLD 1] AUPRC=0.344014 | AUROC=0.841803 | Acc=0.941379 | P=0.767586 | R=0.169446 | Spec=0.976643
#     [FOLD 2] AUPRC=0.344331 | AUROC=0.847462 | Acc=0.940302 | P=0.679509 | R=0.154352 | Spec=0.978579
#     [FOLD 3] AUPRC=0.367198 | AUROC=0.839965 | Acc=0.941467 | P=0.764859 | R=0.163635 | Spec=0.976967
#     [FOLD 4] AUPRC=0.358619 | AUROC=0.841913 | Acc=0.938748 | P=0.753636 | R=0.168050 | Spec=0.975137
#     [FOLD 5] AUPRC=0.353341 | AUROC=0.833506 | Acc=0.941356 | P=0.798711 | R=0.159812 | Spec=0.976296
#
# [TRIAL 29] score(AUPRC_macro)=0.353501 | AUROC=0.840930 | Acc=0.940650 | P=0.752860 | R=0.163059 | Spec=0.976724
# [I 2026-05-07 19:29:46,033] Trial 29 finished with value: 0.35350070906031716 and parameters: {'n_estimators': 1422, 'learning_rate': 0.016236972731924884, 'num_leaves': 172, 'max_depth': 13, 'min_child_samples': 41, 'subsample': 0.6972947731222421, 'colsample_bytree': 0.6066353473015387, 'reg_lambda': 18.829855828376054, 'reg_alpha': 0.0006186677478754244, 'min_split_gain': 0.3593190220090755}. Best is trial 13 with value: 0.37638265456774866.
#
# ================ BEST =================
# Best trial: 13
# Best AUPRC_macro: 0.37638265456774866
# Best params:
# {
#   "n_estimators": 1045,
#   "learning_rate": 0.010136284547794212,
#   "num_leaves": 86,
#   "max_depth": 8,
#   "min_child_samples": 39,
#   "subsample": 0.999515774191902,
#   "colsample_bytree": 0.8184200828646883,
#   "reg_lambda": 2.344862431497,
#   "reg_alpha": 0.16036783824922757,
#   "min_split_gain": 0.008279365666262343
# }
# [SAVED] ./optuna_singlemodel_LIGHTGBM_30trials_5fold_results.csv
# [SAVED] ./used_label_columns_24.csv
# [SAVED] ./used_feature_columns.csv

# %%
# -*- coding: utf-8 -*-
import os
import glob
import json
import warnings
import numpy as np
import pandas as pd

import optuna
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import roc_auc_score, average_precision_score
from sklearn.ensemble import RandomForestClassifier

# =========================
# 0) 配置 & 尽量屏蔽警告
# =========================
RANDOM_SEED = 42
N_TRIALS = 30
N_SPLITS = 5
THRESH = 0.5

os.environ["PYTHONWARNINGS"] = "ignore"
warnings.filterwarnings("ignore", category=UserWarning)
warnings.filterwarnings("ignore", category=FutureWarning)
warnings.filterwarnings("ignore", category=RuntimeWarning)

# 读取特征文件
FEATURE_FILE_GLOB = "./Malodors_Morgan_features.xlsx"

# RandomForest 固定参数，Optuna 只搜索部分超参
BASE_RF_PARAMS = dict(
    n_jobs=-1,
    random_state=RANDOM_SEED,
)


# =========================
# 1) 读取特征文件 & 按固定列位置划分 SMILES / y / X
# =========================
def find_feature_file(pattern: str):
    cands = sorted(glob.glob(pattern))
    if not cands:
        raise FileNotFoundError(
            f"找不到特征文件：{pattern}\n"
            f"请确认 xlsx 文件名，或修改 FEATURE_FILE_GLOB。"
        )
    return cands[-1]


def load_Xy_from_feature_file(xlsx_path: str):
    """
    固定数据格式：
    第 1 列：SMILES
    第 2-25 列：24 个 y 标签
    第 26 列及之后：X 特征列

    说明：
    - 不再通过 0/1 自动判断 y 标签列；
    - 避免 Morgan bit、Rule、FG 等 0/1 特征被误识别为标签；
    - 适用于当前 24 标签任务。
    """
    df = pd.read_excel(xlsx_path)

    if df.shape[1] < 26:
        raise ValueError(
            f"当前文件列数为 {df.shape[1]}，不足以按“1列SMILES + 24列标签 + 特征列”划分。"
        )

    # 固定列位置
    smiles_col = df.columns[0]
    label_cols = list(df.columns[1:25])
    feature_cols = list(df.columns[25:])

    if len(label_cols) != 24:
        raise ValueError(f"标签列数量应为 24，但当前识别为 {len(label_cols)}。")

    if len(feature_cols) == 0:
        raise ValueError("未识别到特征列。请确认第 26 列之后为 X 特征。")

    # y 标签转为 0/1 整数
    y_df = df[label_cols].copy()
    y_df = y_df.apply(pd.to_numeric, errors="coerce").fillna(0).astype(int)

    # 检查 y 标签是否为 0/1
    invalid_label_cols = []
    for c in label_cols:
        vals = set(pd.unique(y_df[c].dropna()))
        if not vals.issubset({0, 1}):
            invalid_label_cols.append(c)

    if invalid_label_cols:
        raise ValueError(
            "以下标签列不是标准 0/1 标签，请检查数据：\n"
            + "\n".join(map(str, invalid_label_cols))
        )

    # X 特征转为数值
    X_df = df[feature_cols].copy()
    X_df = X_df.apply(pd.to_numeric, errors="coerce").fillna(0)

    X = X_df.astype(np.float32).values
    y = y_df.values.astype(int)

    if X.shape[0] != y.shape[0]:
        raise ValueError("X 和 y 行数不一致，请检查文件。")

    print("[INFO] Column split mode: fixed-position")
    print(f"[INFO] SMILES column: {smiles_col}")
    print(f"[INFO] Label columns: columns 2-25, n={len(label_cols)}")
    print(f"[INFO] Feature columns: columns 26-end, n={len(feature_cols)}")

    print("\n[INFO] Label columns:")
    for i, c in enumerate(label_cols, start=1):
        print(f"  y{i:02d}: {c}")

    return X, y, feature_cols, label_cols, df


# =========================
# 2) 指标：macro
# =========================
def multilabel_macro_metrics(y_true, y_prob, thresh=0.5):
    y_true = np.asarray(y_true).astype(int)
    y_prob = np.asarray(y_prob).astype(float)
    y_pred = (y_prob >= thresh).astype(int)

    L = y_true.shape[1]
    accs, precs, recs, specs = [], [], [], []
    aurocs, auprcs = [], []

    for k in range(L):
        yt = y_true[:, k]
        yp = y_pred[:, k]
        ys = y_prob[:, k]

        tp = int(np.sum((yt == 1) & (yp == 1)))
        tn = int(np.sum((yt == 0) & (yp == 0)))
        fp = int(np.sum((yt == 0) & (yp == 1)))
        fn = int(np.sum((yt == 1) & (yp == 0)))
        n = len(yt)

        accs.append((tp + tn) / n if n else np.nan)
        precs.append(tp / (tp + fp) if (tp + fp) else np.nan)
        recs.append(tp / (tp + fn) if (tp + fn) else np.nan)
        specs.append(tn / (tn + fp) if (tn + fp) else np.nan)

        if len(np.unique(yt)) == 2:
            aurocs.append(roc_auc_score(yt, ys))
            auprcs.append(average_precision_score(yt, ys))
        else:
            aurocs.append(np.nan)
            auprcs.append(np.nan)

    def nanmean(x):
        return float(np.nanmean(np.asarray(x, dtype=float)))

    return {
        "Accuracy_macro": nanmean(accs),
        "Precision_macro": nanmean(precs),
        "Recall_macro": nanmean(recs),
        "Specificity_macro": nanmean(specs),
        "AUROC_macro": nanmean(aurocs),
        "AUPRC_macro": nanmean(auprcs),
        "AUROC_valid_labels": int(np.sum(~np.isnan(aurocs))),
        "AUPRC_valid_labels": int(np.sum(~np.isnan(auprcs))),
        "n_labels": int(L),
    }


def extract_positive_proba(p, n_labels: int, classes_list=None):
    """
    兼容：
    - multi-output RF 的 predict_proba: list，长度=labels，每个元素形状为 (n, n_classes_k)
    - 某标签在该 fold 训练集里只有单类时，predict_proba 可能为 (n, 1)
    """
    if isinstance(p, list):
        out = np.zeros((p[0].shape[0], n_labels), dtype=np.float32)

        for k in range(n_labels):
            pk = p[k]

            if pk.ndim != 2:
                raise ValueError(f"predict_proba[{k}] 形状异常: {pk.shape}")

            if pk.shape[1] == 2:
                # 优先按 classes_ 找 class == 1 对应的概率列
                if classes_list is not None and len(classes_list) == n_labels:
                    cls = list(classes_list[k])
                    if 1 in cls:
                        j = cls.index(1)
                        out[:, k] = pk[:, j].astype(np.float32)
                    else:
                        out[:, k] = 0.0
                else:
                    out[:, k] = pk[:, 1].astype(np.float32)

            elif pk.shape[1] == 1:
                # 只有单一类别：若该类别是 1，则概率恒为 1；若是 0，则概率恒为 0
                if classes_list is not None and len(classes_list) == n_labels:
                    only_cls = int(list(classes_list[k])[0])
                    out[:, k] = 1.0 if only_cls == 1 else 0.0
                else:
                    out[:, k] = 0.0

            else:
                raise ValueError(f"predict_proba[{k}] 类别数异常: {pk.shape[1]}")

        return out

    # 非 list 情况，一般不会出现在 multi-output RF
    p = np.asarray(p)

    if p.ndim == 3 and p.shape[-1] == 2:
        return p[:, :, 1].astype(np.float32)

    if p.ndim == 2:
        if p.shape[1] == 2 and n_labels == 1:
            return p[:, 1:2].astype(np.float32)
        return p.astype(np.float32)

    raise ValueError(f"无法解析 predict_proba 输出形状: {p.shape}")


# =========================
# 3) 近似分层 5 折：用 label cardinality 分层
# =========================
def make_stratify_target(y: np.ndarray, n_bins: int = 10):
    """
    多标签任务中没有直接的 StratifiedKFold。
    这里使用每个样本的标签数量 label cardinality 做近似分层。
    """
    card = y.sum(axis=1).astype(int)
    uniq = np.unique(card)

    if len(uniq) <= 15:
        return card

    r = pd.Series(card).rank(method="average").values
    bins = pd.qcut(
        r,
        q=min(n_bins, len(np.unique(r))),
        labels=False,
        duplicates="drop"
    )

    return np.asarray(bins, dtype=int)


def build_folds(X, y, n_splits=5, seed=42):
    strat_y = make_stratify_target(y)
    skf = StratifiedKFold(
        n_splits=n_splits,
        shuffle=True,
        random_state=seed
    )
    return list(skf.split(X, strat_y))


# =========================
# 4) 5 折 CV 评估：RF
# =========================
def cv_eval_one_paramset(X, y, folds, params, thresh=0.5):
    n_labels = y.shape[1]
    fold_metrics = []

    for fold_id, (tr_idx, va_idx) in enumerate(folds, start=1):
        X_tr, X_va = X[tr_idx], X[va_idx]
        y_tr, y_va = y[tr_idx], y[va_idx]

        clf = RandomForestClassifier(**params)
        clf.fit(X_tr, y_tr)

        p = clf.predict_proba(X_va)
        y_prob = extract_positive_proba(
            p,
            n_labels=n_labels,
            classes_list=getattr(clf, "classes_", None)
        )

        m = multilabel_macro_metrics(y_va, y_prob, thresh=thresh)
        fold_metrics.append(m)

        print(
            f"    [FOLD {fold_id}] "
            f"AUPRC={m['AUPRC_macro']:.6f} | "
            f"AUROC={m['AUROC_macro']:.6f} | "
            f"Acc={m['Accuracy_macro']:.6f} | "
            f"P={m['Precision_macro']:.6f} | "
            f"R={m['Recall_macro']:.6f} | "
            f"Spec={m['Specificity_macro']:.6f}"
        )

    keys = list(fold_metrics[0].keys())
    mean_metrics = {}

    for k in keys:
        vals = [fm[k] for fm in fold_metrics]
        if isinstance(vals[0], float):
            mean_metrics[k] = float(np.nanmean(vals))
        else:
            mean_metrics[k] = vals[-1]

    return mean_metrics


# =========================
# 5) Optuna 超参空间：RF
# =========================
def build_trial_params(trial: optuna.Trial):
    params = dict(BASE_RF_PARAMS)

    max_depth_raw = trial.suggest_int("max_depth", 0, 40)
    max_depth = None if max_depth_raw == 0 else max_depth_raw

    params.update({
        "n_estimators": trial.suggest_int("n_estimators", 300, 1500),
        "max_depth": max_depth,
        "max_features": trial.suggest_categorical(
            "max_features",
            ["sqrt", "log2", 0.3, 0.5, 0.8, 1.0]
        ),
        "min_samples_split": trial.suggest_int("min_samples_split", 2, 20),
        "min_samples_leaf": trial.suggest_int("min_samples_leaf", 1, 10),
        "bootstrap": trial.suggest_categorical("bootstrap", [True, False]),
        "criterion": trial.suggest_categorical(
            "criterion",
            ["gini", "entropy", "log_loss"]
        ),
    })

    return params


# =========================
# 6) 主流程：读特征 -> 固定 folds -> Optuna -> 输出保存
# =========================
def main():
    feature_file = find_feature_file(FEATURE_FILE_GLOB)
    print("[INFO] Using feature file:", feature_file)

    X, y, feat_cols, label_cols, df_all = load_Xy_from_feature_file(feature_file)

    print(
        f"\n[INFO] X shape={X.shape} "
        f"(features={len(feat_cols)}) | "
        f"y shape={y.shape} "
        f"(labels={len(label_cols)})"
    )

    folds = build_folds(X, y, n_splits=N_SPLITS, seed=RANDOM_SEED)
    print(f"[INFO] Prepared fixed {N_SPLITS}-fold splits for all trials.")

    def objective(trial: optuna.Trial):
        params = build_trial_params(trial)

        print("\n" + "=" * 80)
        print(f"[TRIAL {trial.number:02d}] params:")
        print(json.dumps(params, indent=2, ensure_ascii=False, default=str))

        mean_metrics = cv_eval_one_paramset(
            X,
            y,
            folds,
            params,
            thresh=THRESH
        )

        score = mean_metrics["AUPRC_macro"]

        print(
            f"\n[TRIAL {trial.number:02d}] "
            f"score(AUPRC_macro)={score:.6f} | "
            f"AUROC={mean_metrics['AUROC_macro']:.6f} | "
            f"Acc={mean_metrics['Accuracy_macro']:.6f} | "
            f"P={mean_metrics['Precision_macro']:.6f} | "
            f"R={mean_metrics['Recall_macro']:.6f} | "
            f"Spec={mean_metrics['Specificity_macro']:.6f}"
        )

        for k, v in mean_metrics.items():
            trial.set_user_attr(k, v)

        return score

    study = optuna.create_study(
        direction="maximize",
        sampler=optuna.samplers.TPESampler(seed=RANDOM_SEED),
    )

    study.optimize(
        objective,
        n_trials=N_TRIALS,
        show_progress_bar=True
    )

    print("\n================ BEST =================")
    print("Best trial:", study.best_trial.number)
    print("Best AUPRC_macro:", study.best_value)
    print("Best params:")
    print(json.dumps(study.best_params, indent=2, ensure_ascii=False))

    rows = []
    for t in study.trials:
        if t.value is None:
            continue

        row = {
            "trial": t.number,
            "AUPRC_macro": t.value,
            **t.params
        }

        row.update({
            k: v for k, v in t.user_attrs.items()
            if k.endswith("_macro")
        })

        rows.append(row)

    res_df = pd.DataFrame(rows).sort_values(
        "AUPRC_macro",
        ascending=False
    )

    out_csv = "./optuna_singlemodel_RF_30trials_5fold_results.csv"
    res_df.to_csv(out_csv, index=False, encoding="utf-8-sig")
    print("[SAVED]", out_csv)

    # 额外保存标签列和特征列，便于后续核查
    label_out = "./used_label_columns_24.csv"
    feature_out = "./used_feature_columns.csv"

    pd.DataFrame({"label_col": label_cols}).to_csv(
        label_out,
        index=False,
        encoding="utf-8-sig"
    )

    pd.DataFrame({"feature_col": feat_cols}).to_csv(
        feature_out,
        index=False,
        encoding="utf-8-sig"
    )

    print("[SAVED]", label_out)
    print("[SAVED]", feature_out)


if __name__ == "__main__":
    main()
# Out:
# [INFO] Using feature file: ./Malodors_Morgan_features.xlsx
# [I 2026-05-07 19:30:39,759] A new study created in memory with name: no-name-438bc081-03f9-44b4-bac4-cd8903affe10
# [INFO] Column split mode: fixed-position
# [INFO] SMILES column: Canonical_SMILES
# [INFO] Label columns: columns 2-25, n=24
# [INFO] Feature columns: columns 26-end, n=2048
#
# [INFO] Label columns:
#   y01: alcoholic
#   y02: aldehydic
#   y03: almond
#   y04: aromatic
#   y05: burnt
#   y06: cabbage
#   y07: cheesy
#   y08: cherry
#   y09: chocolate
#   y10: ethereal
#   y11: fishy
#   y12: fruity
#   y13: garlic
#   y14: gassy
#   y15: green
#   y16: ketonic
#   y17: musty
#   y18: pungent
#   y19: sharp
#   y20: solvent
#   y21: sour
#   y22: sulfurous
#   y23: sweaty
#   y24: sweet
#
# [INFO] X shape=(3756, 2048) (features=2048) | y shape=(3756, 24) (labels=24)
# [INFO] Prepared fixed 5-fold splits for all trials.
#   0%|          | 0/30 [00:00<?, ?it/s]
# ================================================================================
# [TRIAL 00] params:
# {
#   "n_jobs": -1,
#   "random_state": 42,
#   "n_estimators": 1441,
#   "max_depth": 15,
#   "max_features": 1.0,
#   "min_samples_split": 13,
#   "min_samples_leaf": 8,
#   "bootstrap": false,
#   "criterion": "gini"
# }
#     [FOLD 1] AUPRC=0.276561 | AUROC=0.755891 | Acc=0.935228 | P=0.544351 | R=0.190972 | Spec=0.963499
#     [FOLD 2] AUPRC=0.277476 | AUROC=0.781282 | Acc=0.934143 | P=0.484054 | R=0.200868 | Spec=0.963604
#     [FOLD 3] AUPRC=0.283867 | AUROC=0.758796 | Acc=0.936085 | P=0.442791 | R=0.212220 | Spec=0.962408
#     [FOLD 4] AUPRC=0.284564 | AUROC=0.759272 | Acc=0.932590 | P=0.460353 | R=0.181733 | Spec=0.961208
#     [FOLD 5] AUPRC=0.300557 | AUROC=0.755225 | Acc=0.937139 | P=0.550673 | R=0.213790 | Spec=0.964575
#
# [TRIAL 00] score(AUPRC_macro)=0.284605 | AUROC=0.762093 | Acc=0.935037 | P=0.496444 | R=0.199917 | Spec=0.963059
# [I 2026-05-07 19:32:39,848] Trial 0 finished with value: 0.2846051029582034 and parameters: {'max_depth': 15, 'n_estimators': 1441, 'max_features': 1.0, 'min_samples_split': 13, 'min_samples_leaf': 8, 'bootstrap': False, 'criterion': 'gini'}. Best is trial 0 with value: 0.2846051029582034.
#
# ================================================================================
# [TRIAL 01] params:
# {
#   "n_jobs": -1,
#   "random_state": 42,
#   "n_estimators": 665,
#   "max_depth": 7,
#   "max_features": 0.5,
#   "min_samples_split": 8,
#   "min_samples_leaf": 5,
#   "bootstrap": true,
#   "criterion": "entropy"
# }
#     [FOLD 1] AUPRC=0.347128 | AUROC=0.849696 | Acc=0.938774 | P=0.729122 | R=0.127117 | Spec=0.980306
#     [FOLD 2] AUPRC=0.343600 | AUROC=0.858620 | Acc=0.939137 | P=0.664155 | R=0.124406 | Spec=0.982951
#     [FOLD 3] AUPRC=0.359684 | AUROC=0.844517 | Acc=0.940857 | P=0.738018 | R=0.121376 | Spec=0.982303
#     [FOLD 4] AUPRC=0.365858 | AUROC=0.827163 | Acc=0.937583 | P=0.809215 | R=0.127594 | Spec=0.979805
#     [FOLD 5] AUPRC=0.359867 | AUROC=0.836669 | Acc=0.940801 | P=0.838690 | R=0.130794 | Spec=0.981242
#
# [TRIAL 01] score(AUPRC_macro)=0.355227 | AUROC=0.843333 | Acc=0.939430 | P=0.755840 | R=0.126257 | Spec=0.981321
# [I 2026-05-07 19:32:59,387] Trial 1 finished with value: 0.3552271528789121 and parameters: {'max_depth': 7, 'n_estimators': 665, 'max_features': 0.5, 'min_samples_split': 8, 'min_samples_leaf': 5, 'bootstrap': True, 'criterion': 'entropy'}. Best is trial 1 with value: 0.3552271528789121.
#
# ================================================================================
# [TRIAL 02] params:
# {
#   "n_jobs": -1,
#   "random_state": 42,
#   "n_estimators": 504,
#   "max_depth": 24,
#   "max_features": 0.3,
#   "min_samples_split": 15,
#   "min_samples_leaf": 5,
#   "bootstrap": false,
#   "criterion": "entropy"
# }
#     [FOLD 1] AUPRC=0.378938 | AUROC=0.857937 | Acc=0.940714 | P=0.608388 | R=0.166145 | Spec=0.975961
#     [FOLD 2] AUPRC=0.365375 | AUROC=0.854606 | Acc=0.939913 | P=0.548238 | R=0.167173 | Spec=0.977319
#     [FOLD 3] AUPRC=0.378810 | AUROC=0.843396 | Acc=0.943409 | P=0.618529 | R=0.189574 | Spec=0.977199
#     [FOLD 4] AUPRC=0.386313 | AUROC=0.834546 | Acc=0.939802 | P=0.662869 | R=0.169701 | Spec=0.974747
#     [FOLD 5] AUPRC=0.370794 | AUROC=0.837401 | Acc=0.943020 | P=0.799142 | R=0.189096 | Spec=0.975967
#
# [TRIAL 02] score(AUPRC_macro)=0.376046 | AUROC=0.845577 | Acc=0.941372 | P=0.647433 | R=0.176338 | Spec=0.976239
# [I 2026-05-07 19:33:16,853] Trial 2 finished with value: 0.3760458823126998 and parameters: {'max_depth': 24, 'n_estimators': 504, 'max_features': 0.3, 'min_samples_split': 15, 'min_samples_leaf': 5, 'bootstrap': False, 'criterion': 'entropy'}. Best is trial 2 with value: 0.3760458823126998.
#
# ================================================================================
# [TRIAL 03] params:
# {
#   "n_jobs": -1,
#   "random_state": 42,
#   "n_estimators": 674,
#   "max_depth": 27,
#   "max_features": 0.5,
#   "min_samples_split": 19,
#   "min_samples_leaf": 6,
#   "bootstrap": true,
#   "criterion": "log_loss"
# }
#     [FOLD 1] AUPRC=0.368945 | AUROC=0.859603 | Acc=0.939218 | P=0.725043 | R=0.150217 | Spec=0.976159
#     [FOLD 2] AUPRC=0.368910 | AUROC=0.857673 | Acc=0.939636 | P=0.730486 | R=0.153578 | Spec=0.979002
#     [FOLD 3] AUPRC=0.377547 | AUROC=0.844575 | Acc=0.942521 | P=0.756597 | R=0.164574 | Spec=0.978485
#     [FOLD 4] AUPRC=0.390954 | AUROC=0.839941 | Acc=0.939581 | P=0.755471 | R=0.158864 | Spec=0.975698
#     [FOLD 5] AUPRC=0.376660 | AUROC=0.839765 | Acc=0.942188 | P=0.796347 | R=0.169029 | Spec=0.977771
#
# [TRIAL 03] score(AUPRC_macro)=0.376603 | AUROC=0.848311 | Acc=0.940629 | P=0.752789 | R=0.159252 | Spec=0.977423
# [I 2026-05-07 19:33:37,705] Trial 3 finished with value: 0.37660309485573196 and parameters: {'max_depth': 27, 'n_estimators': 674, 'max_features': 0.5, 'min_samples_split': 19, 'min_samples_leaf': 6, 'bootstrap': True, 'criterion': 'log_loss'}. Best is trial 3 with value: 0.37660309485573196.
#
# ================================================================================
# [TRIAL 04] params:
# {
#   "n_jobs": -1,
#   "random_state": 42,
#   "n_estimators": 625,
#   "max_depth": 15,
#   "max_features": "sqrt",
#   "min_samples_split": 3,
#   "min_samples_leaf": 10,
#   "bootstrap": true,
#   "criterion": "entropy"
# }
#     [FOLD 1] AUPRC=0.335380 | AUROC=0.852885 | Acc=0.935284 | P=0.769614 | R=0.051663 | Spec=0.987677
#     [FOLD 2] AUPRC=0.350407 | AUROC=0.861964 | Acc=0.933866 | P=0.826736 | R=0.049656 | Spec=0.987935
#     [FOLD 3] AUPRC=0.348986 | AUROC=0.844720 | Acc=0.934421 | P=0.811635 | R=0.054203 | Spec=0.985778
#     [FOLD 4] AUPRC=0.345847 | AUROC=0.841056 | Acc=0.932923 | P=0.776792 | R=0.051848 | Spec=0.986326
#     [FOLD 5] AUPRC=0.352629 | AUROC=0.837742 | Acc=0.936085 | P=0.812823 | R=0.051643 | Spec=0.987119
#
# [TRIAL 04] score(AUPRC_macro)=0.346650 | AUROC=0.847673 | Acc=0.934516 | P=0.799520 | R=0.051803 | Spec=0.986967
# [I 2026-05-07 19:33:59,442] Trial 4 finished with value: 0.346649681254596 and parameters: {'max_depth': 15, 'n_estimators': 625, 'max_features': 'sqrt', 'min_samples_split': 3, 'min_samples_leaf': 10, 'bootstrap': True, 'criterion': 'entropy'}. Best is trial 3 with value: 0.37660309485573196.
#
# ================================================================================
# [TRIAL 05] params:
# {
#   "n_jobs": -1,
#   "random_state": 42,
#   "n_estimators": 1226,
#   "max_depth": 29,
#   "max_features": 0.5,
#   "min_samples_split": 3,
#   "min_samples_leaf": 4,
#   "bootstrap": false,
#   "criterion": "entropy"
# }
#     [FOLD 1] AUPRC=0.371814 | AUROC=0.852028 | Acc=0.939218 | P=0.551098 | R=0.189013 | Spec=0.972349
#     [FOLD 2] AUPRC=0.353558 | AUROC=0.850855 | Acc=0.939137 | P=0.462463 | R=0.200280 | Spec=0.972309
#     [FOLD 3] AUPRC=0.362836 | AUROC=0.830553 | Acc=0.942632 | P=0.585679 | R=0.206948 | Spec=0.973983
#     [FOLD 4] AUPRC=0.370178 | AUROC=0.825027 | Acc=0.939692 | P=0.608942 | R=0.193805 | Spec=0.972536
#     [FOLD 5] AUPRC=0.370812 | AUROC=0.837021 | Acc=0.941300 | P=0.531090 | R=0.207827 | Spec=0.972772
#
# [TRIAL 05] score(AUPRC_macro)=0.365840 | AUROC=0.839097 | Acc=0.940396 | P=0.547854 | R=0.199574 | Spec=0.972790
# [I 2026-05-07 19:35:00,938] Trial 5 finished with value: 0.3658395804868086 and parameters: {'max_depth': 29, 'n_estimators': 1226, 'max_features': 0.5, 'min_samples_split': 3, 'min_samples_leaf': 4, 'bootstrap': False, 'criterion': 'entropy'}. Best is trial 3 with value: 0.37660309485573196.
#
# ================================================================================
# [TRIAL 06] params:
# {
#   "n_jobs": -1,
#   "random_state": 42,
#   "n_estimators": 1156,
#   "max_depth": 4,
#   "max_features": 0.3,
#   "min_samples_split": 2,
#   "min_samples_leaf": 2,
#   "bootstrap": false,
#   "criterion": "log_loss"
# }
#     [FOLD 1] AUPRC=0.314171 | AUROC=0.827669 | Acc=0.934674 | P=0.813260 | R=0.068627 | Spec=0.986129
#     [FOLD 2] AUPRC=0.302265 | AUROC=0.839343 | Acc=0.933034 | P=0.737652 | R=0.060252 | Spec=0.987027
#     [FOLD 3] AUPRC=0.315168 | AUROC=0.822772 | Acc=0.933533 | P=0.823707 | R=0.059164 | Spec=0.986722
#     [FOLD 4] AUPRC=0.328985 | AUROC=0.799352 | Acc=0.931758 | P=0.780266 | R=0.059570 | Spec=0.985682
#     [FOLD 5] AUPRC=0.303328 | AUROC=0.799961 | Acc=0.934976 | P=0.774929 | R=0.060518 | Spec=0.984893
#
# [TRIAL 06] score(AUPRC_macro)=0.312783 | AUROC=0.817819 | Acc=0.933595 | P=0.785963 | R=0.061626 | Spec=0.986091
# [I 2026-05-07 19:35:32,748] Trial 6 finished with value: 0.31278348633280084 and parameters: {'max_depth': 4, 'n_estimators': 1156, 'max_features': 0.3, 'min_samples_split': 2, 'min_samples_leaf': 2, 'bootstrap': False, 'criterion': 'log_loss'}. Best is trial 3 with value: 0.37660309485573196.
#
# ================================================================================
# [TRIAL 07] params:
# {
#   "n_jobs": -1,
#   "random_state": 42,
#   "n_estimators": 792,
#   "max_depth": 10,
#   "max_features": 1.0,
#   "min_samples_split": 17,
#   "min_samples_leaf": 7,
#   "bootstrap": true,
#   "criterion": "entropy"
# }
#     [FOLD 1] AUPRC=0.360025 | AUROC=0.853252 | Acc=0.939328 | P=0.754890 | R=0.152190 | Spec=0.976445
#     [FOLD 2] AUPRC=0.366031 | AUROC=0.858739 | Acc=0.940135 | P=0.704004 | R=0.148408 | Spec=0.980086
#     [FOLD 3] AUPRC=0.371724 | AUROC=0.843167 | Acc=0.942688 | P=0.732974 | R=0.160597 | Spec=0.979909
#     [FOLD 4] AUPRC=0.370765 | AUROC=0.832649 | Acc=0.939359 | P=0.733435 | R=0.161012 | Spec=0.976502
#     [FOLD 5] AUPRC=0.373271 | AUROC=0.838912 | Acc=0.941356 | P=0.783876 | R=0.175407 | Spec=0.977412
#
# [TRIAL 07] score(AUPRC_macro)=0.368363 | AUROC=0.845344 | Acc=0.940573 | P=0.741836 | R=0.159523 | Spec=0.978071
# [I 2026-05-07 19:36:09,103] Trial 7 finished with value: 0.3683631890743705 and parameters: {'max_depth': 10, 'n_estimators': 792, 'max_features': 1.0, 'min_samples_split': 17, 'min_samples_leaf': 7, 'bootstrap': True, 'criterion': 'entropy'}. Best is trial 3 with value: 0.37660309485573196.
#
# ================================================================================
# [TRIAL 08] params:
# {
#   "n_jobs": -1,
#   "random_state": 42,
#   "n_estimators": 1376,
#   "max_depth": 33,
#   "max_features": 1.0,
#   "min_samples_split": 2,
#   "min_samples_leaf": 6,
#   "bootstrap": true,
#   "criterion": "log_loss"
# }
#     [FOLD 1] AUPRC=0.367120 | AUROC=0.856507 | Acc=0.940381 | P=0.688721 | R=0.164766 | Spec=0.974964
#     [FOLD 2] AUPRC=0.369429 | AUROC=0.856168 | Acc=0.940468 | P=0.674654 | R=0.172310 | Spec=0.977178
#     [FOLD 3] AUPRC=0.372022 | AUROC=0.842674 | Acc=0.943076 | P=0.671271 | R=0.187926 | Spec=0.976896
#     [FOLD 4] AUPRC=0.379711 | AUROC=0.833875 | Acc=0.939303 | P=0.590331 | R=0.172369 | Spec=0.973465
#     [FOLD 5] AUPRC=0.366096 | AUROC=0.836273 | Acc=0.942299 | P=0.801544 | R=0.189903 | Spec=0.976023
#
# [TRIAL 08] score(AUPRC_macro)=0.370876 | AUROC=0.845100 | Acc=0.941106 | P=0.685304 | R=0.177455 | Spec=0.975705
# [I 2026-05-07 19:37:16,345] Trial 8 finished with value: 0.3708758510657386 and parameters: {'max_depth': 33, 'n_estimators': 1376, 'max_features': 1.0, 'min_samples_split': 2, 'min_samples_leaf': 6, 'bootstrap': True, 'criterion': 'log_loss'}. Best is trial 3 with value: 0.37660309485573196.
#
# ================================================================================
# [TRIAL 09] params:
# {
#   "n_jobs": -1,
#   "random_state": 42,
#   "n_estimators": 923,
#   "max_depth": 13,
#   "max_features": 0.3,
#   "min_samples_split": 7,
#   "min_samples_leaf": 3,
#   "bootstrap": false,
#   "criterion": "gini"
# }
#     [FOLD 1] AUPRC=0.361121 | AUROC=0.853430 | Acc=0.939661 | P=0.614874 | R=0.159685 | Spec=0.976476
#     [FOLD 2] AUPRC=0.354389 | AUROC=0.859681 | Acc=0.939248 | P=0.554875 | R=0.158676 | Spec=0.978767
#     [FOLD 3] AUPRC=0.364650 | AUROC=0.841076 | Acc=0.943409 | P=0.625223 | R=0.176123 | Spec=0.978694
#     [FOLD 4] AUPRC=0.387239 | AUROC=0.839265 | Acc=0.938637 | P=0.635381 | R=0.158311 | Spec=0.975665
#     [FOLD 5] AUPRC=0.365858 | AUROC=0.844070 | Acc=0.943076 | P=0.669380 | R=0.191248 | Spec=0.978153
#
# [TRIAL 09] score(AUPRC_macro)=0.366652 | AUROC=0.847505 | Acc=0.940806 | P=0.619947 | R=0.168809 | Spec=0.977551
# [I 2026-05-07 19:37:49,126] Trial 9 finished with value: 0.3666516725603827 and parameters: {'max_depth': 13, 'n_estimators': 923, 'max_features': 0.3, 'min_samples_split': 7, 'min_samples_leaf': 3, 'bootstrap': False, 'criterion': 'gini'}. Best is trial 3 with value: 0.37660309485573196.
#
# ================================================================================
# [TRIAL 10] params:
# {
#   "n_jobs": -1,
#   "random_state": 42,
#   "n_estimators": 307,
#   "max_depth": 39,
#   "max_features": 0.8,
#   "min_samples_split": 20,
#   "min_samples_leaf": 1,
#   "bootstrap": true,
#   "criterion": "log_loss"
# }
#     [FOLD 1] AUPRC=0.371036 | AUROC=0.860425 | Acc=0.940547 | P=0.672539 | R=0.176361 | Spec=0.974423
#     [FOLD 2] AUPRC=0.373982 | AUROC=0.854741 | Acc=0.940635 | P=0.650441 | R=0.166216 | Spec=0.976367
#     [FOLD 3] AUPRC=0.369653 | AUROC=0.842859 | Acc=0.943742 | P=0.758748 | R=0.190815 | Spec=0.977017
#     [FOLD 4] AUPRC=0.379828 | AUROC=0.834683 | Acc=0.939414 | P=0.669385 | R=0.178202 | Spec=0.972739
#     [FOLD 5] AUPRC=0.366269 | AUROC=0.836811 | Acc=0.943131 | P=0.802152 | R=0.191810 | Spec=0.976527
#
# [TRIAL 10] score(AUPRC_macro)=0.372153 | AUROC=0.845904 | Acc=0.941494 | P=0.710653 | R=0.180681 | Spec=0.975415
# [I 2026-05-07 19:38:06,363] Trial 10 finished with value: 0.37215341099617505 and parameters: {'max_depth': 39, 'n_estimators': 307, 'max_features': 0.8, 'min_samples_split': 20, 'min_samples_leaf': 1, 'bootstrap': True, 'criterion': 'log_loss'}. Best is trial 3 with value: 0.37660309485573196.
#
# ================================================================================
# [TRIAL 11] params:
# {
#   "n_jobs": -1,
#   "random_state": 42,
#   "n_estimators": 416,
#   "max_depth": 25,
#   "max_features": "log2",
#   "min_samples_split": 15,
#   "min_samples_leaf": 8,
#   "bootstrap": false,
#   "criterion": "log_loss"
# }
#     [FOLD 1] AUPRC=0.333769 | AUROC=0.855043 | Acc=0.932292 | P=0.796120 | R=0.043465 | Spec=0.987332
#     [FOLD 2] AUPRC=0.361391 | AUROC=0.860663 | Acc=0.931980 | P=0.831787 | R=0.040472 | Spec=0.990216
#     [FOLD 3] AUPRC=0.345726 | AUROC=0.844066 | Acc=0.931980 | P=0.812628 | R=0.042486 | Spec=0.987629
#     [FOLD 4] AUPRC=0.347240 | AUROC=0.839549 | Acc=0.930371 | P=0.791177 | R=0.041122 | Spec=0.987412
#     [FOLD 5] AUPRC=0.337060 | AUROC=0.844256 | Acc=0.934587 | P=0.807222 | R=0.042100 | Spec=0.989999
#
# [TRIAL 11] score(AUPRC_macro)=0.345037 | AUROC=0.848716 | Acc=0.932242 | P=0.807787 | R=0.041929 | Spec=0.988517
# [I 2026-05-07 19:38:19,136] Trial 11 finished with value: 0.3450371511607696 and parameters: {'max_depth': 25, 'n_estimators': 416, 'max_features': 'log2', 'min_samples_split': 15, 'min_samples_leaf': 8, 'bootstrap': False, 'criterion': 'log_loss'}. Best is trial 3 with value: 0.37660309485573196.
#
# ================================================================================
# [TRIAL 12] params:
# {
#   "n_jobs": -1,
#   "random_state": 42,
#   "n_estimators": 531,
#   "max_depth": 21,
#   "max_features": 0.3,
#   "min_samples_split": 20,
#   "min_samples_leaf": 5,
#   "bootstrap": true,
#   "criterion": "entropy"
# }
#     [FOLD 1] AUPRC=0.374389 | AUROC=0.859642 | Acc=0.940049 | P=0.789234 | R=0.146136 | Spec=0.977770
#     [FOLD 2] AUPRC=0.371860 | AUROC=0.859381 | Acc=0.939969 | P=0.711927 | R=0.143637 | Spec=0.980125
#     [FOLD 3] AUPRC=0.380715 | AUROC=0.846171 | Acc=0.942743 | P=0.798338 | R=0.146744 | Spec=0.979605
#     [FOLD 4] AUPRC=0.390113 | AUROC=0.839939 | Acc=0.939359 | P=0.789053 | R=0.148643 | Spec=0.976926
#     [FOLD 5] AUPRC=0.374403 | AUROC=0.840508 | Acc=0.942355 | P=0.837393 | R=0.155377 | Spec=0.979368
#
# [TRIAL 12] score(AUPRC_macro)=0.378296 | AUROC=0.849128 | Acc=0.940895 | P=0.785189 | R=0.148108 | Spec=0.978759
# [I 2026-05-07 19:38:33,213] Trial 12 finished with value: 0.37829600588144563 and parameters: {'max_depth': 21, 'n_estimators': 531, 'max_features': 0.3, 'min_samples_split': 20, 'min_samples_leaf': 5, 'bootstrap': True, 'criterion': 'entropy'}. Best is trial 12 with value: 0.37829600588144563.
#
# ================================================================================
# [TRIAL 13] params:
# {
#   "n_jobs": -1,
#   "random_state": 42,
#   "n_estimators": 925,
#   "max_depth": 21,
#   "max_features": 0.5,
#   "min_samples_split": 20,
#   "min_samples_leaf": 6,
#   "bootstrap": true,
#   "criterion": "log_loss"
# }
#     [FOLD 1] AUPRC=0.367666 | AUROC=0.858544 | Acc=0.939550 | P=0.704790 | R=0.150464 | Spec=0.976337
#     [FOLD 2] AUPRC=0.367864 | AUROC=0.858001 | Acc=0.940135 | P=0.732103 | R=0.153452 | Spec=0.979152
#     [FOLD 3] AUPRC=0.377140 | AUROC=0.843871 | Acc=0.942743 | P=0.752565 | R=0.162876 | Spec=0.978768
#     [FOLD 4] AUPRC=0.388825 | AUROC=0.837290 | Acc=0.939525 | P=0.754787 | R=0.158191 | Spec=0.975715
#     [FOLD 5] AUPRC=0.377015 | AUROC=0.838875 | Acc=0.941911 | P=0.790406 | R=0.168428 | Spec=0.977903
#
# [TRIAL 13] score(AUPRC_macro)=0.375702 | AUROC=0.847316 | Acc=0.940773 | P=0.746930 | R=0.158682 | Spec=0.977575
# [I 2026-05-07 19:39:00,834] Trial 13 finished with value: 0.37570210458304903 and parameters: {'max_depth': 21, 'n_estimators': 925, 'max_features': 0.5, 'min_samples_split': 20, 'min_samples_leaf': 6, 'bootstrap': True, 'criterion': 'log_loss'}. Best is trial 12 with value: 0.37829600588144563.
#
# ================================================================================
# [TRIAL 14] params:
# {
#   "n_jobs": -1,
#   "random_state": 42,
#   "n_estimators": 718,
#   "max_depth": 32,
#   "max_features": "sqrt",
#   "min_samples_split": 18,
#   "min_samples_leaf": 4,
#   "bootstrap": true,
#   "criterion": "gini"
# }
#     [FOLD 1] AUPRC=0.361948 | AUROC=0.858786 | Acc=0.938220 | P=0.826518 | R=0.075185 | Spec=0.984637
#     [FOLD 2] AUPRC=0.378603 | AUROC=0.868208 | Acc=0.937805 | P=0.836174 | R=0.078951 | Spec=0.986475
#     [FOLD 3] AUPRC=0.386220 | AUROC=0.849052 | Acc=0.938970 | P=0.866538 | R=0.081768 | Spec=0.984469
#     [FOLD 4] AUPRC=0.392592 | AUROC=0.850968 | Acc=0.936696 | P=0.802843 | R=0.072905 | Spec=0.984135
#     [FOLD 5] AUPRC=0.367171 | AUROC=0.845261 | Acc=0.938415 | P=0.765131 | R=0.072700 | Spec=0.984374
#
# [TRIAL 14] score(AUPRC_macro)=0.377307 | AUROC=0.854455 | Acc=0.938021 | P=0.819441 | R=0.076302 | Spec=0.984818
# [I 2026-05-07 19:39:21,314] Trial 14 finished with value: 0.37730668782897453 and parameters: {'max_depth': 32, 'n_estimators': 718, 'max_features': 'sqrt', 'min_samples_split': 18, 'min_samples_leaf': 4, 'bootstrap': True, 'criterion': 'gini'}. Best is trial 12 with value: 0.37829600588144563.
#
# ================================================================================
# [TRIAL 15] params:
# {
#   "n_jobs": -1,
#   "random_state": 42,
#   "n_estimators": 505,
#   "max_depth": 35,
#   "max_features": "sqrt",
#   "min_samples_split": 17,
#   "min_samples_leaf": 3,
#   "bootstrap": true,
#   "criterion": "gini"
# }
#     [FOLD 1] AUPRC=0.367446 | AUROC=0.859736 | Acc=0.939051 | P=0.856090 | R=0.085086 | Spec=0.984035
#     [FOLD 2] AUPRC=0.380789 | AUROC=0.869047 | Acc=0.939026 | P=0.760683 | R=0.090702 | Spec=0.985786
#     [FOLD 3] AUPRC=0.379494 | AUROC=0.847938 | Acc=0.940080 | P=0.817125 | R=0.093148 | Spec=0.983443
#     [FOLD 4] AUPRC=0.398574 | AUROC=0.852708 | Acc=0.936973 | P=0.855491 | R=0.083493 | Spec=0.982605
#     [FOLD 5] AUPRC=0.370850 | AUROC=0.846934 | Acc=0.939525 | P=0.833464 | R=0.086840 | Spec=0.983544
#
# [TRIAL 15] score(AUPRC_macro)=0.379431 | AUROC=0.855272 | Acc=0.938931 | P=0.824571 | R=0.087854 | Spec=0.983882
# [I 2026-05-07 19:39:34,740] Trial 15 finished with value: 0.37943050676880735 and parameters: {'max_depth': 35, 'n_estimators': 505, 'max_features': 'sqrt', 'min_samples_split': 17, 'min_samples_leaf': 3, 'bootstrap': True, 'criterion': 'gini'}. Best is trial 15 with value: 0.37943050676880735.
#
# ================================================================================
# [TRIAL 16] params:
# {
#   "n_jobs": -1,
#   "random_state": 42,
#   "n_estimators": 498,
#   "max_depth": 39,
#   "max_features": "sqrt",
#   "min_samples_split": 10,
#   "min_samples_leaf": 3,
#   "bootstrap": true,
#   "criterion": "gini"
# }
#     [FOLD 1] AUPRC=0.365109 | AUROC=0.859409 | Acc=0.939218 | P=0.875811 | R=0.087915 | Spec=0.983565
#     [FOLD 2] AUPRC=0.375595 | AUROC=0.870345 | Acc=0.938693 | P=0.802913 | R=0.092715 | Spec=0.985102
#     [FOLD 3] AUPRC=0.384532 | AUROC=0.848462 | Acc=0.939636 | P=0.780095 | R=0.093039 | Spec=0.983163
#     [FOLD 4] AUPRC=0.396546 | AUROC=0.852307 | Acc=0.937417 | P=0.849558 | R=0.091808 | Spec=0.982278
#     [FOLD 5] AUPRC=0.371775 | AUROC=0.846671 | Acc=0.939359 | P=0.838598 | R=0.087385 | Spec=0.983175
#
# [TRIAL 16] score(AUPRC_macro)=0.378712 | AUROC=0.855439 | Acc=0.938864 | P=0.829395 | R=0.090572 | Spec=0.983457
# [I 2026-05-07 19:39:47,768] Trial 16 finished with value: 0.3787115386924106 and parameters: {'max_depth': 39, 'n_estimators': 498, 'max_features': 'sqrt', 'min_samples_split': 10, 'min_samples_leaf': 3, 'bootstrap': True, 'criterion': 'gini'}. Best is trial 15 with value: 0.37943050676880735.
#
# ================================================================================
# [TRIAL 17] params:
# {
#   "n_jobs": -1,
#   "random_state": 42,
#   "n_estimators": 375,
#   "max_depth": 39,
#   "max_features": "sqrt",
#   "min_samples_split": 9,
#   "min_samples_leaf": 1,
#   "bootstrap": true,
#   "criterion": "gini"
# }
#     [FOLD 1] AUPRC=0.368115 | AUROC=0.857993 | Acc=0.940769 | P=0.786666 | R=0.132755 | Spec=0.979032
#     [FOLD 2] AUPRC=0.365296 | AUROC=0.863520 | Acc=0.941134 | P=0.739643 | R=0.130934 | Spec=0.981278
#     [FOLD 3] AUPRC=0.376880 | AUROC=0.844633 | Acc=0.942521 | P=0.787552 | R=0.133830 | Spec=0.979113
#     [FOLD 4] AUPRC=0.375413 | AUROC=0.847469 | Acc=0.939692 | P=0.773100 | R=0.135426 | Spec=0.977643
#     [FOLD 5] AUPRC=0.383083 | AUROC=0.840523 | Acc=0.942743 | P=0.889632 | R=0.135073 | Spec=0.979272
#
# [TRIAL 17] score(AUPRC_macro)=0.373757 | AUROC=0.850827 | Acc=0.941372 | P=0.795319 | R=0.133604 | Spec=0.979268
# [I 2026-05-07 19:39:55,472] Trial 17 finished with value: 0.37375728281396825 and parameters: {'max_depth': 39, 'n_estimators': 375, 'max_features': 'sqrt', 'min_samples_split': 9, 'min_samples_leaf': 1, 'bootstrap': True, 'criterion': 'gini'}. Best is trial 15 with value: 0.37943050676880735.
#
# ================================================================================
# [TRIAL 18] params:
# {
#   "n_jobs": -1,
#   "random_state": 42,
#   "n_estimators": 1051,
#   "max_depth": 35,
#   "max_features": "sqrt",
#   "min_samples_split": 11,
#   "min_samples_leaf": 3,
#   "bootstrap": true,
#   "criterion": "gini"
# }
#     [FOLD 1] AUPRC=0.369021 | AUROC=0.859736 | Acc=0.939162 | P=0.891272 | R=0.093471 | Spec=0.983609
#     [FOLD 2] AUPRC=0.380384 | AUROC=0.868464 | Acc=0.939359 | P=0.805692 | R=0.096043 | Spec=0.985554
#     [FOLD 3] AUPRC=0.384959 | AUROC=0.849009 | Acc=0.940246 | P=0.818409 | R=0.094287 | Spec=0.983552
#     [FOLD 4] AUPRC=0.394387 | AUROC=0.853154 | Acc=0.936862 | P=0.850356 | R=0.089501 | Spec=0.982418
#     [FOLD 5] AUPRC=0.373000 | AUROC=0.846298 | Acc=0.939414 | P=0.821241 | R=0.084769 | Spec=0.983720
#
# [TRIAL 18] score(AUPRC_macro)=0.380350 | AUROC=0.855332 | Acc=0.939009 | P=0.837394 | R=0.091614 | Spec=0.983771
# [I 2026-05-07 19:40:21,001] Trial 18 finished with value: 0.3803501899294978 and parameters: {'max_depth': 35, 'n_estimators': 1051, 'max_features': 'sqrt', 'min_samples_split': 11, 'min_samples_leaf': 3, 'bootstrap': True, 'criterion': 'gini'}. Best is trial 18 with value: 0.3803501899294978.
#
# ================================================================================
# [TRIAL 19] params:
# {
#   "n_jobs": -1,
#   "random_state": 42,
#   "n_estimators": 1103,
#   "max_depth": 33,
#   "max_features": "sqrt",
#   "min_samples_split": 12,
#   "min_samples_leaf": 3,
#   "bootstrap": true,
#   "criterion": "gini"
# }
#     [FOLD 1] AUPRC=0.367018 | AUROC=0.859879 | Acc=0.938664 | P=0.854163 | R=0.085366 | Spec=0.983586
#     [FOLD 2] AUPRC=0.375925 | AUROC=0.868764 | Acc=0.939248 | P=0.805171 | R=0.093574 | Spec=0.985210
#     [FOLD 3] AUPRC=0.389247 | AUROC=0.849267 | Acc=0.939802 | P=0.815749 | R=0.093255 | Spec=0.983264
#     [FOLD 4] AUPRC=0.394942 | AUROC=0.853102 | Acc=0.937084 | P=0.853025 | R=0.084486 | Spec=0.982418
#     [FOLD 5] AUPRC=0.369496 | AUROC=0.847233 | Acc=0.939636 | P=0.823110 | R=0.083302 | Spec=0.983899
#
# [TRIAL 19] score(AUPRC_macro)=0.379326 | AUROC=0.855649 | Acc=0.938887 | P=0.830244 | R=0.087997 | Spec=0.983676
# [I 2026-05-07 19:40:48,789] Trial 19 finished with value: 0.37932551185929764 and parameters: {'max_depth': 33, 'n_estimators': 1103, 'max_features': 'sqrt', 'min_samples_split': 12, 'min_samples_leaf': 3, 'bootstrap': True, 'criterion': 'gini'}. Best is trial 18 with value: 0.3803501899294978.
#
# ================================================================================
# [TRIAL 20] params:
# {
#   "n_jobs": -1,
#   "random_state": 42,
#   "n_estimators": 1047,
#   "max_depth": 36,
#   "max_features": "log2",
#   "min_samples_split": 6,
#   "min_samples_leaf": 2,
#   "bootstrap": true,
#   "criterion": "gini"
# }
#     [FOLD 1] AUPRC=0.362142 | AUROC=0.859221 | Acc=0.935616 | P=0.833220 | R=0.054501 | Spec=0.986513
#     [FOLD 2] AUPRC=0.381869 | AUROC=0.866676 | Acc=0.936307 | P=0.883602 | R=0.056641 | Spec=0.988912
#     [FOLD 3] AUPRC=0.366107 | AUROC=0.847924 | Acc=0.935919 | P=0.831519 | R=0.057455 | Spec=0.985790
#     [FOLD 4] AUPRC=0.374556 | AUROC=0.848691 | Acc=0.933755 | P=0.833705 | R=0.054214 | Spec=0.985817
#     [FOLD 5] AUPRC=0.364790 | AUROC=0.849422 | Acc=0.937583 | P=0.764940 | R=0.055873 | Spec=0.986865
#
# [TRIAL 20] score(AUPRC_macro)=0.369892 | AUROC=0.854387 | Acc=0.935836 | P=0.829397 | R=0.055737 | Spec=0.986779
# [I 2026-05-07 19:41:29,429] Trial 20 finished with value: 0.3698924424551575 and parameters: {'max_depth': 36, 'n_estimators': 1047, 'max_features': 'log2', 'min_samples_split': 6, 'min_samples_leaf': 2, 'bootstrap': True, 'criterion': 'gini'}. Best is trial 18 with value: 0.3803501899294978.
#
# ================================================================================
# [TRIAL 21] params:
# {
#   "n_jobs": -1,
#   "random_state": 42,
#   "n_estimators": 1070,
#   "max_depth": 32,
#   "max_features": "sqrt",
#   "min_samples_split": 12,
#   "min_samples_leaf": 3,
#   "bootstrap": true,
#   "criterion": "gini"
# }
#     [FOLD 1] AUPRC=0.367643 | AUROC=0.859720 | Acc=0.938996 | P=0.875992 | R=0.087741 | Spec=0.983923
#     [FOLD 2] AUPRC=0.377875 | AUROC=0.868020 | Acc=0.939525 | P=0.809969 | R=0.096132 | Spec=0.985490
#     [FOLD 3] AUPRC=0.382966 | AUROC=0.848419 | Acc=0.939692 | P=0.789534 | R=0.091228 | Spec=0.983376
#     [FOLD 4] AUPRC=0.394360 | AUROC=0.852976 | Acc=0.937028 | P=0.850837 | R=0.086364 | Spec=0.982464
#     [FOLD 5] AUPRC=0.370919 | AUROC=0.847695 | Acc=0.939359 | P=0.821380 | R=0.083095 | Spec=0.983597
#
# [TRIAL 21] score(AUPRC_macro)=0.378752 | AUROC=0.855366 | Acc=0.938920 | P=0.829542 | R=0.088912 | Spec=0.983770
# [I 2026-05-07 19:41:57,992] Trial 21 finished with value: 0.3787523881958569 and parameters: {'max_depth': 32, 'n_estimators': 1070, 'max_features': 'sqrt', 'min_samples_split': 12, 'min_samples_leaf': 3, 'bootstrap': True, 'criterion': 'gini'}. Best is trial 18 with value: 0.3803501899294978.
#
# ================================================================================
# [TRIAL 22] params:
# {
#   "n_jobs": -1,
#   "random_state": 42,
#   "n_estimators": 1268,
#   "max_depth": 35,
#   "max_features": "sqrt",
#   "min_samples_split": 14,
#   "min_samples_leaf": 2,
#   "bootstrap": true,
#   "criterion": "gini"
# }
#     [FOLD 1] AUPRC=0.372970 | AUROC=0.861226 | Acc=0.939605 | P=0.710054 | R=0.105798 | Spec=0.982233
#     [FOLD 2] AUPRC=0.384090 | AUROC=0.868392 | Acc=0.939636 | P=0.813459 | R=0.104788 | Spec=0.984012
#     [FOLD 3] AUPRC=0.384984 | AUROC=0.848358 | Acc=0.940635 | P=0.798298 | R=0.103931 | Spec=0.982446
#     [FOLD 4] AUPRC=0.400336 | AUROC=0.853430 | Acc=0.938304 | P=0.883193 | R=0.114358 | Spec=0.980855
#     [FOLD 5] AUPRC=0.378750 | AUROC=0.848441 | Acc=0.940191 | P=0.875625 | R=0.100001 | Spec=0.982026
#
# [TRIAL 22] score(AUPRC_macro)=0.384226 | AUROC=0.855970 | Acc=0.939674 | P=0.816126 | R=0.105775 | Spec=0.982314
# [I 2026-05-07 19:42:26,194] Trial 22 finished with value: 0.3842261102610659 and parameters: {'max_depth': 35, 'n_estimators': 1268, 'max_features': 'sqrt', 'min_samples_split': 14, 'min_samples_leaf': 2, 'bootstrap': True, 'criterion': 'gini'}. Best is trial 22 with value: 0.3842261102610659.
#
# ================================================================================
# [TRIAL 23] params:
# {
#   "n_jobs": -1,
#   "random_state": 42,
#   "n_estimators": 1298,
#   "max_depth": 30,
#   "max_features": "sqrt",
#   "min_samples_split": 15,
#   "min_samples_leaf": 2,
#   "bootstrap": true,
#   "criterion": "gini"
# }
#     [FOLD 1] AUPRC=0.372043 | AUROC=0.858655 | Acc=0.939661 | P=0.711945 | R=0.105276 | Spec=0.982802
#     [FOLD 2] AUPRC=0.381538 | AUROC=0.868417 | Acc=0.939359 | P=0.807286 | R=0.102955 | Spec=0.984121
#     [FOLD 3] AUPRC=0.381735 | AUROC=0.847703 | Acc=0.940579 | P=0.797835 | R=0.102603 | Spec=0.982560
#     [FOLD 4] AUPRC=0.398371 | AUROC=0.853606 | Acc=0.938083 | P=0.869605 | R=0.109515 | Spec=0.981241
#     [FOLD 5] AUPRC=0.375063 | AUROC=0.846788 | Acc=0.940302 | P=0.844077 | R=0.093838 | Spec=0.982580
#
# [TRIAL 23] score(AUPRC_macro)=0.381750 | AUROC=0.855034 | Acc=0.939597 | P=0.806150 | R=0.102838 | Spec=0.982661
# [I 2026-05-07 19:42:55,219] Trial 23 finished with value: 0.381749811945182 and parameters: {'max_depth': 30, 'n_estimators': 1298, 'max_features': 'sqrt', 'min_samples_split': 15, 'min_samples_leaf': 2, 'bootstrap': True, 'criterion': 'gini'}. Best is trial 22 with value: 0.3842261102610659.
#
# ================================================================================
# [TRIAL 24] params:
# {
#   "n_jobs": -1,
#   "random_state": 42,
#   "n_estimators": 1330,
#   "max_depth": 29,
#   "max_features": 0.8,
#   "min_samples_split": 14,
#   "min_samples_leaf": 2,
#   "bootstrap": true,
#   "criterion": "gini"
# }
#     [FOLD 1] AUPRC=0.375442 | AUROC=0.856752 | Acc=0.940935 | P=0.640929 | R=0.163273 | Spec=0.974624
#     [FOLD 2] AUPRC=0.369319 | AUROC=0.856089 | Acc=0.940080 | P=0.586224 | R=0.161425 | Spec=0.975039
#     [FOLD 3] AUPRC=0.354934 | AUROC=0.841594 | Acc=0.944075 | P=0.644777 | R=0.178129 | Spec=0.976626
#     [FOLD 4] AUPRC=0.379599 | AUROC=0.828881 | Acc=0.939414 | P=0.597576 | R=0.163516 | Spec=0.972779
#     [FOLD 5] AUPRC=0.364582 | AUROC=0.835260 | Acc=0.943520 | P=0.684996 | R=0.195394 | Spec=0.975572
#
# [TRIAL 24] score(AUPRC_macro)=0.368775 | AUROC=0.843715 | Acc=0.941605 | P=0.630900 | R=0.172347 | Spec=0.974928
# [I 2026-05-07 19:44:02,998] Trial 24 finished with value: 0.36877516921773756 and parameters: {'max_depth': 29, 'n_estimators': 1330, 'max_features': 0.8, 'min_samples_split': 14, 'min_samples_leaf': 2, 'bootstrap': True, 'criterion': 'gini'}. Best is trial 22 with value: 0.3842261102610659.
#
# ================================================================================
# [TRIAL 25] params:
# {
#   "n_jobs": -1,
#   "random_state": 42,
#   "n_estimators": 1260,
#   "max_depth": 36,
#   "max_features": "sqrt",
#   "min_samples_split": 11,
#   "min_samples_leaf": 1,
#   "bootstrap": true,
#   "criterion": "gini"
# }
#     [FOLD 1] AUPRC=0.368217 | AUROC=0.856396 | Acc=0.940437 | P=0.700176 | R=0.130815 | Spec=0.979174
#     [FOLD 2] AUPRC=0.367185 | AUROC=0.865253 | Acc=0.940468 | P=0.809833 | R=0.124611 | Spec=0.981344
#     [FOLD 3] AUPRC=0.377464 | AUROC=0.847644 | Acc=0.942909 | P=0.804956 | R=0.128290 | Spec=0.981012
#     [FOLD 4] AUPRC=0.378393 | AUROC=0.848385 | Acc=0.939470 | P=0.844154 | R=0.126796 | Spec=0.978346
#     [FOLD 5] AUPRC=0.379831 | AUROC=0.842982 | Acc=0.942688 | P=0.891880 | R=0.129058 | Spec=0.980199
#
# [TRIAL 25] score(AUPRC_macro)=0.374218 | AUROC=0.852132 | Acc=0.941194 | P=0.810200 | R=0.127914 | Spec=0.980015
# [I 2026-05-07 19:44:28,053] Trial 25 finished with value: 0.3742180020791044 and parameters: {'max_depth': 36, 'n_estimators': 1260, 'max_features': 'sqrt', 'min_samples_split': 11, 'min_samples_leaf': 1, 'bootstrap': True, 'criterion': 'gini'}. Best is trial 22 with value: 0.3842261102610659.
#
# ================================================================================
# [TRIAL 26] params:
# {
#   "n_jobs": -1,
#   "random_state": 42,
#   "n_estimators": 1485,
#   "max_depth": 29,
#   "max_features": "sqrt",
#   "min_samples_split": 16,
#   "min_samples_leaf": 4,
#   "bootstrap": true,
#   "criterion": "gini"
# }
#     [FOLD 1] AUPRC=0.363306 | AUROC=0.859012 | Acc=0.938331 | P=0.831725 | R=0.074449 | Spec=0.985283
#     [FOLD 2] AUPRC=0.374393 | AUROC=0.868061 | Acc=0.937694 | P=0.810788 | R=0.079781 | Spec=0.986036
#     [FOLD 3] AUPRC=0.385006 | AUROC=0.848587 | Acc=0.938804 | P=0.863717 | R=0.081845 | Spec=0.984091
#     [FOLD 4] AUPRC=0.394159 | AUROC=0.852753 | Acc=0.936862 | P=0.841595 | R=0.074989 | Spec=0.984306
#     [FOLD 5] AUPRC=0.365711 | AUROC=0.844251 | Acc=0.938637 | P=0.767717 | R=0.071006 | Spec=0.984884
#
# [TRIAL 26] score(AUPRC_macro)=0.376515 | AUROC=0.854533 | Acc=0.938066 | P=0.823108 | R=0.076414 | Spec=0.984920
# [I 2026-05-07 19:45:09,836] Trial 26 finished with value: 0.37651497185899274 and parameters: {'max_depth': 29, 'n_estimators': 1485, 'max_features': 'sqrt', 'min_samples_split': 16, 'min_samples_leaf': 4, 'bootstrap': True, 'criterion': 'gini'}. Best is trial 22 with value: 0.3842261102610659.
#
# ================================================================================
# [TRIAL 27] params:
# {
#   "n_jobs": -1,
#   "random_state": 42,
#   "n_estimators": 1005,
#   "max_depth": 40,
#   "max_features": "sqrt",
#   "min_samples_split": 13,
#   "min_samples_leaf": 2,
#   "bootstrap": true,
#   "criterion": "gini"
# }
#     [FOLD 1] AUPRC=0.376114 | AUROC=0.859088 | Acc=0.939716 | P=0.709914 | R=0.107386 | Spec=0.982078
#     [FOLD 2] AUPRC=0.383100 | AUROC=0.867991 | Acc=0.939636 | P=0.813005 | R=0.105559 | Spec=0.983705
#     [FOLD 3] AUPRC=0.385296 | AUROC=0.848767 | Acc=0.940857 | P=0.798801 | R=0.104275 | Spec=0.982362
#     [FOLD 4] AUPRC=0.397717 | AUROC=0.852176 | Acc=0.937639 | P=0.879990 | R=0.111558 | Spec=0.980284
#     [FOLD 5] AUPRC=0.378930 | AUROC=0.847255 | Acc=0.940801 | P=0.877697 | R=0.100947 | Spec=0.982327
#
# [TRIAL 27] score(AUPRC_macro)=0.384232 | AUROC=0.855055 | Acc=0.939730 | P=0.815881 | R=0.105945 | Spec=0.982151
# [I 2026-05-07 19:45:31,532] Trial 27 finished with value: 0.38423155109225393 and parameters: {'max_depth': 40, 'n_estimators': 1005, 'max_features': 'sqrt', 'min_samples_split': 13, 'min_samples_leaf': 2, 'bootstrap': True, 'criterion': 'gini'}. Best is trial 27 with value: 0.38423155109225393.
#
# ================================================================================
# [TRIAL 28] params:
# {
#   "n_jobs": -1,
#   "random_state": 42,
#   "n_estimators": 1227,
#   "max_depth": null,
#   "max_features": "sqrt",
#   "min_samples_split": 14,
#   "min_samples_leaf": 2,
#   "bootstrap": true,
#   "criterion": "gini"
# }
#     [FOLD 1] AUPRC=0.375098 | AUROC=0.859919 | Acc=0.940270 | P=0.712167 | R=0.109327 | Spec=0.982434
#     [FOLD 2] AUPRC=0.387106 | AUROC=0.868944 | Acc=0.939858 | P=0.813342 | R=0.105816 | Spec=0.983958
#     [FOLD 3] AUPRC=0.385230 | AUROC=0.848271 | Acc=0.940635 | P=0.784728 | R=0.106967 | Spec=0.982188
#     [FOLD 4] AUPRC=0.402010 | AUROC=0.853611 | Acc=0.938526 | P=0.884011 | R=0.113283 | Spec=0.980993
#     [FOLD 5] AUPRC=0.379471 | AUROC=0.848847 | Acc=0.940413 | P=0.876167 | R=0.100355 | Spec=0.982149
#
# [TRIAL 28] score(AUPRC_macro)=0.385783 | AUROC=0.855918 | Acc=0.939940 | P=0.814083 | R=0.107149 | Spec=0.982344
# [I 2026-05-07 19:45:58,045] Trial 28 finished with value: 0.38578284430463883 and parameters: {'max_depth': 0, 'n_estimators': 1227, 'max_features': 'sqrt', 'min_samples_split': 14, 'min_samples_leaf': 2, 'bootstrap': True, 'criterion': 'gini'}. Best is trial 28 with value: 0.38578284430463883.
#
# ================================================================================
# [TRIAL 29] params:
# {
#   "n_jobs": -1,
#   "random_state": 42,
#   "n_estimators": 1404,
#   "max_depth": 1,
#   "max_features": 0.8,
#   "min_samples_split": 13,
#   "min_samples_leaf": 1,
#   "bootstrap": false,
#   "criterion": "gini"
# }
#     [FOLD 1] AUPRC=0.132766 | AUROC=0.677895 | Acc=0.927914 | P=0.739496 | R=0.028947 | Spec=0.989583
#     [FOLD 2] AUPRC=0.157162 | AUROC=0.701931 | Acc=0.926431 | P=0.707386 | R=0.028270 | Spec=0.988824
#     [FOLD 3] AUPRC=0.177421 | AUROC=0.709829 | Acc=0.927985 | P=0.736000 | R=0.030423 | Spec=0.988941
#     [FOLD 4] AUPRC=0.150996 | AUROC=0.675358 | Acc=0.926209 | P=0.711370 | R=0.028163 | Spec=0.989423
#     [FOLD 5] AUPRC=0.147137 | AUROC=0.677847 | Acc=0.929538 | P=0.769022 | R=0.028621 | Spec=0.989553
#
# [TRIAL 29] score(AUPRC_macro)=0.153097 | AUROC=0.688572 | Acc=0.927616 | P=0.732655 | R=0.028885 | Spec=0.989265
# [I 2026-05-07 19:46:31,213] Trial 29 finished with value: 0.15309662642079577 and parameters: {'max_depth': 1, 'n_estimators': 1404, 'max_features': 0.8, 'min_samples_split': 13, 'min_samples_leaf': 1, 'bootstrap': False, 'criterion': 'gini'}. Best is trial 28 with value: 0.38578284430463883.
#
# ================ BEST =================
# Best trial: 28
# Best AUPRC_macro: 0.38578284430463883
# Best params:
# {
#   "max_depth": 0,
#   "n_estimators": 1227,
#   "max_features": "sqrt",
#   "min_samples_split": 14,
#   "min_samples_leaf": 2,
#   "bootstrap": true,
#   "criterion": "gini"
# }
# [SAVED] ./optuna_singlemodel_RF_30trials_5fold_results.csv
# [SAVED] ./used_label_columns_24.csv
# [SAVED] ./used_feature_columns.csv
