# %%
# -*- coding: utf-8 -*-
import os
import glob
import json
import warnings
import numpy as np
import pandas as pd

import optuna
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import roc_auc_score, average_precision_score
from sklearn.multioutput import MultiOutputClassifier

# =========================
# 0) 全局：尽量屏蔽警告 + LightGBM 日志
# =========================
os.environ["PYTHONWARNINGS"] = "ignore"
warnings.filterwarnings("ignore", category=UserWarning)
warnings.filterwarnings("ignore", category=FutureWarning)
warnings.filterwarnings("ignore", category=RuntimeWarning)

try:
    import lightgbm as lgb
except Exception as e:
    raise RuntimeError(
        "未检测到 lightgbm。请先安装：pip install lightgbm\n"
        f"原始错误：{repr(e)}"
    )

# =========================
# 1) 配置
# =========================
RANDOM_SEED = 42
N_TRIALS = 30
N_SPLITS = 5
THRESH = 0.5

# 直接读取你已生成的特征文件
FEATURE_FILE_GLOB = "./Malodors_Morgan&StructKG_features.xlsx"

# 固定参数：Optuna 只搜索部分超参
BASE_LGB_PARAMS = dict(
    objective="binary",
    boosting_type="gbdt",
    n_jobs=-1,
    random_state=RANDOM_SEED,
    verbosity=-1,
)


# =========================
# 2) 读取特征文件 & 按固定列位置划分 SMILES / y / X
# =========================
def find_feature_file(pattern: str):
    cands = sorted(glob.glob(pattern))

    if not cands:
        raise FileNotFoundError(
            f"找不到特征文件：{pattern}\n"
            f"请确认 xlsx 文件名，或修改 FEATURE_FILE_GLOB。"
        )

    return cands[-1]


def load_Xy_from_feature_file(xlsx_path: str):
    """
    固定数据格式：
    第 1 列：SMILES
    第 2-25 列：24 个 y 标签
    第 26 列及之后：X 特征列

    说明：
    - 不再通过 0/1 自动判断 y 标签列；
    - 避免 Rule、FG、Morgan、StructKG 等 0/1 或数值特征被误识别为标签；
    - 适用于当前 24 标签任务。
    """
    df = pd.read_excel(xlsx_path)

    if df.shape[1] < 26:
        raise ValueError(
            f"当前文件列数为 {df.shape[1]}，不足以按“1列SMILES + 24列标签 + 特征列”划分。"
        )

    # 固定列位置
    smiles_col = df.columns[0]
    label_cols = list(df.columns[1:25])
    feature_cols = list(df.columns[25:])

    if len(label_cols) != 24:
        raise ValueError(
            f"标签列数量应为 24，但当前识别为 {len(label_cols)}。"
        )

    if len(feature_cols) == 0:
        raise ValueError(
            "未识别到特征列。请确认第 26 列之后为 X 特征。"
        )

    # y 标签转为 0/1 整数
    y_df = df[label_cols].copy()
    y_df = y_df.apply(pd.to_numeric, errors="coerce").fillna(0).astype(int)

    # 检查 y 标签是否为 0/1
    invalid_label_cols = []
    for c in label_cols:
        vals = set(pd.unique(y_df[c].dropna()))
        if not vals.issubset({0, 1}):
            invalid_label_cols.append(c)

    if invalid_label_cols:
        raise ValueError(
            "以下标签列不是标准 0/1 标签，请检查数据：\n"
            + "\n".join(map(str, invalid_label_cols))
        )

    # X 特征转为数值
    X_df = df[feature_cols].copy()
    X_df = X_df.apply(pd.to_numeric, errors="coerce").fillna(0)

    X = X_df.astype(np.float32).values
    y = y_df.values.astype(int)

    if X.shape[0] != y.shape[0]:
        raise ValueError("X 和 y 行数不一致，请检查文件。")

    print("[INFO] Column split mode: fixed-position")
    print(f"[INFO] SMILES column: {smiles_col}")
    print(f"[INFO] Label columns: columns 2-25, n={len(label_cols)}")
    print(f"[INFO] Feature columns: columns 26-end, n={len(feature_cols)}")

    print("\n[INFO] Label columns:")
    for i, c in enumerate(label_cols, start=1):
        print(f"  y{i:02d}: {c}")

    return X, y, feature_cols, label_cols, df


# =========================
# 3) 指标：macro
# =========================
def multilabel_macro_metrics(y_true, y_prob, thresh=0.5):
    y_true = np.asarray(y_true).astype(int)
    y_prob = np.asarray(y_prob).astype(float)
    y_pred = (y_prob >= thresh).astype(int)

    L = y_true.shape[1]
    accs, precs, recs, specs = [], [], [], []
    aurocs, auprcs = [], []

    for k in range(L):
        yt = y_true[:, k]
        yp = y_pred[:, k]
        ys = y_prob[:, k]

        tp = int(np.sum((yt == 1) & (yp == 1)))
        tn = int(np.sum((yt == 0) & (yp == 0)))
        fp = int(np.sum((yt == 0) & (yp == 1)))
        fn = int(np.sum((yt == 1) & (yp == 0)))
        n = len(yt)

        accs.append((tp + tn) / n if n else np.nan)
        precs.append(tp / (tp + fp) if (tp + fp) else np.nan)
        recs.append(tp / (tp + fn) if (tp + fn) else np.nan)
        specs.append(tn / (tn + fp) if (tn + fp) else np.nan)

        if len(np.unique(yt)) == 2:
            aurocs.append(roc_auc_score(yt, ys))
            auprcs.append(average_precision_score(yt, ys))
        else:
            aurocs.append(np.nan)
            auprcs.append(np.nan)

    def nanmean(x):
        return float(np.nanmean(np.asarray(x, dtype=float)))

    return {
        "Accuracy_macro": nanmean(accs),
        "Precision_macro": nanmean(precs),
        "Recall_macro": nanmean(recs),
        "Specificity_macro": nanmean(specs),
        "AUROC_macro": nanmean(aurocs),
        "AUPRC_macro": nanmean(auprcs),
        "AUROC_valid_labels": int(np.sum(~np.isnan(aurocs))),
        "AUPRC_valid_labels": int(np.sum(~np.isnan(auprcs))),
        "n_labels": int(L),
    }


def extract_positive_proba(p, n_labels: int):
    """
    MultiOutputClassifier.predict_proba 通常返回 list：
    list 长度 = 标签数，每个元素形状为 (n_samples, n_classes)。

    注意：
    - 若某个 fold 中某个标签训练集只有单类，LightGBM 可能只返回 1 列；
    - 这里做了兼容，避免 pi[:, 1] 越界。
    """
    if isinstance(p, list):
        out = np.zeros((p[0].shape[0], n_labels), dtype=np.float32)

        for k in range(n_labels):
            pk = p[k]

            if pk.ndim != 2:
                raise ValueError(f"predict_proba[{k}] 形状异常: {pk.shape}")

            if pk.shape[1] == 2:
                out[:, k] = pk[:, 1].astype(np.float32)
            elif pk.shape[1] == 1:
                # 无法从 predict_proba 本身判断该单类是 0 还是 1；
                # 这里兜底使用该列概率。通常极少发生。
                out[:, k] = pk[:, 0].astype(np.float32)
            else:
                raise ValueError(
                    f"predict_proba[{k}] 类别数异常: {pk.shape[1]}"
                )

        return out

    p = np.asarray(p)

    if p.ndim == 3 and p.shape[-1] == 2:
        return p[:, :, 1].astype(np.float32)

    if p.ndim == 2:
        if p.shape[1] == 2 and n_labels == 1:
            return p[:, 1:2].astype(np.float32)

        if p.shape[1] == n_labels:
            return p.astype(np.float32)

        raise ValueError(
            f"predict_proba 输出为二维，但列数 {p.shape[1]} 与标签数 {n_labels} 不一致。"
        )

    raise ValueError(f"无法解析 predict_proba 输出形状: {p.shape}")


# =========================
# 4) 近似分层 5 折：用 label cardinality 分层
# =========================
def make_stratify_target(y: np.ndarray, n_bins: int = 10):
    """
    多标签任务中没有直接的 StratifiedKFold。
    这里使用每个样本的标签数量 label cardinality 做近似分层。
    """
    card = y.sum(axis=1).astype(int)
    uniq = np.unique(card)

    if len(uniq) <= 15:
        return card

    r = pd.Series(card).rank(method="average").values
    bins = pd.qcut(
        r,
        q=min(n_bins, len(np.unique(r))),
        labels=False,
        duplicates="drop"
    )

    return np.asarray(bins, dtype=int)


def build_folds(X, y, n_splits=5, seed=42):
    strat_y = make_stratify_target(y)

    skf = StratifiedKFold(
        n_splits=n_splits,
        shuffle=True,
        random_state=seed
    )

    return list(skf.split(X, strat_y))


# =========================
# 5) 5 折 CV 评估：LightGBM + MultiOutput
# =========================
def cv_eval_one_paramset(X, y, folds, params, thresh=0.5):
    n_labels = y.shape[1]
    fold_metrics = []

    for fold_id, (tr_idx, va_idx) in enumerate(folds, start=1):
        X_tr, X_va = X[tr_idx], X[va_idx]
        y_tr, y_va = y[tr_idx], y[va_idx]

        base_est = lgb.LGBMClassifier(**params)

        # 每个标签一个 LGBM；
        # n_jobs=1 避免“外层并行 + 内层线程”导致线程过载
        clf = MultiOutputClassifier(base_est, n_jobs=1)

        clf.fit(X_tr, y_tr)

        p = clf.predict_proba(X_va)
        y_prob = extract_positive_proba(p, n_labels=n_labels)

        m = multilabel_macro_metrics(y_va, y_prob, thresh=thresh)
        fold_metrics.append(m)

        print(
            f"    [FOLD {fold_id}] "
            f"AUPRC={m['AUPRC_macro']:.6f} | "
            f"AUROC={m['AUROC_macro']:.6f} | "
            f"Acc={m['Accuracy_macro']:.6f} | "
            f"P={m['Precision_macro']:.6f} | "
            f"R={m['Recall_macro']:.6f} | "
            f"Spec={m['Specificity_macro']:.6f}"
        )

    keys = list(fold_metrics[0].keys())
    mean_metrics = {}

    for k in keys:
        vals = [fm[k] for fm in fold_metrics]

        if isinstance(vals[0], float):
            mean_metrics[k] = float(np.nanmean(vals))
        else:
            mean_metrics[k] = vals[-1]

    return mean_metrics


# =========================
# 6) Optuna 超参空间：LightGBM
# =========================
def build_trial_params(trial: optuna.Trial):
    params = dict(BASE_LGB_PARAMS)

    params.update({
        "n_estimators": trial.suggest_int("n_estimators", 300, 2000),
        "learning_rate": trial.suggest_float("learning_rate", 0.01, 0.2, log=True),

        "num_leaves": trial.suggest_int("num_leaves", 31, 255),
        "max_depth": trial.suggest_int("max_depth", -1, 20),
        "min_child_samples": trial.suggest_int("min_child_samples", 5, 80),

        "subsample": trial.suggest_float("subsample", 0.6, 1.0),
        "colsample_bytree": trial.suggest_float("colsample_bytree", 0.6, 1.0),

        "reg_lambda": trial.suggest_float("reg_lambda", 1e-3, 50.0, log=True),
        "reg_alpha": trial.suggest_float("reg_alpha", 1e-8, 10.0, log=True),

        "min_split_gain": trial.suggest_float("min_split_gain", 0.0, 5.0),
    })

    return params


# =========================
# 7) 主流程：读特征 -> 固定 folds -> Optuna -> 输出保存
# =========================
def main():
    feature_file = find_feature_file(FEATURE_FILE_GLOB)
    print("[INFO] Using feature file:", feature_file)

    X, y, feat_cols, label_cols, df_all = load_Xy_from_feature_file(feature_file)

    print(
        f"\n[INFO] X shape={X.shape} "
        f"(features={len(feat_cols)}) | "
        f"y shape={y.shape} "
        f"(labels={len(label_cols)})"
    )

    folds = build_folds(X, y, n_splits=N_SPLITS, seed=RANDOM_SEED)
    print(f"[INFO] Prepared fixed {N_SPLITS}-fold splits for all trials.")

    def objective(trial: optuna.Trial):
        params = build_trial_params(trial)

        print("\n" + "=" * 80)
        print(f"[TRIAL {trial.number:02d}] params:")
        print(json.dumps(params, indent=2, ensure_ascii=False, default=str))

        mean_metrics = cv_eval_one_paramset(
            X,
            y,
            folds,
            params,
            thresh=THRESH
        )

        score = mean_metrics["AUPRC_macro"]

        print(
            f"\n[TRIAL {trial.number:02d}] "
            f"score(AUPRC_macro)={score:.6f} | "
            f"AUROC={mean_metrics['AUROC_macro']:.6f} | "
            f"Acc={mean_metrics['Accuracy_macro']:.6f} | "
            f"P={mean_metrics['Precision_macro']:.6f} | "
            f"R={mean_metrics['Recall_macro']:.6f} | "
            f"Spec={mean_metrics['Specificity_macro']:.6f}"
        )

        for k, v in mean_metrics.items():
            trial.set_user_attr(k, v)

        return score

    study = optuna.create_study(
        direction="maximize",
        sampler=optuna.samplers.TPESampler(seed=RANDOM_SEED),
    )

    study.optimize(
        objective,
        n_trials=N_TRIALS,
        show_progress_bar=True
    )

    print("\n================ BEST =================")
    print("Best trial:", study.best_trial.number)
    print("Best AUPRC_macro:", study.best_value)
    print("Best params:")
    print(json.dumps(study.best_params, indent=2, ensure_ascii=False))

    rows = []

    for t in study.trials:
        if t.value is None:
            continue

        row = {
            "trial": t.number,
            "AUPRC_macro": t.value,
            **t.params
        }

        row.update({
            k: v for k, v in t.user_attrs.items()
            if k.endswith("_macro")
        })

        rows.append(row)

    res_df = pd.DataFrame(rows).sort_values(
        "AUPRC_macro",
        ascending=False
    )

    out_csv = "./optuna_singlemodel_LIGHTGBM_30trials_5fold_results.csv"
    res_df.to_csv(out_csv, index=False, encoding="utf-8-sig")
    print("[SAVED]", out_csv)

    # 额外保存标签列和特征列，便于核查
    label_out = "./used_label_columns_24.csv"
    feature_out = "./used_feature_columns.csv"

    pd.DataFrame({"label_col": label_cols}).to_csv(
        label_out,
        index=False,
        encoding="utf-8-sig"
    )

    pd.DataFrame({"feature_col": feat_cols}).to_csv(
        feature_out,
        index=False,
        encoding="utf-8-sig"
    )

    print("[SAVED]", label_out)
    print("[SAVED]", feature_out)


if __name__ == "__main__":
    main()
# Out:
# [INFO] Using feature file: ./Malodors_Morgan&StructKG_features.xlsx
# [I 2026-07-01 20:08:55,565] A new study created in memory with name: no-name-0c56ea96-a93e-4658-9474-2a6bcd656c7f
# [INFO] Column split mode: fixed-position
# [INFO] SMILES column: Canonical_SMILES
# [INFO] Label columns: columns 2-25, n=24
# [INFO] Feature columns: columns 26-end, n=2216
#
# [INFO] Label columns:
#   y01: alcoholic
#   y02: aldehydic
#   y03: almond
#   y04: aromatic
#   y05: burnt
#   y06: cabbage
#   y07: cheesy
#   y08: cherry
#   y09: chocolate
#   y10: ethereal
#   y11: fishy
#   y12: fruity
#   y13: garlic
#   y14: grassy
#   y15: green
#   y16: ketonic
#   y17: musty
#   y18: pungent
#   y19: sharp
#   y20: solvent
#   y21: sour
#   y22: sulfurous
#   y23: sweaty
#   y24: sweet
#
# [INFO] X shape=(3756, 2216) (features=2216) | y shape=(3756, 24) (labels=24)
# [INFO] Prepared fixed 5-fold splits for all trials.
#   0%|          | 0/30 [00:00<?, ?it/s]
# ================================================================================
# [TRIAL 00] params:
# {
#   "objective": "binary",
#   "boosting_type": "gbdt",
#   "n_jobs": -1,
#   "random_state": 42,
#   "verbosity": -1,
#   "n_estimators": 937,
#   "learning_rate": 0.17254716573280354,
#   "num_leaves": 195,
#   "max_depth": 12,
#   "min_child_samples": 16,
#   "subsample": 0.662397808134481,
#   "colsample_bytree": 0.6232334448672797,
#   "reg_lambda": 11.752647960576219,
#   "reg_alpha": 0.002570603566117598,
#   "min_split_gain": 3.540362888980227
# }
#     [FOLD 1] AUPRC=0.331144 | AUROC=0.834124 | Acc=0.941545 | P=0.841262 | R=0.133543 | Spec=0.979764
#     [FOLD 2] AUPRC=0.326363 | AUROC=0.830442 | Acc=0.939248 | P=0.721544 | R=0.124856 | Spec=0.982186
#     [FOLD 3] AUPRC=0.319795 | AUROC=0.817514 | Acc=0.940968 | P=0.759531 | R=0.130181 | Spec=0.980411
#     [FOLD 4] AUPRC=0.306350 | AUROC=0.822393 | Acc=0.937861 | P=0.695382 | R=0.131676 | Spec=0.978281
#     [FOLD 5] AUPRC=0.313263 | AUROC=0.823291 | Acc=0.940857 | P=0.745954 | R=0.122416 | Spec=0.979962
#
# [TRIAL 00] score(AUPRC_macro)=0.319383 | AUROC=0.825553 | Acc=0.940095 | P=0.752735 | R=0.128535 | Spec=0.980121
# [I 2026-07-01 20:09:30,845] Trial 0 finished with value: 0.31938302629388465 and parameters: {'n_estimators': 937, 'learning_rate': 0.17254716573280354, 'num_leaves': 195, 'max_depth': 12, 'min_child_samples': 16, 'subsample': 0.662397808134481, 'colsample_bytree': 0.6232334448672797, 'reg_lambda': 11.752647960576219, 'reg_alpha': 0.002570603566117598, 'min_split_gain': 3.540362888980227}. Best is trial 0 with value: 0.31938302629388465.
#
# ================================================================================
# [TRIAL 01] params:
# {
#   "objective": "binary",
#   "boosting_type": "gbdt",
#   "n_jobs": -1,
#   "random_state": 42,
#   "verbosity": -1,
#   "n_estimators": 335,
#   "learning_rate": 0.18276027831785724,
#   "num_leaves": 218,
#   "max_depth": 3,
#   "min_child_samples": 18,
#   "subsample": 0.6733618039413735,
#   "colsample_bytree": 0.7216968971838151,
#   "reg_lambda": 0.2922905212920093,
#   "reg_alpha": 7.71800699380605e-05,
#   "min_split_gain": 1.4561457009902097
# }
#     [FOLD 1] AUPRC=0.365297 | AUROC=0.852666 | Acc=0.941933 | P=0.582806 | R=0.194577 | Spec=0.977490
#     [FOLD 2] AUPRC=0.377203 | AUROC=0.858339 | Acc=0.940468 | P=0.591013 | R=0.185384 | Spec=0.979874
#     [FOLD 3] AUPRC=0.389402 | AUROC=0.846986 | Acc=0.943575 | P=0.667906 | R=0.197342 | Spec=0.978699
#     [FOLD 4] AUPRC=0.391729 | AUROC=0.840812 | Acc=0.939802 | P=0.652507 | R=0.184473 | Spec=0.975367
#     [FOLD 5] AUPRC=0.371885 | AUROC=0.848951 | Acc=0.943797 | P=0.676003 | R=0.199046 | Spec=0.977404
#
# [TRIAL 01] score(AUPRC_macro)=0.379103 | AUROC=0.849551 | Acc=0.941915 | P=0.634047 | R=0.192164 | Spec=0.977767
# [I 2026-07-01 20:09:44,298] Trial 1 finished with value: 0.3791031062007469 and parameters: {'n_estimators': 335, 'learning_rate': 0.18276027831785724, 'num_leaves': 218, 'max_depth': 3, 'min_child_samples': 18, 'subsample': 0.6733618039413735, 'colsample_bytree': 0.7216968971838151, 'reg_lambda': 0.2922905212920093, 'reg_alpha': 7.71800699380605e-05, 'min_split_gain': 1.4561457009902097}. Best is trial 1 with value: 0.3791031062007469.
#
# ================================================================================
# [TRIAL 02] params:
# {
#   "objective": "binary",
#   "boosting_type": "gbdt",
#   "n_jobs": -1,
#   "random_state": 42,
#   "verbosity": -1,
#   "n_estimators": 1340,
#   "learning_rate": 0.01518747922672247,
#   "num_leaves": 96,
#   "max_depth": 7,
#   "min_child_samples": 39,
#   "subsample": 0.9140703845572055,
#   "colsample_bytree": 0.6798695128633439,
#   "reg_lambda": 0.2608388046560993,
#   "reg_alpha": 0.0021465011216654484,
#   "min_split_gain": 0.23225206359998862
# }
#     [FOLD 1] AUPRC=0.396865 | AUROC=0.860479 | Acc=0.942431 | P=0.601492 | R=0.249926 | Spec=0.974227
#     [FOLD 2] AUPRC=0.383848 | AUROC=0.862642 | Acc=0.941467 | P=0.508352 | R=0.228964 | Spec=0.976158
#     [FOLD 3] AUPRC=0.392618 | AUROC=0.851527 | Acc=0.943353 | P=0.605712 | R=0.251780 | Spec=0.974680
#     [FOLD 4] AUPRC=0.406376 | AUROC=0.848334 | Acc=0.940912 | P=0.653804 | R=0.246689 | Spec=0.972376
#     [FOLD 5] AUPRC=0.396219 | AUROC=0.846862 | Acc=0.943575 | P=0.614320 | R=0.245472 | Spec=0.974856
#
# [TRIAL 02] score(AUPRC_macro)=0.395185 | AUROC=0.853969 | Acc=0.942348 | P=0.596736 | R=0.244566 | Spec=0.974459
# [I 2026-07-01 20:10:32,688] Trial 2 finished with value: 0.39518501161522346 and parameters: {'n_estimators': 1340, 'learning_rate': 0.01518747922672247, 'num_leaves': 96, 'max_depth': 7, 'min_child_samples': 39, 'subsample': 0.9140703845572055, 'colsample_bytree': 0.6798695128633439, 'reg_lambda': 0.2608388046560993, 'reg_alpha': 0.0021465011216654484, 'min_split_gain': 0.23225206359998862}. Best is trial 2 with value: 0.39518501161522346.
#
# ================================================================================
# [TRIAL 03] params:
# {
#   "objective": "binary",
#   "boosting_type": "gbdt",
#   "n_jobs": -1,
#   "random_state": 42,
#   "verbosity": -1,
#   "n_estimators": 1333,
#   "learning_rate": 0.016666983286066417,
#   "num_leaves": 45,
#   "max_depth": 19,
#   "min_child_samples": 78,
#   "subsample": 0.9233589392465844,
#   "colsample_bytree": 0.7218455076693483,
#   "reg_lambda": 0.002877122371623787,
#   "reg_alpha": 0.014391207615728067,
#   "min_split_gain": 2.2007624686980067
# }
#     [FOLD 1] AUPRC=0.361427 | AUROC=0.855955 | Acc=0.942320 | P=0.764083 | R=0.168574 | Spec=0.978089
#     [FOLD 2] AUPRC=0.359186 | AUROC=0.850909 | Acc=0.939692 | P=0.692731 | R=0.144066 | Spec=0.980057
#     [FOLD 3] AUPRC=0.376824 | AUROC=0.845017 | Acc=0.941578 | P=0.787353 | R=0.152743 | Spec=0.979049
#     [FOLD 4] AUPRC=0.368452 | AUROC=0.839516 | Acc=0.937805 | P=0.718650 | R=0.173955 | Spec=0.973999
#     [FOLD 5] AUPRC=0.361096 | AUROC=0.844958 | Acc=0.941855 | P=0.799567 | R=0.154896 | Spec=0.978418
#
# [TRIAL 03] score(AUPRC_macro)=0.365397 | AUROC=0.847271 | Acc=0.940650 | P=0.752477 | R=0.158847 | Spec=0.977922
# [I 2026-07-01 20:10:53,601] Trial 3 finished with value: 0.36539679606151176 and parameters: {'n_estimators': 1333, 'learning_rate': 0.016666983286066417, 'num_leaves': 45, 'max_depth': 19, 'min_child_samples': 78, 'subsample': 0.9233589392465844, 'colsample_bytree': 0.7218455076693483, 'reg_lambda': 0.002877122371623787, 'reg_alpha': 0.014391207615728067, 'min_split_gain': 2.2007624686980067}. Best is trial 2 with value: 0.39518501161522346.
#
# ================================================================================
# [TRIAL 04] params:
# {
#   "objective": "binary",
#   "boosting_type": "gbdt",
#   "n_jobs": -1,
#   "random_state": 42,
#   "verbosity": -1,
#   "n_estimators": 507,
#   "learning_rate": 0.04407984038169244,
#   "num_leaves": 38,
#   "max_depth": 19,
#   "min_child_samples": 24,
#   "subsample": 0.8650089137415928,
#   "colsample_bytree": 0.7246844304357644,
#   "reg_lambda": 0.2778331300797557,
#   "reg_alpha": 0.0008325158565947976,
#   "min_split_gain": 0.9242722776276352
# }
#     [FOLD 1] AUPRC=0.380087 | AUROC=0.859470 | Acc=0.941933 | P=0.565622 | R=0.205130 | Spec=0.976210
#     [FOLD 2] AUPRC=0.390597 | AUROC=0.857624 | Acc=0.941245 | P=0.529343 | R=0.193619 | Spec=0.978646
#     [FOLD 3] AUPRC=0.406694 | AUROC=0.849650 | Acc=0.943520 | P=0.690760 | R=0.209906 | Spec=0.976095
#     [FOLD 4] AUPRC=0.406226 | AUROC=0.839852 | Acc=0.940080 | P=0.642574 | R=0.204453 | Spec=0.973996
#     [FOLD 5] AUPRC=0.388630 | AUROC=0.849929 | Acc=0.943575 | P=0.676216 | R=0.195723 | Spec=0.977466
#
# [TRIAL 04] score(AUPRC_macro)=0.394447 | AUROC=0.851305 | Acc=0.942071 | P=0.620903 | R=0.201766 | Spec=0.976482
# [I 2026-07-01 20:11:11,788] Trial 4 finished with value: 0.39444674223153176 and parameters: {'n_estimators': 507, 'learning_rate': 0.04407984038169244, 'num_leaves': 38, 'max_depth': 19, 'min_child_samples': 24, 'subsample': 0.8650089137415928, 'colsample_bytree': 0.7246844304357644, 'reg_lambda': 0.2778331300797557, 'reg_alpha': 0.0008325158565947976, 'min_split_gain': 0.9242722776276352}. Best is trial 2 with value: 0.39518501161522346.
#
# ================================================================================
# [TRIAL 05] params:
# {
#   "objective": "binary",
#   "boosting_type": "gbdt",
#   "n_jobs": -1,
#   "random_state": 42,
#   "verbosity": -1,
#   "n_estimators": 1949,
#   "learning_rate": 0.10196967939171485,
#   "num_leaves": 242,
#   "max_depth": 18,
#   "min_child_samples": 50,
#   "subsample": 0.9687496940092467,
#   "colsample_bytree": 0.6353970008207678,
#   "reg_lambda": 0.008335230071817131,
#   "reg_alpha": 2.5529693461039728e-08,
#   "min_split_gain": 1.6266516538163218
# }
#     [FOLD 1] AUPRC=0.368012 | AUROC=0.857486 | Acc=0.942653 | P=0.780031 | R=0.183985 | Spec=0.978539
#     [FOLD 2] AUPRC=0.386409 | AUROC=0.853343 | Acc=0.940302 | P=0.717602 | R=0.171580 | Spec=0.980390
#     [FOLD 3] AUPRC=0.390893 | AUROC=0.848628 | Acc=0.943076 | P=0.749109 | R=0.188636 | Spec=0.979375
#     [FOLD 4] AUPRC=0.388474 | AUROC=0.843078 | Acc=0.939248 | P=0.776643 | R=0.178638 | Spec=0.975188
#     [FOLD 5] AUPRC=0.371986 | AUROC=0.848461 | Acc=0.941356 | P=0.701595 | R=0.174686 | Spec=0.976519
#
# [TRIAL 05] score(AUPRC_macro)=0.381155 | AUROC=0.850199 | Acc=0.941327 | P=0.744996 | R=0.179505 | Spec=0.978002
# [I 2026-07-01 20:11:53,484] Trial 5 finished with value: 0.3811547540343996 and parameters: {'n_estimators': 1949, 'learning_rate': 0.10196967939171485, 'num_leaves': 242, 'max_depth': 18, 'min_child_samples': 50, 'subsample': 0.9687496940092467, 'colsample_bytree': 0.6353970008207678, 'reg_lambda': 0.008335230071817131, 'reg_alpha': 2.5529693461039728e-08, 'min_split_gain': 1.6266516538163218}. Best is trial 2 with value: 0.39518501161522346.
#
# ================================================================================
# [TRIAL 06] params:
# {
#   "objective": "binary",
#   "boosting_type": "gbdt",
#   "n_jobs": -1,
#   "random_state": 42,
#   "verbosity": -1,
#   "n_estimators": 961,
#   "learning_rate": 0.022544116997360492,
#   "num_leaves": 217,
#   "max_depth": 6,
#   "min_child_samples": 26,
#   "subsample": 0.8170784332632994,
#   "colsample_bytree": 0.6563696899899051,
#   "reg_lambda": 5.881655048861897,
#   "reg_alpha": 4.6876566400928895e-08,
#   "min_split_gain": 4.9344346830025865
# }
#     [FOLD 1] AUPRC=0.331696 | AUROC=0.835124 | Acc=0.940880 | P=0.819134 | R=0.118939 | Spec=0.980802
#     [FOLD 2] AUPRC=0.328576 | AUROC=0.826942 | Acc=0.938526 | P=0.712490 | R=0.108830 | Spec=0.983573
#     [FOLD 3] AUPRC=0.319991 | AUROC=0.815011 | Acc=0.940579 | P=0.773745 | R=0.120366 | Spec=0.981124
#     [FOLD 4] AUPRC=0.316669 | AUROC=0.820965 | Acc=0.936751 | P=0.785327 | R=0.118205 | Spec=0.976910
#     [FOLD 5] AUPRC=0.311478 | AUROC=0.822918 | Acc=0.940080 | P=0.768996 | R=0.115652 | Spec=0.980002
#
# [TRIAL 06] score(AUPRC_macro)=0.321682 | AUROC=0.824192 | Acc=0.939363 | P=0.771938 | R=0.116398 | Spec=0.980482
# [I 2026-07-01 20:12:17,725] Trial 6 finished with value: 0.3216817982784423 and parameters: {'n_estimators': 961, 'learning_rate': 0.022544116997360492, 'num_leaves': 217, 'max_depth': 6, 'min_child_samples': 26, 'subsample': 0.8170784332632994, 'colsample_bytree': 0.6563696899899051, 'reg_lambda': 5.881655048861897, 'reg_alpha': 4.6876566400928895e-08, 'min_split_gain': 4.9344346830025865}. Best is trial 2 with value: 0.39518501161522346.
#
# ================================================================================
# [TRIAL 07] params:
# {
#   "objective": "binary",
#   "boosting_type": "gbdt",
#   "n_jobs": -1,
#   "random_state": 42,
#   "verbosity": -1,
#   "n_estimators": 1613,
#   "learning_rate": 0.018135730867783396,
#   "num_leaves": 32,
#   "max_depth": 16,
#   "min_child_samples": 58,
#   "subsample": 0.8916028672163949,
#   "colsample_bytree": 0.9085081386743783,
#   "reg_lambda": 0.0022280944532589255,
#   "reg_alpha": 1.683416412018213e-05,
#   "min_split_gain": 0.5793452976256486
# }
#     [FOLD 1] AUPRC=0.388217 | AUROC=0.860700 | Acc=0.941102 | P=0.729745 | R=0.189909 | Spec=0.975908
#     [FOLD 2] AUPRC=0.382782 | AUROC=0.857259 | Acc=0.939525 | P=0.598169 | R=0.188883 | Spec=0.976058
#     [FOLD 3] AUPRC=0.386169 | AUROC=0.849135 | Acc=0.942133 | P=0.606639 | R=0.203299 | Spec=0.976182
#     [FOLD 4] AUPRC=0.392342 | AUROC=0.841904 | Acc=0.939137 | P=0.643659 | R=0.214553 | Spec=0.973104
#     [FOLD 5] AUPRC=0.383809 | AUROC=0.847941 | Acc=0.941966 | P=0.615182 | R=0.193877 | Spec=0.975147
#
# [TRIAL 07] score(AUPRC_macro)=0.386664 | AUROC=0.851388 | Acc=0.940772 | P=0.638679 | R=0.198104 | Spec=0.975280
# [I 2026-07-01 20:12:48,813] Trial 7 finished with value: 0.38666413660190746 and parameters: {'n_estimators': 1613, 'learning_rate': 0.018135730867783396, 'num_leaves': 32, 'max_depth': 16, 'min_child_samples': 58, 'subsample': 0.8916028672163949, 'colsample_bytree': 0.9085081386743783, 'reg_lambda': 0.0022280944532589255, 'reg_alpha': 1.683416412018213e-05, 'min_split_gain': 0.5793452976256486}. Best is trial 2 with value: 0.39518501161522346.
#
# ================================================================================
# [TRIAL 08] params:
# {
#   "objective": "binary",
#   "boosting_type": "gbdt",
#   "n_jobs": -1,
#   "random_state": 42,
#   "verbosity": -1,
#   "n_estimators": 1768,
#   "learning_rate": 0.06470376604234768,
#   "num_leaves": 105,
#   "max_depth": 0,
#   "min_child_samples": 28,
#   "subsample": 0.7300733288106989,
#   "colsample_bytree": 0.8918424713352255,
#   "reg_lambda": 0.9905204218383901,
#   "reg_alpha": 0.9658611176861268,
#   "min_split_gain": 2.3610746258097466
# }
#     [FOLD 1] AUPRC=0.349137 | AUROC=0.848765 | Acc=0.941600 | P=0.725236 | R=0.173311 | Spec=0.977679
#     [FOLD 2] AUPRC=0.367079 | AUROC=0.845783 | Acc=0.940357 | P=0.769096 | R=0.155738 | Spec=0.980925
#     [FOLD 3] AUPRC=0.363871 | AUROC=0.833190 | Acc=0.942244 | P=0.795879 | R=0.153276 | Spec=0.979929
#     [FOLD 4] AUPRC=0.365741 | AUROC=0.833784 | Acc=0.937916 | P=0.757143 | R=0.148111 | Spec=0.975329
#     [FOLD 5] AUPRC=0.350633 | AUROC=0.839166 | Acc=0.941966 | P=0.805976 | R=0.162753 | Spec=0.978398
#
# [TRIAL 08] score(AUPRC_macro)=0.359292 | AUROC=0.840138 | Acc=0.940817 | P=0.770666 | R=0.158638 | Spec=0.978452
# [I 2026-07-01 20:13:15,231] Trial 8 finished with value: 0.35929202020079865 and parameters: {'n_estimators': 1768, 'learning_rate': 0.06470376604234768, 'num_leaves': 105, 'max_depth': 0, 'min_child_samples': 28, 'subsample': 0.7300733288106989, 'colsample_bytree': 0.8918424713352255, 'reg_lambda': 0.9905204218383901, 'reg_alpha': 0.9658611176861268, 'min_split_gain': 2.3610746258097466}. Best is trial 2 with value: 0.39518501161522346.
#
# ================================================================================
# [TRIAL 09] params:
# {
#   "objective": "binary",
#   "boosting_type": "gbdt",
#   "n_jobs": -1,
#   "random_state": 42,
#   "verbosity": -1,
#   "n_estimators": 503,
#   "learning_rate": 0.08471354625326555,
#   "num_leaves": 202,
#   "max_depth": 11,
#   "min_child_samples": 63,
#   "subsample": 0.7975182385457563,
#   "colsample_bytree": 0.8090931317527976,
#   "reg_lambda": 0.10209451747520762,
#   "reg_alpha": 1.6934490731313353e-08,
#   "min_split_gain": 0.5394571349665223
# }
#     [FOLD 1] AUPRC=0.391851 | AUROC=0.861609 | Acc=0.941600 | P=0.737771 | R=0.193925 | Spec=0.975196
#     [FOLD 2] AUPRC=0.380966 | AUROC=0.855797 | Acc=0.939692 | P=0.560305 | R=0.193250 | Spec=0.975802
#     [FOLD 3] AUPRC=0.385441 | AUROC=0.848103 | Acc=0.942022 | P=0.579044 | R=0.206933 | Spec=0.975641
#     [FOLD 4] AUPRC=0.390444 | AUROC=0.843663 | Acc=0.939525 | P=0.618546 | R=0.205363 | Spec=0.973354
#     [FOLD 5] AUPRC=0.382646 | AUROC=0.852454 | Acc=0.941578 | P=0.629826 | R=0.191241 | Spec=0.975420
#
# [TRIAL 09] score(AUPRC_macro)=0.386270 | AUROC=0.852325 | Acc=0.940883 | P=0.625098 | R=0.198142 | Spec=0.975082
# [I 2026-07-01 20:13:28,204] Trial 9 finished with value: 0.3862697329710082 and parameters: {'n_estimators': 503, 'learning_rate': 0.08471354625326555, 'num_leaves': 202, 'max_depth': 11, 'min_child_samples': 63, 'subsample': 0.7975182385457563, 'colsample_bytree': 0.8090931317527976, 'reg_lambda': 0.10209451747520762, 'reg_alpha': 1.6934490731313353e-08, 'min_split_gain': 0.5394571349665223}. Best is trial 2 with value: 0.39518501161522346.
#
# ================================================================================
# [TRIAL 10] params:
# {
#   "objective": "binary",
#   "boosting_type": "gbdt",
#   "n_jobs": -1,
#   "random_state": 42,
#   "verbosity": -1,
#   "n_estimators": 1301,
#   "learning_rate": 0.010181283131439633,
#   "num_leaves": 127,
#   "max_depth": 6,
#   "min_child_samples": 40,
#   "subsample": 0.9630659181130071,
#   "colsample_bytree": 0.983908298378168,
#   "reg_lambda": 0.03379534397108484,
#   "reg_alpha": 3.3316309468938505,
#   "min_split_gain": 0.061555847824686705
# }
#     [FOLD 1] AUPRC=0.369630 | AUROC=0.854847 | Acc=0.941822 | P=0.751425 | R=0.179184 | Spec=0.976264
#     [FOLD 2] AUPRC=0.383752 | AUROC=0.849890 | Acc=0.940912 | P=0.721093 | R=0.161970 | Spec=0.979533
#     [FOLD 3] AUPRC=0.385903 | AUROC=0.839294 | Acc=0.942188 | P=0.739402 | R=0.165118 | Spec=0.978152
#     [FOLD 4] AUPRC=0.381237 | AUROC=0.845660 | Acc=0.939026 | P=0.699063 | R=0.174271 | Spec=0.974518
#     [FOLD 5] AUPRC=0.386489 | AUROC=0.847702 | Acc=0.942521 | P=0.797966 | R=0.175662 | Spec=0.976870
#
# [TRIAL 10] score(AUPRC_macro)=0.381402 | AUROC=0.847479 | Acc=0.941294 | P=0.741790 | R=0.171241 | Spec=0.977067
# [I 2026-07-01 20:14:03,329] Trial 10 finished with value: 0.38140218312266694 and parameters: {'n_estimators': 1301, 'learning_rate': 0.010181283131439633, 'num_leaves': 127, 'max_depth': 6, 'min_child_samples': 40, 'subsample': 0.9630659181130071, 'colsample_bytree': 0.983908298378168, 'reg_lambda': 0.03379534397108484, 'reg_alpha': 3.3316309468938505, 'min_split_gain': 0.061555847824686705}. Best is trial 2 with value: 0.39518501161522346.
#
# ================================================================================
# [TRIAL 11] params:
# {
#   "objective": "binary",
#   "boosting_type": "gbdt",
#   "n_jobs": -1,
#   "random_state": 42,
#   "verbosity": -1,
#   "n_estimators": 776,
#   "learning_rate": 0.03507491451049357,
#   "num_leaves": 74,
#   "max_depth": 14,
#   "min_child_samples": 38,
#   "subsample": 0.8528283491443681,
#   "colsample_bytree": 0.7389917503278137,
#   "reg_lambda": 1.507231417469703,
#   "reg_alpha": 0.027019779735714396,
#   "min_split_gain": 1.0718581779940537
# }
#     [FOLD 1] AUPRC=0.375352 | AUROC=0.860161 | Acc=0.941711 | P=0.743258 | R=0.185411 | Spec=0.976746
#     [FOLD 2] AUPRC=0.388362 | AUROC=0.852691 | Acc=0.940468 | P=0.710962 | R=0.175811 | Spec=0.979254
#     [FOLD 3] AUPRC=0.395512 | AUROC=0.850011 | Acc=0.943076 | P=0.717592 | R=0.185715 | Spec=0.978153
#     [FOLD 4] AUPRC=0.401530 | AUROC=0.847280 | Acc=0.938970 | P=0.704528 | R=0.186899 | Spec=0.973819
#     [FOLD 5] AUPRC=0.402139 | AUROC=0.851519 | Acc=0.942688 | P=0.755789 | R=0.180331 | Spec=0.977060
#
# [TRIAL 11] score(AUPRC_macro)=0.392579 | AUROC=0.852332 | Acc=0.941383 | P=0.726426 | R=0.182833 | Spec=0.977007
# [I 2026-07-01 20:14:21,707] Trial 11 finished with value: 0.39257885529948805 and parameters: {'n_estimators': 776, 'learning_rate': 0.03507491451049357, 'num_leaves': 74, 'max_depth': 14, 'min_child_samples': 38, 'subsample': 0.8528283491443681, 'colsample_bytree': 0.7389917503278137, 'reg_lambda': 1.507231417469703, 'reg_alpha': 0.027019779735714396, 'min_split_gain': 1.0718581779940537}. Best is trial 2 with value: 0.39518501161522346.
#
# ================================================================================
# [TRIAL 12] params:
# {
#   "objective": "binary",
#   "boosting_type": "gbdt",
#   "n_jobs": -1,
#   "random_state": 42,
#   "verbosity": -1,
#   "n_estimators": 1503,
#   "learning_rate": 0.03943884516061402,
#   "num_leaves": 84,
#   "max_depth": 8,
#   "min_child_samples": 7,
#   "subsample": 0.8891499127306165,
#   "colsample_bytree": 0.7925153971864091,
#   "reg_lambda": 47.89076853424982,
#   "reg_alpha": 3.0027540878413585e-06,
#   "min_split_gain": 0.009027489905749114
# }
#     [FOLD 1] AUPRC=0.395878 | AUROC=0.863367 | Acc=0.942043 | P=0.597198 | R=0.258345 | Spec=0.972510
#     [FOLD 2] AUPRC=0.379356 | AUROC=0.858910 | Acc=0.940801 | P=0.457201 | R=0.228223 | Spec=0.974594
#     [FOLD 3] AUPRC=0.404189 | AUROC=0.851583 | Acc=0.944296 | P=0.477943 | R=0.265215 | Spec=0.972962
#     [FOLD 4] AUPRC=0.404060 | AUROC=0.851063 | Acc=0.941467 | P=0.632521 | R=0.276603 | Spec=0.970338
#     [FOLD 5] AUPRC=0.387270 | AUROC=0.858403 | Acc=0.943575 | P=0.489521 | R=0.247100 | Spec=0.972692
#
# [TRIAL 12] score(AUPRC_macro)=0.394151 | AUROC=0.856665 | Acc=0.942437 | P=0.530877 | R=0.255097 | Spec=0.972619
# [I 2026-07-01 20:16:34,899] Trial 12 finished with value: 0.3941507229745561 and parameters: {'n_estimators': 1503, 'learning_rate': 0.03943884516061402, 'num_leaves': 84, 'max_depth': 8, 'min_child_samples': 7, 'subsample': 0.8891499127306165, 'colsample_bytree': 0.7925153971864091, 'reg_lambda': 47.89076853424982, 'reg_alpha': 3.0027540878413585e-06, 'min_split_gain': 0.009027489905749114}. Best is trial 2 with value: 0.39518501161522346.
#
# ================================================================================
# [TRIAL 13] params:
# {
#   "objective": "binary",
#   "boosting_type": "gbdt",
#   "n_jobs": -1,
#   "random_state": 42,
#   "verbosity": -1,
#   "n_estimators": 649,
#   "learning_rate": 0.010444406415184166,
#   "num_leaves": 162,
#   "max_depth": 8,
#   "min_child_samples": 32,
#   "subsample": 0.9981543705456256,
#   "colsample_bytree": 0.6782204589759935,
#   "reg_lambda": 0.05083762407403203,
#   "reg_alpha": 0.0028198498393717567,
#   "min_split_gain": 3.6904917106311634
# }
#     [FOLD 1] AUPRC=0.355843 | AUROC=0.848585 | Acc=0.941600 | P=0.806566 | R=0.160031 | Spec=0.979504
#     [FOLD 2] AUPRC=0.383345 | AUROC=0.851195 | Acc=0.940579 | P=0.793455 | R=0.144638 | Spec=0.983200
#     [FOLD 3] AUPRC=0.380230 | AUROC=0.840838 | Acc=0.942466 | P=0.765499 | R=0.155419 | Spec=0.980863
#     [FOLD 4] AUPRC=0.378154 | AUROC=0.833507 | Acc=0.938526 | P=0.810210 | R=0.150758 | Spec=0.976697
#     [FOLD 5] AUPRC=0.358307 | AUROC=0.840146 | Acc=0.942244 | P=0.828297 | R=0.162044 | Spec=0.979742
#
# [TRIAL 13] score(AUPRC_macro)=0.371176 | AUROC=0.842854 | Acc=0.941083 | P=0.800805 | R=0.154578 | Spec=0.980001
# [I 2026-07-01 20:16:55,894] Trial 13 finished with value: 0.37117590805652495 and parameters: {'n_estimators': 649, 'learning_rate': 0.010444406415184166, 'num_leaves': 162, 'max_depth': 8, 'min_child_samples': 32, 'subsample': 0.9981543705456256, 'colsample_bytree': 0.6782204589759935, 'reg_lambda': 0.05083762407403203, 'reg_alpha': 0.0028198498393717567, 'min_split_gain': 3.6904917106311634}. Best is trial 2 with value: 0.39518501161522346.
#
# ================================================================================
# [TRIAL 14] params:
# {
#   "objective": "binary",
#   "boosting_type": "gbdt",
#   "n_jobs": -1,
#   "random_state": 42,
#   "verbosity": -1,
#   "n_estimators": 1193,
#   "learning_rate": 0.024400293504008196,
#   "num_leaves": 69,
#   "max_depth": 20,
#   "min_child_samples": 50,
#   "subsample": 0.7702357857455316,
#   "colsample_bytree": 0.7901530268661332,
#   "reg_lambda": 0.43069286056305955,
#   "reg_alpha": 0.0004236629819025505,
#   "min_split_gain": 0.9171299471299958
# }
#     [FOLD 1] AUPRC=0.382676 | AUROC=0.860979 | Acc=0.941157 | P=0.703886 | R=0.185061 | Spec=0.976397
#     [FOLD 2] AUPRC=0.383736 | AUROC=0.854819 | Acc=0.939414 | P=0.636023 | R=0.183298 | Spec=0.978010
#     [FOLD 3] AUPRC=0.391535 | AUROC=0.849878 | Acc=0.942688 | P=0.690920 | R=0.194612 | Spec=0.977360
#     [FOLD 4] AUPRC=0.390559 | AUROC=0.844478 | Acc=0.939248 | P=0.672014 | R=0.187229 | Spec=0.974800
#     [FOLD 5] AUPRC=0.385363 | AUROC=0.852513 | Acc=0.941855 | P=0.641366 | R=0.180057 | Spec=0.976648
#
# [TRIAL 14] score(AUPRC_macro)=0.386774 | AUROC=0.852533 | Acc=0.940872 | P=0.668842 | R=0.186051 | Spec=0.976643
# [I 2026-07-01 20:17:20,397] Trial 14 finished with value: 0.38677379650893096 and parameters: {'n_estimators': 1193, 'learning_rate': 0.024400293504008196, 'num_leaves': 69, 'max_depth': 20, 'min_child_samples': 50, 'subsample': 0.7702357857455316, 'colsample_bytree': 0.7901530268661332, 'reg_lambda': 0.43069286056305955, 'reg_alpha': 0.0004236629819025505, 'min_split_gain': 0.9171299471299958}. Best is trial 2 with value: 0.39518501161522346.
#
# ================================================================================
# [TRIAL 15] params:
# {
#   "objective": "binary",
#   "boosting_type": "gbdt",
#   "n_jobs": -1,
#   "random_state": 42,
#   "verbosity": -1,
#   "n_estimators": 931,
#   "learning_rate": 0.05415040659238008,
#   "num_leaves": 139,
#   "max_depth": 14,
#   "min_child_samples": 5,
#   "subsample": 0.8557873865083512,
#   "colsample_bytree": 0.6006549219376077,
#   "reg_lambda": 0.01622242063515459,
#   "reg_alpha": 0.07476985772132953,
#   "min_split_gain": 1.7299202332916908
# }
#     [FOLD 1] AUPRC=0.384816 | AUROC=0.853568 | Acc=0.941600 | P=0.649828 | R=0.187582 | Spec=0.977277
#     [FOLD 2] AUPRC=0.387172 | AUROC=0.847789 | Acc=0.940468 | P=0.625052 | R=0.182186 | Spec=0.978999
#     [FOLD 3] AUPRC=0.386604 | AUROC=0.846964 | Acc=0.944907 | P=0.700744 | R=0.198168 | Spec=0.978764
#     [FOLD 4] AUPRC=0.386702 | AUROC=0.842718 | Acc=0.939802 | P=0.621360 | R=0.196235 | Spec=0.973743
#     [FOLD 5] AUPRC=0.379211 | AUROC=0.848648 | Acc=0.943464 | P=0.611649 | R=0.192849 | Spec=0.978238
#
# [TRIAL 15] score(AUPRC_macro)=0.384901 | AUROC=0.847937 | Acc=0.942048 | P=0.641727 | R=0.191404 | Spec=0.977404
# [I 2026-07-01 20:18:11,585] Trial 15 finished with value: 0.3849009825632563 and parameters: {'n_estimators': 931, 'learning_rate': 0.05415040659238008, 'num_leaves': 139, 'max_depth': 14, 'min_child_samples': 5, 'subsample': 0.8557873865083512, 'colsample_bytree': 0.6006549219376077, 'reg_lambda': 0.01622242063515459, 'reg_alpha': 0.07476985772132953, 'min_split_gain': 1.7299202332916908}. Best is trial 2 with value: 0.39518501161522346.
#
# ================================================================================
# [TRIAL 16] params:
# {
#   "objective": "binary",
#   "boosting_type": "gbdt",
#   "n_jobs": -1,
#   "random_state": 42,
#   "verbosity": -1,
#   "n_estimators": 301,
#   "learning_rate": 0.031132631470862867,
#   "num_leaves": 107,
#   "max_depth": 3,
#   "min_child_samples": 18,
#   "subsample": 0.609478164602333,
#   "colsample_bytree": 0.6852224778895979,
#   "reg_lambda": 0.1438364744608722,
#   "reg_alpha": 1.0845062115979571e-06,
#   "min_split_gain": 3.0938436243245784
# }
#     [FOLD 1] AUPRC=0.360289 | AUROC=0.850718 | Acc=0.942154 | P=0.823048 | R=0.170499 | Spec=0.980621
#     [FOLD 2] AUPRC=0.382034 | AUROC=0.851164 | Acc=0.940302 | P=0.713807 | R=0.153910 | Spec=0.982378
#     [FOLD 3] AUPRC=0.381237 | AUROC=0.837843 | Acc=0.942466 | P=0.813942 | R=0.164970 | Spec=0.980920
#     [FOLD 4] AUPRC=0.373682 | AUROC=0.839352 | Acc=0.939525 | P=0.789493 | R=0.156113 | Spec=0.977593
#     [FOLD 5] AUPRC=0.360247 | AUROC=0.841755 | Acc=0.942077 | P=0.781367 | R=0.171788 | Spec=0.979225
#
# [TRIAL 16] score(AUPRC_macro)=0.371498 | AUROC=0.844167 | Acc=0.941305 | P=0.784331 | R=0.163456 | Spec=0.980147
# [I 2026-07-01 20:18:25,170] Trial 16 finished with value: 0.3714979145602373 and parameters: {'n_estimators': 301, 'learning_rate': 0.031132631470862867, 'num_leaves': 107, 'max_depth': 3, 'min_child_samples': 18, 'subsample': 0.609478164602333, 'colsample_bytree': 0.6852224778895979, 'reg_lambda': 0.1438364744608722, 'reg_alpha': 1.0845062115979571e-06, 'min_split_gain': 3.0938436243245784}. Best is trial 2 with value: 0.39518501161522346.
#
# ================================================================================
# [TRIAL 17] params:
# {
#   "objective": "binary",
#   "boosting_type": "gbdt",
#   "n_jobs": -1,
#   "random_state": 42,
#   "verbosity": -1,
#   "n_estimators": 1127,
#   "learning_rate": 0.01454868271619218,
#   "num_leaves": 59,
#   "max_depth": 0,
#   "min_child_samples": 47,
#   "subsample": 0.9153884787798737,
#   "colsample_bytree": 0.8416634198004798,
#   "reg_lambda": 2.5358207357631524,
#   "reg_alpha": 0.30170776649870923,
#   "min_split_gain": 0.6612516943433948
# }
#     [FOLD 1] AUPRC=0.380103 | AUROC=0.862074 | Acc=0.941434 | P=0.779381 | R=0.187704 | Spec=0.976218
#     [FOLD 2] AUPRC=0.390260 | AUROC=0.852114 | Acc=0.940024 | P=0.707810 | R=0.178545 | Spec=0.978256
#     [FOLD 3] AUPRC=0.395519 | AUROC=0.850065 | Acc=0.942965 | P=0.780627 | R=0.191065 | Spec=0.977700
#     [FOLD 4] AUPRC=0.400748 | AUROC=0.847049 | Acc=0.939192 | P=0.703342 | R=0.183962 | Spec=0.974324
#     [FOLD 5] AUPRC=0.391376 | AUROC=0.852775 | Acc=0.941578 | P=0.668012 | R=0.176802 | Spec=0.975803
#
# [TRIAL 17] score(AUPRC_macro)=0.391601 | AUROC=0.852815 | Acc=0.941039 | P=0.727835 | R=0.183615 | Spec=0.976460
# [I 2026-07-01 20:18:53,821] Trial 17 finished with value: 0.3916012566252449 and parameters: {'n_estimators': 1127, 'learning_rate': 0.01454868271619218, 'num_leaves': 59, 'max_depth': 0, 'min_child_samples': 47, 'subsample': 0.9153884787798737, 'colsample_bytree': 0.8416634198004798, 'reg_lambda': 2.5358207357631524, 'reg_alpha': 0.30170776649870923, 'min_split_gain': 0.6612516943433948}. Best is trial 2 with value: 0.39518501161522346.
#
# ================================================================================
# [TRIAL 18] params:
# {
#   "objective": "binary",
#   "boosting_type": "gbdt",
#   "n_jobs": -1,
#   "random_state": 42,
#   "verbosity": -1,
#   "n_estimators": 1498,
#   "learning_rate": 0.10903567711615332,
#   "num_leaves": 165,
#   "max_depth": 10,
#   "min_child_samples": 35,
#   "subsample": 0.8423807474389287,
#   "colsample_bytree": 0.7546609557466136,
#   "reg_lambda": 0.5373804046176045,
#   "reg_alpha": 0.00039957667456266854,
#   "min_split_gain": 1.2779063156255037
# }
#     [FOLD 1] AUPRC=0.374907 | AUROC=0.859654 | Acc=0.942653 | P=0.707643 | R=0.192786 | Spec=0.977302
#     [FOLD 2] AUPRC=0.387405 | AUROC=0.849204 | Acc=0.941134 | P=0.581728 | R=0.183510 | Spec=0.979855
#     [FOLD 3] AUPRC=0.400679 | AUROC=0.849475 | Acc=0.942521 | P=0.684485 | R=0.178888 | Spec=0.978325
#     [FOLD 4] AUPRC=0.401714 | AUROC=0.848544 | Acc=0.938970 | P=0.679240 | R=0.191271 | Spec=0.974360
#     [FOLD 5] AUPRC=0.376250 | AUROC=0.850887 | Acc=0.942688 | P=0.695530 | R=0.186543 | Spec=0.976675
#
# [TRIAL 18] score(AUPRC_macro)=0.388191 | AUROC=0.851553 | Acc=0.941593 | P=0.669725 | R=0.186600 | Spec=0.977303
# [I 2026-07-01 20:19:19,014] Trial 18 finished with value: 0.3881910198887133 and parameters: {'n_estimators': 1498, 'learning_rate': 0.10903567711615332, 'num_leaves': 165, 'max_depth': 10, 'min_child_samples': 35, 'subsample': 0.8423807474389287, 'colsample_bytree': 0.7546609557466136, 'reg_lambda': 0.5373804046176045, 'reg_alpha': 0.00039957667456266854, 'min_split_gain': 1.2779063156255037}. Best is trial 2 with value: 0.39518501161522346.
#
# ================================================================================
# [TRIAL 19] params:
# {
#   "objective": "binary",
#   "boosting_type": "gbdt",
#   "n_jobs": -1,
#   "random_state": 42,
#   "verbosity": -1,
#   "n_estimators": 528,
#   "learning_rate": 0.050124499073911845,
#   "num_leaves": 98,
#   "max_depth": 16,
#   "min_child_samples": 25,
#   "subsample": 0.7590602526122234,
#   "colsample_bytree": 0.6991295320977609,
#   "reg_lambda": 0.10787604280683159,
#   "reg_alpha": 2.1578855507902905e-05,
#   "min_split_gain": 1.9076705424944373
# }
#     [FOLD 1] AUPRC=0.371248 | AUROC=0.858958 | Acc=0.941711 | P=0.680250 | R=0.182204 | Spec=0.977707
#     [FOLD 2] AUPRC=0.390289 | AUROC=0.853295 | Acc=0.940635 | P=0.593563 | R=0.160804 | Spec=0.980943
#     [FOLD 3] AUPRC=0.397908 | AUROC=0.845566 | Acc=0.943353 | P=0.796030 | R=0.182330 | Spec=0.979323
#     [FOLD 4] AUPRC=0.404220 | AUROC=0.841531 | Acc=0.939636 | P=0.741895 | R=0.183804 | Spec=0.975367
#     [FOLD 5] AUPRC=0.375548 | AUROC=0.846270 | Acc=0.943353 | P=0.754052 | R=0.178899 | Spec=0.978894
#
# [TRIAL 19] score(AUPRC_macro)=0.387843 | AUROC=0.849124 | Acc=0.941738 | P=0.713158 | R=0.177608 | Spec=0.978447
# [I 2026-07-01 20:19:35,096] Trial 19 finished with value: 0.387842755654177 and parameters: {'n_estimators': 528, 'learning_rate': 0.050124499073911845, 'num_leaves': 98, 'max_depth': 16, 'min_child_samples': 25, 'subsample': 0.7590602526122234, 'colsample_bytree': 0.6991295320977609, 'reg_lambda': 0.10787604280683159, 'reg_alpha': 2.1578855507902905e-05, 'min_split_gain': 1.9076705424944373}. Best is trial 2 with value: 0.39518501161522346.
#
# ================================================================================
# [TRIAL 20] params:
# {
#   "objective": "binary",
#   "boosting_type": "gbdt",
#   "n_jobs": -1,
#   "random_state": 42,
#   "verbosity": -1,
#   "n_estimators": 778,
#   "learning_rate": 0.025065231110380545,
#   "num_leaves": 51,
#   "max_depth": 3,
#   "min_child_samples": 61,
#   "subsample": 0.9369290173194924,
#   "colsample_bytree": 0.76320346282282,
#   "reg_lambda": 3.774401339460368,
#   "reg_alpha": 0.002732044889740839,
#   "min_split_gain": 2.7053637827277726
# }
#     [FOLD 1] AUPRC=0.344380 | AUROC=0.849107 | Acc=0.942487 | P=0.731716 | R=0.161709 | Spec=0.980819
#     [FOLD 2] AUPRC=0.345158 | AUROC=0.843486 | Acc=0.939414 | P=0.692447 | R=0.135025 | Spec=0.983200
#     [FOLD 3] AUPRC=0.347887 | AUROC=0.829202 | Acc=0.941633 | P=0.780550 | R=0.151671 | Spec=0.980482
#     [FOLD 4] AUPRC=0.344205 | AUROC=0.834485 | Acc=0.937805 | P=0.750833 | R=0.133258 | Spec=0.977105
#     [FOLD 5] AUPRC=0.336712 | AUROC=0.835981 | Acc=0.941134 | P=0.784304 | R=0.149090 | Spec=0.979443
#
# [TRIAL 20] score(AUPRC_macro)=0.343669 | AUROC=0.838452 | Acc=0.940495 | P=0.747970 | R=0.146151 | Spec=0.980210
# [I 2026-07-01 20:19:49,732] Trial 20 finished with value: 0.34366850041387986 and parameters: {'n_estimators': 778, 'learning_rate': 0.025065231110380545, 'num_leaves': 51, 'max_depth': 3, 'min_child_samples': 61, 'subsample': 0.9369290173194924, 'colsample_bytree': 0.76320346282282, 'reg_lambda': 3.774401339460368, 'reg_alpha': 0.002732044889740839, 'min_split_gain': 2.7053637827277726}. Best is trial 2 with value: 0.39518501161522346.
#
# ================================================================================
# [TRIAL 21] params:
# {
#   "objective": "binary",
#   "boosting_type": "gbdt",
#   "n_jobs": -1,
#   "random_state": 42,
#   "verbosity": -1,
#   "n_estimators": 1426,
#   "learning_rate": 0.03829871073750756,
#   "num_leaves": 84,
#   "max_depth": 7,
#   "min_child_samples": 6,
#   "subsample": 0.8871975834497376,
#   "colsample_bytree": 0.8303405839227247,
#   "reg_lambda": 10.37473599513754,
#   "reg_alpha": 6.595164322658067e-07,
#   "min_split_gain": 0.04925036044747972
# }
#     [FOLD 1] AUPRC=0.390595 | AUROC=0.860810 | Acc=0.942043 | P=0.634861 | R=0.266901 | Spec=0.972022
#     [FOLD 2] AUPRC=0.375138 | AUROC=0.857775 | Acc=0.941079 | P=0.486702 | R=0.244859 | Spec=0.974331
#     [FOLD 3] AUPRC=0.398082 | AUROC=0.848412 | Acc=0.943908 | P=0.499261 | R=0.271565 | Spec=0.972974
#     [FOLD 4] AUPRC=0.400152 | AUROC=0.847491 | Acc=0.940912 | P=0.553119 | R=0.267326 | Spec=0.970158
#     [FOLD 5] AUPRC=0.393075 | AUROC=0.852072 | Acc=0.943631 | P=0.515661 | R=0.253704 | Spec=0.972550
#
# [TRIAL 21] score(AUPRC_macro)=0.391408 | AUROC=0.853312 | Acc=0.942315 | P=0.537921 | R=0.260871 | Spec=0.972407
# [I 2026-07-01 20:21:16,784] Trial 21 finished with value: 0.3914081804264763 and parameters: {'n_estimators': 1426, 'learning_rate': 0.03829871073750756, 'num_leaves': 84, 'max_depth': 7, 'min_child_samples': 6, 'subsample': 0.8871975834497376, 'colsample_bytree': 0.8303405839227247, 'reg_lambda': 10.37473599513754, 'reg_alpha': 6.595164322658067e-07, 'min_split_gain': 0.04925036044747972}. Best is trial 2 with value: 0.39518501161522346.
#
# ================================================================================
# [TRIAL 22] params:
# {
#   "objective": "binary",
#   "boosting_type": "gbdt",
#   "n_jobs": -1,
#   "random_state": 42,
#   "verbosity": -1,
#   "n_estimators": 1624,
#   "learning_rate": 0.06940785135782676,
#   "num_leaves": 90,
#   "max_depth": 9,
#   "min_child_samples": 13,
#   "subsample": 0.8826164186595434,
#   "colsample_bytree": 0.7804563220246579,
#   "reg_lambda": 49.68371142684821,
#   "reg_alpha": 6.468416357847133e-06,
#   "min_split_gain": 0.22668745381516725
# }
#     [FOLD 1] AUPRC=0.387486 | AUROC=0.866990 | Acc=0.942985 | P=0.764321 | R=0.197195 | Spec=0.975830
#     [FOLD 2] AUPRC=0.380075 | AUROC=0.857186 | Acc=0.941855 | P=0.681048 | R=0.184690 | Spec=0.978249
#     [FOLD 3] AUPRC=0.395381 | AUROC=0.847680 | Acc=0.943631 | P=0.707990 | R=0.191598 | Spec=0.975985
#     [FOLD 4] AUPRC=0.395609 | AUROC=0.849175 | Acc=0.939581 | P=0.669841 | R=0.188131 | Spec=0.973275
#     [FOLD 5] AUPRC=0.393884 | AUROC=0.854887 | Acc=0.943964 | P=0.778512 | R=0.187715 | Spec=0.976660
#
# [TRIAL 22] score(AUPRC_macro)=0.390487 | AUROC=0.855184 | Acc=0.942403 | P=0.720342 | R=0.189866 | Spec=0.976000
# [I 2026-07-01 20:21:56,304] Trial 22 finished with value: 0.3904869529175441 and parameters: {'n_estimators': 1624, 'learning_rate': 0.06940785135782676, 'num_leaves': 90, 'max_depth': 9, 'min_child_samples': 13, 'subsample': 0.8826164186595434, 'colsample_bytree': 0.7804563220246579, 'reg_lambda': 49.68371142684821, 'reg_alpha': 6.468416357847133e-06, 'min_split_gain': 0.22668745381516725}. Best is trial 2 with value: 0.39518501161522346.
#
# ================================================================================
# [TRIAL 23] params:
# {
#   "objective": "binary",
#   "boosting_type": "gbdt",
#   "n_jobs": -1,
#   "random_state": 42,
#   "verbosity": -1,
#   "n_estimators": 1193,
#   "learning_rate": 0.041979016982663486,
#   "num_leaves": 37,
#   "max_depth": 5,
#   "min_child_samples": 11,
#   "subsample": 0.8253509337518037,
#   "colsample_bytree": 0.8625354373632149,
#   "reg_lambda": 33.599673787383054,
#   "reg_alpha": 0.00013476206145016028,
#   "min_split_gain": 0.49707304729578206
# }
#     [FOLD 1] AUPRC=0.372892 | AUROC=0.863673 | Acc=0.942653 | P=0.798088 | R=0.184914 | Spec=0.976943
#     [FOLD 2] AUPRC=0.377826 | AUROC=0.856985 | Acc=0.941855 | P=0.735182 | R=0.166404 | Spec=0.979911
#     [FOLD 3] AUPRC=0.380659 | AUROC=0.840172 | Acc=0.943187 | P=0.767479 | R=0.179241 | Spec=0.977970
#     [FOLD 4] AUPRC=0.382263 | AUROC=0.845658 | Acc=0.938859 | P=0.785135 | R=0.174200 | Spec=0.974180
#     [FOLD 5] AUPRC=0.379902 | AUROC=0.848678 | Acc=0.943298 | P=0.770654 | R=0.176596 | Spec=0.977457
#
# [TRIAL 23] score(AUPRC_macro)=0.378708 | AUROC=0.851033 | Acc=0.941970 | P=0.771308 | R=0.176271 | Spec=0.977292
# [I 2026-07-01 20:22:28,794] Trial 23 finished with value: 0.378708385439375 and parameters: {'n_estimators': 1193, 'learning_rate': 0.041979016982663486, 'num_leaves': 37, 'max_depth': 5, 'min_child_samples': 11, 'subsample': 0.8253509337518037, 'colsample_bytree': 0.8625354373632149, 'reg_lambda': 33.599673787383054, 'reg_alpha': 0.00013476206145016028, 'min_split_gain': 0.49707304729578206}. Best is trial 2 with value: 0.39518501161522346.
#
# ================================================================================
# [TRIAL 24] params:
# {
#   "objective": "binary",
#   "boosting_type": "gbdt",
#   "n_jobs": -1,
#   "random_state": 42,
#   "verbosity": -1,
#   "n_estimators": 1744,
#   "learning_rate": 0.02866115916334848,
#   "num_leaves": 125,
#   "max_depth": 12,
#   "min_child_samples": 22,
#   "subsample": 0.8753962129045451,
#   "colsample_bytree": 0.7110500810526534,
#   "reg_lambda": 1.0464949503834282,
#   "reg_alpha": 1.1037302968419532e-06,
#   "min_split_gain": 0.9588674468668306
# }
#     [FOLD 1] AUPRC=0.382043 | AUROC=0.860957 | Acc=0.942431 | P=0.677877 | R=0.196509 | Spec=0.976658
#     [FOLD 2] AUPRC=0.395664 | AUROC=0.850195 | Acc=0.941522 | P=0.549522 | R=0.187421 | Spec=0.979718
#     [FOLD 3] AUPRC=0.408346 | AUROC=0.849179 | Acc=0.943464 | P=0.719225 | R=0.190860 | Spec=0.977646
#     [FOLD 4] AUPRC=0.406673 | AUROC=0.844668 | Acc=0.939692 | P=0.670206 | R=0.193327 | Spec=0.974272
#     [FOLD 5] AUPRC=0.396119 | AUROC=0.851376 | Acc=0.944241 | P=0.665126 | R=0.187692 | Spec=0.978133
#
# [TRIAL 24] score(AUPRC_macro)=0.397769 | AUROC=0.851275 | Acc=0.942270 | P=0.656391 | R=0.191162 | Spec=0.977285
# [I 2026-07-01 20:23:03,389] Trial 24 finished with value: 0.39776887875312594 and parameters: {'n_estimators': 1744, 'learning_rate': 0.02866115916334848, 'num_leaves': 125, 'max_depth': 12, 'min_child_samples': 22, 'subsample': 0.8753962129045451, 'colsample_bytree': 0.7110500810526534, 'reg_lambda': 1.0464949503834282, 'reg_alpha': 1.1037302968419532e-06, 'min_split_gain': 0.9588674468668306}. Best is trial 24 with value: 0.39776887875312594.
#
# ================================================================================
# [TRIAL 25] params:
# {
#   "objective": "binary",
#   "boosting_type": "gbdt",
#   "n_jobs": -1,
#   "random_state": 42,
#   "verbosity": -1,
#   "n_estimators": 1919,
#   "learning_rate": 0.013511197712024643,
#   "num_leaves": 121,
#   "max_depth": 13,
#   "min_child_samples": 22,
#   "subsample": 0.9482827040597936,
#   "colsample_bytree": 0.6664420060900526,
#   "reg_lambda": 0.8700259489955255,
#   "reg_alpha": 1.7072410390071675e-07,
#   "min_split_gain": 1.022148812724184
# }
#     [FOLD 1] AUPRC=0.382128 | AUROC=0.861021 | Acc=0.942099 | P=0.663404 | R=0.186462 | Spec=0.976913
#     [FOLD 2] AUPRC=0.397206 | AUROC=0.851600 | Acc=0.941356 | P=0.571158 | R=0.184666 | Spec=0.979822
#     [FOLD 3] AUPRC=0.410486 | AUROC=0.850220 | Acc=0.943298 | P=0.722367 | R=0.190545 | Spec=0.977436
#     [FOLD 4] AUPRC=0.406768 | AUROC=0.844961 | Acc=0.940135 | P=0.688251 | R=0.189938 | Spec=0.974790
#     [FOLD 5] AUPRC=0.397554 | AUROC=0.852243 | Acc=0.944740 | P=0.674948 | R=0.190151 | Spec=0.978334
#
# [TRIAL 25] score(AUPRC_macro)=0.398828 | AUROC=0.852009 | Acc=0.942326 | P=0.664026 | R=0.188352 | Spec=0.977459
# [I 2026-07-01 20:23:49,484] Trial 25 finished with value: 0.39882840869609776 and parameters: {'n_estimators': 1919, 'learning_rate': 0.013511197712024643, 'num_leaves': 121, 'max_depth': 13, 'min_child_samples': 22, 'subsample': 0.9482827040597936, 'colsample_bytree': 0.6664420060900526, 'reg_lambda': 0.8700259489955255, 'reg_alpha': 1.7072410390071675e-07, 'min_split_gain': 1.022148812724184}. Best is trial 25 with value: 0.39882840869609776.
#
# ================================================================================
# [TRIAL 26] params:
# {
#   "objective": "binary",
#   "boosting_type": "gbdt",
#   "n_jobs": -1,
#   "random_state": 42,
#   "verbosity": -1,
#   "n_estimators": 1993,
#   "learning_rate": 0.013088952247890109,
#   "num_leaves": 115,
#   "max_depth": 12,
#   "min_child_samples": 44,
#   "subsample": 0.9549772951275722,
#   "colsample_bytree": 0.6544782552855256,
#   "reg_lambda": 0.7330573917905174,
#   "reg_alpha": 1.339756997169568e-07,
#   "min_split_gain": 1.2559347889487436
# }
#     [FOLD 1] AUPRC=0.374511 | AUROC=0.858953 | Acc=0.941822 | P=0.753015 | R=0.183775 | Spec=0.977309
#     [FOLD 2] AUPRC=0.395163 | AUROC=0.853729 | Acc=0.940524 | P=0.730197 | R=0.175615 | Spec=0.979900
#     [FOLD 3] AUPRC=0.393141 | AUROC=0.850401 | Acc=0.942965 | P=0.790304 | R=0.186580 | Spec=0.978480
#     [FOLD 4] AUPRC=0.403670 | AUROC=0.845909 | Acc=0.939414 | P=0.736748 | R=0.182198 | Spec=0.975168
#     [FOLD 5] AUPRC=0.391733 | AUROC=0.851527 | Acc=0.942188 | P=0.718231 | R=0.175883 | Spec=0.977468
#
# [TRIAL 26] score(AUPRC_macro)=0.391644 | AUROC=0.852104 | Acc=0.941383 | P=0.745699 | R=0.180810 | Spec=0.977665
# [I 2026-07-01 20:24:32,521] Trial 26 finished with value: 0.3916436473555149 and parameters: {'n_estimators': 1993, 'learning_rate': 0.013088952247890109, 'num_leaves': 115, 'max_depth': 12, 'min_child_samples': 44, 'subsample': 0.9549772951275722, 'colsample_bytree': 0.6544782552855256, 'reg_lambda': 0.7330573917905174, 'reg_alpha': 1.339756997169568e-07, 'min_split_gain': 1.2559347889487436}. Best is trial 25 with value: 0.39882840869609776.
#
# ================================================================================
# [TRIAL 27] params:
# {
#   "objective": "binary",
#   "boosting_type": "gbdt",
#   "n_jobs": -1,
#   "random_state": 42,
#   "verbosity": -1,
#   "n_estimators": 1834,
#   "learning_rate": 0.01982273844939028,
#   "num_leaves": 158,
#   "max_depth": 14,
#   "min_child_samples": 32,
#   "subsample": 0.9974365973773758,
#   "colsample_bytree": 0.6957765371853208,
#   "reg_lambda": 1.6477055459906484,
#   "reg_alpha": 4.1207902708448353e-07,
#   "min_split_gain": 2.025941348995226
# }
#     [FOLD 1] AUPRC=0.362452 | AUROC=0.853962 | Acc=0.942542 | P=0.751728 | R=0.177072 | Spec=0.978520
#     [FOLD 2] AUPRC=0.386874 | AUROC=0.851703 | Acc=0.940524 | P=0.687364 | R=0.160359 | Spec=0.980546
#     [FOLD 3] AUPRC=0.392046 | AUROC=0.844412 | Acc=0.942521 | P=0.765878 | R=0.163088 | Spec=0.979553
#     [FOLD 4] AUPRC=0.389478 | AUROC=0.843460 | Acc=0.938415 | P=0.735049 | R=0.157755 | Spec=0.975177
#     [FOLD 5] AUPRC=0.375031 | AUROC=0.847668 | Acc=0.942466 | P=0.795441 | R=0.167684 | Spec=0.978555
#
# [TRIAL 27] score(AUPRC_macro)=0.381176 | AUROC=0.848241 | Acc=0.941294 | P=0.747092 | R=0.165192 | Spec=0.978470
# [I 2026-07-01 20:25:04,478] Trial 27 finished with value: 0.3811764938728509 and parameters: {'n_estimators': 1834, 'learning_rate': 0.01982273844939028, 'num_leaves': 158, 'max_depth': 14, 'min_child_samples': 32, 'subsample': 0.9974365973773758, 'colsample_bytree': 0.6957765371853208, 'reg_lambda': 1.6477055459906484, 'reg_alpha': 4.1207902708448353e-07, 'min_split_gain': 2.025941348995226}. Best is trial 25 with value: 0.39882840869609776.
#
# ================================================================================
# [TRIAL 28] params:
# {
#   "objective": "binary",
#   "boosting_type": "gbdt",
#   "n_jobs": -1,
#   "random_state": 42,
#   "verbosity": -1,
#   "n_estimators": 1766,
#   "learning_rate": 0.013255666254295525,
#   "num_leaves": 144,
#   "max_depth": 12,
#   "min_child_samples": 20,
#   "subsample": 0.9197400525235581,
#   "colsample_bytree": 0.601464456684806,
#   "reg_lambda": 0.05594786346107906,
#   "reg_alpha": 1.8974433904743013e-07,
#   "min_split_gain": 0.8383510545371347
# }
#     [FOLD 1] AUPRC=0.378603 | AUROC=0.857838 | Acc=0.940824 | P=0.535900 | R=0.202968 | Spec=0.975120
#     [FOLD 2] AUPRC=0.389836 | AUROC=0.859149 | Acc=0.941467 | P=0.522876 | R=0.198357 | Spec=0.979536
#     [FOLD 3] AUPRC=0.407210 | AUROC=0.849372 | Acc=0.944574 | P=0.629704 | R=0.216910 | Spec=0.977661
#     [FOLD 4] AUPRC=0.402721 | AUROC=0.839390 | Acc=0.941245 | P=0.632300 | R=0.216397 | Spec=0.974814
#     [FOLD 5] AUPRC=0.399956 | AUROC=0.848751 | Acc=0.944186 | P=0.660853 | R=0.205021 | Spec=0.977160
#
# [TRIAL 28] score(AUPRC_macro)=0.395665 | AUROC=0.850900 | Acc=0.942459 | P=0.596327 | R=0.207931 | Spec=0.976858
# [I 2026-07-01 20:26:33,446] Trial 28 finished with value: 0.39566535964927585 and parameters: {'n_estimators': 1766, 'learning_rate': 0.013255666254295525, 'num_leaves': 144, 'max_depth': 12, 'min_child_samples': 20, 'subsample': 0.9197400525235581, 'colsample_bytree': 0.601464456684806, 'reg_lambda': 0.05594786346107906, 'reg_alpha': 1.8974433904743013e-07, 'min_split_gain': 0.8383510545371347}. Best is trial 25 with value: 0.39882840869609776.
#
# ================================================================================
# [TRIAL 29] params:
# {
#   "objective": "binary",
#   "boosting_type": "gbdt",
#   "n_jobs": -1,
#   "random_state": 42,
#   "verbosity": -1,
#   "n_estimators": 1763,
#   "learning_rate": 0.012289395781451795,
#   "num_leaves": 177,
#   "max_depth": 12,
#   "min_child_samples": 20,
#   "subsample": 0.9425488634892167,
#   "colsample_bytree": 0.6002041434522676,
#   "reg_lambda": 0.05039439859888889,
#   "reg_alpha": 1.2613593911945632e-07,
#   "min_split_gain": 4.698707456902114
# }
#     [FOLD 1] AUPRC=0.355917 | AUROC=0.847632 | Acc=0.941600 | P=0.828091 | R=0.154891 | Spec=0.980857
#     [FOLD 2] AUPRC=0.373008 | AUROC=0.844790 | Acc=0.939969 | P=0.746659 | R=0.139333 | Spec=0.983149
#     [FOLD 3] AUPRC=0.367966 | AUROC=0.832260 | Acc=0.941800 | P=0.772942 | R=0.149921 | Spec=0.980894
#     [FOLD 4] AUPRC=0.373200 | AUROC=0.830926 | Acc=0.938304 | P=0.809687 | R=0.146129 | Spec=0.976777
#     [FOLD 5] AUPRC=0.350850 | AUROC=0.838481 | Acc=0.941689 | P=0.812425 | R=0.153174 | Spec=0.980363
#
# [TRIAL 29] score(AUPRC_macro)=0.364188 | AUROC=0.838818 | Acc=0.940672 | P=0.793961 | R=0.148690 | Spec=0.980408
# [I 2026-07-01 20:27:49,454] Trial 29 finished with value: 0.36418823603067285 and parameters: {'n_estimators': 1763, 'learning_rate': 0.012289395781451795, 'num_leaves': 177, 'max_depth': 12, 'min_child_samples': 20, 'subsample': 0.9425488634892167, 'colsample_bytree': 0.6002041434522676, 'reg_lambda': 0.05039439859888889, 'reg_alpha': 1.2613593911945632e-07, 'min_split_gain': 4.698707456902114}. Best is trial 25 with value: 0.39882840869609776.
#
# ================ BEST =================
# Best trial: 25
# Best AUPRC_macro: 0.39882840869609776
# Best params:
# {
#   "n_estimators": 1919,
#   "learning_rate": 0.013511197712024643,
#   "num_leaves": 121,
#   "max_depth": 13,
#   "min_child_samples": 22,
#   "subsample": 0.9482827040597936,
#   "colsample_bytree": 0.6664420060900526,
#   "reg_lambda": 0.8700259489955255,
#   "reg_alpha": 1.7072410390071675e-07,
#   "min_split_gain": 1.022148812724184
# }
# [SAVED] ./optuna_singlemodel_LIGHTGBM_30trials_5fold_results.csv
# [SAVED] ./used_label_columns_24.csv
# [SAVED] ./used_feature_columns.csv

# %%
# -*- coding: utf-8 -*-
import os
import glob
import json
import warnings
import numpy as np
import pandas as pd

import optuna
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import roc_auc_score, average_precision_score
from sklearn.ensemble import RandomForestClassifier

# =========================
# 0) 配置 & 尽量屏蔽警告
# =========================
RANDOM_SEED = 42
N_TRIALS = 30
N_SPLITS = 5
THRESH = 0.5

os.environ["PYTHONWARNINGS"] = "ignore"
warnings.filterwarnings("ignore", category=UserWarning)
warnings.filterwarnings("ignore", category=FutureWarning)
warnings.filterwarnings("ignore", category=RuntimeWarning)

# 读取特征文件
FEATURE_FILE_GLOB = "./Malodors_Morgan&StructKG_features.xlsx"

# RandomForest 固定参数，Optuna 只搜索部分超参
BASE_RF_PARAMS = dict(
    n_jobs=-1,
    random_state=RANDOM_SEED,
)


# =========================
# 1) 读取特征文件 & 按固定列位置划分 SMILES / y / X
# =========================
def find_feature_file(pattern: str):
    cands = sorted(glob.glob(pattern))
    if not cands:
        raise FileNotFoundError(
            f"找不到特征文件：{pattern}\n"
            f"请确认 xlsx 文件名，或修改 FEATURE_FILE_GLOB。"
        )
    return cands[-1]


def load_Xy_from_feature_file(xlsx_path: str):
    """
    固定数据格式：
    第 1 列：SMILES
    第 2-25 列：24 个 y 标签
    第 26 列及之后：X 特征列

    说明：
    - 不再通过 0/1 自动判断 y 标签列；
    - 避免 Morgan bit、Rule、FG 等 0/1 特征被误识别为标签；
    - 适用于当前 24 标签任务。
    """
    df = pd.read_excel(xlsx_path)

    if df.shape[1] < 26:
        raise ValueError(
            f"当前文件列数为 {df.shape[1]}，不足以按“1列SMILES + 24列标签 + 特征列”划分。"
        )

    # 固定列位置
    smiles_col = df.columns[0]
    label_cols = list(df.columns[1:25])
    feature_cols = list(df.columns[25:])

    if len(label_cols) != 24:
        raise ValueError(f"标签列数量应为 24，但当前识别为 {len(label_cols)}。")

    if len(feature_cols) == 0:
        raise ValueError("未识别到特征列。请确认第 26 列之后为 X 特征。")

    # y 标签转为 0/1 整数
    y_df = df[label_cols].copy()
    y_df = y_df.apply(pd.to_numeric, errors="coerce").fillna(0).astype(int)

    # 检查 y 标签是否为 0/1
    invalid_label_cols = []
    for c in label_cols:
        vals = set(pd.unique(y_df[c].dropna()))
        if not vals.issubset({0, 1}):
            invalid_label_cols.append(c)

    if invalid_label_cols:
        raise ValueError(
            "以下标签列不是标准 0/1 标签，请检查数据：\n"
            + "\n".join(map(str, invalid_label_cols))
        )

    # X 特征转为数值
    X_df = df[feature_cols].copy()
    X_df = X_df.apply(pd.to_numeric, errors="coerce").fillna(0)

    X = X_df.astype(np.float32).values
    y = y_df.values.astype(int)

    if X.shape[0] != y.shape[0]:
        raise ValueError("X 和 y 行数不一致，请检查文件。")

    print("[INFO] Column split mode: fixed-position")
    print(f"[INFO] SMILES column: {smiles_col}")
    print(f"[INFO] Label columns: columns 2-25, n={len(label_cols)}")
    print(f"[INFO] Feature columns: columns 26-end, n={len(feature_cols)}")

    print("\n[INFO] Label columns:")
    for i, c in enumerate(label_cols, start=1):
        print(f"  y{i:02d}: {c}")

    return X, y, feature_cols, label_cols, df


# =========================
# 2) 指标：macro
# =========================
def multilabel_macro_metrics(y_true, y_prob, thresh=0.5):
    y_true = np.asarray(y_true).astype(int)
    y_prob = np.asarray(y_prob).astype(float)
    y_pred = (y_prob >= thresh).astype(int)

    L = y_true.shape[1]
    accs, precs, recs, specs = [], [], [], []
    aurocs, auprcs = [], []

    for k in range(L):
        yt = y_true[:, k]
        yp = y_pred[:, k]
        ys = y_prob[:, k]

        tp = int(np.sum((yt == 1) & (yp == 1)))
        tn = int(np.sum((yt == 0) & (yp == 0)))
        fp = int(np.sum((yt == 0) & (yp == 1)))
        fn = int(np.sum((yt == 1) & (yp == 0)))
        n = len(yt)

        accs.append((tp + tn) / n if n else np.nan)
        precs.append(tp / (tp + fp) if (tp + fp) else np.nan)
        recs.append(tp / (tp + fn) if (tp + fn) else np.nan)
        specs.append(tn / (tn + fp) if (tn + fp) else np.nan)

        if len(np.unique(yt)) == 2:
            aurocs.append(roc_auc_score(yt, ys))
            auprcs.append(average_precision_score(yt, ys))
        else:
            aurocs.append(np.nan)
            auprcs.append(np.nan)

    def nanmean(x):
        return float(np.nanmean(np.asarray(x, dtype=float)))

    return {
        "Accuracy_macro": nanmean(accs),
        "Precision_macro": nanmean(precs),
        "Recall_macro": nanmean(recs),
        "Specificity_macro": nanmean(specs),
        "AUROC_macro": nanmean(aurocs),
        "AUPRC_macro": nanmean(auprcs),
        "AUROC_valid_labels": int(np.sum(~np.isnan(aurocs))),
        "AUPRC_valid_labels": int(np.sum(~np.isnan(auprcs))),
        "n_labels": int(L),
    }


def extract_positive_proba(p, n_labels: int, classes_list=None):
    """
    兼容：
    - multi-output RF 的 predict_proba: list，长度=labels，每个元素形状为 (n, n_classes_k)
    - 某标签在该 fold 训练集里只有单类时，predict_proba 可能为 (n, 1)
    """
    if isinstance(p, list):
        out = np.zeros((p[0].shape[0], n_labels), dtype=np.float32)

        for k in range(n_labels):
            pk = p[k]

            if pk.ndim != 2:
                raise ValueError(f"predict_proba[{k}] 形状异常: {pk.shape}")

            if pk.shape[1] == 2:
                # 优先按 classes_ 找 class == 1 对应的概率列
                if classes_list is not None and len(classes_list) == n_labels:
                    cls = list(classes_list[k])
                    if 1 in cls:
                        j = cls.index(1)
                        out[:, k] = pk[:, j].astype(np.float32)
                    else:
                        out[:, k] = 0.0
                else:
                    out[:, k] = pk[:, 1].astype(np.float32)

            elif pk.shape[1] == 1:
                # 只有单一类别：若该类别是 1，则概率恒为 1；若是 0，则概率恒为 0
                if classes_list is not None and len(classes_list) == n_labels:
                    only_cls = int(list(classes_list[k])[0])
                    out[:, k] = 1.0 if only_cls == 1 else 0.0
                else:
                    out[:, k] = 0.0

            else:
                raise ValueError(f"predict_proba[{k}] 类别数异常: {pk.shape[1]}")

        return out

    # 非 list 情况，一般不会出现在 multi-output RF
    p = np.asarray(p)

    if p.ndim == 3 and p.shape[-1] == 2:
        return p[:, :, 1].astype(np.float32)

    if p.ndim == 2:
        if p.shape[1] == 2 and n_labels == 1:
            return p[:, 1:2].astype(np.float32)
        return p.astype(np.float32)

    raise ValueError(f"无法解析 predict_proba 输出形状: {p.shape}")


# =========================
# 3) 近似分层 5 折：用 label cardinality 分层
# =========================
def make_stratify_target(y: np.ndarray, n_bins: int = 10):
    """
    多标签任务中没有直接的 StratifiedKFold。
    这里使用每个样本的标签数量 label cardinality 做近似分层。
    """
    card = y.sum(axis=1).astype(int)
    uniq = np.unique(card)

    if len(uniq) <= 15:
        return card

    r = pd.Series(card).rank(method="average").values
    bins = pd.qcut(
        r,
        q=min(n_bins, len(np.unique(r))),
        labels=False,
        duplicates="drop"
    )

    return np.asarray(bins, dtype=int)


def build_folds(X, y, n_splits=5, seed=42):
    strat_y = make_stratify_target(y)
    skf = StratifiedKFold(
        n_splits=n_splits,
        shuffle=True,
        random_state=seed
    )
    return list(skf.split(X, strat_y))


# =========================
# 4) 5 折 CV 评估：RF
# =========================
def cv_eval_one_paramset(X, y, folds, params, thresh=0.5):
    n_labels = y.shape[1]
    fold_metrics = []

    for fold_id, (tr_idx, va_idx) in enumerate(folds, start=1):
        X_tr, X_va = X[tr_idx], X[va_idx]
        y_tr, y_va = y[tr_idx], y[va_idx]

        clf = RandomForestClassifier(**params)
        clf.fit(X_tr, y_tr)

        p = clf.predict_proba(X_va)
        y_prob = extract_positive_proba(
            p,
            n_labels=n_labels,
            classes_list=getattr(clf, "classes_", None)
        )

        m = multilabel_macro_metrics(y_va, y_prob, thresh=thresh)
        fold_metrics.append(m)

        print(
            f"    [FOLD {fold_id}] "
            f"AUPRC={m['AUPRC_macro']:.6f} | "
            f"AUROC={m['AUROC_macro']:.6f} | "
            f"Acc={m['Accuracy_macro']:.6f} | "
            f"P={m['Precision_macro']:.6f} | "
            f"R={m['Recall_macro']:.6f} | "
            f"Spec={m['Specificity_macro']:.6f}"
        )

    keys = list(fold_metrics[0].keys())
    mean_metrics = {}

    for k in keys:
        vals = [fm[k] for fm in fold_metrics]
        if isinstance(vals[0], float):
            mean_metrics[k] = float(np.nanmean(vals))
        else:
            mean_metrics[k] = vals[-1]

    return mean_metrics


# =========================
# 5) Optuna 超参空间：RF
# =========================
def build_trial_params(trial: optuna.Trial):
    params = dict(BASE_RF_PARAMS)

    max_depth_raw = trial.suggest_int("max_depth", 0, 40)
    max_depth = None if max_depth_raw == 0 else max_depth_raw

    params.update({
        "n_estimators": trial.suggest_int("n_estimators", 300, 1500),
        "max_depth": max_depth,
        "max_features": trial.suggest_categorical(
            "max_features",
            ["sqrt", "log2", 0.3, 0.5, 0.8, 1.0]
        ),
        "min_samples_split": trial.suggest_int("min_samples_split", 2, 20),
        "min_samples_leaf": trial.suggest_int("min_samples_leaf", 1, 10),
        "bootstrap": trial.suggest_categorical("bootstrap", [True, False]),
        "criterion": trial.suggest_categorical(
            "criterion",
            ["gini", "entropy", "log_loss"]
        ),
    })

    return params


# =========================
# 6) 主流程：读特征 -> 固定 folds -> Optuna -> 输出保存
# =========================
def main():
    feature_file = find_feature_file(FEATURE_FILE_GLOB)
    print("[INFO] Using feature file:", feature_file)

    X, y, feat_cols, label_cols, df_all = load_Xy_from_feature_file(feature_file)

    print(
        f"\n[INFO] X shape={X.shape} "
        f"(features={len(feat_cols)}) | "
        f"y shape={y.shape} "
        f"(labels={len(label_cols)})"
    )

    folds = build_folds(X, y, n_splits=N_SPLITS, seed=RANDOM_SEED)
    print(f"[INFO] Prepared fixed {N_SPLITS}-fold splits for all trials.")

    def objective(trial: optuna.Trial):
        params = build_trial_params(trial)

        print("\n" + "=" * 80)
        print(f"[TRIAL {trial.number:02d}] params:")
        print(json.dumps(params, indent=2, ensure_ascii=False, default=str))

        mean_metrics = cv_eval_one_paramset(
            X,
            y,
            folds,
            params,
            thresh=THRESH
        )

        score = mean_metrics["AUPRC_macro"]

        print(
            f"\n[TRIAL {trial.number:02d}] "
            f"score(AUPRC_macro)={score:.6f} | "
            f"AUROC={mean_metrics['AUROC_macro']:.6f} | "
            f"Acc={mean_metrics['Accuracy_macro']:.6f} | "
            f"P={mean_metrics['Precision_macro']:.6f} | "
            f"R={mean_metrics['Recall_macro']:.6f} | "
            f"Spec={mean_metrics['Specificity_macro']:.6f}"
        )

        for k, v in mean_metrics.items():
            trial.set_user_attr(k, v)

        return score

    study = optuna.create_study(
        direction="maximize",
        sampler=optuna.samplers.TPESampler(seed=RANDOM_SEED),
    )

    study.optimize(
        objective,
        n_trials=N_TRIALS,
        show_progress_bar=True
    )

    print("\n================ BEST =================")
    print("Best trial:", study.best_trial.number)
    print("Best AUPRC_macro:", study.best_value)
    print("Best params:")
    print(json.dumps(study.best_params, indent=2, ensure_ascii=False))

    rows = []
    for t in study.trials:
        if t.value is None:
            continue

        row = {
            "trial": t.number,
            "AUPRC_macro": t.value,
            **t.params
        }

        row.update({
            k: v for k, v in t.user_attrs.items()
            if k.endswith("_macro")
        })

        rows.append(row)

    res_df = pd.DataFrame(rows).sort_values(
        "AUPRC_macro",
        ascending=False
    )

    out_csv = "./optuna_singlemodel_RF_30trials_5fold_results.csv"
    res_df.to_csv(out_csv, index=False, encoding="utf-8-sig")
    print("[SAVED]", out_csv)

    # 额外保存标签列和特征列，便于后续核查
    label_out = "./used_label_columns_24.csv"
    feature_out = "./used_feature_columns.csv"

    pd.DataFrame({"label_col": label_cols}).to_csv(
        label_out,
        index=False,
        encoding="utf-8-sig"
    )

    pd.DataFrame({"feature_col": feat_cols}).to_csv(
        feature_out,
        index=False,
        encoding="utf-8-sig"
    )

    print("[SAVED]", label_out)
    print("[SAVED]", feature_out)


if __name__ == "__main__":
    main()
# Out:
# [INFO] Using feature file: ./Malodors_Morgan&StructKG_features.xlsx
# [I 2026-07-01 20:29:03,493] A new study created in memory with name: no-name-78242f49-0484-465a-9e88-461c0e226554
# [INFO] Column split mode: fixed-position
# [INFO] SMILES column: Canonical_SMILES
# [INFO] Label columns: columns 2-25, n=24
# [INFO] Feature columns: columns 26-end, n=2216
#
# [INFO] Label columns:
#   y01: alcoholic
#   y02: aldehydic
#   y03: almond
#   y04: aromatic
#   y05: burnt
#   y06: cabbage
#   y07: cheesy
#   y08: cherry
#   y09: chocolate
#   y10: ethereal
#   y11: fishy
#   y12: fruity
#   y13: garlic
#   y14: grassy
#   y15: green
#   y16: ketonic
#   y17: musty
#   y18: pungent
#   y19: sharp
#   y20: solvent
#   y21: sour
#   y22: sulfurous
#   y23: sweaty
#   y24: sweet
#
# [INFO] X shape=(3756, 2216) (features=2216) | y shape=(3756, 24) (labels=24)
# [INFO] Prepared fixed 5-fold splits for all trials.
#   0%|          | 0/30 [00:00<?, ?it/s]
# ================================================================================
# [TRIAL 00] params:
# {
#   "n_jobs": -1,
#   "random_state": 42,
#   "n_estimators": 1441,
#   "max_depth": 15,
#   "max_features": 1.0,
#   "min_samples_split": 13,
#   "min_samples_leaf": 8,
#   "bootstrap": false,
#   "criterion": "gini"
# }
#     [FOLD 1] AUPRC=0.321585 | AUROC=0.781496 | Acc=0.934730 | P=0.478350 | R=0.240766 | Spec=0.962453
#     [FOLD 2] AUPRC=0.307658 | AUROC=0.769330 | Acc=0.933034 | P=0.451417 | R=0.221375 | Spec=0.960407
#     [FOLD 3] AUPRC=0.312426 | AUROC=0.764694 | Acc=0.937583 | P=0.568647 | R=0.230262 | Spec=0.964781
#     [FOLD 4] AUPRC=0.327641 | AUROC=0.760599 | Acc=0.934698 | P=0.508400 | R=0.219538 | Spec=0.960287
#     [FOLD 5] AUPRC=0.330158 | AUROC=0.771319 | Acc=0.936806 | P=0.527898 | R=0.250020 | Spec=0.964252
#
# [TRIAL 00] score(AUPRC_macro)=0.319894 | AUROC=0.769488 | Acc=0.935370 | P=0.506942 | R=0.232392 | Spec=0.962436
# [I 2026-07-01 20:31:18,154] Trial 0 finished with value: 0.31989363951930544 and parameters: {'max_depth': 15, 'n_estimators': 1441, 'max_features': 1.0, 'min_samples_split': 13, 'min_samples_leaf': 8, 'bootstrap': False, 'criterion': 'gini'}. Best is trial 0 with value: 0.31989363951930544.
#
# ================================================================================
# [TRIAL 01] params:
# {
#   "n_jobs": -1,
#   "random_state": 42,
#   "n_estimators": 665,
#   "max_depth": 7,
#   "max_features": 0.5,
#   "min_samples_split": 8,
#   "min_samples_leaf": 5,
#   "bootstrap": true,
#   "criterion": "entropy"
# }
#     [FOLD 1] AUPRC=0.377765 | AUROC=0.859228 | Acc=0.940437 | P=0.693272 | R=0.159154 | Spec=0.977968
#     [FOLD 2] AUPRC=0.368779 | AUROC=0.864291 | Acc=0.939303 | P=0.723842 | R=0.157018 | Spec=0.980551
#     [FOLD 3] AUPRC=0.365362 | AUROC=0.847936 | Acc=0.941411 | P=0.751085 | R=0.155182 | Spec=0.980858
#     [FOLD 4] AUPRC=0.371329 | AUROC=0.834522 | Acc=0.938582 | P=0.746563 | R=0.163332 | Spec=0.976972
#     [FOLD 5] AUPRC=0.384635 | AUROC=0.846767 | Acc=0.940302 | P=0.791858 | R=0.171076 | Spec=0.977241
#
# [TRIAL 01] score(AUPRC_macro)=0.373574 | AUROC=0.850549 | Acc=0.940007 | P=0.741324 | R=0.161152 | Spec=0.978718
# [I 2026-07-01 20:31:54,783] Trial 1 finished with value: 0.37357402182142224 and parameters: {'max_depth': 7, 'n_estimators': 665, 'max_features': 0.5, 'min_samples_split': 8, 'min_samples_leaf': 5, 'bootstrap': True, 'criterion': 'entropy'}. Best is trial 1 with value: 0.37357402182142224.
#
# ================================================================================
# [TRIAL 02] params:
# {
#   "n_jobs": -1,
#   "random_state": 42,
#   "n_estimators": 504,
#   "max_depth": 24,
#   "max_features": 0.3,
#   "min_samples_split": 15,
#   "min_samples_leaf": 5,
#   "bootstrap": false,
#   "criterion": "entropy"
# }
#     [FOLD 1] AUPRC=0.387030 | AUROC=0.866404 | Acc=0.940935 | P=0.626890 | R=0.199764 | Spec=0.974743
#     [FOLD 2] AUPRC=0.378819 | AUROC=0.860929 | Acc=0.940912 | P=0.566385 | R=0.194671 | Spec=0.975607
#     [FOLD 3] AUPRC=0.385987 | AUROC=0.841695 | Acc=0.943908 | P=0.679542 | R=0.193215 | Spec=0.976809
#     [FOLD 4] AUPRC=0.401425 | AUROC=0.845426 | Acc=0.942632 | P=0.649325 | R=0.208662 | Spec=0.974437
#     [FOLD 5] AUPRC=0.388801 | AUROC=0.851349 | Acc=0.943686 | P=0.634080 | R=0.216690 | Spec=0.973989
#
# [TRIAL 02] score(AUPRC_macro)=0.388412 | AUROC=0.853161 | Acc=0.942415 | P=0.631244 | R=0.202600 | Spec=0.975117
# [I 2026-07-01 20:32:19,492] Trial 2 finished with value: 0.3884124440751428 and parameters: {'max_depth': 24, 'n_estimators': 504, 'max_features': 0.3, 'min_samples_split': 15, 'min_samples_leaf': 5, 'bootstrap': False, 'criterion': 'entropy'}. Best is trial 2 with value: 0.3884124440751428.
#
# ================================================================================
# [TRIAL 03] params:
# {
#   "n_jobs": -1,
#   "random_state": 42,
#   "n_estimators": 674,
#   "max_depth": 27,
#   "max_features": 0.5,
#   "min_samples_split": 19,
#   "min_samples_leaf": 6,
#   "bootstrap": true,
#   "criterion": "log_loss"
# }
#     [FOLD 1] AUPRC=0.390031 | AUROC=0.869227 | Acc=0.941268 | P=0.710161 | R=0.191338 | Spec=0.975016
#     [FOLD 2] AUPRC=0.382258 | AUROC=0.864525 | Acc=0.940135 | P=0.709807 | R=0.176805 | Spec=0.976360
#     [FOLD 3] AUPRC=0.387611 | AUROC=0.849069 | Acc=0.943187 | P=0.765114 | R=0.181914 | Spec=0.977323
#     [FOLD 4] AUPRC=0.403900 | AUROC=0.844546 | Acc=0.940690 | P=0.727114 | R=0.185455 | Spec=0.975821
#     [FOLD 5] AUPRC=0.393018 | AUROC=0.851273 | Acc=0.943131 | P=0.770986 | R=0.201575 | Spec=0.975959
#
# [TRIAL 03] score(AUPRC_macro)=0.391364 | AUROC=0.855728 | Acc=0.941682 | P=0.736636 | R=0.187417 | Spec=0.976096
# [I 2026-07-01 20:32:49,386] Trial 3 finished with value: 0.39136360667653763 and parameters: {'max_depth': 27, 'n_estimators': 674, 'max_features': 0.5, 'min_samples_split': 19, 'min_samples_leaf': 6, 'bootstrap': True, 'criterion': 'log_loss'}. Best is trial 3 with value: 0.39136360667653763.
#
# ================================================================================
# [TRIAL 04] params:
# {
#   "n_jobs": -1,
#   "random_state": 42,
#   "n_estimators": 625,
#   "max_depth": 15,
#   "max_features": "sqrt",
#   "min_samples_split": 3,
#   "min_samples_leaf": 10,
#   "bootstrap": true,
#   "criterion": "entropy"
# }
#     [FOLD 1] AUPRC=0.373158 | AUROC=0.865728 | Acc=0.938331 | P=0.807473 | R=0.076298 | Spec=0.986529
#     [FOLD 2] AUPRC=0.369467 | AUROC=0.862878 | Acc=0.937639 | P=0.798203 | R=0.076024 | Spec=0.987876
#     [FOLD 3] AUPRC=0.383959 | AUROC=0.849080 | Acc=0.937805 | P=0.800532 | R=0.075730 | Spec=0.985575
#     [FOLD 4] AUPRC=0.371481 | AUROC=0.847433 | Acc=0.935364 | P=0.741023 | R=0.073025 | Spec=0.983791
#     [FOLD 5] AUPRC=0.374721 | AUROC=0.847237 | Acc=0.936973 | P=0.749935 | R=0.069225 | Spec=0.984410
#
# [TRIAL 04] score(AUPRC_macro)=0.374557 | AUROC=0.854471 | Acc=0.937222 | P=0.779433 | R=0.074061 | Spec=0.985636
# [I 2026-07-01 20:33:53,764] Trial 4 finished with value: 0.3745569963664154 and parameters: {'max_depth': 15, 'n_estimators': 625, 'max_features': 'sqrt', 'min_samples_split': 3, 'min_samples_leaf': 10, 'bootstrap': True, 'criterion': 'entropy'}. Best is trial 3 with value: 0.39136360667653763.
#
# ================================================================================
# [TRIAL 05] params:
# {
#   "n_jobs": -1,
#   "random_state": 42,
#   "n_estimators": 1226,
#   "max_depth": 29,
#   "max_features": 0.5,
#   "min_samples_split": 3,
#   "min_samples_leaf": 4,
#   "bootstrap": false,
#   "criterion": "entropy"
# }
#     [FOLD 1] AUPRC=0.377126 | AUROC=0.858484 | Acc=0.938553 | P=0.497907 | R=0.231922 | Spec=0.970087
#     [FOLD 2] AUPRC=0.362754 | AUROC=0.858383 | Acc=0.939858 | P=0.487488 | R=0.213772 | Spec=0.972426
#     [FOLD 3] AUPRC=0.367603 | AUROC=0.834574 | Acc=0.943686 | P=0.554275 | R=0.222651 | Spec=0.973342
#     [FOLD 4] AUPRC=0.391355 | AUROC=0.838396 | Acc=0.941356 | P=0.621681 | R=0.223923 | Spec=0.971018
#     [FOLD 5] AUPRC=0.383649 | AUROC=0.842182 | Acc=0.942299 | P=0.537685 | R=0.230834 | Spec=0.972001
#
# [TRIAL 05] score(AUPRC_macro)=0.376497 | AUROC=0.846404 | Acc=0.941150 | P=0.539807 | R=0.224620 | Spec=0.971775
# [I 2026-07-01 20:35:14,007] Trial 5 finished with value: 0.37649737346999995 and parameters: {'max_depth': 29, 'n_estimators': 1226, 'max_features': 0.5, 'min_samples_split': 3, 'min_samples_leaf': 4, 'bootstrap': False, 'criterion': 'entropy'}. Best is trial 3 with value: 0.39136360667653763.
#
# ================================================================================
# [TRIAL 06] params:
# {
#   "n_jobs": -1,
#   "random_state": 42,
#   "n_estimators": 1156,
#   "max_depth": 4,
#   "max_features": 0.3,
#   "min_samples_split": 2,
#   "min_samples_leaf": 2,
#   "bootstrap": false,
#   "criterion": "log_loss"
# }
#     [FOLD 1] AUPRC=0.334130 | AUROC=0.835845 | Acc=0.937057 | P=0.777833 | R=0.097301 | Spec=0.981387
#     [FOLD 2] AUPRC=0.313622 | AUROC=0.829572 | Acc=0.935586 | P=0.769411 | R=0.092542 | Spec=0.983865
#     [FOLD 3] AUPRC=0.315625 | AUROC=0.826085 | Acc=0.936307 | P=0.803765 | R=0.091410 | Spec=0.984342
#     [FOLD 4] AUPRC=0.328576 | AUROC=0.809127 | Acc=0.933478 | P=0.668622 | R=0.093989 | Spec=0.978925
#     [FOLD 5] AUPRC=0.314695 | AUROC=0.814272 | Acc=0.937750 | P=0.761965 | R=0.098360 | Spec=0.980161
#
# [TRIAL 06] score(AUPRC_macro)=0.321329 | AUROC=0.822980 | Acc=0.936035 | P=0.756319 | R=0.094720 | Spec=0.981736
# [I 2026-07-01 20:36:06,367] Trial 6 finished with value: 0.3213294680158275 and parameters: {'max_depth': 4, 'n_estimators': 1156, 'max_features': 0.3, 'min_samples_split': 2, 'min_samples_leaf': 2, 'bootstrap': False, 'criterion': 'log_loss'}. Best is trial 3 with value: 0.39136360667653763.
#
# ================================================================================
# [TRIAL 07] params:
# {
#   "n_jobs": -1,
#   "random_state": 42,
#   "n_estimators": 792,
#   "max_depth": 10,
#   "max_features": 1.0,
#   "min_samples_split": 17,
#   "min_samples_leaf": 7,
#   "bootstrap": true,
#   "criterion": "entropy"
# }
#     [FOLD 1] AUPRC=0.387786 | AUROC=0.858597 | Acc=0.939550 | P=0.688621 | R=0.195823 | Spec=0.973782
#     [FOLD 2] AUPRC=0.376314 | AUROC=0.863820 | Acc=0.939248 | P=0.622116 | R=0.176784 | Spec=0.975516
#     [FOLD 3] AUPRC=0.375724 | AUROC=0.848307 | Acc=0.942521 | P=0.754182 | R=0.176976 | Spec=0.977574
#     [FOLD 4] AUPRC=0.396504 | AUROC=0.837189 | Acc=0.939636 | P=0.728656 | R=0.182272 | Spec=0.974717
#     [FOLD 5] AUPRC=0.388539 | AUROC=0.845053 | Acc=0.943076 | P=0.779450 | R=0.197859 | Spec=0.976846
#
# [TRIAL 07] score(AUPRC_macro)=0.384973 | AUROC=0.850593 | Acc=0.940806 | P=0.714605 | R=0.185943 | Spec=0.975687
# [I 2026-07-01 20:36:56,215] Trial 7 finished with value: 0.384973182505172 and parameters: {'max_depth': 10, 'n_estimators': 792, 'max_features': 1.0, 'min_samples_split': 17, 'min_samples_leaf': 7, 'bootstrap': True, 'criterion': 'entropy'}. Best is trial 3 with value: 0.39136360667653763.
#
# ================================================================================
# [TRIAL 08] params:
# {
#   "n_jobs": -1,
#   "random_state": 42,
#   "n_estimators": 1376,
#   "max_depth": 33,
#   "max_features": 1.0,
#   "min_samples_split": 2,
#   "min_samples_leaf": 6,
#   "bootstrap": true,
#   "criterion": "log_loss"
# }
#     [FOLD 1] AUPRC=0.389061 | AUROC=0.861142 | Acc=0.940991 | P=0.683840 | R=0.204466 | Spec=0.973941
#     [FOLD 2] AUPRC=0.378198 | AUROC=0.862012 | Acc=0.940912 | P=0.586939 | R=0.194474 | Spec=0.975440
#     [FOLD 3] AUPRC=0.384332 | AUROC=0.846235 | Acc=0.943353 | P=0.754701 | R=0.184217 | Spec=0.976646
#     [FOLD 4] AUPRC=0.403301 | AUROC=0.839034 | Acc=0.940690 | P=0.660405 | R=0.191342 | Spec=0.973755
#     [FOLD 5] AUPRC=0.381549 | AUROC=0.839109 | Acc=0.944186 | P=0.806953 | R=0.210234 | Spec=0.976395
#
# [TRIAL 08] score(AUPRC_macro)=0.387288 | AUROC=0.849507 | Acc=0.942026 | P=0.698568 | R=0.196947 | Spec=0.975235
# [I 2026-07-01 20:38:19,510] Trial 8 finished with value: 0.38728840927792163 and parameters: {'max_depth': 33, 'n_estimators': 1376, 'max_features': 1.0, 'min_samples_split': 2, 'min_samples_leaf': 6, 'bootstrap': True, 'criterion': 'log_loss'}. Best is trial 3 with value: 0.39136360667653763.
#
# ================================================================================
# [TRIAL 09] params:
# {
#   "n_jobs": -1,
#   "random_state": 42,
#   "n_estimators": 923,
#   "max_depth": 13,
#   "max_features": 0.3,
#   "min_samples_split": 7,
#   "min_samples_leaf": 3,
#   "bootstrap": false,
#   "criterion": "gini"
# }
#     [FOLD 1] AUPRC=0.378695 | AUROC=0.861552 | Acc=0.940049 | P=0.584644 | R=0.211621 | Spec=0.974097
#     [FOLD 2] AUPRC=0.374379 | AUROC=0.865499 | Acc=0.940135 | P=0.538531 | R=0.191255 | Spec=0.975245
#     [FOLD 3] AUPRC=0.386349 | AUROC=0.844247 | Acc=0.944130 | P=0.572390 | R=0.204642 | Spec=0.977007
#     [FOLD 4] AUPRC=0.401141 | AUROC=0.842769 | Acc=0.940357 | P=0.647632 | R=0.204614 | Spec=0.973227
#     [FOLD 5] AUPRC=0.396718 | AUROC=0.852983 | Acc=0.943298 | P=0.642705 | R=0.222242 | Spec=0.975272
#
# [TRIAL 09] score(AUPRC_macro)=0.387456 | AUROC=0.853410 | Acc=0.941594 | P=0.597180 | R=0.206875 | Spec=0.974969
# [I 2026-07-01 20:39:02,342] Trial 9 finished with value: 0.38745620322672675 and parameters: {'max_depth': 13, 'n_estimators': 923, 'max_features': 0.3, 'min_samples_split': 7, 'min_samples_leaf': 3, 'bootstrap': False, 'criterion': 'gini'}. Best is trial 3 with value: 0.39136360667653763.
#
# ================================================================================
# [TRIAL 10] params:
# {
#   "n_jobs": -1,
#   "random_state": 42,
#   "n_estimators": 307,
#   "max_depth": 39,
#   "max_features": 0.8,
#   "min_samples_split": 20,
#   "min_samples_leaf": 1,
#   "bootstrap": true,
#   "criterion": "log_loss"
# }
#     [FOLD 1] AUPRC=0.389562 | AUROC=0.864887 | Acc=0.940381 | P=0.667494 | R=0.198489 | Spec=0.972741
#     [FOLD 2] AUPRC=0.376549 | AUROC=0.860406 | Acc=0.940191 | P=0.631827 | R=0.180338 | Spec=0.974804
#     [FOLD 3] AUPRC=0.376830 | AUROC=0.845336 | Acc=0.944241 | P=0.760953 | R=0.192098 | Spec=0.976343
#     [FOLD 4] AUPRC=0.392497 | AUROC=0.839116 | Acc=0.940857 | P=0.670091 | R=0.195951 | Spec=0.973076
#     [FOLD 5] AUPRC=0.380204 | AUROC=0.844707 | Acc=0.944463 | P=0.768191 | R=0.208630 | Spec=0.976070
#
# [TRIAL 10] score(AUPRC_macro)=0.383128 | AUROC=0.850890 | Acc=0.942027 | P=0.699711 | R=0.195101 | Spec=0.974607
# [I 2026-07-01 20:39:26,575] Trial 10 finished with value: 0.38312819427295614 and parameters: {'max_depth': 39, 'n_estimators': 307, 'max_features': 0.8, 'min_samples_split': 20, 'min_samples_leaf': 1, 'bootstrap': True, 'criterion': 'log_loss'}. Best is trial 3 with value: 0.39136360667653763.
#
# ================================================================================
# [TRIAL 11] params:
# {
#   "n_jobs": -1,
#   "random_state": 42,
#   "n_estimators": 416,
#   "max_depth": 25,
#   "max_features": "log2",
#   "min_samples_split": 15,
#   "min_samples_leaf": 8,
#   "bootstrap": false,
#   "criterion": "log_loss"
# }
#     [FOLD 1] AUPRC=0.372763 | AUROC=0.866663 | Acc=0.933954 | P=0.783931 | R=0.047516 | Spec=0.988072
#     [FOLD 2] AUPRC=0.379726 | AUROC=0.865550 | Acc=0.933755 | P=0.841910 | R=0.046800 | Spec=0.989490
#     [FOLD 3] AUPRC=0.373631 | AUROC=0.847831 | Acc=0.933145 | P=0.799275 | R=0.046007 | Spec=0.987917
#     [FOLD 4] AUPRC=0.377119 | AUROC=0.846019 | Acc=0.931647 | P=0.767675 | R=0.045940 | Spec=0.986750
#     [FOLD 5] AUPRC=0.364643 | AUROC=0.847385 | Acc=0.934643 | P=0.763694 | R=0.044848 | Spec=0.988521
#
# [TRIAL 11] score(AUPRC_macro)=0.373576 | AUROC=0.854690 | Acc=0.933429 | P=0.791297 | R=0.046222 | Spec=0.988150
# [I 2026-07-01 20:39:59,844] Trial 11 finished with value: 0.3735762464572259 and parameters: {'max_depth': 25, 'n_estimators': 416, 'max_features': 'log2', 'min_samples_split': 15, 'min_samples_leaf': 8, 'bootstrap': False, 'criterion': 'log_loss'}. Best is trial 3 with value: 0.39136360667653763.
#
# ================================================================================
# [TRIAL 12] params:
# {
#   "n_jobs": -1,
#   "random_state": 42,
#   "n_estimators": 531,
#   "max_depth": 21,
#   "max_features": 0.3,
#   "min_samples_split": 20,
#   "min_samples_leaf": 5,
#   "bootstrap": true,
#   "criterion": "entropy"
# }
#     [FOLD 1] AUPRC=0.393916 | AUROC=0.870141 | Acc=0.941489 | P=0.705994 | R=0.179278 | Spec=0.976393
#     [FOLD 2] AUPRC=0.386764 | AUROC=0.865283 | Acc=0.939858 | P=0.689641 | R=0.171912 | Spec=0.976839
#     [FOLD 3] AUPRC=0.386973 | AUROC=0.848630 | Acc=0.943298 | P=0.767866 | R=0.179922 | Spec=0.978258
#     [FOLD 4] AUPRC=0.413025 | AUROC=0.848212 | Acc=0.941300 | P=0.734907 | R=0.182271 | Spec=0.976684
#     [FOLD 5] AUPRC=0.391670 | AUROC=0.852875 | Acc=0.943964 | P=0.779595 | R=0.203836 | Spec=0.977074
#
# [TRIAL 12] score(AUPRC_macro)=0.394470 | AUROC=0.857028 | Acc=0.941982 | P=0.735601 | R=0.183444 | Spec=0.977049
# [I 2026-07-01 20:40:46,492] Trial 12 finished with value: 0.39446955599059 and parameters: {'max_depth': 21, 'n_estimators': 531, 'max_features': 0.3, 'min_samples_split': 20, 'min_samples_leaf': 5, 'bootstrap': True, 'criterion': 'entropy'}. Best is trial 12 with value: 0.39446955599059.
#
# ================================================================================
# [TRIAL 13] params:
# {
#   "n_jobs": -1,
#   "random_state": 42,
#   "n_estimators": 925,
#   "max_depth": 21,
#   "max_features": 0.5,
#   "min_samples_split": 20,
#   "min_samples_leaf": 6,
#   "bootstrap": true,
#   "criterion": "log_loss"
# }
#     [FOLD 1] AUPRC=0.390587 | AUROC=0.867764 | Acc=0.940991 | P=0.746758 | R=0.192305 | Spec=0.974709
#     [FOLD 2] AUPRC=0.379408 | AUROC=0.866037 | Acc=0.940302 | P=0.706140 | R=0.174939 | Spec=0.976988
#     [FOLD 3] AUPRC=0.386917 | AUROC=0.847861 | Acc=0.943298 | P=0.766616 | R=0.180018 | Spec=0.977625
#     [FOLD 4] AUPRC=0.403761 | AUROC=0.846617 | Acc=0.940690 | P=0.726124 | R=0.185223 | Spec=0.975689
#     [FOLD 5] AUPRC=0.392197 | AUROC=0.850749 | Acc=0.943242 | P=0.771206 | R=0.205350 | Spec=0.975967
#
# [TRIAL 13] score(AUPRC_macro)=0.390574 | AUROC=0.855806 | Acc=0.941705 | P=0.743369 | R=0.187567 | Spec=0.976196
# [I 2026-07-01 20:41:48,330] Trial 13 finished with value: 0.3905739647225211 and parameters: {'max_depth': 21, 'n_estimators': 925, 'max_features': 0.5, 'min_samples_split': 20, 'min_samples_leaf': 6, 'bootstrap': True, 'criterion': 'log_loss'}. Best is trial 12 with value: 0.39446955599059.
#
# ================================================================================
# [TRIAL 14] params:
# {
#   "n_jobs": -1,
#   "random_state": 42,
#   "n_estimators": 718,
#   "max_depth": 32,
#   "max_features": "sqrt",
#   "min_samples_split": 18,
#   "min_samples_leaf": 4,
#   "bootstrap": true,
#   "criterion": "gini"
# }
#     [FOLD 1] AUPRC=0.387973 | AUROC=0.869416 | Acc=0.941268 | P=0.864862 | R=0.108405 | Spec=0.983554
#     [FOLD 2] AUPRC=0.388921 | AUROC=0.866052 | Acc=0.939525 | P=0.817177 | R=0.103877 | Spec=0.985436
#     [FOLD 3] AUPRC=0.398728 | AUROC=0.851722 | Acc=0.941411 | P=0.825856 | R=0.111614 | Spec=0.982668
#     [FOLD 4] AUPRC=0.406146 | AUROC=0.852423 | Acc=0.937972 | P=0.808264 | R=0.099691 | Spec=0.981872
#     [FOLD 5] AUPRC=0.398009 | AUROC=0.855044 | Acc=0.940635 | P=0.814475 | R=0.097688 | Spec=0.982734
#
# [TRIAL 14] score(AUPRC_macro)=0.395955 | AUROC=0.858931 | Acc=0.940162 | P=0.826127 | R=0.104255 | Spec=0.983253
# [I 2026-07-01 20:43:07,643] Trial 14 finished with value: 0.3959553764954249 and parameters: {'max_depth': 32, 'n_estimators': 718, 'max_features': 'sqrt', 'min_samples_split': 18, 'min_samples_leaf': 4, 'bootstrap': True, 'criterion': 'gini'}. Best is trial 14 with value: 0.3959553764954249.
#
# ================================================================================
# [TRIAL 15] params:
# {
#   "n_jobs": -1,
#   "random_state": 42,
#   "n_estimators": 505,
#   "max_depth": 35,
#   "max_features": "sqrt",
#   "min_samples_split": 17,
#   "min_samples_leaf": 3,
#   "bootstrap": true,
#   "criterion": "gini"
# }
#     [FOLD 1] AUPRC=0.393313 | AUROC=0.868929 | Acc=0.941379 | P=0.700939 | R=0.120054 | Spec=0.982299
#     [FOLD 2] AUPRC=0.388669 | AUROC=0.867478 | Acc=0.940246 | P=0.803898 | R=0.118261 | Spec=0.983761
#     [FOLD 3] AUPRC=0.396967 | AUROC=0.853318 | Acc=0.941800 | P=0.754258 | R=0.119379 | Spec=0.981939
#     [FOLD 4] AUPRC=0.403206 | AUROC=0.855323 | Acc=0.938804 | P=0.822923 | R=0.120731 | Spec=0.980664
#     [FOLD 5] AUPRC=0.397406 | AUROC=0.857018 | Acc=0.941245 | P=0.872918 | R=0.112742 | Spec=0.981707
#
# [TRIAL 15] score(AUPRC_macro)=0.395912 | AUROC=0.860413 | Acc=0.940695 | P=0.790987 | R=0.118233 | Spec=0.982074
# [I 2026-07-01 20:44:00,177] Trial 15 finished with value: 0.395912180243506 and parameters: {'max_depth': 35, 'n_estimators': 505, 'max_features': 'sqrt', 'min_samples_split': 17, 'min_samples_leaf': 3, 'bootstrap': True, 'criterion': 'gini'}. Best is trial 14 with value: 0.3959553764954249.
#
# ================================================================================
# [TRIAL 16] params:
# {
#   "n_jobs": -1,
#   "random_state": 42,
#   "n_estimators": 808,
#   "max_depth": 39,
#   "max_features": "sqrt",
#   "min_samples_split": 10,
#   "min_samples_leaf": 3,
#   "bootstrap": true,
#   "criterion": "gini"
# }
#     [FOLD 1] AUPRC=0.393132 | AUROC=0.869746 | Acc=0.941434 | P=0.699193 | R=0.123003 | Spec=0.981996
#     [FOLD 2] AUPRC=0.389560 | AUROC=0.869124 | Acc=0.940635 | P=0.825438 | R=0.118987 | Spec=0.984368
#     [FOLD 3] AUPRC=0.402959 | AUROC=0.854538 | Acc=0.941966 | P=0.781983 | R=0.123410 | Spec=0.981939
#     [FOLD 4] AUPRC=0.405433 | AUROC=0.855601 | Acc=0.939081 | P=0.802920 | R=0.120335 | Spec=0.980839
#     [FOLD 5] AUPRC=0.402808 | AUROC=0.857999 | Acc=0.941411 | P=0.873496 | R=0.116241 | Spec=0.981402
#
# [TRIAL 16] score(AUPRC_macro)=0.398779 | AUROC=0.861402 | Acc=0.940906 | P=0.796606 | R=0.120395 | Spec=0.982109
# [I 2026-07-01 20:45:26,121] Trial 16 finished with value: 0.39877863416941733 and parameters: {'max_depth': 39, 'n_estimators': 808, 'max_features': 'sqrt', 'min_samples_split': 10, 'min_samples_leaf': 3, 'bootstrap': True, 'criterion': 'gini'}. Best is trial 16 with value: 0.39877863416941733.
#
# ================================================================================
# [TRIAL 17] params:
# {
#   "n_jobs": -1,
#   "random_state": 42,
#   "n_estimators": 1097,
#   "max_depth": 39,
#   "max_features": "sqrt",
#   "min_samples_split": 9,
#   "min_samples_leaf": 1,
#   "bootstrap": true,
#   "criterion": "gini"
# }
#     [FOLD 1] AUPRC=0.393926 | AUROC=0.867157 | Acc=0.942431 | P=0.772919 | R=0.182763 | Spec=0.976498
#     [FOLD 2] AUPRC=0.380338 | AUROC=0.864563 | Acc=0.942299 | P=0.751619 | R=0.160539 | Spec=0.979625
#     [FOLD 3] AUPRC=0.395152 | AUROC=0.852556 | Acc=0.944407 | P=0.792854 | R=0.176695 | Spec=0.977813
#     [FOLD 4] AUPRC=0.399344 | AUROC=0.850289 | Acc=0.941245 | P=0.731204 | R=0.171465 | Spec=0.976121
#     [FOLD 5] AUPRC=0.417456 | AUROC=0.854795 | Acc=0.945018 | P=0.768511 | R=0.179351 | Spec=0.978092
#
# [TRIAL 17] score(AUPRC_macro)=0.397243 | AUROC=0.857872 | Acc=0.943080 | P=0.763422 | R=0.174163 | Spec=0.977630
# [I 2026-07-01 20:47:21,913] Trial 17 finished with value: 0.3972432606719822 and parameters: {'max_depth': 39, 'n_estimators': 1097, 'max_features': 'sqrt', 'min_samples_split': 9, 'min_samples_leaf': 1, 'bootstrap': True, 'criterion': 'gini'}. Best is trial 16 with value: 0.39877863416941733.
#
# ================================================================================
# [TRIAL 18] params:
# {
#   "n_jobs": -1,
#   "random_state": 42,
#   "n_estimators": 1065,
#   "max_depth": 40,
#   "max_features": "sqrt",
#   "min_samples_split": 9,
#   "min_samples_leaf": 1,
#   "bootstrap": true,
#   "criterion": "gini"
# }
#     [FOLD 1] AUPRC=0.393142 | AUROC=0.866834 | Acc=0.942598 | P=0.772776 | R=0.182554 | Spec=0.976772
#     [FOLD 2] AUPRC=0.379907 | AUROC=0.865499 | Acc=0.941800 | P=0.741216 | R=0.159624 | Spec=0.979169
#     [FOLD 3] AUPRC=0.393729 | AUROC=0.850353 | Acc=0.944296 | P=0.793087 | R=0.176260 | Spec=0.978037
#     [FOLD 4] AUPRC=0.399290 | AUROC=0.848378 | Acc=0.941245 | P=0.731000 | R=0.171002 | Spec=0.976125
#     [FOLD 5] AUPRC=0.414171 | AUROC=0.855369 | Acc=0.945240 | P=0.762909 | R=0.181163 | Spec=0.977923
#
# [TRIAL 18] score(AUPRC_macro)=0.396048 | AUROC=0.857286 | Acc=0.943036 | P=0.760198 | R=0.174121 | Spec=0.977605
# [I 2026-07-01 20:49:08,297] Trial 18 finished with value: 0.39604775250287283 and parameters: {'max_depth': 40, 'n_estimators': 1065, 'max_features': 'sqrt', 'min_samples_split': 9, 'min_samples_leaf': 1, 'bootstrap': True, 'criterion': 'gini'}. Best is trial 16 with value: 0.39877863416941733.
#
# ================================================================================
# [TRIAL 19] params:
# {
#   "n_jobs": -1,
#   "random_state": 42,
#   "n_estimators": 1031,
#   "max_depth": 36,
#   "max_features": "sqrt",
#   "min_samples_split": 11,
#   "min_samples_leaf": 2,
#   "bootstrap": true,
#   "criterion": "gini"
# }
#     [FOLD 1] AUPRC=0.397598 | AUROC=0.871360 | Acc=0.942099 | P=0.778212 | R=0.142052 | Spec=0.980470
#     [FOLD 2] AUPRC=0.389349 | AUROC=0.867960 | Acc=0.940857 | P=0.832630 | R=0.133885 | Spec=0.982459
#     [FOLD 3] AUPRC=0.396719 | AUROC=0.855011 | Acc=0.943187 | P=0.789464 | R=0.151120 | Spec=0.981073
#     [FOLD 4] AUPRC=0.412458 | AUROC=0.854817 | Acc=0.940135 | P=0.875197 | R=0.147381 | Spec=0.979688
#     [FOLD 5] AUPRC=0.409841 | AUROC=0.858588 | Acc=0.943409 | P=0.901212 | R=0.149803 | Spec=0.980885
#
# [TRIAL 19] score(AUPRC_macro)=0.401193 | AUROC=0.861547 | Acc=0.941937 | P=0.835343 | R=0.144848 | Spec=0.980915
# [I 2026-07-01 20:50:57,553] Trial 19 finished with value: 0.4011931167780224 and parameters: {'max_depth': 36, 'n_estimators': 1031, 'max_features': 'sqrt', 'min_samples_split': 11, 'min_samples_leaf': 2, 'bootstrap': True, 'criterion': 'gini'}. Best is trial 19 with value: 0.4011931167780224.
#
# ================================================================================
# [TRIAL 20] params:
# {
#   "n_jobs": -1,
#   "random_state": 42,
#   "n_estimators": 983,
#   "max_depth": 36,
#   "max_features": "log2",
#   "min_samples_split": 11,
#   "min_samples_leaf": 3,
#   "bootstrap": true,
#   "criterion": "gini"
# }
#     [FOLD 1] AUPRC=0.381849 | AUROC=0.869430 | Acc=0.935450 | P=0.803093 | R=0.056409 | Spec=0.987098
#     [FOLD 2] AUPRC=0.390233 | AUROC=0.866631 | Acc=0.936141 | P=0.824201 | R=0.057084 | Spec=0.989174
#     [FOLD 3] AUPRC=0.381151 | AUROC=0.851186 | Acc=0.935863 | P=0.805191 | R=0.059587 | Spec=0.985919
#     [FOLD 4] AUPRC=0.377689 | AUROC=0.851369 | Acc=0.934365 | P=0.772638 | R=0.058526 | Spec=0.985377
#     [FOLD 5] AUPRC=0.366029 | AUROC=0.851887 | Acc=0.936529 | P=0.746012 | R=0.055636 | Spec=0.986422
#
# [TRIAL 20] score(AUPRC_macro)=0.379390 | AUROC=0.858101 | Acc=0.935670 | P=0.790227 | R=0.057449 | Spec=0.986798
# [I 2026-07-01 20:52:43,940] Trial 20 finished with value: 0.37939008359462323 and parameters: {'max_depth': 36, 'n_estimators': 983, 'max_features': 'log2', 'min_samples_split': 11, 'min_samples_leaf': 3, 'bootstrap': True, 'criterion': 'gini'}. Best is trial 19 with value: 0.4011931167780224.
#
# ================================================================================
# [TRIAL 21] params:
# {
#   "n_jobs": -1,
#   "random_state": 42,
#   "n_estimators": 1283,
#   "max_depth": 40,
#   "max_features": "sqrt",
#   "min_samples_split": 6,
#   "min_samples_leaf": 2,
#   "bootstrap": true,
#   "criterion": "gini"
# }
#     [FOLD 1] AUPRC=0.396071 | AUROC=0.872010 | Acc=0.942210 | P=0.778308 | R=0.146709 | Spec=0.980160
#     [FOLD 2] AUPRC=0.385591 | AUROC=0.867486 | Acc=0.940801 | P=0.830169 | R=0.138100 | Spec=0.981793
#     [FOLD 3] AUPRC=0.398785 | AUROC=0.854135 | Acc=0.943353 | P=0.796476 | R=0.152675 | Spec=0.980804
#     [FOLD 4] AUPRC=0.406688 | AUROC=0.854745 | Acc=0.940302 | P=0.874732 | R=0.147948 | Spec=0.979623
#     [FOLD 5] AUPRC=0.409407 | AUROC=0.858547 | Acc=0.943631 | P=0.900233 | R=0.152138 | Spec=0.980790
#
# [TRIAL 21] score(AUPRC_macro)=0.399308 | AUROC=0.861385 | Acc=0.942059 | P=0.835984 | R=0.147514 | Spec=0.980634
# [I 2026-07-01 20:55:02,703] Trial 21 finished with value: 0.3993083441885191 and parameters: {'max_depth': 40, 'n_estimators': 1283, 'max_features': 'sqrt', 'min_samples_split': 6, 'min_samples_leaf': 2, 'bootstrap': True, 'criterion': 'gini'}. Best is trial 19 with value: 0.4011931167780224.
#
# ================================================================================
# [TRIAL 22] params:
# {
#   "n_jobs": -1,
#   "random_state": 42,
#   "n_estimators": 1273,
#   "max_depth": 31,
#   "max_features": "sqrt",
#   "min_samples_split": 6,
#   "min_samples_leaf": 2,
#   "bootstrap": true,
#   "criterion": "gini"
# }
#     [FOLD 1] AUPRC=0.394602 | AUROC=0.872273 | Acc=0.942376 | P=0.780115 | R=0.146089 | Spec=0.980761
#     [FOLD 2] AUPRC=0.386907 | AUROC=0.868321 | Acc=0.940579 | P=0.831320 | R=0.138337 | Spec=0.981605
#     [FOLD 3] AUPRC=0.399019 | AUROC=0.854127 | Acc=0.943076 | P=0.795465 | R=0.152051 | Spec=0.980832
#     [FOLD 4] AUPRC=0.409090 | AUROC=0.853635 | Acc=0.940302 | P=0.875561 | R=0.145718 | Spec=0.979804
#     [FOLD 5] AUPRC=0.409770 | AUROC=0.858565 | Acc=0.943631 | P=0.900497 | R=0.151314 | Spec=0.981125
#
# [TRIAL 22] score(AUPRC_macro)=0.399878 | AUROC=0.861384 | Acc=0.941993 | P=0.836592 | R=0.146702 | Spec=0.980825
# [I 2026-07-01 20:57:20,639] Trial 22 finished with value: 0.39987756064989277 and parameters: {'max_depth': 31, 'n_estimators': 1273, 'max_features': 'sqrt', 'min_samples_split': 6, 'min_samples_leaf': 2, 'bootstrap': True, 'criterion': 'gini'}. Best is trial 19 with value: 0.4011931167780224.
#
# ================================================================================
# [TRIAL 23] params:
# {
#   "n_jobs": -1,
#   "random_state": 42,
#   "n_estimators": 1323,
#   "max_depth": 30,
#   "max_features": "sqrt",
#   "min_samples_split": 6,
#   "min_samples_leaf": 2,
#   "bootstrap": true,
#   "criterion": "gini"
# }
#     [FOLD 1] AUPRC=0.397501 | AUROC=0.871474 | Acc=0.942320 | P=0.779455 | R=0.146161 | Spec=0.980721
#     [FOLD 2] AUPRC=0.385759 | AUROC=0.867362 | Acc=0.940690 | P=0.829275 | R=0.138155 | Spec=0.981804
#     [FOLD 3] AUPRC=0.397648 | AUROC=0.853496 | Acc=0.943131 | P=0.795850 | R=0.151868 | Spec=0.981008
#     [FOLD 4] AUPRC=0.407478 | AUROC=0.853749 | Acc=0.940357 | P=0.875365 | R=0.144972 | Spec=0.980126
#     [FOLD 5] AUPRC=0.408204 | AUROC=0.858581 | Acc=0.943520 | P=0.901110 | R=0.152167 | Spec=0.980816
#
# [TRIAL 23] score(AUPRC_macro)=0.399318 | AUROC=0.860932 | Acc=0.942004 | P=0.836211 | R=0.146665 | Spec=0.980895
# [I 2026-07-01 20:59:44,085] Trial 23 finished with value: 0.3993180556928869 and parameters: {'max_depth': 30, 'n_estimators': 1323, 'max_features': 'sqrt', 'min_samples_split': 6, 'min_samples_leaf': 2, 'bootstrap': True, 'criterion': 'gini'}. Best is trial 19 with value: 0.4011931167780224.
#
# ================================================================================
# [TRIAL 24] params:
# {
#   "n_jobs": -1,
#   "random_state": 42,
#   "n_estimators": 1317,
#   "max_depth": 30,
#   "max_features": 0.8,
#   "min_samples_split": 5,
#   "min_samples_leaf": 2,
#   "bootstrap": true,
#   "criterion": "gini"
# }
#     [FOLD 1] AUPRC=0.385618 | AUROC=0.859560 | Acc=0.941268 | P=0.560678 | R=0.233418 | Spec=0.971861
#     [FOLD 2] AUPRC=0.371320 | AUROC=0.859475 | Acc=0.941134 | P=0.535541 | R=0.206672 | Spec=0.973628
#     [FOLD 3] AUPRC=0.374916 | AUROC=0.837187 | Acc=0.944296 | P=0.558172 | R=0.215844 | Spec=0.973803
#     [FOLD 4] AUPRC=0.387891 | AUROC=0.832106 | Acc=0.940413 | P=0.657358 | R=0.213092 | Spec=0.970346
#     [FOLD 5] AUPRC=0.391065 | AUROC=0.840083 | Acc=0.943409 | P=0.604040 | R=0.233140 | Spec=0.972763
#
# [TRIAL 24] score(AUPRC_macro)=0.382162 | AUROC=0.845682 | Acc=0.942104 | P=0.583158 | R=0.220433 | Spec=0.972480
# [I 2026-07-01 21:01:15,199] Trial 24 finished with value: 0.3821620625346507 and parameters: {'max_depth': 30, 'n_estimators': 1317, 'max_features': 0.8, 'min_samples_split': 5, 'min_samples_leaf': 2, 'bootstrap': True, 'criterion': 'gini'}. Best is trial 19 with value: 0.4011931167780224.
#
# ================================================================================
# [TRIAL 25] params:
# {
#   "n_jobs": -1,
#   "random_state": 42,
#   "n_estimators": 1454,
#   "max_depth": 35,
#   "max_features": "sqrt",
#   "min_samples_split": 5,
#   "min_samples_leaf": 2,
#   "bootstrap": true,
#   "criterion": "gini"
# }
#     [FOLD 1] AUPRC=0.397751 | AUROC=0.871390 | Acc=0.942099 | P=0.779131 | R=0.146583 | Spec=0.980315
#     [FOLD 2] AUPRC=0.385357 | AUROC=0.867506 | Acc=0.940968 | P=0.848979 | R=0.137957 | Spec=0.982124
#     [FOLD 3] AUPRC=0.399850 | AUROC=0.854577 | Acc=0.943409 | P=0.796951 | R=0.152730 | Spec=0.981208
#     [FOLD 4] AUPRC=0.409941 | AUROC=0.855582 | Acc=0.940246 | P=0.875304 | R=0.147790 | Spec=0.979577
#     [FOLD 5] AUPRC=0.408541 | AUROC=0.859480 | Acc=0.943742 | P=0.900877 | R=0.152764 | Spec=0.980879
#
# [TRIAL 25] score(AUPRC_macro)=0.400288 | AUROC=0.861707 | Acc=0.942093 | P=0.840248 | R=0.147565 | Spec=0.980821
# [I 2026-07-01 21:03:42,704] Trial 25 finished with value: 0.4002880539944595 and parameters: {'max_depth': 35, 'n_estimators': 1454, 'max_features': 'sqrt', 'min_samples_split': 5, 'min_samples_leaf': 2, 'bootstrap': True, 'criterion': 'gini'}. Best is trial 19 with value: 0.4011931167780224.
#
# ================================================================================
# [TRIAL 26] params:
# {
#   "n_jobs": -1,
#   "random_state": 42,
#   "n_estimators": 1492,
#   "max_depth": 36,
#   "max_features": "sqrt",
#   "min_samples_split": 4,
#   "min_samples_leaf": 4,
#   "bootstrap": true,
#   "criterion": "gini"
# }
#     [FOLD 1] AUPRC=0.388707 | AUROC=0.869584 | Acc=0.941046 | P=0.862783 | R=0.107943 | Spec=0.983356
#     [FOLD 2] AUPRC=0.387962 | AUROC=0.868280 | Acc=0.939913 | P=0.824746 | R=0.105709 | Spec=0.985191
#     [FOLD 3] AUPRC=0.403077 | AUROC=0.853966 | Acc=0.941023 | P=0.793565 | R=0.109752 | Spec=0.982414
#     [FOLD 4] AUPRC=0.405979 | AUROC=0.853907 | Acc=0.937972 | P=0.805575 | R=0.098433 | Spec=0.981741
#     [FOLD 5] AUPRC=0.395108 | AUROC=0.857208 | Acc=0.940468 | P=0.819482 | R=0.099422 | Spec=0.982214
#
# [TRIAL 26] score(AUPRC_macro)=0.396166 | AUROC=0.860589 | Acc=0.940084 | P=0.821230 | R=0.104252 | Spec=0.982983
# [I 2026-07-01 21:06:26,112] Trial 26 finished with value: 0.39616648230110496 and parameters: {'max_depth': 36, 'n_estimators': 1492, 'max_features': 'sqrt', 'min_samples_split': 4, 'min_samples_leaf': 4, 'bootstrap': True, 'criterion': 'gini'}. Best is trial 19 with value: 0.4011931167780224.
#
# ================================================================================
# [TRIAL 27] params:
# {
#   "n_jobs": -1,
#   "random_state": 42,
#   "n_estimators": 1174,
#   "max_depth": 34,
#   "max_features": "sqrt",
#   "min_samples_split": 13,
#   "min_samples_leaf": 1,
#   "bootstrap": true,
#   "criterion": "gini"
# }
#     [FOLD 1] AUPRC=0.392946 | AUROC=0.868709 | Acc=0.942653 | P=0.825948 | R=0.175794 | Spec=0.977807
#     [FOLD 2] AUPRC=0.381615 | AUROC=0.867034 | Acc=0.941411 | P=0.748892 | R=0.156275 | Spec=0.980281
#     [FOLD 3] AUPRC=0.391526 | AUROC=0.853509 | Acc=0.944685 | P=0.793974 | R=0.171219 | Spec=0.979787
#     [FOLD 4] AUPRC=0.404680 | AUROC=0.850975 | Acc=0.940746 | P=0.757980 | R=0.164138 | Spec=0.977674
#     [FOLD 5] AUPRC=0.419474 | AUROC=0.858366 | Acc=0.944740 | P=0.826475 | R=0.168778 | Spec=0.979346
#
# [TRIAL 27] score(AUPRC_macro)=0.398048 | AUROC=0.859719 | Acc=0.942847 | P=0.790653 | R=0.167241 | Spec=0.978979
# [I 2026-07-01 21:08:29,673] Trial 27 finished with value: 0.3980479863127616 and parameters: {'max_depth': 34, 'n_estimators': 1174, 'max_features': 'sqrt', 'min_samples_split': 13, 'min_samples_leaf': 1, 'bootstrap': True, 'criterion': 'gini'}. Best is trial 19 with value: 0.4011931167780224.
#
# ================================================================================
# [TRIAL 28] params:
# {
#   "n_jobs": -1,
#   "random_state": 42,
#   "n_estimators": 1426,
#   "max_depth": null,
#   "max_features": "sqrt",
#   "min_samples_split": 7,
#   "min_samples_leaf": 2,
#   "bootstrap": true,
#   "criterion": "gini"
# }
#     [FOLD 1] AUPRC=0.400008 | AUROC=0.870411 | Acc=0.942043 | P=0.778267 | R=0.145871 | Spec=0.980450
#     [FOLD 2] AUPRC=0.385233 | AUROC=0.866905 | Acc=0.940357 | P=0.828569 | R=0.138276 | Spec=0.981532
#     [FOLD 3] AUPRC=0.398055 | AUROC=0.854522 | Acc=0.943131 | P=0.796350 | R=0.151909 | Spec=0.981143
#     [FOLD 4] AUPRC=0.406445 | AUROC=0.856306 | Acc=0.940357 | P=0.874798 | R=0.145905 | Spec=0.979412
#     [FOLD 5] AUPRC=0.408947 | AUROC=0.859593 | Acc=0.943742 | P=0.901568 | R=0.152344 | Spec=0.980816
#
# [TRIAL 28] score(AUPRC_macro)=0.399738 | AUROC=0.861547 | Acc=0.941926 | P=0.835910 | R=0.146861 | Spec=0.980671
# [I 2026-07-01 21:10:54,942] Trial 28 finished with value: 0.39973775909312337 and parameters: {'max_depth': 0, 'n_estimators': 1426, 'max_features': 'sqrt', 'min_samples_split': 7, 'min_samples_leaf': 2, 'bootstrap': True, 'criterion': 'gini'}. Best is trial 19 with value: 0.4011931167780224.
#
# ================================================================================
# [TRIAL 29] params:
# {
#   "n_jobs": -1,
#   "random_state": 42,
#   "n_estimators": 1033,
#   "max_depth": 27,
#   "max_features": 0.8,
#   "min_samples_split": 12,
#   "min_samples_leaf": 4,
#   "bootstrap": false,
#   "criterion": "gini"
# }
#     [FOLD 1] AUPRC=0.365244 | AUROC=0.846129 | Acc=0.939107 | P=0.489837 | R=0.240295 | Spec=0.970007
#     [FOLD 2] AUPRC=0.352575 | AUROC=0.850093 | Acc=0.938083 | P=0.508204 | R=0.223016 | Spec=0.969725
#     [FOLD 3] AUPRC=0.360417 | AUROC=0.823549 | Acc=0.941633 | P=0.470469 | R=0.230983 | Spec=0.969743
#     [FOLD 4] AUPRC=0.363764 | AUROC=0.826774 | Acc=0.938360 | P=0.609407 | R=0.223618 | Spec=0.967839
#     [FOLD 5] AUPRC=0.362861 | AUROC=0.823005 | Acc=0.941633 | P=0.528984 | R=0.248434 | Spec=0.970762
#
# [TRIAL 29] score(AUPRC_macro)=0.360972 | AUROC=0.833910 | Acc=0.939763 | P=0.521380 | R=0.233269 | Spec=0.969615
# [I 2026-07-01 21:12:29,741] Trial 29 finished with value: 0.36097232585913874 and parameters: {'max_depth': 27, 'n_estimators': 1033, 'max_features': 0.8, 'min_samples_split': 12, 'min_samples_leaf': 4, 'bootstrap': False, 'criterion': 'gini'}. Best is trial 19 with value: 0.4011931167780224.
#
# ================ BEST =================
# Best trial: 19
# Best AUPRC_macro: 0.4011931167780224
# Best params:
# {
#   "max_depth": 36,
#   "n_estimators": 1031,
#   "max_features": "sqrt",
#   "min_samples_split": 11,
#   "min_samples_leaf": 2,
#   "bootstrap": true,
#   "criterion": "gini"
# }
# [SAVED] ./optuna_singlemodel_RF_30trials_5fold_results.csv
# [SAVED] ./used_label_columns_24.csv
# [SAVED] ./used_feature_columns.csv

# %%
# -*- coding: utf-8 -*-
import os
import re
import glob
import json
import numpy as np
import pandas as pd

import optuna
import xgboost as xgb
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import roc_auc_score, average_precision_score

# =========================
# 0) 配置
# =========================
RANDOM_SEED = 42
N_TRIALS = 30
N_SPLITS = 5
THRESH = 0.5

# 直接读取你已生成的特征文件（xlsx）
FEATURE_FILE_GLOB = "./Malodors_Morgan&StructKG_features.xlsx"
# 如果你的文件名不同，改成你的，例如：
# FEATURE_FILE_GLOB = "./Malodors_transformed_MORGAN_features.xlsx"

# 固定参数：Optuna 只搜索部分超参
BASE_XGB_PARAMS = dict(
    objective="binary:logistic",
    eval_metric="logloss",
    tree_method="hist",
    n_jobs=-1,
    random_state=RANDOM_SEED,
    verbosity=0,
    multi_strategy="multi_output_tree",
)


# =========================
# 1) XGBoost 版本检查
# =========================
def _ver_tuple(v: str):
    parts = re.split(r"[.+-]", v.strip())
    nums = []

    for p in parts[:3]:
        try:
            nums.append(int(p))
        except Exception:
            nums.append(0)

    while len(nums) < 3:
        nums.append(0)

    return tuple(nums)


def check_xgb_version():
    v = _ver_tuple(xgb.__version__)

    if v < (1, 6, 0):
        raise RuntimeError(
            f"xgboost=={xgb.__version__} 太旧：multi-label 需要 >=1.6"
        )

    if "multi_strategy" in BASE_XGB_PARAMS and v < (2, 0, 0):
        raise RuntimeError(
            f"xgboost=={xgb.__version__} 不支持 multi_output_tree，需要 >=2.0。\n"
            f"请升级 xgboost，或删除 BASE_XGB_PARAMS 中的 multi_strategy。"
        )


# =========================
# 2) 读取特征文件 & 按固定列位置划分 SMILES / y / X
# =========================
def find_feature_file(pattern: str):
    cands = sorted(glob.glob(pattern))

    if not cands:
        raise FileNotFoundError(
            f"找不到特征文件：{pattern}\n"
            f"请确认 xlsx 文件名，或修改 FEATURE_FILE_GLOB。"
        )

    return cands[-1]


def load_Xy_from_feature_file(xlsx_path: str):
    """
    固定数据格式：
    第 1 列：SMILES
    第 2-25 列：24 个 y 标签
    第 26 列及之后：X 特征列

    说明：
    - 不再通过 0/1 自动判断 y 标签列；
    - 避免 Morgan bit、Rule、FG、StructKG 等 0/1 或数值特征被误识别为标签；
    - 适用于当前 24 标签任务。
    """
    df = pd.read_excel(xlsx_path)

    if df.shape[1] < 26:
        raise ValueError(
            f"当前文件列数为 {df.shape[1]}，不足以按“1列SMILES + 24列标签 + 特征列”划分。"
        )

    # 固定列位置
    smiles_col = df.columns[0]
    label_cols = list(df.columns[1:25])
    feature_cols = list(df.columns[25:])

    if len(label_cols) != 24:
        raise ValueError(
            f"标签列数量应为 24，但当前识别为 {len(label_cols)}。"
        )

    if len(feature_cols) == 0:
        raise ValueError(
            "未识别到特征列。请确认第 26 列之后为 X 特征。"
        )

    # y 标签转为 0/1 整数
    y_df = df[label_cols].copy()
    y_df = y_df.apply(pd.to_numeric, errors="coerce").fillna(0).astype(int)

    # 检查 y 标签是否为 0/1
    invalid_label_cols = []
    for c in label_cols:
        vals = set(pd.unique(y_df[c].dropna()))
        if not vals.issubset({0, 1}):
            invalid_label_cols.append(c)

    if invalid_label_cols:
        raise ValueError(
            "以下标签列不是标准 0/1 标签，请检查数据：\n"
            + "\n".join(map(str, invalid_label_cols))
        )

    # X 特征转为数值
    X_df = df[feature_cols].copy()
    X_df = X_df.apply(pd.to_numeric, errors="coerce").fillna(0)

    X = X_df.astype(np.float32).values
    y = y_df.values.astype(int)

    if X.shape[0] != y.shape[0]:
        raise ValueError("X 和 y 行数不一致，请检查文件。")

    print("[INFO] Column split mode: fixed-position")
    print(f"[INFO] SMILES column: {smiles_col}")
    print(f"[INFO] Label columns: columns 2-25, n={len(label_cols)}")
    print(f"[INFO] Feature columns: columns 26-end, n={len(feature_cols)}")

    print("\n[INFO] Label columns:")
    for i, c in enumerate(label_cols, start=1):
        print(f"  y{i:02d}: {c}")

    return X, y, feature_cols, label_cols, df


# =========================
# 3) 指标：macro
# =========================
def multilabel_macro_metrics(y_true, y_prob, thresh=0.5):
    y_true = np.asarray(y_true).astype(int)
    y_prob = np.asarray(y_prob).astype(float)
    y_pred = (y_prob >= thresh).astype(int)

    L = y_true.shape[1]
    accs, precs, recs, specs = [], [], [], []
    aurocs, auprcs = [], []

    for k in range(L):
        yt = y_true[:, k]
        yp = y_pred[:, k]
        ys = y_prob[:, k]

        tp = int(np.sum((yt == 1) & (yp == 1)))
        tn = int(np.sum((yt == 0) & (yp == 0)))
        fp = int(np.sum((yt == 0) & (yp == 1)))
        fn = int(np.sum((yt == 1) & (yp == 0)))
        n = len(yt)

        accs.append((tp + tn) / n if n else np.nan)
        precs.append(tp / (tp + fp) if (tp + fp) else np.nan)
        recs.append(tp / (tp + fn) if (tp + fn) else np.nan)
        specs.append(tn / (tn + fp) if (tn + fp) else np.nan)

        if len(np.unique(yt)) == 2:
            aurocs.append(roc_auc_score(yt, ys))
            auprcs.append(average_precision_score(yt, ys))
        else:
            aurocs.append(np.nan)
            auprcs.append(np.nan)

    def nanmean(x):
        return float(np.nanmean(np.asarray(x, dtype=float)))

    return {
        "Accuracy_macro": nanmean(accs),
        "Precision_macro": nanmean(precs),
        "Recall_macro": nanmean(recs),
        "Specificity_macro": nanmean(specs),
        "AUROC_macro": nanmean(aurocs),
        "AUPRC_macro": nanmean(auprcs),
        "AUROC_valid_labels": int(np.sum(~np.isnan(aurocs))),
        "AUPRC_valid_labels": int(np.sum(~np.isnan(auprcs))),
        "n_labels": int(L),
    }


def extract_positive_proba(p, n_labels: int):
    """
    兼容 XGBoost 多标签输出：

    常见情况：
    - multi_output_tree 下 predict_proba 通常返回形状为 (n_samples, n_labels)
    - 某些版本或设置下可能返回 list 或 3D array
    """
    if isinstance(p, list):
        out = np.zeros((p[0].shape[0], n_labels), dtype=np.float32)

        for k in range(n_labels):
            pk = p[k]

            if pk.ndim != 2:
                raise ValueError(f"predict_proba[{k}] 形状异常: {pk.shape}")

            if pk.shape[1] == 2:
                out[:, k] = pk[:, 1].astype(np.float32)
            elif pk.shape[1] == 1:
                out[:, k] = pk[:, 0].astype(np.float32)
            else:
                raise ValueError(
                    f"predict_proba[{k}] 类别数异常: {pk.shape[1]}"
                )

        return out

    p = np.asarray(p)

    if p.ndim == 3 and p.shape[-1] == 2:
        return p[:, :, 1].astype(np.float32)

    if p.ndim == 2:
        if p.shape[1] == 2 and n_labels == 1:
            return p[:, 1:2].astype(np.float32)

        if p.shape[1] == n_labels:
            return p.astype(np.float32)

        raise ValueError(
            f"predict_proba 输出为二维，但列数 {p.shape[1]} 与标签数 {n_labels} 不一致。"
        )

    raise ValueError(f"无法解析 predict_proba 输出形状: {p.shape}")


# =========================
# 4) 近似分层 5 折：用 label cardinality 分层
# =========================
def make_stratify_target(y: np.ndarray, n_bins: int = 10):
    """
    多标签任务中没有直接的 StratifiedKFold。
    这里使用每个样本的标签数量 label cardinality 做近似分层。
    """
    card = y.sum(axis=1).astype(int)
    uniq = np.unique(card)

    if len(uniq) <= 15:
        return card

    r = pd.Series(card).rank(method="average").values
    bins = pd.qcut(
        r,
        q=min(n_bins, len(np.unique(r))),
        labels=False,
        duplicates="drop"
    )

    return np.asarray(bins, dtype=int)


def build_folds(X, y, n_splits=5, seed=42):
    strat_y = make_stratify_target(y)

    skf = StratifiedKFold(
        n_splits=n_splits,
        shuffle=True,
        random_state=seed
    )

    return list(skf.split(X, strat_y))


# =========================
# 5) 5 折 CV 评估
# =========================
def cv_eval_one_paramset(X, y, folds, params, thresh=0.5):
    n_labels = y.shape[1]
    fold_metrics = []

    for fold_id, (tr_idx, va_idx) in enumerate(folds, start=1):
        X_tr, X_va = X[tr_idx], X[va_idx]
        y_tr, y_va = y[tr_idx], y[va_idx]

        clf = xgb.XGBClassifier(**params)
        clf.fit(X_tr, y_tr)

        p = clf.predict_proba(X_va)
        y_prob = extract_positive_proba(p, n_labels=n_labels)

        m = multilabel_macro_metrics(y_va, y_prob, thresh=thresh)
        fold_metrics.append(m)

        print(
            f"    [FOLD {fold_id}] "
            f"AUPRC={m['AUPRC_macro']:.6f} | "
            f"AUROC={m['AUROC_macro']:.6f} | "
            f"Acc={m['Accuracy_macro']:.6f} | "
            f"P={m['Precision_macro']:.6f} | "
            f"R={m['Recall_macro']:.6f} | "
            f"Spec={m['Specificity_macro']:.6f}"
        )

    keys = list(fold_metrics[0].keys())
    mean_metrics = {}

    for k in keys:
        vals = [fm[k] for fm in fold_metrics]

        if isinstance(vals[0], float):
            mean_metrics[k] = float(np.nanmean(vals))
        else:
            mean_metrics[k] = vals[-1]

    return mean_metrics


# =========================
# 6) Optuna 超参空间
# =========================
def build_trial_params(trial: optuna.Trial):
    params = dict(BASE_XGB_PARAMS)

    params.update({
        "n_estimators": trial.suggest_int("n_estimators", 300, 1200),
        "max_depth": trial.suggest_int("max_depth", 3, 10),
        "learning_rate": trial.suggest_float("learning_rate", 0.01, 0.2, log=True),
        "subsample": trial.suggest_float("subsample", 0.6, 1.0),
        "colsample_bytree": trial.suggest_float("colsample_bytree", 0.6, 1.0),
        "min_child_weight": trial.suggest_float("min_child_weight", 0.5, 10.0, log=True),
        "reg_lambda": trial.suggest_float("reg_lambda", 1e-3, 20.0, log=True),
        "reg_alpha": trial.suggest_float("reg_alpha", 1e-8, 5.0, log=True),
        "gamma": trial.suggest_float("gamma", 0.0, 5.0),
    })

    return params


# =========================
# 7) 主流程：读特征 -> 固定 folds -> Optuna -> 输出保存
# =========================
def main():
    check_xgb_version()

    feature_file = find_feature_file(FEATURE_FILE_GLOB)
    print("[INFO] Using feature file:", feature_file)

    X, y, feat_cols, label_cols, df_all = load_Xy_from_feature_file(feature_file)

    print(
        f"\n[INFO] X shape={X.shape} "
        f"(features={len(feat_cols)}) | "
        f"y shape={y.shape} "
        f"(labels={len(label_cols)})"
    )

    folds = build_folds(X, y, n_splits=N_SPLITS, seed=RANDOM_SEED)
    print(f"[INFO] Prepared fixed {N_SPLITS}-fold splits for all trials.")

    def objective(trial: optuna.Trial):
        params = build_trial_params(trial)

        print("\n" + "=" * 80)
        print(f"[TRIAL {trial.number:02d}] params:")
        print(json.dumps(params, indent=2, ensure_ascii=False, default=str))

        mean_metrics = cv_eval_one_paramset(
            X,
            y,
            folds,
            params,
            thresh=THRESH
        )

        score = mean_metrics["AUPRC_macro"]

        print(
            f"\n[TRIAL {trial.number:02d}] "
            f"score(AUPRC_macro)={score:.6f} | "
            f"AUROC={mean_metrics['AUROC_macro']:.6f} | "
            f"Acc={mean_metrics['Accuracy_macro']:.6f} | "
            f"P={mean_metrics['Precision_macro']:.6f} | "
            f"R={mean_metrics['Recall_macro']:.6f} | "
            f"Spec={mean_metrics['Specificity_macro']:.6f}"
        )

        for k, v in mean_metrics.items():
            trial.set_user_attr(k, v)

        return score

    study = optuna.create_study(
        direction="maximize",
        sampler=optuna.samplers.TPESampler(seed=RANDOM_SEED),
    )

    study.optimize(
        objective,
        n_trials=N_TRIALS,
        show_progress_bar=True
    )

    print("\n================ BEST =================")
    print("Best trial:", study.best_trial.number)
    print("Best AUPRC_macro:", study.best_value)
    print("Best params:")
    print(json.dumps(study.best_params, indent=2, ensure_ascii=False))

    rows = []

    for t in study.trials:
        if t.value is None:
            continue

        row = {
            "trial": t.number,
            "AUPRC_macro": t.value,
            **t.params
        }

        row.update({
            k: v for k, v in t.user_attrs.items()
            if k.endswith("_macro")
        })

        rows.append(row)

    res_df = pd.DataFrame(rows).sort_values(
        "AUPRC_macro",
        ascending=False
    )

    out_csv = "./optuna_singlemodel_XGB_30trials_5fold_results.csv"
    res_df.to_csv(out_csv, index=False, encoding="utf-8-sig")
    print("[SAVED]", out_csv)

    # 额外保存标签列和特征列，便于后续核查
    label_out = "./used_label_columns_24.csv"
    feature_out = "./used_feature_columns.csv"

    pd.DataFrame({"label_col": label_cols}).to_csv(
        label_out,
        index=False,
        encoding="utf-8-sig"
    )

    pd.DataFrame({"feature_col": feat_cols}).to_csv(
        feature_out,
        index=False,
        encoding="utf-8-sig"
    )

    print("[SAVED]", label_out)
    print("[SAVED]", feature_out)


if __name__ == "__main__":
    main()
# Out:
# [INFO] Using feature file: ./Malodors_Morgan&StructKG_features.xlsx
# /root/miniconda3/lib/python3.12/site-packages/sklearn/model_selection/_split.py:813: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# [I 2026-07-02 09:35:09,427] A new study created in memory with name: no-name-b0681d7c-c088-4bfc-aa08-f0e737d7df36
# [INFO] Column split mode: fixed-position
# [INFO] SMILES column: Canonical_SMILES
# [INFO] Label columns: columns 2-25, n=24
# [INFO] Feature columns: columns 26-end, n=2216
#
# [INFO] Label columns:
#   y01: alcoholic
#   y02: aldehydic
#   y03: almond
#   y04: aromatic
#   y05: burnt
#   y06: cabbage
#   y07: cheesy
#   y08: cherry
#   y09: chocolate
#   y10: ethereal
#   y11: fishy
#   y12: fruity
#   y13: garlic
#   y14: grassy
#   y15: green
#   y16: ketonic
#   y17: musty
#   y18: pungent
#   y19: sharp
#   y20: solvent
#   y21: sour
#   y22: sulfurous
#   y23: sweaty
#   y24: sweet
#
# [INFO] X shape=(3756, 2216) (features=2216) | y shape=(3756, 24) (labels=24)
# [INFO] Prepared fixed 5-fold splits for all trials.
#   0%|          | 0/30 [00:00<?, ?it/s]
# ================================================================================
# [TRIAL 00] params:
# {
#   "objective": "binary:logistic",
#   "eval_metric": "logloss",
#   "tree_method": "hist",
#   "n_jobs": -1,
#   "random_state": 42,
#   "verbosity": 0,
#   "multi_strategy": "multi_output_tree",
#   "n_estimators": 637,
#   "max_depth": 10,
#   "learning_rate": 0.08960785365368121,
#   "subsample": 0.8394633936788146,
#   "colsample_bytree": 0.6624074561769746,
#   "min_child_weight": 0.7978542347074177,
#   "reg_lambda": 0.0017775399007348214,
#   "reg_alpha": 0.3426417745118369,
#   "gamma": 3.005575058716044
# }
#     [FOLD 1] AUPRC=0.395172 | AUROC=0.857932 | Acc=0.941212 | P=0.492934 | R=0.274278 | Spec=0.969715
#     [FOLD 2] AUPRC=0.372111 | AUROC=0.856873 | Acc=0.940080 | P=0.499816 | R=0.251164 | Spec=0.970794
#     [FOLD 3] AUPRC=0.406026 | AUROC=0.850487 | Acc=0.944019 | P=0.572278 | R=0.289394 | Spec=0.970648
#     [FOLD 4] AUPRC=0.408331 | AUROC=0.862635 | Acc=0.942022 | P=0.569027 | R=0.276433 | Spec=0.969832
#     [FOLD 5] AUPRC=0.398488 | AUROC=0.852180 | Acc=0.943242 | P=0.486771 | R=0.286090 | Spec=0.971122
#
# [TRIAL 00] score(AUPRC_macro)=0.396025 | AUROC=0.856022 | Acc=0.942115 | P=0.524165 | R=0.275472 | Spec=0.970422
# [I 2026-07-02 09:40:50,086] Trial 0 finished with value: 0.39602540813167975 and parameters: {'n_estimators': 637, 'max_depth': 10, 'learning_rate': 0.08960785365368121, 'subsample': 0.8394633936788146, 'colsample_bytree': 0.6624074561769746, 'min_child_weight': 0.7978542347074177, 'reg_lambda': 0.0017775399007348214, 'reg_alpha': 0.3426417745118369, 'gamma': 3.005575058716044}. Best is trial 0 with value: 0.39602540813167975.
#
# ================================================================================
# [TRIAL 01] params:
# {
#   "objective": "binary:logistic",
#   "eval_metric": "logloss",
#   "tree_method": "hist",
#   "n_jobs": -1,
#   "random_state": 42,
#   "verbosity": 0,
#   "multi_strategy": "multi_output_tree",
#   "n_estimators": 937,
#   "max_depth": 3,
#   "learning_rate": 0.18276027831785724,
#   "subsample": 0.9329770563201687,
#   "colsample_bytree": 0.6849356442713105,
#   "min_child_weight": 0.8620446097910766,
#   "reg_lambda": 0.006149337057087106,
#   "reg_alpha": 4.4319427891510175e-06,
#   "gamma": 2.6237821581611893
# }
#     [FOLD 1] AUPRC=0.392846 | AUROC=0.859034 | Acc=0.941046 | P=0.500897 | R=0.286881 | Spec=0.968795
#     [FOLD 2] AUPRC=0.365866 | AUROC=0.851077 | Acc=0.941134 | P=0.519964 | R=0.254796 | Spec=0.971851
#     [FOLD 3] AUPRC=0.393295 | AUROC=0.850401 | Acc=0.943853 | P=0.527751 | R=0.280907 | Spec=0.970551
#     [FOLD 4] AUPRC=0.404669 | AUROC=0.858849 | Acc=0.939692 | P=0.548293 | R=0.274829 | Spec=0.966637
#     [FOLD 5] AUPRC=0.392448 | AUROC=0.848077 | Acc=0.942577 | P=0.532931 | R=0.274062 | Spec=0.969060
#
# [TRIAL 01] score(AUPRC_macro)=0.389825 | AUROC=0.853488 | Acc=0.941660 | P=0.525967 | R=0.274295 | Spec=0.969379
# [I 2026-07-02 09:43:21,627] Trial 1 finished with value: 0.38982500628190847 and parameters: {'n_estimators': 937, 'max_depth': 3, 'learning_rate': 0.18276027831785724, 'subsample': 0.9329770563201687, 'colsample_bytree': 0.6849356442713105, 'min_child_weight': 0.8620446097910766, 'reg_lambda': 0.006149337057087106, 'reg_alpha': 4.4319427891510175e-06, 'gamma': 2.6237821581611893}. Best is trial 0 with value: 0.39602540813167975.
#
# ================================================================================
# [TRIAL 02] params:
# {
#   "objective": "binary:logistic",
#   "eval_metric": "logloss",
#   "tree_method": "hist",
#   "n_jobs": -1,
#   "random_state": 42,
#   "verbosity": 0,
#   "multi_strategy": "multi_output_tree",
#   "n_estimators": 689,
#   "max_depth": 5,
#   "learning_rate": 0.06252287916406217,
#   "subsample": 0.6557975442608167,
#   "colsample_bytree": 0.7168578594140873,
#   "min_child_weight": 1.498365454855079,
#   "reg_lambda": 0.09153152164233955,
#   "reg_alpha": 0.06764288719681069,
#   "gamma": 0.9983689107917987
# }
#     [FOLD 1] AUPRC=0.389880 | AUROC=0.853907 | Acc=0.940991 | P=0.530062 | R=0.264215 | Spec=0.969425
#     [FOLD 2] AUPRC=0.367643 | AUROC=0.849148 | Acc=0.940857 | P=0.432958 | R=0.230360 | Spec=0.972215
#     [FOLD 3] AUPRC=0.390700 | AUROC=0.848374 | Acc=0.943631 | P=0.526222 | R=0.252213 | Spec=0.970502
#     [FOLD 4] AUPRC=0.408731 | AUROC=0.854544 | Acc=0.940191 | P=0.627478 | R=0.265693 | Spec=0.968586
#     [FOLD 5] AUPRC=0.392307 | AUROC=0.852489 | Acc=0.942077 | P=0.490156 | R=0.255530 | Spec=0.970657
#
# [TRIAL 02] score(AUPRC_macro)=0.389852 | AUROC=0.851692 | Acc=0.941549 | P=0.521375 | R=0.253602 | Spec=0.970277
# [I 2026-07-02 09:47:59,734] Trial 2 finished with value: 0.38985223171795147 and parameters: {'n_estimators': 689, 'max_depth': 5, 'learning_rate': 0.06252287916406217, 'subsample': 0.6557975442608167, 'colsample_bytree': 0.7168578594140873, 'min_child_weight': 1.498365454855079, 'reg_lambda': 0.09153152164233955, 'reg_alpha': 0.06764288719681069, 'gamma': 0.9983689107917987}. Best is trial 0 with value: 0.39602540813167975.
#
# ================================================================================
# [TRIAL 03] params:
# {
#   "objective": "binary:logistic",
#   "eval_metric": "logloss",
#   "tree_method": "hist",
#   "n_jobs": -1,
#   "random_state": 42,
#   "verbosity": 0,
#   "multi_strategy": "multi_output_tree",
#   "n_estimators": 763,
#   "max_depth": 7,
#   "learning_rate": 0.011492999300221412,
#   "subsample": 0.8430179407605753,
#   "colsample_bytree": 0.6682096494749166,
#   "min_child_weight": 0.6075808513336687,
#   "reg_lambda": 12.055498078944888,
#   "reg_alpha": 2.5119100929409792,
#   "gamma": 4.041986740582305
# }
#     [FOLD 1] AUPRC=0.388698 | AUROC=0.862457 | Acc=0.941933 | P=0.782875 | R=0.174075 | Spec=0.977881
#     [FOLD 2] AUPRC=0.377438 | AUROC=0.860647 | Acc=0.938804 | P=0.694724 | R=0.130699 | Spec=0.979766
#     [FOLD 3] AUPRC=0.387009 | AUROC=0.840538 | Acc=0.942466 | P=0.805169 | R=0.159886 | Spec=0.980016
#     [FOLD 4] AUPRC=0.372129 | AUROC=0.842369 | Acc=0.937972 | P=0.770624 | R=0.143189 | Spec=0.976085
#     [FOLD 5] AUPRC=0.373968 | AUROC=0.841268 | Acc=0.941134 | P=0.798155 | R=0.156228 | Spec=0.978079
#
# [TRIAL 03] score(AUPRC_macro)=0.379849 | AUROC=0.849456 | Acc=0.940462 | P=0.770309 | R=0.152815 | Spec=0.978366
# [I 2026-07-02 09:53:49,255] Trial 3 finished with value: 0.379848525101167 and parameters: {'n_estimators': 763, 'max_depth': 7, 'learning_rate': 0.011492999300221412, 'subsample': 0.8430179407605753, 'colsample_bytree': 0.6682096494749166, 'min_child_weight': 0.6075808513336687, 'reg_lambda': 12.055498078944888, 'reg_alpha': 2.5119100929409792, 'gamma': 4.041986740582305}. Best is trial 0 with value: 0.39602540813167975.
#
# ================================================================================
# [TRIAL 04] params:
# {
#   "objective": "binary:logistic",
#   "eval_metric": "logloss",
#   "tree_method": "hist",
#   "n_jobs": -1,
#   "random_state": 42,
#   "verbosity": 0,
#   "multi_strategy": "multi_output_tree",
#   "n_estimators": 574,
#   "max_depth": 3,
#   "learning_rate": 0.07766184280392888,
#   "subsample": 0.7760609974958406,
#   "colsample_bytree": 0.6488152939379115,
#   "min_child_weight": 2.2039920190846214,
#   "reg_lambda": 0.001405743424794793,
#   "reg_alpha": 0.8131129951713353,
#   "gamma": 1.2938999080000846
# }
#     [FOLD 1] AUPRC=0.392605 | AUROC=0.867897 | Acc=0.942154 | P=0.770542 | R=0.216570 | Spec=0.974276
#     [FOLD 2] AUPRC=0.385149 | AUROC=0.863863 | Acc=0.942188 | P=0.644723 | R=0.199725 | Spec=0.977541
#     [FOLD 3] AUPRC=0.406803 | AUROC=0.854245 | Acc=0.943908 | P=0.551936 | R=0.214047 | Spec=0.975620
#     [FOLD 4] AUPRC=0.419137 | AUROC=0.862165 | Acc=0.940357 | P=0.671502 | R=0.202686 | Spec=0.973166
#     [FOLD 5] AUPRC=0.408085 | AUROC=0.861526 | Acc=0.943797 | P=0.625213 | R=0.208450 | Spec=0.975153
#
# [TRIAL 04] score(AUPRC_macro)=0.402356 | AUROC=0.861939 | Acc=0.942481 | P=0.652783 | R=0.208296 | Spec=0.975151
# [I 2026-07-02 09:55:41,450] Trial 4 finished with value: 0.40235586544205193 and parameters: {'n_estimators': 574, 'max_depth': 3, 'learning_rate': 0.07766184280392888, 'subsample': 0.7760609974958406, 'colsample_bytree': 0.6488152939379115, 'min_child_weight': 2.2039920190846214, 'reg_lambda': 0.001405743424794793, 'reg_alpha': 0.8131129951713353, 'gamma': 1.2938999080000846}. Best is trial 4 with value: 0.40235586544205193.
#
# ================================================================================
# [TRIAL 05] params:
# {
#   "objective": "binary:logistic",
#   "eval_metric": "logloss",
#   "tree_method": "hist",
#   "n_jobs": -1,
#   "random_state": 42,
#   "verbosity": 0,
#   "multi_strategy": "multi_output_tree",
#   "n_estimators": 896,
#   "max_depth": 5,
#   "learning_rate": 0.04749239763680407,
#   "subsample": 0.8186841117373118,
#   "colsample_bytree": 0.6739417822102108,
#   "min_child_weight": 9.129115219600122,
#   "reg_lambda": 2.1570962503558295,
#   "reg_alpha": 1.4882404753442915,
#   "gamma": 4.474136752138244
# }
#     [FOLD 1] AUPRC=0.380332 | AUROC=0.863024 | Acc=0.941933 | P=0.782859 | R=0.198235 | Spec=0.975272
#     [FOLD 2] AUPRC=0.373055 | AUROC=0.862008 | Acc=0.940413 | P=0.597457 | R=0.168067 | Spec=0.978026
#     [FOLD 3] AUPRC=0.390907 | AUROC=0.842050 | Acc=0.942743 | P=0.643591 | R=0.177417 | Spec=0.977482
#     [FOLD 4] AUPRC=0.380527 | AUROC=0.850300 | Acc=0.939359 | P=0.627522 | R=0.184799 | Spec=0.974272
#     [FOLD 5] AUPRC=0.387848 | AUROC=0.850104 | Acc=0.942688 | P=0.623270 | R=0.185375 | Spec=0.976966
#
# [TRIAL 05] score(AUPRC_macro)=0.382534 | AUROC=0.853497 | Acc=0.941427 | P=0.654940 | R=0.182778 | Spec=0.976404
# [I 2026-07-02 09:59:26,508] Trial 5 finished with value: 0.38253367912872566 and parameters: {'n_estimators': 896, 'max_depth': 5, 'learning_rate': 0.04749239763680407, 'subsample': 0.8186841117373118, 'colsample_bytree': 0.6739417822102108, 'min_child_weight': 9.129115219600122, 'reg_lambda': 2.1570962503558295, 'reg_alpha': 1.4882404753442915, 'gamma': 4.474136752138244}. Best is trial 4 with value: 0.40235586544205193.
#
# ================================================================================
# [TRIAL 06] params:
# {
#   "objective": "binary:logistic",
#   "eval_metric": "logloss",
#   "tree_method": "hist",
#   "n_jobs": -1,
#   "random_state": 42,
#   "verbosity": 0,
#   "multi_strategy": "multi_output_tree",
#   "n_estimators": 838,
#   "max_depth": 10,
#   "learning_rate": 0.01303561122512888,
#   "subsample": 0.6783931449676581,
#   "colsample_bytree": 0.6180909155642152,
#   "min_child_weight": 1.3250568853729487,
#   "reg_lambda": 0.0469583341176048,
#   "reg_alpha": 2.293280024184598e-06,
#   "gamma": 4.143687545759647
# }
#     [FOLD 1] AUPRC=0.401478 | AUROC=0.862724 | Acc=0.942043 | P=0.559070 | R=0.251852 | Spec=0.972651
#     [FOLD 2] AUPRC=0.382049 | AUROC=0.861824 | Acc=0.942521 | P=0.514930 | R=0.223256 | Spec=0.975273
#     [FOLD 3] AUPRC=0.412372 | AUROC=0.855370 | Acc=0.944241 | P=0.601301 | R=0.244478 | Spec=0.973684
#     [FOLD 4] AUPRC=0.422362 | AUROC=0.859634 | Acc=0.941744 | P=0.703049 | R=0.246542 | Spec=0.972103
#     [FOLD 5] AUPRC=0.408153 | AUROC=0.857489 | Acc=0.944740 | P=0.521521 | R=0.233713 | Spec=0.974862
#
# [TRIAL 06] score(AUPRC_macro)=0.405283 | AUROC=0.859408 | Acc=0.943058 | P=0.579974 | R=0.239968 | Spec=0.973714
# [I 2026-07-02 10:15:01,359] Trial 6 finished with value: 0.4052826630136776 and parameters: {'n_estimators': 838, 'max_depth': 10, 'learning_rate': 0.01303561122512888, 'subsample': 0.6783931449676581, 'colsample_bytree': 0.6180909155642152, 'min_child_weight': 1.3250568853729487, 'reg_lambda': 0.0469583341176048, 'reg_alpha': 2.293280024184598e-06, 'gamma': 4.143687545759647}. Best is trial 6 with value: 0.4052826630136776.
#
# ================================================================================
# [TRIAL 07] params:
# {
#   "objective": "binary:logistic",
#   "eval_metric": "logloss",
#   "tree_method": "hist",
#   "n_jobs": -1,
#   "random_state": 42,
#   "verbosity": 0,
#   "multi_strategy": "multi_output_tree",
#   "n_estimators": 621,
#   "max_depth": 5,
#   "learning_rate": 0.05082341959721458,
#   "subsample": 0.6563696899899051,
#   "colsample_bytree": 0.9208787923016158,
#   "min_child_weight": 0.6251188975400557,
#   "reg_lambda": 17.564278579581362,
#   "reg_alpha": 0.05220764268782494,
#   "gamma": 0.993578407670862
# }
#     [FOLD 1] AUPRC=0.398818 | AUROC=0.870984 | Acc=0.942210 | P=0.748277 | R=0.218677 | Spec=0.973819
#     [FOLD 2] AUPRC=0.391669 | AUROC=0.868842 | Acc=0.942688 | P=0.668258 | R=0.202222 | Spec=0.977836
#     [FOLD 3] AUPRC=0.404267 | AUROC=0.857435 | Acc=0.943908 | P=0.612593 | R=0.201208 | Spec=0.976400
#     [FOLD 4] AUPRC=0.406669 | AUROC=0.857596 | Acc=0.941245 | P=0.694011 | R=0.201977 | Spec=0.973574
#     [FOLD 5] AUPRC=0.404693 | AUROC=0.859952 | Acc=0.943908 | P=0.635673 | R=0.206328 | Spec=0.975955
#
# [TRIAL 07] score(AUPRC_macro)=0.401223 | AUROC=0.862962 | Acc=0.942792 | P=0.671763 | R=0.206082 | Spec=0.975517
# [I 2026-07-02 10:19:33,856] Trial 7 finished with value: 0.4012232041777474 and parameters: {'n_estimators': 621, 'max_depth': 5, 'learning_rate': 0.05082341959721458, 'subsample': 0.6563696899899051, 'colsample_bytree': 0.9208787923016158, 'min_child_weight': 0.6251188975400557, 'reg_lambda': 17.564278579581362, 'reg_alpha': 0.05220764268782494, 'gamma': 0.993578407670862}. Best is trial 6 with value: 0.4052826630136776.
#
# ================================================================================
# [TRIAL 08] params:
# {
#   "objective": "binary:logistic",
#   "eval_metric": "logloss",
#   "tree_method": "hist",
#   "n_jobs": -1,
#   "random_state": 42,
#   "verbosity": 0,
#   "multi_strategy": "multi_output_tree",
#   "n_estimators": 304,
#   "max_depth": 9,
#   "learning_rate": 0.08310795711416077,
#   "subsample": 0.8916028672163949,
#   "colsample_bytree": 0.9085081386743783,
#   "min_child_weight": 0.6241720498669826,
#   "reg_lambda": 0.034815437009482725,
#   "reg_alpha": 1.0184541290289273e-07,
#   "gamma": 4.315517129377968
# }
#     [FOLD 1] AUPRC=0.398889 | AUROC=0.863069 | Acc=0.941434 | P=0.544840 | R=0.285375 | Spec=0.970090
#     [FOLD 2] AUPRC=0.367543 | AUROC=0.863743 | Acc=0.941411 | P=0.453576 | R=0.230504 | Spec=0.972497
#     [FOLD 3] AUPRC=0.402990 | AUROC=0.852126 | Acc=0.944130 | P=0.527317 | R=0.286337 | Spec=0.970662
#     [FOLD 4] AUPRC=0.412306 | AUROC=0.860788 | Acc=0.940968 | P=0.550856 | R=0.281716 | Spec=0.969267
#     [FOLD 5] AUPRC=0.420643 | AUROC=0.853570 | Acc=0.943464 | P=0.501051 | R=0.295011 | Spec=0.969836
#
# [TRIAL 08] score(AUPRC_macro)=0.400474 | AUROC=0.858659 | Acc=0.942281 | P=0.515528 | R=0.275789 | Spec=0.970470
# [I 2026-07-02 10:23:15,198] Trial 8 finished with value: 0.40047446191018343 and parameters: {'n_estimators': 304, 'max_depth': 9, 'learning_rate': 0.08310795711416077, 'subsample': 0.8916028672163949, 'colsample_bytree': 0.9085081386743783, 'min_child_weight': 0.6241720498669826, 'reg_lambda': 0.034815437009482725, 'reg_alpha': 1.0184541290289273e-07, 'gamma': 4.315517129377968}. Best is trial 6 with value: 0.4052826630136776.
#
# ================================================================================
# [TRIAL 09] params:
# {
#   "objective": "binary:logistic",
#   "eval_metric": "logloss",
#   "tree_method": "hist",
#   "n_jobs": -1,
#   "random_state": 42,
#   "verbosity": 0,
#   "multi_strategy": "multi_output_tree",
#   "n_estimators": 861,
#   "max_depth": 5,
#   "learning_rate": 0.012097379927033842,
#   "subsample": 0.7243929286862649,
#   "colsample_bytree": 0.7300733288106989,
#   "min_child_weight": 4.448458336296337,
#   "reg_lambda": 0.5522729957780633,
#   "reg_alpha": 0.5222002015831414,
#   "gamma": 2.3610746258097466
# }
#     [FOLD 1] AUPRC=0.392528 | AUROC=0.864967 | Acc=0.943152 | P=0.782668 | R=0.213285 | Spec=0.976470
#     [FOLD 2] AUPRC=0.385371 | AUROC=0.865712 | Acc=0.940912 | P=0.690500 | R=0.185352 | Spec=0.978698
#     [FOLD 3] AUPRC=0.395683 | AUROC=0.845825 | Acc=0.943631 | P=0.675354 | R=0.183396 | Spec=0.978328
#     [FOLD 4] AUPRC=0.393646 | AUROC=0.851437 | Acc=0.939969 | P=0.679867 | R=0.192627 | Spec=0.974658
#     [FOLD 5] AUPRC=0.390338 | AUROC=0.852091 | Acc=0.943520 | P=0.703788 | R=0.201720 | Spec=0.977185
#
# [TRIAL 09] score(AUPRC_macro)=0.391513 | AUROC=0.856007 | Acc=0.942237 | P=0.706435 | R=0.195276 | Spec=0.977068
# [I 2026-07-02 10:29:29,248] Trial 9 finished with value: 0.39151329830405757 and parameters: {'n_estimators': 861, 'max_depth': 5, 'learning_rate': 0.012097379927033842, 'subsample': 0.7243929286862649, 'colsample_bytree': 0.7300733288106989, 'min_child_weight': 4.448458336296337, 'reg_lambda': 0.5522729957780633, 'reg_alpha': 0.5222002015831414, 'gamma': 2.3610746258097466}. Best is trial 6 with value: 0.4052826630136776.
#
# ================================================================================
# [TRIAL 10] params:
# {
#   "objective": "binary:logistic",
#   "eval_metric": "logloss",
#   "tree_method": "hist",
#   "n_jobs": -1,
#   "random_state": 42,
#   "verbosity": 0,
#   "multi_strategy": "multi_output_tree",
#   "n_estimators": 1159,
#   "max_depth": 8,
#   "learning_rate": 0.02120936045478828,
#   "subsample": 0.6071847502459279,
#   "colsample_bytree": 0.8262452362725613,
#   "min_child_weight": 1.4778843806130162,
#   "reg_lambda": 0.014168088907480319,
#   "reg_alpha": 2.5937967187312596e-05,
#   "gamma": 3.3446220352955045
# }
#     [FOLD 1] AUPRC=0.395292 | AUROC=0.853084 | Acc=0.939938 | P=0.515537 | R=0.268651 | Spec=0.968822
#     [FOLD 2] AUPRC=0.373015 | AUROC=0.849294 | Acc=0.940413 | P=0.459888 | R=0.235684 | Spec=0.971247
#     [FOLD 3] AUPRC=0.396476 | AUROC=0.847202 | Acc=0.944352 | P=0.539962 | R=0.275555 | Spec=0.971347
#     [FOLD 4] AUPRC=0.412546 | AUROC=0.853205 | Acc=0.941190 | P=0.669870 | R=0.267738 | Spec=0.969192
#     [FOLD 5] AUPRC=0.400092 | AUROC=0.850146 | Acc=0.942798 | P=0.527606 | R=0.252903 | Spec=0.970629
#
# [TRIAL 10] score(AUPRC_macro)=0.395484 | AUROC=0.850586 | Acc=0.941738 | P=0.542573 | R=0.260106 | Spec=0.970247
# [I 2026-07-02 10:45:06,793] Trial 10 finished with value: 0.39548420425146774 and parameters: {'n_estimators': 1159, 'max_depth': 8, 'learning_rate': 0.02120936045478828, 'subsample': 0.6071847502459279, 'colsample_bytree': 0.8262452362725613, 'min_child_weight': 1.4778843806130162, 'reg_lambda': 0.014168088907480319, 'reg_alpha': 2.5937967187312596e-05, 'gamma': 3.3446220352955045}. Best is trial 6 with value: 0.4052826630136776.
#
# ================================================================================
# [TRIAL 11] params:
# {
#   "objective": "binary:logistic",
#   "eval_metric": "logloss",
#   "tree_method": "hist",
#   "n_jobs": -1,
#   "random_state": 42,
#   "verbosity": 0,
#   "multi_strategy": "multi_output_tree",
#   "n_estimators": 465,
#   "max_depth": 3,
#   "learning_rate": 0.029059314335235016,
#   "subsample": 0.7467143880908638,
#   "colsample_bytree": 0.6125516819803675,
#   "min_child_weight": 2.8261678791728673,
#   "reg_lambda": 0.00151458457676152,
#   "reg_alpha": 0.0009706016345215861,
#   "gamma": 0.15590624136109477
# }
#     [FOLD 1] AUPRC=0.390878 | AUROC=0.866096 | Acc=0.942265 | P=0.816713 | R=0.200110 | Spec=0.977290
#     [FOLD 2] AUPRC=0.375972 | AUROC=0.863750 | Acc=0.940968 | P=0.701630 | R=0.177436 | Spec=0.979821
#     [FOLD 3] AUPRC=0.389892 | AUROC=0.849516 | Acc=0.942909 | P=0.635001 | R=0.185181 | Spec=0.978698
#     [FOLD 4] AUPRC=0.395378 | AUROC=0.853657 | Acc=0.939248 | P=0.701671 | R=0.181973 | Spec=0.975579
#     [FOLD 5] AUPRC=0.389406 | AUROC=0.854335 | Acc=0.942299 | P=0.688593 | R=0.186692 | Spec=0.977208
#
# [TRIAL 11] score(AUPRC_macro)=0.388305 | AUROC=0.857471 | Acc=0.941538 | P=0.708722 | R=0.186278 | Spec=0.977719
# [I 2026-07-02 10:46:58,778] Trial 11 finished with value: 0.38830532253155414 and parameters: {'n_estimators': 465, 'max_depth': 3, 'learning_rate': 0.029059314335235016, 'subsample': 0.7467143880908638, 'colsample_bytree': 0.6125516819803675, 'min_child_weight': 2.8261678791728673, 'reg_lambda': 0.00151458457676152, 'reg_alpha': 0.0009706016345215861, 'gamma': 0.15590624136109477}. Best is trial 6 with value: 0.4052826630136776.
#
# ================================================================================
# [TRIAL 12] params:
# {
#   "objective": "binary:logistic",
#   "eval_metric": "logloss",
#   "tree_method": "hist",
#   "n_jobs": -1,
#   "random_state": 42,
#   "verbosity": 0,
#   "multi_strategy": "multi_output_tree",
#   "n_estimators": 487,
#   "max_depth": 10,
#   "learning_rate": 0.1536140751385009,
#   "subsample": 0.7382774980993067,
#   "colsample_bytree": 0.6083722002970473,
#   "min_child_weight": 2.4856135028694935,
#   "reg_lambda": 0.2998350844502907,
#   "reg_alpha": 1.959578228249567e-08,
#   "gamma": 1.6921629101016429
# }
#     [FOLD 1] AUPRC=0.386662 | AUROC=0.844375 | Acc=0.938996 | P=0.507979 | R=0.279765 | Spec=0.965714
#     [FOLD 2] AUPRC=0.357981 | AUROC=0.843559 | Acc=0.938582 | P=0.479972 | R=0.255513 | Spec=0.967763
#     [FOLD 3] AUPRC=0.384819 | AUROC=0.841057 | Acc=0.942577 | P=0.537425 | R=0.283577 | Spec=0.968440
#     [FOLD 4] AUPRC=0.379316 | AUROC=0.845213 | Acc=0.938138 | P=0.497702 | R=0.265036 | Spec=0.965602
#     [FOLD 5] AUPRC=0.380555 | AUROC=0.842457 | Acc=0.941855 | P=0.485888 | R=0.289955 | Spec=0.967439
#
# [TRIAL 12] score(AUPRC_macro)=0.377867 | AUROC=0.843332 | Acc=0.940030 | P=0.501793 | R=0.274769 | Spec=0.966992
# [I 2026-07-02 10:54:46,701] Trial 12 finished with value: 0.3778666196162492 and parameters: {'n_estimators': 487, 'max_depth': 10, 'learning_rate': 0.1536140751385009, 'subsample': 0.7382774980993067, 'colsample_bytree': 0.6083722002970473, 'min_child_weight': 2.4856135028694935, 'reg_lambda': 0.2998350844502907, 'reg_alpha': 1.959578228249567e-08, 'gamma': 1.6921629101016429}. Best is trial 6 with value: 0.4052826630136776.
#
# ================================================================================
# [TRIAL 13] params:
# {
#   "objective": "binary:logistic",
#   "eval_metric": "logloss",
#   "tree_method": "hist",
#   "n_jobs": -1,
#   "random_state": 42,
#   "verbosity": 0,
#   "multi_strategy": "multi_output_tree",
#   "n_estimators": 1049,
#   "max_depth": 7,
#   "learning_rate": 0.024392092558350818,
#   "subsample": 0.9997449754566206,
#   "colsample_bytree": 0.7960752676332242,
#   "min_child_weight": 1.3328916206250172,
#   "reg_lambda": 0.009842063437907906,
#   "reg_alpha": 0.0019986943920015034,
#   "gamma": 4.9892170262441
# }
#     [FOLD 1] AUPRC=0.408433 | AUROC=0.865823 | Acc=0.941933 | P=0.634853 | R=0.249732 | Spec=0.972401
#     [FOLD 2] AUPRC=0.388141 | AUROC=0.866136 | Acc=0.942909 | P=0.558461 | R=0.220051 | Spec=0.977419
#     [FOLD 3] AUPRC=0.416191 | AUROC=0.859616 | Acc=0.944740 | P=0.658827 | R=0.236758 | Spec=0.975049
#     [FOLD 4] AUPRC=0.422597 | AUROC=0.857658 | Acc=0.942410 | P=0.647155 | R=0.245484 | Spec=0.973411
#     [FOLD 5] AUPRC=0.417716 | AUROC=0.861772 | Acc=0.944186 | P=0.587941 | R=0.236716 | Spec=0.974649
#
# [TRIAL 13] score(AUPRC_macro)=0.410616 | AUROC=0.862201 | Acc=0.943236 | P=0.617448 | R=0.237748 | Spec=0.974586
# [I 2026-07-02 11:00:56,150] Trial 13 finished with value: 0.4106156707644434 and parameters: {'n_estimators': 1049, 'max_depth': 7, 'learning_rate': 0.024392092558350818, 'subsample': 0.9997449754566206, 'colsample_bytree': 0.7960752676332242, 'min_child_weight': 1.3328916206250172, 'reg_lambda': 0.009842063437907906, 'reg_alpha': 0.0019986943920015034, 'gamma': 4.9892170262441}. Best is trial 13 with value: 0.4106156707644434.
#
# ================================================================================
# [TRIAL 14] params:
# {
#   "objective": "binary:logistic",
#   "eval_metric": "logloss",
#   "tree_method": "hist",
#   "n_jobs": -1,
#   "random_state": 42,
#   "verbosity": 0,
#   "multi_strategy": "multi_output_tree",
#   "n_estimators": 1098,
#   "max_depth": 7,
#   "learning_rate": 0.019708694858161537,
#   "subsample": 0.9984067957444854,
#   "colsample_bytree": 0.9989535998571444,
#   "min_child_weight": 1.244287190574086,
#   "reg_lambda": 0.04394332470854731,
#   "reg_alpha": 0.0021279990144585747,
#   "gamma": 4.72352421824454
# }
#     [FOLD 1] AUPRC=0.404768 | AUROC=0.861555 | Acc=0.942265 | P=0.637862 | R=0.261207 | Spec=0.972664
#     [FOLD 2] AUPRC=0.390366 | AUROC=0.868324 | Acc=0.942410 | P=0.564485 | R=0.225571 | Spec=0.976243
#     [FOLD 3] AUPRC=0.413870 | AUROC=0.859371 | Acc=0.944851 | P=0.646485 | R=0.245684 | Spec=0.974709
#     [FOLD 4] AUPRC=0.421463 | AUROC=0.856177 | Acc=0.942077 | P=0.653501 | R=0.255934 | Spec=0.972332
#     [FOLD 5] AUPRC=0.419762 | AUROC=0.860941 | Acc=0.944629 | P=0.607778 | R=0.248390 | Spec=0.974387
#
# [TRIAL 14] score(AUPRC_macro)=0.410046 | AUROC=0.861274 | Acc=0.943247 | P=0.622022 | R=0.247357 | Spec=0.974067
# [I 2026-07-02 11:08:43,519] Trial 14 finished with value: 0.4100460226659079 and parameters: {'n_estimators': 1098, 'max_depth': 7, 'learning_rate': 0.019708694858161537, 'subsample': 0.9984067957444854, 'colsample_bytree': 0.9989535998571444, 'min_child_weight': 1.244287190574086, 'reg_lambda': 0.04394332470854731, 'reg_alpha': 0.0021279990144585747, 'gamma': 4.72352421824454}. Best is trial 13 with value: 0.4106156707644434.
#
# ================================================================================
# [TRIAL 15] params:
# {
#   "objective": "binary:logistic",
#   "eval_metric": "logloss",
#   "tree_method": "hist",
#   "n_jobs": -1,
#   "random_state": 42,
#   "verbosity": 0,
#   "multi_strategy": "multi_output_tree",
#   "n_estimators": 1187,
#   "max_depth": 7,
#   "learning_rate": 0.026279535691638902,
#   "subsample": 0.9890905890927089,
#   "colsample_bytree": 0.9800312316192605,
#   "min_child_weight": 1.106796160574764,
#   "reg_lambda": 0.009024881017075352,
#   "reg_alpha": 0.001994959502248866,
#   "gamma": 4.88633232797539
# }
#     [FOLD 1] AUPRC=0.413143 | AUROC=0.863315 | Acc=0.941933 | P=0.655988 | R=0.271651 | Spec=0.971640
#     [FOLD 2] AUPRC=0.389852 | AUROC=0.866732 | Acc=0.942577 | P=0.536001 | R=0.229528 | Spec=0.975970
#     [FOLD 3] AUPRC=0.416755 | AUROC=0.858146 | Acc=0.944463 | P=0.599588 | R=0.244454 | Spec=0.974304
#     [FOLD 4] AUPRC=0.417490 | AUROC=0.858351 | Acc=0.942521 | P=0.636985 | R=0.258075 | Spec=0.972320
#     [FOLD 5] AUPRC=0.417532 | AUROC=0.861143 | Acc=0.944574 | P=0.607768 | R=0.262940 | Spec=0.973981
#
# [TRIAL 15] score(AUPRC_macro)=0.410954 | AUROC=0.861537 | Acc=0.943213 | P=0.607266 | R=0.253330 | Spec=0.973643
# [I 2026-07-02 11:15:05,093] Trial 15 finished with value: 0.41095437583387096 and parameters: {'n_estimators': 1187, 'max_depth': 7, 'learning_rate': 0.026279535691638902, 'subsample': 0.9890905890927089, 'colsample_bytree': 0.9800312316192605, 'min_child_weight': 1.106796160574764, 'reg_lambda': 0.009024881017075352, 'reg_alpha': 0.001994959502248866, 'gamma': 4.88633232797539}. Best is trial 15 with value: 0.41095437583387096.
#
# ================================================================================
# [TRIAL 16] params:
# {
#   "objective": "binary:logistic",
#   "eval_metric": "logloss",
#   "tree_method": "hist",
#   "n_jobs": -1,
#   "random_state": 42,
#   "verbosity": 0,
#   "multi_strategy": "multi_output_tree",
#   "n_estimators": 1033,
#   "max_depth": 8,
#   "learning_rate": 0.03507688229451908,
#   "subsample": 0.9947153135691091,
#   "colsample_bytree": 0.7926625480650832,
#   "min_child_weight": 0.9983780280790232,
#   "reg_lambda": 0.006663375168226882,
#   "reg_alpha": 0.0002198134035439981,
#   "gamma": 3.6604397421777977
# }
#     [FOLD 1] AUPRC=0.402705 | AUROC=0.862881 | Acc=0.942210 | P=0.533663 | R=0.268228 | Spec=0.971098
#     [FOLD 2] AUPRC=0.382705 | AUROC=0.864518 | Acc=0.941522 | P=0.509179 | R=0.233303 | Spec=0.974077
#     [FOLD 3] AUPRC=0.408192 | AUROC=0.856253 | Acc=0.943631 | P=0.589919 | R=0.255196 | Spec=0.971817
#     [FOLD 4] AUPRC=0.416501 | AUROC=0.856642 | Acc=0.942466 | P=0.623409 | R=0.277889 | Spec=0.971794
#     [FOLD 5] AUPRC=0.421093 | AUROC=0.857118 | Acc=0.943908 | P=0.542468 | R=0.264915 | Spec=0.972696
#
# [TRIAL 16] score(AUPRC_macro)=0.406239 | AUROC=0.859482 | Acc=0.942747 | P=0.559728 | R=0.259906 | Spec=0.972296
# [I 2026-07-02 11:21:36,628] Trial 16 finished with value: 0.40623914042679915 and parameters: {'n_estimators': 1033, 'max_depth': 8, 'learning_rate': 0.03507688229451908, 'subsample': 0.9947153135691091, 'colsample_bytree': 0.7926625480650832, 'min_child_weight': 0.9983780280790232, 'reg_lambda': 0.006663375168226882, 'reg_alpha': 0.0002198134035439981, 'gamma': 3.6604397421777977}. Best is trial 15 with value: 0.41095437583387096.
#
# ================================================================================
# [TRIAL 17] params:
# {
#   "objective": "binary:logistic",
#   "eval_metric": "logloss",
#   "tree_method": "hist",
#   "n_jobs": -1,
#   "random_state": 42,
#   "verbosity": 0,
#   "multi_strategy": "multi_output_tree",
#   "n_estimators": 1191,
#   "max_depth": 6,
#   "learning_rate": 0.020451180653431673,
#   "subsample": 0.9406069544760228,
#   "colsample_bytree": 0.8221702495010313,
#   "min_child_weight": 3.5152160537686594,
#   "reg_lambda": 0.009088451500733804,
#   "reg_alpha": 0.010503601826451452,
#   "gamma": 4.993108722845746
# }
#     [FOLD 1] AUPRC=0.399091 | AUROC=0.861634 | Acc=0.942598 | P=0.635967 | R=0.241303 | Spec=0.973690
#     [FOLD 2] AUPRC=0.383927 | AUROC=0.863427 | Acc=0.942577 | P=0.570416 | R=0.218221 | Spec=0.977010
#     [FOLD 3] AUPRC=0.403005 | AUROC=0.853886 | Acc=0.944574 | P=0.581563 | R=0.233592 | Spec=0.974591
#     [FOLD 4] AUPRC=0.411376 | AUROC=0.857571 | Acc=0.941134 | P=0.654923 | R=0.218870 | Spec=0.973144
#     [FOLD 5] AUPRC=0.401479 | AUROC=0.859129 | Acc=0.944629 | P=0.608377 | R=0.224375 | Spec=0.975599
#
# [TRIAL 17] score(AUPRC_macro)=0.399776 | AUROC=0.859130 | Acc=0.943102 | P=0.610249 | R=0.227272 | Spec=0.974807
# [I 2026-07-02 11:29:39,561] Trial 17 finished with value: 0.3997757013286457 and parameters: {'n_estimators': 1191, 'max_depth': 6, 'learning_rate': 0.020451180653431673, 'subsample': 0.9406069544760228, 'colsample_bytree': 0.8221702495010313, 'min_child_weight': 3.5152160537686594, 'reg_lambda': 0.009088451500733804, 'reg_alpha': 0.010503601826451452, 'gamma': 4.993108722845746}. Best is trial 15 with value: 0.41095437583387096.
#
# ================================================================================
# [TRIAL 18] params:
# {
#   "objective": "binary:logistic",
#   "eval_metric": "logloss",
#   "tree_method": "hist",
#   "n_jobs": -1,
#   "random_state": 42,
#   "verbosity": 0,
#   "multi_strategy": "multi_output_tree",
#   "n_estimators": 1018,
#   "max_depth": 8,
#   "learning_rate": 0.030937346837782095,
#   "subsample": 0.9513792712689798,
#   "colsample_bytree": 0.8766481547213913,
#   "min_child_weight": 2.003148188593708,
#   "reg_lambda": 0.0037509519400280487,
#   "reg_alpha": 0.00011785142147962486,
#   "gamma": 3.6218293201124587
# }
#     [FOLD 1] AUPRC=0.407576 | AUROC=0.856644 | Acc=0.941379 | P=0.602073 | R=0.265739 | Spec=0.971352
#     [FOLD 2] AUPRC=0.381706 | AUROC=0.851171 | Acc=0.941911 | P=0.503117 | R=0.237305 | Spec=0.973897
#     [FOLD 3] AUPRC=0.405645 | AUROC=0.854463 | Acc=0.944019 | P=0.583567 | R=0.270067 | Spec=0.972228
#     [FOLD 4] AUPRC=0.421354 | AUROC=0.857356 | Acc=0.941800 | P=0.670150 | R=0.267622 | Spec=0.970748
#     [FOLD 5] AUPRC=0.407065 | AUROC=0.857430 | Acc=0.943575 | P=0.497823 | R=0.257825 | Spec=0.972159
#
# [TRIAL 18] score(AUPRC_macro)=0.404669 | AUROC=0.855413 | Acc=0.942537 | P=0.571346 | R=0.259712 | Spec=0.972077
# [I 2026-07-02 11:38:43,899] Trial 18 finished with value: 0.4046694070462952 and parameters: {'n_estimators': 1018, 'max_depth': 8, 'learning_rate': 0.030937346837782095, 'subsample': 0.9513792712689798, 'colsample_bytree': 0.8766481547213913, 'min_child_weight': 2.003148188593708, 'reg_lambda': 0.0037509519400280487, 'reg_alpha': 0.00011785142147962486, 'gamma': 3.6218293201124587}. Best is trial 15 with value: 0.41095437583387096.
#
# ================================================================================
# [TRIAL 19] params:
# {
#   "objective": "binary:logistic",
#   "eval_metric": "logloss",
#   "tree_method": "hist",
#   "n_jobs": -1,
#   "random_state": 42,
#   "verbosity": 0,
#   "multi_strategy": "multi_output_tree",
#   "n_estimators": 1003,
#   "max_depth": 6,
#   "learning_rate": 0.017938153425811867,
#   "subsample": 0.8788760859597049,
#   "colsample_bytree": 0.991719233086637,
#   "min_child_weight": 5.935938448729198,
#   "reg_lambda": 0.023808974229572188,
#   "reg_alpha": 0.0039029897289188063,
#   "gamma": 4.9132714013690135
# }
#     [FOLD 1] AUPRC=0.394309 | AUROC=0.864459 | Acc=0.942099 | P=0.655264 | R=0.222204 | Spec=0.974173
#     [FOLD 2] AUPRC=0.381998 | AUROC=0.864716 | Acc=0.942299 | P=0.609674 | R=0.207065 | Spec=0.977052
#     [FOLD 3] AUPRC=0.398284 | AUROC=0.845887 | Acc=0.944407 | P=0.707174 | R=0.227893 | Spec=0.975862
#     [FOLD 4] AUPRC=0.398714 | AUROC=0.855316 | Acc=0.941079 | P=0.707674 | R=0.205847 | Spec=0.973299
#     [FOLD 5] AUPRC=0.401139 | AUROC=0.857750 | Acc=0.943964 | P=0.635613 | R=0.206712 | Spec=0.976131
#
# [TRIAL 19] score(AUPRC_macro)=0.394889 | AUROC=0.857626 | Acc=0.942770 | P=0.663080 | R=0.213944 | Spec=0.975303
# [I 2026-07-02 11:46:51,333] Trial 19 finished with value: 0.39488881964041267 and parameters: {'n_estimators': 1003, 'max_depth': 6, 'learning_rate': 0.017938153425811867, 'subsample': 0.8788760859597049, 'colsample_bytree': 0.991719233086637, 'min_child_weight': 5.935938448729198, 'reg_lambda': 0.023808974229572188, 'reg_alpha': 0.0039029897289188063, 'gamma': 4.9132714013690135}. Best is trial 15 with value: 0.41095437583387096.
#
# ================================================================================
# [TRIAL 20] params:
# {
#   "objective": "binary:logistic",
#   "eval_metric": "logloss",
#   "tree_method": "hist",
#   "n_jobs": -1,
#   "random_state": 42,
#   "verbosity": 0,
#   "multi_strategy": "multi_output_tree",
#   "n_estimators": 1087,
#   "max_depth": 7,
#   "learning_rate": 0.029488467813210305,
#   "subsample": 0.9013788130447657,
#   "colsample_bytree": 0.7616675016944651,
#   "min_child_weight": 1.70252173922857,
#   "reg_lambda": 0.15865833847284075,
#   "reg_alpha": 1.4233888489846805e-05,
#   "gamma": 2.2319938141008553
# }
#     [FOLD 1] AUPRC=0.403590 | AUROC=0.855920 | Acc=0.940824 | P=0.521166 | R=0.275802 | Spec=0.969809
#     [FOLD 2] AUPRC=0.373787 | AUROC=0.853007 | Acc=0.940524 | P=0.495434 | R=0.242786 | Spec=0.972039
#     [FOLD 3] AUPRC=0.401029 | AUROC=0.852235 | Acc=0.944186 | P=0.565824 | R=0.270367 | Spec=0.971246
#     [FOLD 4] AUPRC=0.412613 | AUROC=0.857857 | Acc=0.941522 | P=0.624872 | R=0.265791 | Spec=0.970568
#     [FOLD 5] AUPRC=0.397726 | AUROC=0.854959 | Acc=0.942632 | P=0.500426 | R=0.261738 | Spec=0.969976
#
# [TRIAL 20] score(AUPRC_macro)=0.397749 | AUROC=0.854796 | Acc=0.941938 | P=0.541544 | R=0.263297 | Spec=0.970728
# [I 2026-07-02 11:58:19,720] Trial 20 finished with value: 0.39774891847317007 and parameters: {'n_estimators': 1087, 'max_depth': 7, 'learning_rate': 0.029488467813210305, 'subsample': 0.9013788130447657, 'colsample_bytree': 0.7616675016944651, 'min_child_weight': 1.70252173922857, 'reg_lambda': 0.15865833847284075, 'reg_alpha': 1.4233888489846805e-05, 'gamma': 2.2319938141008553}. Best is trial 15 with value: 0.41095437583387096.
#
# ================================================================================
# [TRIAL 21] params:
# {
#   "objective": "binary:logistic",
#   "eval_metric": "logloss",
#   "tree_method": "hist",
#   "n_jobs": -1,
#   "random_state": 42,
#   "verbosity": 0,
#   "multi_strategy": "multi_output_tree",
#   "n_estimators": 1147,
#   "max_depth": 7,
#   "learning_rate": 0.016542138108534818,
#   "subsample": 0.9951788340516367,
#   "colsample_bytree": 0.9976985100984884,
#   "min_child_weight": 1.1108801228578953,
#   "reg_lambda": 0.06071153875840678,
#   "reg_alpha": 0.0015375359118794984,
#   "gamma": 4.741686786506579
# }
#     [FOLD 1] AUPRC=0.410483 | AUROC=0.863109 | Acc=0.942376 | P=0.672282 | R=0.269940 | Spec=0.972434
#     [FOLD 2] AUPRC=0.390929 | AUROC=0.866780 | Acc=0.943187 | P=0.566121 | R=0.225378 | Spec=0.977569
#     [FOLD 3] AUPRC=0.411393 | AUROC=0.857982 | Acc=0.944407 | P=0.610031 | R=0.242718 | Spec=0.974378
#     [FOLD 4] AUPRC=0.416400 | AUROC=0.856309 | Acc=0.942577 | P=0.638523 | R=0.253707 | Spec=0.972911
#     [FOLD 5] AUPRC=0.420582 | AUROC=0.859218 | Acc=0.944352 | P=0.617635 | R=0.260429 | Spec=0.973488
#
# [TRIAL 21] score(AUPRC_macro)=0.409957 | AUROC=0.860680 | Acc=0.943380 | P=0.620918 | R=0.250434 | Spec=0.974156
# [I 2026-07-02 12:07:50,175] Trial 21 finished with value: 0.4099572750957474 and parameters: {'n_estimators': 1147, 'max_depth': 7, 'learning_rate': 0.016542138108534818, 'subsample': 0.9951788340516367, 'colsample_bytree': 0.9976985100984884, 'min_child_weight': 1.1108801228578953, 'reg_lambda': 0.06071153875840678, 'reg_alpha': 0.0015375359118794984, 'gamma': 4.741686786506579}. Best is trial 15 with value: 0.41095437583387096.
#
# ================================================================================
# [TRIAL 22] params:
# {
#   "objective": "binary:logistic",
#   "eval_metric": "logloss",
#   "tree_method": "hist",
#   "n_jobs": -1,
#   "random_state": 42,
#   "verbosity": 0,
#   "multi_strategy": "multi_output_tree",
#   "n_estimators": 1097,
#   "max_depth": 6,
#   "learning_rate": 0.024032795537785832,
#   "subsample": 0.9685667653416757,
#   "colsample_bytree": 0.9675815560272018,
#   "min_child_weight": 1.1312116186024124,
#   "reg_lambda": 0.018283773644246396,
#   "reg_alpha": 0.017611968878751823,
#   "gamma": 4.5307637705384
# }
#     [FOLD 1] AUPRC=0.410176 | AUROC=0.861848 | Acc=0.941988 | P=0.605921 | R=0.264909 | Spec=0.972027
#     [FOLD 2] AUPRC=0.387573 | AUROC=0.866722 | Acc=0.943187 | P=0.535201 | R=0.225504 | Spec=0.977009
#     [FOLD 3] AUPRC=0.410807 | AUROC=0.857470 | Acc=0.945184 | P=0.685505 | R=0.253291 | Spec=0.974906
#     [FOLD 4] AUPRC=0.415705 | AUROC=0.857791 | Acc=0.942410 | P=0.636325 | R=0.255548 | Spec=0.972537
#     [FOLD 5] AUPRC=0.413261 | AUROC=0.860686 | Acc=0.944019 | P=0.539385 | R=0.246522 | Spec=0.973601
#
# [TRIAL 22] score(AUPRC_macro)=0.407504 | AUROC=0.860903 | Acc=0.943358 | P=0.600467 | R=0.249155 | Spec=0.974016
# [I 2026-07-02 12:14:56,935] Trial 22 finished with value: 0.40750449561703206 and parameters: {'n_estimators': 1097, 'max_depth': 6, 'learning_rate': 0.024032795537785832, 'subsample': 0.9685667653416757, 'colsample_bytree': 0.9675815560272018, 'min_child_weight': 1.1312116186024124, 'reg_lambda': 0.018283773644246396, 'reg_alpha': 0.017611968878751823, 'gamma': 4.5307637705384}. Best is trial 15 with value: 0.41095437583387096.
#
# ================================================================================
# [TRIAL 23] params:
# {
#   "objective": "binary:logistic",
#   "eval_metric": "logloss",
#   "tree_method": "hist",
#   "n_jobs": -1,
#   "random_state": 42,
#   "verbosity": 0,
#   "multi_strategy": "multi_output_tree",
#   "n_estimators": 965,
#   "max_depth": 8,
#   "learning_rate": 0.015380507548442607,
#   "subsample": 0.9997173908335091,
#   "colsample_bytree": 0.9464116612639636,
#   "min_child_weight": 0.8808208042123128,
#   "reg_lambda": 0.0036458135097672674,
#   "reg_alpha": 0.0016235289658689837,
#   "gamma": 3.874463364715151
# }
#     [FOLD 1] AUPRC=0.406889 | AUROC=0.865211 | Acc=0.942154 | P=0.570206 | R=0.260127 | Spec=0.972179
#     [FOLD 2] AUPRC=0.383579 | AUROC=0.868255 | Acc=0.942577 | P=0.543530 | R=0.229890 | Spec=0.975353
#     [FOLD 3] AUPRC=0.410520 | AUROC=0.857651 | Acc=0.943686 | P=0.566054 | R=0.247982 | Spec=0.972855
#     [FOLD 4] AUPRC=0.417351 | AUROC=0.856960 | Acc=0.943020 | P=0.648706 | R=0.275318 | Spec=0.973047
#     [FOLD 5] AUPRC=0.420557 | AUROC=0.859169 | Acc=0.944130 | P=0.551362 | R=0.268272 | Spec=0.973651
#
# [TRIAL 23] score(AUPRC_macro)=0.407779 | AUROC=0.861449 | Acc=0.943113 | P=0.575972 | R=0.256318 | Spec=0.973417
# [I 2026-07-02 12:27:00,796] Trial 23 finished with value: 0.40777903205502586 and parameters: {'n_estimators': 965, 'max_depth': 8, 'learning_rate': 0.015380507548442607, 'subsample': 0.9997173908335091, 'colsample_bytree': 0.9464116612639636, 'min_child_weight': 0.8808208042123128, 'reg_lambda': 0.0036458135097672674, 'reg_alpha': 0.0016235289658689837, 'gamma': 3.874463364715151}. Best is trial 15 with value: 0.41095437583387096.
#
# ================================================================================
# [TRIAL 24] params:
# {
#   "objective": "binary:logistic",
#   "eval_metric": "logloss",
#   "tree_method": "hist",
#   "n_jobs": -1,
#   "random_state": 42,
#   "verbosity": 0,
#   "multi_strategy": "multi_output_tree",
#   "n_estimators": 1112,
#   "max_depth": 9,
#   "learning_rate": 0.04059124471938742,
#   "subsample": 0.9276750129329341,
#   "colsample_bytree": 0.8839451177308427,
#   "min_child_weight": 1.8130998419384088,
#   "reg_lambda": 0.15377945243844393,
#   "reg_alpha": 0.00039948494310507507,
#   "gamma": 4.957370588589447
# }
#     [FOLD 1] AUPRC=0.403217 | AUROC=0.857076 | Acc=0.941933 | P=0.593732 | R=0.263906 | Spec=0.971580
#     [FOLD 2] AUPRC=0.382291 | AUROC=0.853078 | Acc=0.942077 | P=0.491599 | R=0.228298 | Spec=0.974279
#     [FOLD 3] AUPRC=0.409478 | AUROC=0.855688 | Acc=0.943742 | P=0.570136 | R=0.262591 | Spec=0.972037
#     [FOLD 4] AUPRC=0.417308 | AUROC=0.858539 | Acc=0.942133 | P=0.666784 | R=0.262709 | Spec=0.971405
#     [FOLD 5] AUPRC=0.410743 | AUROC=0.857119 | Acc=0.944352 | P=0.537009 | R=0.259973 | Spec=0.973650
#
# [TRIAL 24] score(AUPRC_macro)=0.404607 | AUROC=0.856300 | Acc=0.942847 | P=0.571852 | R=0.255495 | Spec=0.972590
# [I 2026-07-02 12:34:29,825] Trial 24 finished with value: 0.40460736440820744 and parameters: {'n_estimators': 1112, 'max_depth': 9, 'learning_rate': 0.04059124471938742, 'subsample': 0.9276750129329341, 'colsample_bytree': 0.8839451177308427, 'min_child_weight': 1.8130998419384088, 'reg_lambda': 0.15377945243844393, 'reg_alpha': 0.00039948494310507507, 'gamma': 4.957370588589447}. Best is trial 15 with value: 0.41095437583387096.
#
# ================================================================================
# [TRIAL 25] params:
# {
#   "objective": "binary:logistic",
#   "eval_metric": "logloss",
#   "tree_method": "hist",
#   "n_jobs": -1,
#   "random_state": 42,
#   "verbosity": 0,
#   "multi_strategy": "multi_output_tree",
#   "n_estimators": 1200,
#   "max_depth": 7,
#   "learning_rate": 0.024759398611140758,
#   "subsample": 0.9677495135207513,
#   "colsample_bytree": 0.863853115625784,
#   "min_child_weight": 0.5031787501116344,
#   "reg_lambda": 0.01815389860214243,
#   "reg_alpha": 5.892565404804815e-05,
#   "gamma": 4.410179756104592
# }
#     [FOLD 1] AUPRC=0.410143 | AUROC=0.864294 | Acc=0.942320 | P=0.585739 | R=0.269257 | Spec=0.971636
#     [FOLD 2] AUPRC=0.383283 | AUROC=0.867990 | Acc=0.941855 | P=0.468984 | R=0.231395 | Spec=0.974294
#     [FOLD 3] AUPRC=0.416453 | AUROC=0.858574 | Acc=0.944796 | P=0.650167 | R=0.268805 | Spec=0.972519
#     [FOLD 4] AUPRC=0.412579 | AUROC=0.860277 | Acc=0.941911 | P=0.586327 | R=0.258038 | Spec=0.971575
#     [FOLD 5] AUPRC=0.415520 | AUROC=0.858670 | Acc=0.943631 | P=0.541021 | R=0.267395 | Spec=0.972420
#
# [TRIAL 25] score(AUPRC_macro)=0.407596 | AUROC=0.861961 | Acc=0.942903 | P=0.566447 | R=0.258978 | Spec=0.972489
# [I 2026-07-02 12:42:46,187] Trial 25 finished with value: 0.4075955630069396 and parameters: {'n_estimators': 1200, 'max_depth': 7, 'learning_rate': 0.024759398611140758, 'subsample': 0.9677495135207513, 'colsample_bytree': 0.863853115625784, 'min_child_weight': 0.5031787501116344, 'reg_lambda': 0.01815389860214243, 'reg_alpha': 5.892565404804815e-05, 'gamma': 4.410179756104592}. Best is trial 15 with value: 0.41095437583387096.
#
# ================================================================================
# [TRIAL 26] params:
# {
#   "objective": "binary:logistic",
#   "eval_metric": "logloss",
#   "tree_method": "hist",
#   "n_jobs": -1,
#   "random_state": 42,
#   "verbosity": 0,
#   "multi_strategy": "multi_output_tree",
#   "n_estimators": 1058,
#   "max_depth": 9,
#   "learning_rate": 0.040263346813108496,
#   "subsample": 0.9156660835951828,
#   "colsample_bytree": 0.9461971370325296,
#   "min_child_weight": 1.2806554496505393,
#   "reg_lambda": 0.5387575360787606,
#   "reg_alpha": 0.07972720273482886,
#   "gamma": 3.1681450486571965
# }
#     [FOLD 1] AUPRC=0.402107 | AUROC=0.858860 | Acc=0.940991 | P=0.506294 | R=0.267149 | Spec=0.969983
#     [FOLD 2] AUPRC=0.375726 | AUROC=0.854620 | Acc=0.941023 | P=0.465048 | R=0.244969 | Spec=0.971891
#     [FOLD 3] AUPRC=0.409554 | AUROC=0.854593 | Acc=0.944352 | P=0.572939 | R=0.285391 | Spec=0.971196
#     [FOLD 4] AUPRC=0.412434 | AUROC=0.858411 | Acc=0.942410 | P=0.625205 | R=0.286181 | Spec=0.970300
#     [FOLD 5] AUPRC=0.408255 | AUROC=0.855425 | Acc=0.943464 | P=0.521829 | R=0.273383 | Spec=0.971663
#
# [TRIAL 26] score(AUPRC_macro)=0.401615 | AUROC=0.856382 | Acc=0.942448 | P=0.538263 | R=0.271415 | Spec=0.971007
# [I 2026-07-02 12:54:07,584] Trial 26 finished with value: 0.4016153637242284 and parameters: {'n_estimators': 1058, 'max_depth': 9, 'learning_rate': 0.040263346813108496, 'subsample': 0.9156660835951828, 'colsample_bytree': 0.9461971370325296, 'min_child_weight': 1.2806554496505393, 'reg_lambda': 0.5387575360787606, 'reg_alpha': 0.07972720273482886, 'gamma': 3.1681450486571965}. Best is trial 15 with value: 0.41095437583387096.
#
# ================================================================================
# [TRIAL 27] params:
# {
#   "objective": "binary:logistic",
#   "eval_metric": "logloss",
#   "tree_method": "hist",
#   "n_jobs": -1,
#   "random_state": 42,
#   "verbosity": 0,
#   "multi_strategy": "multi_output_tree",
#   "n_estimators": 786,
#   "max_depth": 4,
#   "learning_rate": 0.023653195911954056,
#   "subsample": 0.8610534224017057,
#   "colsample_bytree": 0.8441029571671419,
#   "min_child_weight": 0.745371201624288,
#   "reg_lambda": 0.011386426679751961,
#   "reg_alpha": 0.0031806169927131246,
#   "gamma": 4.612344248524354
# }
#     [FOLD 1] AUPRC=0.415816 | AUROC=0.869852 | Acc=0.942708 | P=0.669594 | R=0.226664 | Spec=0.974805
#     [FOLD 2] AUPRC=0.391900 | AUROC=0.873525 | Acc=0.942022 | P=0.562200 | R=0.199553 | Spec=0.978427
#     [FOLD 3] AUPRC=0.411848 | AUROC=0.856272 | Acc=0.944130 | P=0.662925 | R=0.218338 | Spec=0.976810
#     [FOLD 4] AUPRC=0.410017 | AUROC=0.858794 | Acc=0.940968 | P=0.674929 | R=0.212888 | Spec=0.973954
#     [FOLD 5] AUPRC=0.415368 | AUROC=0.860668 | Acc=0.943187 | P=0.589990 | R=0.212902 | Spec=0.975667
#
# [TRIAL 27] score(AUPRC_macro)=0.408990 | AUROC=0.863822 | Acc=0.942603 | P=0.631928 | R=0.214069 | Spec=0.975933
# [I 2026-07-02 12:57:59,496] Trial 27 finished with value: 0.4089897639657247 and parameters: {'n_estimators': 786, 'max_depth': 4, 'learning_rate': 0.023653195911954056, 'subsample': 0.8610534224017057, 'colsample_bytree': 0.8441029571671419, 'min_child_weight': 0.745371201624288, 'reg_lambda': 0.011386426679751961, 'reg_alpha': 0.0031806169927131246, 'gamma': 4.612344248524354}. Best is trial 15 with value: 0.41095437583387096.
#
# ================================================================================
# [TRIAL 28] params:
# {
#   "objective": "binary:logistic",
#   "eval_metric": "logloss",
#   "tree_method": "hist",
#   "n_jobs": -1,
#   "random_state": 42,
#   "verbosity": 0,
#   "multi_strategy": "multi_output_tree",
#   "n_estimators": 943,
#   "max_depth": 6,
#   "learning_rate": 0.010098667231474153,
#   "subsample": 0.9708876675717859,
#   "colsample_bytree": 0.7828436536165114,
#   "min_child_weight": 1.0315595354556064,
#   "reg_lambda": 0.0034444715065664626,
#   "reg_alpha": 0.013554636682826459,
#   "gamma": 3.856379029753902
# }
#     [FOLD 1] AUPRC=0.417263 | AUROC=0.866845 | Acc=0.942764 | P=0.678461 | R=0.242155 | Spec=0.974513
#     [FOLD 2] AUPRC=0.395184 | AUROC=0.870399 | Acc=0.942577 | P=0.608087 | R=0.204277 | Spec=0.978201
#     [FOLD 3] AUPRC=0.414917 | AUROC=0.858546 | Acc=0.944075 | P=0.674660 | R=0.227665 | Spec=0.975878
#     [FOLD 4] AUPRC=0.418841 | AUROC=0.857722 | Acc=0.941245 | P=0.705555 | R=0.226931 | Spec=0.973705
#     [FOLD 5] AUPRC=0.426106 | AUROC=0.859742 | Acc=0.944241 | P=0.574897 | R=0.224808 | Spec=0.975598
#
# [TRIAL 28] score(AUPRC_macro)=0.414462 | AUROC=0.862651 | Acc=0.942980 | P=0.648332 | R=0.225167 | Spec=0.975579
# [I 2026-07-02 13:05:37,242] Trial 28 finished with value: 0.41446214416569604 and parameters: {'n_estimators': 943, 'max_depth': 6, 'learning_rate': 0.010098667231474153, 'subsample': 0.9708876675717859, 'colsample_bytree': 0.7828436536165114, 'min_child_weight': 1.0315595354556064, 'reg_lambda': 0.0034444715065664626, 'reg_alpha': 0.013554636682826459, 'gamma': 3.856379029753902}. Best is trial 28 with value: 0.41446214416569604.
#
# ================================================================================
# [TRIAL 29] params:
# {
#   "objective": "binary:logistic",
#   "eval_metric": "logloss",
#   "tree_method": "hist",
#   "n_jobs": -1,
#   "random_state": 42,
#   "verbosity": 0,
#   "multi_strategy": "multi_output_tree",
#   "n_estimators": 970,
#   "max_depth": 6,
#   "learning_rate": 0.11447166407653211,
#   "subsample": 0.9650584750514755,
#   "colsample_bytree": 0.7795405086006133,
#   "min_child_weight": 0.748372620891733,
#   "reg_lambda": 0.002855934862560198,
#   "reg_alpha": 0.20217597156683653,
#   "gamma": 3.5245386667104324
# }
#     [FOLD 1] AUPRC=0.406957 | AUROC=0.866515 | Acc=0.941600 | P=0.541112 | R=0.262543 | Spec=0.971119
#     [FOLD 2] AUPRC=0.377966 | AUROC=0.863083 | Acc=0.941134 | P=0.503288 | R=0.229948 | Spec=0.973345
#     [FOLD 3] AUPRC=0.408343 | AUROC=0.857883 | Acc=0.944296 | P=0.552745 | R=0.265805 | Spec=0.971777
#     [FOLD 4] AUPRC=0.414013 | AUROC=0.857147 | Acc=0.942355 | P=0.632077 | R=0.268279 | Spec=0.971419
#     [FOLD 5] AUPRC=0.415022 | AUROC=0.857022 | Acc=0.943631 | P=0.572299 | R=0.267072 | Spec=0.972237
#
# [TRIAL 29] score(AUPRC_macro)=0.404460 | AUROC=0.860330 | Acc=0.942603 | P=0.560304 | R=0.258729 | Spec=0.971979
# [I 2026-07-02 13:08:44,330] Trial 29 finished with value: 0.40446036533976815 and parameters: {'n_estimators': 970, 'max_depth': 6, 'learning_rate': 0.11447166407653211, 'subsample': 0.9650584750514755, 'colsample_bytree': 0.7795405086006133, 'min_child_weight': 0.748372620891733, 'reg_lambda': 0.002855934862560198, 'reg_alpha': 0.20217597156683653, 'gamma': 3.5245386667104324}. Best is trial 28 with value: 0.41446214416569604.
#
# ================ BEST =================
# Best trial: 28
# Best AUPRC_macro: 0.41446214416569604
# Best params:
# {
#   "n_estimators": 943,
#   "max_depth": 6,
#   "learning_rate": 0.010098667231474153,
#   "subsample": 0.9708876675717859,
#   "colsample_bytree": 0.7828436536165114,
#   "min_child_weight": 1.0315595354556064,
#   "reg_lambda": 0.0034444715065664626,
#   "reg_alpha": 0.013554636682826459,
#   "gamma": 3.856379029753902
# }
# [SAVED] ./optuna_singlemodel_XGB_30trials_5fold_results.csv
# [SAVED] ./used_label_columns_24.csv
# [SAVED] ./used_feature_columns.csv
