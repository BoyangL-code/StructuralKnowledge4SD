# %%
# -*- coding: utf-8 -*-
import os
import re
import glob
import json
import numpy as np
import pandas as pd

import optuna
import xgboost as xgb
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import roc_auc_score, average_precision_score

# =========================
# 0) 配置
# =========================
RANDOM_SEED = 42
N_TRIALS = 30
N_SPLITS = 5
THRESH = 0.5

# 直接读取你已生成的特征文件（xlsx）
FEATURE_FILE_GLOB = "./Malodors_Rule&FG&Morgan_features.xlsx"
# 如果你的文件名不同，改成你的，例如：
# FEATURE_FILE_GLOB = "./Malodors_transformed_MORGAN_features.xlsx"

# 固定参数：Optuna 只搜索部分超参
BASE_XGB_PARAMS = dict(
    objective="binary:logistic",
    eval_metric="logloss",
    tree_method="hist",
    n_jobs=-1,
    random_state=RANDOM_SEED,
    verbosity=0,
    multi_strategy="multi_output_tree",
)


# =========================
# 1) XGBoost 版本检查
# =========================
def _ver_tuple(v: str):
    parts = re.split(r"[.+-]", v.strip())
    nums = []

    for p in parts[:3]:
        try:
            nums.append(int(p))
        except Exception:
            nums.append(0)

    while len(nums) < 3:
        nums.append(0)

    return tuple(nums)


def check_xgb_version():
    v = _ver_tuple(xgb.__version__)

    if v < (1, 6, 0):
        raise RuntimeError(
            f"xgboost=={xgb.__version__} 太旧：multi-label 需要 >=1.6"
        )

    if "multi_strategy" in BASE_XGB_PARAMS and v < (2, 0, 0):
        raise RuntimeError(
            f"xgboost=={xgb.__version__} 不支持 multi_output_tree，需要 >=2.0。\n"
            f"请升级 xgboost，或删除 BASE_XGB_PARAMS 中的 multi_strategy。"
        )


# =========================
# 2) 读取特征文件 & 按固定列位置划分 SMILES / y / X
# =========================
def find_feature_file(pattern: str):
    cands = sorted(glob.glob(pattern))

    if not cands:
        raise FileNotFoundError(
            f"找不到特征文件：{pattern}\n"
            f"请确认 xlsx 文件名，或修改 FEATURE_FILE_GLOB。"
        )

    return cands[-1]


def load_Xy_from_feature_file(xlsx_path: str):
    """
    固定数据格式：
    第 1 列：SMILES
    第 2-25 列：24 个 y 标签
    第 26 列及之后：X 特征列

    说明：
    - 不再通过 0/1 自动判断 y 标签列；
    - 避免 Morgan bit、Rule、FG、StructKG 等 0/1 或数值特征被误识别为标签；
    - 适用于当前 24 标签任务。
    """
    df = pd.read_excel(xlsx_path)

    if df.shape[1] < 26:
        raise ValueError(
            f"当前文件列数为 {df.shape[1]}，不足以按“1列SMILES + 24列标签 + 特征列”划分。"
        )

    # 固定列位置
    smiles_col = df.columns[0]
    label_cols = list(df.columns[1:25])
    feature_cols = list(df.columns[25:])

    if len(label_cols) != 24:
        raise ValueError(
            f"标签列数量应为 24，但当前识别为 {len(label_cols)}。"
        )

    if len(feature_cols) == 0:
        raise ValueError(
            "未识别到特征列。请确认第 26 列之后为 X 特征。"
        )

    # y 标签转为 0/1 整数
    y_df = df[label_cols].copy()
    y_df = y_df.apply(pd.to_numeric, errors="coerce").fillna(0).astype(int)

    # 检查 y 标签是否为 0/1
    invalid_label_cols = []
    for c in label_cols:
        vals = set(pd.unique(y_df[c].dropna()))
        if not vals.issubset({0, 1}):
            invalid_label_cols.append(c)

    if invalid_label_cols:
        raise ValueError(
            "以下标签列不是标准 0/1 标签，请检查数据：\n"
            + "\n".join(map(str, invalid_label_cols))
        )

    # X 特征转为数值
    X_df = df[feature_cols].copy()
    X_df = X_df.apply(pd.to_numeric, errors="coerce").fillna(0)

    X = X_df.astype(np.float32).values
    y = y_df.values.astype(int)

    if X.shape[0] != y.shape[0]:
        raise ValueError("X 和 y 行数不一致，请检查文件。")

    print("[INFO] Column split mode: fixed-position")
    print(f"[INFO] SMILES column: {smiles_col}")
    print(f"[INFO] Label columns: columns 2-25, n={len(label_cols)}")
    print(f"[INFO] Feature columns: columns 26-end, n={len(feature_cols)}")

    print("\n[INFO] Label columns:")
    for i, c in enumerate(label_cols, start=1):
        print(f"  y{i:02d}: {c}")

    return X, y, feature_cols, label_cols, df


# =========================
# 3) 指标：macro
# =========================
def multilabel_macro_metrics(y_true, y_prob, thresh=0.5):
    y_true = np.asarray(y_true).astype(int)
    y_prob = np.asarray(y_prob).astype(float)
    y_pred = (y_prob >= thresh).astype(int)

    L = y_true.shape[1]
    accs, precs, recs, specs = [], [], [], []
    aurocs, auprcs = [], []

    for k in range(L):
        yt = y_true[:, k]
        yp = y_pred[:, k]
        ys = y_prob[:, k]

        tp = int(np.sum((yt == 1) & (yp == 1)))
        tn = int(np.sum((yt == 0) & (yp == 0)))
        fp = int(np.sum((yt == 0) & (yp == 1)))
        fn = int(np.sum((yt == 1) & (yp == 0)))
        n = len(yt)

        accs.append((tp + tn) / n if n else np.nan)
        precs.append(tp / (tp + fp) if (tp + fp) else np.nan)
        recs.append(tp / (tp + fn) if (tp + fn) else np.nan)
        specs.append(tn / (tn + fp) if (tn + fp) else np.nan)

        if len(np.unique(yt)) == 2:
            aurocs.append(roc_auc_score(yt, ys))
            auprcs.append(average_precision_score(yt, ys))
        else:
            aurocs.append(np.nan)
            auprcs.append(np.nan)

    def nanmean(x):
        return float(np.nanmean(np.asarray(x, dtype=float)))

    return {
        "Accuracy_macro": nanmean(accs),
        "Precision_macro": nanmean(precs),
        "Recall_macro": nanmean(recs),
        "Specificity_macro": nanmean(specs),
        "AUROC_macro": nanmean(aurocs),
        "AUPRC_macro": nanmean(auprcs),
        "AUROC_valid_labels": int(np.sum(~np.isnan(aurocs))),
        "AUPRC_valid_labels": int(np.sum(~np.isnan(auprcs))),
        "n_labels": int(L),
    }


def extract_positive_proba(p, n_labels: int):
    """
    兼容 XGBoost 多标签输出：

    常见情况：
    - multi_output_tree 下 predict_proba 通常返回形状为 (n_samples, n_labels)
    - 某些版本或设置下可能返回 list 或 3D array
    """
    if isinstance(p, list):
        out = np.zeros((p[0].shape[0], n_labels), dtype=np.float32)

        for k in range(n_labels):
            pk = p[k]

            if pk.ndim != 2:
                raise ValueError(f"predict_proba[{k}] 形状异常: {pk.shape}")

            if pk.shape[1] == 2:
                out[:, k] = pk[:, 1].astype(np.float32)
            elif pk.shape[1] == 1:
                out[:, k] = pk[:, 0].astype(np.float32)
            else:
                raise ValueError(
                    f"predict_proba[{k}] 类别数异常: {pk.shape[1]}"
                )

        return out

    p = np.asarray(p)

    if p.ndim == 3 and p.shape[-1] == 2:
        return p[:, :, 1].astype(np.float32)

    if p.ndim == 2:
        if p.shape[1] == 2 and n_labels == 1:
            return p[:, 1:2].astype(np.float32)

        if p.shape[1] == n_labels:
            return p.astype(np.float32)

        raise ValueError(
            f"predict_proba 输出为二维，但列数 {p.shape[1]} 与标签数 {n_labels} 不一致。"
        )

    raise ValueError(f"无法解析 predict_proba 输出形状: {p.shape}")


# =========================
# 4) 近似分层 5 折：用 label cardinality 分层
# =========================
def make_stratify_target(y: np.ndarray, n_bins: int = 10):
    """
    多标签任务中没有直接的 StratifiedKFold。
    这里使用每个样本的标签数量 label cardinality 做近似分层。
    """
    card = y.sum(axis=1).astype(int)
    uniq = np.unique(card)

    if len(uniq) <= 15:
        return card

    r = pd.Series(card).rank(method="average").values
    bins = pd.qcut(
        r,
        q=min(n_bins, len(np.unique(r))),
        labels=False,
        duplicates="drop"
    )

    return np.asarray(bins, dtype=int)


def build_folds(X, y, n_splits=5, seed=42):
    strat_y = make_stratify_target(y)

    skf = StratifiedKFold(
        n_splits=n_splits,
        shuffle=True,
        random_state=seed
    )

    return list(skf.split(X, strat_y))


# =========================
# 5) 5 折 CV 评估
# =========================
def cv_eval_one_paramset(X, y, folds, params, thresh=0.5):
    n_labels = y.shape[1]
    fold_metrics = []

    for fold_id, (tr_idx, va_idx) in enumerate(folds, start=1):
        X_tr, X_va = X[tr_idx], X[va_idx]
        y_tr, y_va = y[tr_idx], y[va_idx]

        clf = xgb.XGBClassifier(**params)
        clf.fit(X_tr, y_tr)

        p = clf.predict_proba(X_va)
        y_prob = extract_positive_proba(p, n_labels=n_labels)

        m = multilabel_macro_metrics(y_va, y_prob, thresh=thresh)
        fold_metrics.append(m)

        print(
            f"    [FOLD {fold_id}] "
            f"AUPRC={m['AUPRC_macro']:.6f} | "
            f"AUROC={m['AUROC_macro']:.6f} | "
            f"Acc={m['Accuracy_macro']:.6f} | "
            f"P={m['Precision_macro']:.6f} | "
            f"R={m['Recall_macro']:.6f} | "
            f"Spec={m['Specificity_macro']:.6f}"
        )

    keys = list(fold_metrics[0].keys())
    mean_metrics = {}

    for k in keys:
        vals = [fm[k] for fm in fold_metrics]

        if isinstance(vals[0], float):
            mean_metrics[k] = float(np.nanmean(vals))
        else:
            mean_metrics[k] = vals[-1]

    return mean_metrics


# =========================
# 6) Optuna 超参空间
# =========================
def build_trial_params(trial: optuna.Trial):
    params = dict(BASE_XGB_PARAMS)

    params.update({
        "n_estimators": trial.suggest_int("n_estimators", 300, 1200),
        "max_depth": trial.suggest_int("max_depth", 3, 10),
        "learning_rate": trial.suggest_float("learning_rate", 0.01, 0.2, log=True),
        "subsample": trial.suggest_float("subsample", 0.6, 1.0),
        "colsample_bytree": trial.suggest_float("colsample_bytree", 0.6, 1.0),
        "min_child_weight": trial.suggest_float("min_child_weight", 0.5, 10.0, log=True),
        "reg_lambda": trial.suggest_float("reg_lambda", 1e-3, 20.0, log=True),
        "reg_alpha": trial.suggest_float("reg_alpha", 1e-8, 5.0, log=True),
        "gamma": trial.suggest_float("gamma", 0.0, 5.0),
    })

    return params


# =========================
# 7) 主流程：读特征 -> 固定 folds -> Optuna -> 输出保存
# =========================
def main():
    check_xgb_version()

    feature_file = find_feature_file(FEATURE_FILE_GLOB)
    print("[INFO] Using feature file:", feature_file)

    X, y, feat_cols, label_cols, df_all = load_Xy_from_feature_file(feature_file)

    print(
        f"\n[INFO] X shape={X.shape} "
        f"(features={len(feat_cols)}) | "
        f"y shape={y.shape} "
        f"(labels={len(label_cols)})"
    )

    folds = build_folds(X, y, n_splits=N_SPLITS, seed=RANDOM_SEED)
    print(f"[INFO] Prepared fixed {N_SPLITS}-fold splits for all trials.")

    def objective(trial: optuna.Trial):
        params = build_trial_params(trial)

        print("\n" + "=" * 80)
        print(f"[TRIAL {trial.number:02d}] params:")
        print(json.dumps(params, indent=2, ensure_ascii=False, default=str))

        mean_metrics = cv_eval_one_paramset(
            X,
            y,
            folds,
            params,
            thresh=THRESH
        )

        score = mean_metrics["AUPRC_macro"]

        print(
            f"\n[TRIAL {trial.number:02d}] "
            f"score(AUPRC_macro)={score:.6f} | "
            f"AUROC={mean_metrics['AUROC_macro']:.6f} | "
            f"Acc={mean_metrics['Accuracy_macro']:.6f} | "
            f"P={mean_metrics['Precision_macro']:.6f} | "
            f"R={mean_metrics['Recall_macro']:.6f} | "
            f"Spec={mean_metrics['Specificity_macro']:.6f}"
        )

        for k, v in mean_metrics.items():
            trial.set_user_attr(k, v)

        return score

    study = optuna.create_study(
        direction="maximize",
        sampler=optuna.samplers.TPESampler(seed=RANDOM_SEED),
    )

    study.optimize(
        objective,
        n_trials=N_TRIALS,
        show_progress_bar=True
    )

    print("\n================ BEST =================")
    print("Best trial:", study.best_trial.number)
    print("Best AUPRC_macro:", study.best_value)
    print("Best params:")
    print(json.dumps(study.best_params, indent=2, ensure_ascii=False))

    rows = []

    for t in study.trials:
        if t.value is None:
            continue

        row = {
            "trial": t.number,
            "AUPRC_macro": t.value,
            **t.params
        }

        row.update({
            k: v for k, v in t.user_attrs.items()
            if k.endswith("_macro")
        })

        rows.append(row)

    res_df = pd.DataFrame(rows).sort_values(
        "AUPRC_macro",
        ascending=False
    )

    out_csv = "./optuna_singlemodel_XGB_30trials_5fold_results.csv"
    res_df.to_csv(out_csv, index=False, encoding="utf-8-sig")
    print("[SAVED]", out_csv)

    # 额外保存标签列和特征列，便于后续核查
    label_out = "./used_label_columns_24.csv"
    feature_out = "./used_feature_columns.csv"

    pd.DataFrame({"label_col": label_cols}).to_csv(
        label_out,
        index=False,
        encoding="utf-8-sig"
    )

    pd.DataFrame({"feature_col": feat_cols}).to_csv(
        feature_out,
        index=False,
        encoding="utf-8-sig"
    )

    print("[SAVED]", label_out)
    print("[SAVED]", feature_out)


if __name__ == "__main__":
    main()
# Out:
# [INFO] Using feature file: ./Malodors_Rule&FG&Morgan_features.xlsx
# [I 2026-07-01 22:28:52,382] A new study created in memory with name: no-name-a9ff4f77-788b-4105-a2e5-3134588cfe69
# [INFO] Column split mode: fixed-position
# [INFO] SMILES column: Canonical_SMILES
# [INFO] Label columns: columns 2-25, n=24
# [INFO] Feature columns: columns 26-end, n=2427
#
# [INFO] Label columns:
#   y01: alcoholic
#   y02: aldehydic
#   y03: almond
#   y04: aromatic
#   y05: burnt
#   y06: cabbage
#   y07: cheesy
#   y08: cherry
#   y09: chocolate
#   y10: ethereal
#   y11: fishy
#   y12: fruity
#   y13: garlic
#   y14: grassy
#   y15: green
#   y16: ketonic
#   y17: musty
#   y18: pungent
#   y19: sharp
#   y20: solvent
#   y21: sour
#   y22: sulfurous
#   y23: sweaty
#   y24: sweet
#
# [INFO] X shape=(3756, 2427) (features=2427) | y shape=(3756, 24) (labels=24)
# [INFO] Prepared fixed 5-fold splits for all trials.
#   0%|          | 0/30 [00:00<?, ?it/s]
# ================================================================================
# [TRIAL 00] params:
# {
#   "objective": "binary:logistic",
#   "eval_metric": "logloss",
#   "tree_method": "hist",
#   "n_jobs": -1,
#   "random_state": 42,
#   "verbosity": 0,
#   "multi_strategy": "multi_output_tree",
#   "n_estimators": 637,
#   "max_depth": 10,
#   "learning_rate": 0.08960785365368121,
#   "subsample": 0.8394633936788146,
#   "colsample_bytree": 0.6624074561769746,
#   "min_child_weight": 0.7978542347074177,
#   "reg_lambda": 0.0017775399007348214,
#   "reg_alpha": 0.3426417745118369,
#   "gamma": 3.005575058716044
# }
#     [FOLD 1] AUPRC=0.429855 | AUROC=0.863597 | Acc=0.942875 | P=0.552234 | R=0.301222 | Spec=0.969899
#     [FOLD 2] AUPRC=0.401622 | AUROC=0.864694 | Acc=0.942077 | P=0.496094 | R=0.270360 | Spec=0.971827
#     [FOLD 3] AUPRC=0.422113 | AUROC=0.856336 | Acc=0.944629 | P=0.557389 | R=0.311461 | Spec=0.971569
#     [FOLD 4] AUPRC=0.433440 | AUROC=0.864949 | Acc=0.942299 | P=0.641713 | R=0.305918 | Spec=0.969414
#     [FOLD 5] AUPRC=0.431938 | AUROC=0.861436 | Acc=0.945184 | P=0.532584 | R=0.297959 | Spec=0.970849
#
# [TRIAL 00] score(AUPRC_macro)=0.423794 | AUROC=0.862202 | Acc=0.943413 | P=0.556003 | R=0.297384 | Spec=0.970711
# [I 2026-07-01 22:35:00,326] Trial 0 finished with value: 0.42379371572294033 and parameters: {'n_estimators': 637, 'max_depth': 10, 'learning_rate': 0.08960785365368121, 'subsample': 0.8394633936788146, 'colsample_bytree': 0.6624074561769746, 'min_child_weight': 0.7978542347074177, 'reg_lambda': 0.0017775399007348214, 'reg_alpha': 0.3426417745118369, 'gamma': 3.005575058716044}. Best is trial 0 with value: 0.42379371572294033.
#
# ================================================================================
# [TRIAL 01] params:
# {
#   "objective": "binary:logistic",
#   "eval_metric": "logloss",
#   "tree_method": "hist",
#   "n_jobs": -1,
#   "random_state": 42,
#   "verbosity": 0,
#   "multi_strategy": "multi_output_tree",
#   "n_estimators": 937,
#   "max_depth": 3,
#   "learning_rate": 0.18276027831785724,
#   "subsample": 0.9329770563201687,
#   "colsample_bytree": 0.6849356442713105,
#   "min_child_weight": 0.8620446097910766,
#   "reg_lambda": 0.006149337057087106,
#   "reg_alpha": 4.4319427891510175e-06,
#   "gamma": 2.6237821581611893
# }
#     [FOLD 1] AUPRC=0.415398 | AUROC=0.862342 | Acc=0.941379 | P=0.521559 | R=0.299490 | Spec=0.967937
#     [FOLD 2] AUPRC=0.388850 | AUROC=0.858112 | Acc=0.941079 | P=0.460609 | R=0.265367 | Spec=0.971510
#     [FOLD 3] AUPRC=0.409725 | AUROC=0.850243 | Acc=0.944851 | P=0.526649 | R=0.309711 | Spec=0.970897
#     [FOLD 4] AUPRC=0.415001 | AUROC=0.854303 | Acc=0.940413 | P=0.577370 | R=0.287112 | Spec=0.967700
#     [FOLD 5] AUPRC=0.406606 | AUROC=0.855715 | Acc=0.942466 | P=0.500373 | R=0.281321 | Spec=0.969074
#
# [TRIAL 01] score(AUPRC_macro)=0.407116 | AUROC=0.856143 | Acc=0.942037 | P=0.517312 | R=0.288600 | Spec=0.969424
# [I 2026-07-01 22:37:48,666] Trial 1 finished with value: 0.40711609361754597 and parameters: {'n_estimators': 937, 'max_depth': 3, 'learning_rate': 0.18276027831785724, 'subsample': 0.9329770563201687, 'colsample_bytree': 0.6849356442713105, 'min_child_weight': 0.8620446097910766, 'reg_lambda': 0.006149337057087106, 'reg_alpha': 4.4319427891510175e-06, 'gamma': 2.6237821581611893}. Best is trial 0 with value: 0.42379371572294033.
#
# ================================================================================
# [TRIAL 02] params:
# {
#   "objective": "binary:logistic",
#   "eval_metric": "logloss",
#   "tree_method": "hist",
#   "n_jobs": -1,
#   "random_state": 42,
#   "verbosity": 0,
#   "multi_strategy": "multi_output_tree",
#   "n_estimators": 689,
#   "max_depth": 5,
#   "learning_rate": 0.06252287916406217,
#   "subsample": 0.6557975442608167,
#   "colsample_bytree": 0.7168578594140873,
#   "min_child_weight": 1.498365454855079,
#   "reg_lambda": 0.09153152164233955,
#   "reg_alpha": 0.06764288719681069,
#   "gamma": 0.9983689107917987
# }
#     [FOLD 1] AUPRC=0.409186 | AUROC=0.855886 | Acc=0.942930 | P=0.569316 | R=0.273135 | Spec=0.969423
#     [FOLD 2] AUPRC=0.410511 | AUROC=0.860345 | Acc=0.942965 | P=0.544975 | R=0.250784 | Spec=0.973821
#     [FOLD 3] AUPRC=0.413727 | AUROC=0.853167 | Acc=0.945517 | P=0.558033 | R=0.305529 | Spec=0.971700
#     [FOLD 4] AUPRC=0.429514 | AUROC=0.860036 | Acc=0.941190 | P=0.645633 | R=0.273288 | Spec=0.969030
#     [FOLD 5] AUPRC=0.412165 | AUROC=0.859707 | Acc=0.944075 | P=0.527187 | R=0.271796 | Spec=0.970703
#
# [TRIAL 02] score(AUPRC_macro)=0.415020 | AUROC=0.857828 | Acc=0.943335 | P=0.569029 | R=0.274906 | Spec=0.970935
# [I 2026-07-01 22:43:03,196] Trial 2 finished with value: 0.41502039609011926 and parameters: {'n_estimators': 689, 'max_depth': 5, 'learning_rate': 0.06252287916406217, 'subsample': 0.6557975442608167, 'colsample_bytree': 0.7168578594140873, 'min_child_weight': 1.498365454855079, 'reg_lambda': 0.09153152164233955, 'reg_alpha': 0.06764288719681069, 'gamma': 0.9983689107917987}. Best is trial 0 with value: 0.42379371572294033.
#
# ================================================================================
# [TRIAL 03] params:
# {
#   "objective": "binary:logistic",
#   "eval_metric": "logloss",
#   "tree_method": "hist",
#   "n_jobs": -1,
#   "random_state": 42,
#   "verbosity": 0,
#   "multi_strategy": "multi_output_tree",
#   "n_estimators": 763,
#   "max_depth": 7,
#   "learning_rate": 0.011492999300221412,
#   "subsample": 0.8430179407605753,
#   "colsample_bytree": 0.6682096494749166,
#   "min_child_weight": 0.6075808513336687,
#   "reg_lambda": 12.055498078944888,
#   "reg_alpha": 2.5119100929409792,
#   "gamma": 4.041986740582305
# }
#     [FOLD 1] AUPRC=0.396223 | AUROC=0.864709 | Acc=0.941323 | P=0.793033 | R=0.135506 | Spec=0.978299
#     [FOLD 2] AUPRC=0.408309 | AUROC=0.868629 | Acc=0.940135 | P=0.665166 | R=0.140000 | Spec=0.979590
#     [FOLD 3] AUPRC=0.400752 | AUROC=0.851598 | Acc=0.943409 | P=0.816604 | R=0.156160 | Spec=0.980778
#     [FOLD 4] AUPRC=0.399532 | AUROC=0.854565 | Acc=0.939137 | P=0.800704 | R=0.138122 | Spec=0.978000
#     [FOLD 5] AUPRC=0.394964 | AUROC=0.843528 | Acc=0.941023 | P=0.778381 | R=0.138313 | Spec=0.977430
#
# [TRIAL 03] score(AUPRC_macro)=0.399956 | AUROC=0.856606 | Acc=0.941005 | P=0.770777 | R=0.141620 | Spec=0.978820
# [I 2026-07-01 22:49:36,522] Trial 3 finished with value: 0.3999563219754207 and parameters: {'n_estimators': 763, 'max_depth': 7, 'learning_rate': 0.011492999300221412, 'subsample': 0.8430179407605753, 'colsample_bytree': 0.6682096494749166, 'min_child_weight': 0.6075808513336687, 'reg_lambda': 12.055498078944888, 'reg_alpha': 2.5119100929409792, 'gamma': 4.041986740582305}. Best is trial 0 with value: 0.42379371572294033.
#
# ================================================================================
# [TRIAL 04] params:
# {
#   "objective": "binary:logistic",
#   "eval_metric": "logloss",
#   "tree_method": "hist",
#   "n_jobs": -1,
#   "random_state": 42,
#   "verbosity": 0,
#   "multi_strategy": "multi_output_tree",
#   "n_estimators": 574,
#   "max_depth": 3,
#   "learning_rate": 0.07766184280392888,
#   "subsample": 0.7760609974958406,
#   "colsample_bytree": 0.6488152939379115,
#   "min_child_weight": 2.2039920190846214,
#   "reg_lambda": 0.001405743424794793,
#   "reg_alpha": 0.8131129951713353,
#   "gamma": 1.2938999080000846
# }
#     [FOLD 1] AUPRC=0.408773 | AUROC=0.870992 | Acc=0.943373 | P=0.709898 | R=0.234215 | Spec=0.973321
#     [FOLD 2] AUPRC=0.413236 | AUROC=0.870795 | Acc=0.943076 | P=0.613149 | R=0.207503 | Spec=0.977066
#     [FOLD 3] AUPRC=0.427445 | AUROC=0.861669 | Acc=0.946904 | P=0.634184 | R=0.254908 | Spec=0.976630
#     [FOLD 4] AUPRC=0.435854 | AUROC=0.860685 | Acc=0.942133 | P=0.734229 | R=0.224422 | Spec=0.974582
#     [FOLD 5] AUPRC=0.425379 | AUROC=0.862224 | Acc=0.944241 | P=0.580304 | R=0.224656 | Spec=0.973128
#
# [TRIAL 04] score(AUPRC_macro)=0.422137 | AUROC=0.865273 | Acc=0.943945 | P=0.654353 | R=0.229141 | Spec=0.974946
# [I 2026-07-01 22:51:47,529] Trial 4 finished with value: 0.422137339580661 and parameters: {'n_estimators': 574, 'max_depth': 3, 'learning_rate': 0.07766184280392888, 'subsample': 0.7760609974958406, 'colsample_bytree': 0.6488152939379115, 'min_child_weight': 2.2039920190846214, 'reg_lambda': 0.001405743424794793, 'reg_alpha': 0.8131129951713353, 'gamma': 1.2938999080000846}. Best is trial 0 with value: 0.42379371572294033.
#
# ================================================================================
# [TRIAL 05] params:
# {
#   "objective": "binary:logistic",
#   "eval_metric": "logloss",
#   "tree_method": "hist",
#   "n_jobs": -1,
#   "random_state": 42,
#   "verbosity": 0,
#   "multi_strategy": "multi_output_tree",
#   "n_estimators": 896,
#   "max_depth": 5,
#   "learning_rate": 0.04749239763680407,
#   "subsample": 0.8186841117373118,
#   "colsample_bytree": 0.6739417822102108,
#   "min_child_weight": 9.129115219600122,
#   "reg_lambda": 2.1570962503558295,
#   "reg_alpha": 1.4882404753442915,
#   "gamma": 4.474136752138244
# }
#     [FOLD 1] AUPRC=0.393758 | AUROC=0.863773 | Acc=0.942542 | P=0.744923 | R=0.202535 | Spec=0.975315
#     [FOLD 2] AUPRC=0.407032 | AUROC=0.869172 | Acc=0.941633 | P=0.613615 | R=0.175851 | Spec=0.977328
#     [FOLD 3] AUPRC=0.406867 | AUROC=0.851993 | Acc=0.944463 | P=0.685737 | R=0.189143 | Spec=0.977841
#     [FOLD 4] AUPRC=0.402469 | AUROC=0.856489 | Acc=0.940968 | P=0.709172 | R=0.193509 | Spec=0.974904
#     [FOLD 5] AUPRC=0.406154 | AUROC=0.853700 | Acc=0.943797 | P=0.706333 | R=0.199974 | Spec=0.975888
#
# [TRIAL 05] score(AUPRC_macro)=0.403256 | AUROC=0.859025 | Acc=0.942681 | P=0.691956 | R=0.192202 | Spec=0.976255
# [I 2026-07-01 22:56:05,388] Trial 5 finished with value: 0.4032558348744043 and parameters: {'n_estimators': 896, 'max_depth': 5, 'learning_rate': 0.04749239763680407, 'subsample': 0.8186841117373118, 'colsample_bytree': 0.6739417822102108, 'min_child_weight': 9.129115219600122, 'reg_lambda': 2.1570962503558295, 'reg_alpha': 1.4882404753442915, 'gamma': 4.474136752138244}. Best is trial 0 with value: 0.42379371572294033.
#
# ================================================================================
# [TRIAL 06] params:
# {
#   "objective": "binary:logistic",
#   "eval_metric": "logloss",
#   "tree_method": "hist",
#   "n_jobs": -1,
#   "random_state": 42,
#   "verbosity": 0,
#   "multi_strategy": "multi_output_tree",
#   "n_estimators": 838,
#   "max_depth": 10,
#   "learning_rate": 0.01303561122512888,
#   "subsample": 0.6783931449676581,
#   "colsample_bytree": 0.6180909155642152,
#   "min_child_weight": 1.3250568853729487,
#   "reg_lambda": 0.0469583341176048,
#   "reg_alpha": 2.293280024184598e-06,
#   "gamma": 4.143687545759647
# }
#     [FOLD 1] AUPRC=0.425190 | AUROC=0.866996 | Acc=0.943484 | P=0.604415 | R=0.258400 | Spec=0.972495
#     [FOLD 2] AUPRC=0.422639 | AUROC=0.870853 | Acc=0.943575 | P=0.540269 | R=0.234038 | Spec=0.975655
#     [FOLD 3] AUPRC=0.433422 | AUROC=0.861585 | Acc=0.945295 | P=0.537210 | R=0.276834 | Spec=0.973529
#     [FOLD 4] AUPRC=0.448196 | AUROC=0.867876 | Acc=0.943853 | P=0.723059 | R=0.275672 | Spec=0.971828
#     [FOLD 5] AUPRC=0.432794 | AUROC=0.860217 | Acc=0.946405 | P=0.555415 | R=0.267898 | Spec=0.973811
#
# [TRIAL 06] score(AUPRC_macro)=0.432448 | AUROC=0.865505 | Acc=0.944522 | P=0.592074 | R=0.262568 | Spec=0.973464
# [I 2026-07-01 23:13:31,459] Trial 6 finished with value: 0.4324482267282993 and parameters: {'n_estimators': 838, 'max_depth': 10, 'learning_rate': 0.01303561122512888, 'subsample': 0.6783931449676581, 'colsample_bytree': 0.6180909155642152, 'min_child_weight': 1.3250568853729487, 'reg_lambda': 0.0469583341176048, 'reg_alpha': 2.293280024184598e-06, 'gamma': 4.143687545759647}. Best is trial 6 with value: 0.4324482267282993.
#
# ================================================================================
# [TRIAL 07] params:
# {
#   "objective": "binary:logistic",
#   "eval_metric": "logloss",
#   "tree_method": "hist",
#   "n_jobs": -1,
#   "random_state": 42,
#   "verbosity": 0,
#   "multi_strategy": "multi_output_tree",
#   "n_estimators": 621,
#   "max_depth": 5,
#   "learning_rate": 0.05082341959721458,
#   "subsample": 0.6563696899899051,
#   "colsample_bytree": 0.9208787923016158,
#   "min_child_weight": 0.6251188975400557,
#   "reg_lambda": 17.564278579581362,
#   "reg_alpha": 0.05220764268782494,
#   "gamma": 0.993578407670862
# }
#     [FOLD 1] AUPRC=0.413033 | AUROC=0.875383 | Acc=0.944094 | P=0.727172 | R=0.219185 | Spec=0.974405
#     [FOLD 2] AUPRC=0.421576 | AUROC=0.877926 | Acc=0.942798 | P=0.641438 | R=0.202587 | Spec=0.976193
#     [FOLD 3] AUPRC=0.427732 | AUROC=0.865913 | Acc=0.946460 | P=0.718168 | R=0.230335 | Spec=0.976547
#     [FOLD 4] AUPRC=0.429770 | AUROC=0.866210 | Acc=0.942743 | P=0.764413 | R=0.223174 | Spec=0.974175
#     [FOLD 5] AUPRC=0.425470 | AUROC=0.864883 | Acc=0.945073 | P=0.697100 | R=0.218795 | Spec=0.974874
#
# [TRIAL 07] score(AUPRC_macro)=0.423516 | AUROC=0.870063 | Acc=0.944234 | P=0.709658 | R=0.218815 | Spec=0.975239
# [I 2026-07-01 23:18:16,663] Trial 7 finished with value: 0.4235161794709197 and parameters: {'n_estimators': 621, 'max_depth': 5, 'learning_rate': 0.05082341959721458, 'subsample': 0.6563696899899051, 'colsample_bytree': 0.9208787923016158, 'min_child_weight': 0.6251188975400557, 'reg_lambda': 17.564278579581362, 'reg_alpha': 0.05220764268782494, 'gamma': 0.993578407670862}. Best is trial 6 with value: 0.4324482267282993.
#
# ================================================================================
# [TRIAL 08] params:
# {
#   "objective": "binary:logistic",
#   "eval_metric": "logloss",
#   "tree_method": "hist",
#   "n_jobs": -1,
#   "random_state": 42,
#   "verbosity": 0,
#   "multi_strategy": "multi_output_tree",
#   "n_estimators": 304,
#   "max_depth": 9,
#   "learning_rate": 0.08310795711416077,
#   "subsample": 0.8916028672163949,
#   "colsample_bytree": 0.9085081386743783,
#   "min_child_weight": 0.6241720498669826,
#   "reg_lambda": 0.034815437009482725,
#   "reg_alpha": 1.0184541290289273e-07,
#   "gamma": 4.315517129377968
# }
#     [FOLD 1] AUPRC=0.428771 | AUROC=0.868151 | Acc=0.942154 | P=0.507395 | R=0.298314 | Spec=0.968642
#     [FOLD 2] AUPRC=0.397337 | AUROC=0.866226 | Acc=0.942188 | P=0.495208 | R=0.265977 | Spec=0.971887
#     [FOLD 3] AUPRC=0.428662 | AUROC=0.860672 | Acc=0.944851 | P=0.542846 | R=0.317938 | Spec=0.970595
#     [FOLD 4] AUPRC=0.424136 | AUROC=0.865064 | Acc=0.941744 | P=0.614373 | R=0.292331 | Spec=0.969020
#     [FOLD 5] AUPRC=0.428139 | AUROC=0.857664 | Acc=0.943464 | P=0.525671 | R=0.307511 | Spec=0.969381
#
# [TRIAL 08] score(AUPRC_macro)=0.421409 | AUROC=0.863555 | Acc=0.942880 | P=0.537099 | R=0.296414 | Spec=0.969905
# [I 2026-07-01 23:21:53,891] Trial 8 finished with value: 0.4214089259856225 and parameters: {'n_estimators': 304, 'max_depth': 9, 'learning_rate': 0.08310795711416077, 'subsample': 0.8916028672163949, 'colsample_bytree': 0.9085081386743783, 'min_child_weight': 0.6241720498669826, 'reg_lambda': 0.034815437009482725, 'reg_alpha': 1.0184541290289273e-07, 'gamma': 4.315517129377968}. Best is trial 6 with value: 0.4324482267282993.
#
# ================================================================================
# [TRIAL 09] params:
# {
#   "objective": "binary:logistic",
#   "eval_metric": "logloss",
#   "tree_method": "hist",
#   "n_jobs": -1,
#   "random_state": 42,
#   "verbosity": 0,
#   "multi_strategy": "multi_output_tree",
#   "n_estimators": 861,
#   "max_depth": 5,
#   "learning_rate": 0.012097379927033842,
#   "subsample": 0.7243929286862649,
#   "colsample_bytree": 0.7300733288106989,
#   "min_child_weight": 4.448458336296337,
#   "reg_lambda": 0.5522729957780633,
#   "reg_alpha": 0.5222002015831414,
#   "gamma": 2.3610746258097466
# }
#     [FOLD 1] AUPRC=0.409421 | AUROC=0.870020 | Acc=0.943927 | P=0.733662 | R=0.212931 | Spec=0.975894
#     [FOLD 2] AUPRC=0.413210 | AUROC=0.871685 | Acc=0.942022 | P=0.570841 | R=0.183558 | Spec=0.977859
#     [FOLD 3] AUPRC=0.411331 | AUROC=0.854035 | Acc=0.945240 | P=0.755758 | R=0.204719 | Spec=0.979341
#     [FOLD 4] AUPRC=0.412805 | AUROC=0.861478 | Acc=0.941911 | P=0.729661 | R=0.204494 | Spec=0.976025
#     [FOLD 5] AUPRC=0.409778 | AUROC=0.858066 | Acc=0.944907 | P=0.781590 | R=0.212714 | Spec=0.976894
#
# [TRIAL 09] score(AUPRC_macro)=0.411309 | AUROC=0.863057 | Acc=0.943601 | P=0.714302 | R=0.203683 | Spec=0.977203
# [I 2026-07-01 23:28:23,722] Trial 9 finished with value: 0.4113091569941479 and parameters: {'n_estimators': 861, 'max_depth': 5, 'learning_rate': 0.012097379927033842, 'subsample': 0.7243929286862649, 'colsample_bytree': 0.7300733288106989, 'min_child_weight': 4.448458336296337, 'reg_lambda': 0.5522729957780633, 'reg_alpha': 0.5222002015831414, 'gamma': 2.3610746258097466}. Best is trial 6 with value: 0.4324482267282993.
#
# ================================================================================
# [TRIAL 10] params:
# {
#   "objective": "binary:logistic",
#   "eval_metric": "logloss",
#   "tree_method": "hist",
#   "n_jobs": -1,
#   "random_state": 42,
#   "verbosity": 0,
#   "multi_strategy": "multi_output_tree",
#   "n_estimators": 1159,
#   "max_depth": 8,
#   "learning_rate": 0.02120936045478828,
#   "subsample": 0.6071847502459279,
#   "colsample_bytree": 0.8262452362725613,
#   "min_child_weight": 1.4778843806130162,
#   "reg_lambda": 0.014168088907480319,
#   "reg_alpha": 2.5937967187312596e-05,
#   "gamma": 3.3446220352955045
# }
#     [FOLD 1] AUPRC=0.416899 | AUROC=0.862460 | Acc=0.943041 | P=0.572866 | R=0.271963 | Spec=0.970893
#     [FOLD 2] AUPRC=0.400517 | AUROC=0.862844 | Acc=0.943020 | P=0.509420 | R=0.252961 | Spec=0.973208
#     [FOLD 3] AUPRC=0.420109 | AUROC=0.854448 | Acc=0.945240 | P=0.539843 | R=0.293443 | Spec=0.971554
#     [FOLD 4] AUPRC=0.431428 | AUROC=0.861036 | Acc=0.942133 | P=0.679832 | R=0.280331 | Spec=0.969216
#     [FOLD 5] AUPRC=0.421557 | AUROC=0.854086 | Acc=0.943520 | P=0.479067 | R=0.264048 | Spec=0.970473
#
# [TRIAL 10] score(AUPRC_macro)=0.418102 | AUROC=0.858974 | Acc=0.943391 | P=0.556206 | R=0.272549 | Spec=0.971069
# [I 2026-07-01 23:43:01,103] Trial 10 finished with value: 0.4181022199405103 and parameters: {'n_estimators': 1159, 'max_depth': 8, 'learning_rate': 0.02120936045478828, 'subsample': 0.6071847502459279, 'colsample_bytree': 0.8262452362725613, 'min_child_weight': 1.4778843806130162, 'reg_lambda': 0.014168088907480319, 'reg_alpha': 2.5937967187312596e-05, 'gamma': 3.3446220352955045}. Best is trial 6 with value: 0.4324482267282993.
#
# ================================================================================
# [TRIAL 11] params:
# {
#   "objective": "binary:logistic",
#   "eval_metric": "logloss",
#   "tree_method": "hist",
#   "n_jobs": -1,
#   "random_state": 42,
#   "verbosity": 0,
#   "multi_strategy": "multi_output_tree",
#   "n_estimators": 465,
#   "max_depth": 10,
#   "learning_rate": 0.13540080806350732,
#   "subsample": 0.7427309202896064,
#   "colsample_bytree": 0.6125516819803675,
#   "min_child_weight": 1.1896099689267106,
#   "reg_lambda": 0.0015401228201441667,
#   "reg_alpha": 0.0009706016345215861,
#   "gamma": 4.990699946844692
# }
#     [FOLD 1] AUPRC=0.412863 | AUROC=0.854501 | Acc=0.941268 | P=0.480766 | R=0.307377 | Spec=0.966684
#     [FOLD 2] AUPRC=0.382761 | AUROC=0.849335 | Acc=0.941245 | P=0.492833 | R=0.273517 | Spec=0.970767
#     [FOLD 3] AUPRC=0.410275 | AUROC=0.851957 | Acc=0.943964 | P=0.539917 | R=0.337042 | Spec=0.969342
#     [FOLD 4] AUPRC=0.418312 | AUROC=0.860586 | Acc=0.940690 | P=0.579777 | R=0.300338 | Spec=0.967242
#     [FOLD 5] AUPRC=0.407923 | AUROC=0.850108 | Acc=0.942299 | P=0.517692 | R=0.320709 | Spec=0.967403
#
# [TRIAL 11] score(AUPRC_macro)=0.406427 | AUROC=0.853297 | Acc=0.941893 | P=0.522197 | R=0.307797 | Spec=0.968288
# [I 2026-07-01 23:48:09,846] Trial 11 finished with value: 0.40642690676549603 and parameters: {'n_estimators': 465, 'max_depth': 10, 'learning_rate': 0.13540080806350732, 'subsample': 0.7427309202896064, 'colsample_bytree': 0.6125516819803675, 'min_child_weight': 1.1896099689267106, 'reg_lambda': 0.0015401228201441667, 'reg_alpha': 0.0009706016345215861, 'gamma': 4.990699946844692}. Best is trial 6 with value: 0.4324482267282993.
#
# ================================================================================
# [TRIAL 12] params:
# {
#   "objective": "binary:logistic",
#   "eval_metric": "logloss",
#   "tree_method": "hist",
#   "n_jobs": -1,
#   "random_state": 42,
#   "verbosity": 0,
#   "multi_strategy": "multi_output_tree",
#   "n_estimators": 1071,
#   "max_depth": 10,
#   "learning_rate": 0.024721037896855882,
#   "subsample": 0.9982632308542216,
#   "colsample_bytree": 0.7874820875551369,
#   "min_child_weight": 2.87818963294604,
#   "reg_lambda": 0.2692775441651686,
#   "reg_alpha": 1.959578228249567e-08,
#   "gamma": 3.2805819929043145
# }
#     [FOLD 1] AUPRC=0.421508 | AUROC=0.863767 | Acc=0.944758 | P=0.658647 | R=0.259189 | Spec=0.973490
#     [FOLD 2] AUPRC=0.417539 | AUROC=0.868760 | Acc=0.942466 | P=0.578440 | R=0.235306 | Spec=0.974478
#     [FOLD 3] AUPRC=0.426550 | AUROC=0.862185 | Acc=0.945739 | P=0.550254 | R=0.287286 | Spec=0.973128
#     [FOLD 4] AUPRC=0.447085 | AUROC=0.868863 | Acc=0.943409 | P=0.653889 | R=0.269475 | Spec=0.971554
#     [FOLD 5] AUPRC=0.431914 | AUROC=0.864349 | Acc=0.945406 | P=0.530458 | R=0.260736 | Spec=0.972777
#
# [TRIAL 12] score(AUPRC_macro)=0.428919 | AUROC=0.865585 | Acc=0.944356 | P=0.594338 | R=0.262398 | Spec=0.973085
# [I 2026-07-02 00:00:05,985] Trial 12 finished with value: 0.42891926483997855 and parameters: {'n_estimators': 1071, 'max_depth': 10, 'learning_rate': 0.024721037896855882, 'subsample': 0.9982632308542216, 'colsample_bytree': 0.7874820875551369, 'min_child_weight': 2.87818963294604, 'reg_lambda': 0.2692775441651686, 'reg_alpha': 1.959578228249567e-08, 'gamma': 3.2805819929043145}. Best is trial 6 with value: 0.4324482267282993.
#
# ================================================================================
# [TRIAL 13] params:
# {
#   "objective": "binary:logistic",
#   "eval_metric": "logloss",
#   "tree_method": "hist",
#   "n_jobs": -1,
#   "random_state": 42,
#   "verbosity": 0,
#   "multi_strategy": "multi_output_tree",
#   "n_estimators": 1107,
#   "max_depth": 9,
#   "learning_rate": 0.025255352033400326,
#   "subsample": 0.9997449754566206,
#   "colsample_bytree": 0.8064121721048421,
#   "min_child_weight": 3.3676775723125956,
#   "reg_lambda": 0.3037795470626853,
#   "reg_alpha": 3.932599823454418e-08,
#   "gamma": 3.559376126428361
# }
#     [FOLD 1] AUPRC=0.426348 | AUROC=0.866832 | Acc=0.944204 | P=0.592710 | R=0.247037 | Spec=0.973351
#     [FOLD 2] AUPRC=0.416015 | AUROC=0.869676 | Acc=0.943187 | P=0.624111 | R=0.225088 | Spec=0.975367
#     [FOLD 3] AUPRC=0.422735 | AUROC=0.860602 | Acc=0.945684 | P=0.522429 | R=0.268339 | Spec=0.974111
#     [FOLD 4] AUPRC=0.443374 | AUROC=0.868373 | Acc=0.943298 | P=0.683829 | R=0.251692 | Spec=0.973185
#     [FOLD 5] AUPRC=0.426753 | AUROC=0.861776 | Acc=0.944740 | P=0.510189 | R=0.257452 | Spec=0.972883
#
# [TRIAL 13] score(AUPRC_macro)=0.427045 | AUROC=0.865452 | Acc=0.944223 | P=0.586653 | R=0.249922 | Spec=0.973780
# [I 2026-07-02 00:09:31,132] Trial 13 finished with value: 0.4270448326084974 and parameters: {'n_estimators': 1107, 'max_depth': 9, 'learning_rate': 0.025255352033400326, 'subsample': 0.9997449754566206, 'colsample_bytree': 0.8064121721048421, 'min_child_weight': 3.3676775723125956, 'reg_lambda': 0.3037795470626853, 'reg_alpha': 3.932599823454418e-08, 'gamma': 3.559376126428361}. Best is trial 6 with value: 0.4324482267282993.
#
# ================================================================================
# [TRIAL 14] params:
# {
#   "objective": "binary:logistic",
#   "eval_metric": "logloss",
#   "tree_method": "hist",
#   "n_jobs": -1,
#   "random_state": 42,
#   "verbosity": 0,
#   "multi_strategy": "multi_output_tree",
#   "n_estimators": 1030,
#   "max_depth": 8,
#   "learning_rate": 0.026248363486644114,
#   "subsample": 0.9984067957444854,
#   "colsample_bytree": 0.9988320624630888,
#   "min_child_weight": 2.5385600992984467,
#   "reg_lambda": 0.9623699958951423,
#   "reg_alpha": 7.441340095247838e-07,
#   "gamma": 1.894250232357759
# }
#     [FOLD 1] AUPRC=0.419638 | AUROC=0.860305 | Acc=0.943872 | P=0.538890 | R=0.267857 | Spec=0.972008
#     [FOLD 2] AUPRC=0.419315 | AUROC=0.868137 | Acc=0.942798 | P=0.548569 | R=0.241652 | Spec=0.973472
#     [FOLD 3] AUPRC=0.426537 | AUROC=0.860437 | Acc=0.945628 | P=0.535717 | R=0.289226 | Spec=0.972136
#     [FOLD 4] AUPRC=0.436382 | AUROC=0.865196 | Acc=0.943631 | P=0.671124 | R=0.271221 | Spec=0.970829
#     [FOLD 5] AUPRC=0.423672 | AUROC=0.863850 | Acc=0.944518 | P=0.506192 | R=0.269485 | Spec=0.971668
#
# [TRIAL 14] score(AUPRC_macro)=0.425109 | AUROC=0.863585 | Acc=0.944090 | P=0.560098 | R=0.267888 | Spec=0.972023
# [I 2026-07-02 00:22:22,865] Trial 14 finished with value: 0.42510875702388634 and parameters: {'n_estimators': 1030, 'max_depth': 8, 'learning_rate': 0.026248363486644114, 'subsample': 0.9984067957444854, 'colsample_bytree': 0.9988320624630888, 'min_child_weight': 2.5385600992984467, 'reg_lambda': 0.9623699958951423, 'reg_alpha': 7.441340095247838e-07, 'gamma': 1.894250232357759}. Best is trial 6 with value: 0.4324482267282993.
#
# ================================================================================
# [TRIAL 15] params:
# {
#   "objective": "binary:logistic",
#   "eval_metric": "logloss",
#   "tree_method": "hist",
#   "n_jobs": -1,
#   "random_state": 42,
#   "verbosity": 0,
#   "multi_strategy": "multi_output_tree",
#   "n_estimators": 1041,
#   "max_depth": 10,
#   "learning_rate": 0.016946762191681942,
#   "subsample": 0.6992422232898451,
#   "colsample_bytree": 0.7578401452071897,
#   "min_child_weight": 5.336161676227781,
#   "reg_lambda": 0.09917313051780433,
#   "reg_alpha": 1.1843520455276855e-08,
#   "gamma": 3.7592846259730464
# }
#     [FOLD 1] AUPRC=0.408497 | AUROC=0.869873 | Acc=0.944149 | P=0.698828 | R=0.228527 | Spec=0.974681
#     [FOLD 2] AUPRC=0.413448 | AUROC=0.873905 | Acc=0.942854 | P=0.633561 | R=0.207048 | Spec=0.976911
#     [FOLD 3] AUPRC=0.420415 | AUROC=0.857026 | Acc=0.945905 | P=0.602295 | R=0.240148 | Spec=0.975944
#     [FOLD 4] AUPRC=0.423422 | AUROC=0.860619 | Acc=0.942077 | P=0.710157 | R=0.231011 | Spec=0.973203
#     [FOLD 5] AUPRC=0.421142 | AUROC=0.856733 | Acc=0.945184 | P=0.676011 | R=0.230231 | Spec=0.975178
#
# [TRIAL 15] score(AUPRC_macro)=0.417385 | AUROC=0.863631 | Acc=0.944034 | P=0.664171 | R=0.227393 | Spec=0.975184
# [I 2026-07-02 00:33:48,276] Trial 15 finished with value: 0.4173847811408799 and parameters: {'n_estimators': 1041, 'max_depth': 10, 'learning_rate': 0.016946762191681942, 'subsample': 0.6992422232898451, 'colsample_bytree': 0.7578401452071897, 'min_child_weight': 5.336161676227781, 'reg_lambda': 0.09917313051780433, 'reg_alpha': 1.1843520455276855e-08, 'gamma': 3.7592846259730464}. Best is trial 6 with value: 0.4324482267282993.
#
# ================================================================================
# [TRIAL 16] params:
# {
#   "objective": "binary:logistic",
#   "eval_metric": "logloss",
#   "tree_method": "hist",
#   "n_jobs": -1,
#   "random_state": 42,
#   "verbosity": 0,
#   "multi_strategy": "multi_output_tree",
#   "n_estimators": 787,
#   "max_depth": 9,
#   "learning_rate": 0.029425496267013667,
#   "subsample": 0.9196154753386481,
#   "colsample_bytree": 0.8642396983313834,
#   "min_child_weight": 2.123396987707551,
#   "reg_lambda": 2.4896659973205026,
#   "reg_alpha": 0.0002860683145778128,
#   "gamma": 0.06589607190461733
# }
#     [FOLD 1] AUPRC=0.419324 | AUROC=0.865473 | Acc=0.944094 | P=0.603454 | R=0.269187 | Spec=0.971615
#     [FOLD 2] AUPRC=0.418993 | AUROC=0.870728 | Acc=0.943742 | P=0.576262 | R=0.243172 | Spec=0.974223
#     [FOLD 3] AUPRC=0.436939 | AUROC=0.861468 | Acc=0.945462 | P=0.534739 | R=0.302349 | Spec=0.971070
#     [FOLD 4] AUPRC=0.448064 | AUROC=0.868492 | Acc=0.942798 | P=0.618061 | R=0.282792 | Spec=0.969715
#     [FOLD 5] AUPRC=0.433285 | AUROC=0.861571 | Acc=0.945794 | P=0.575688 | R=0.288695 | Spec=0.971892
#
# [TRIAL 16] score(AUPRC_macro)=0.431321 | AUROC=0.865546 | Acc=0.944378 | P=0.581641 | R=0.277239 | Spec=0.971703
# [I 2026-07-02 00:56:18,772] Trial 16 finished with value: 0.43132113502972536 and parameters: {'n_estimators': 787, 'max_depth': 9, 'learning_rate': 0.029425496267013667, 'subsample': 0.9196154753386481, 'colsample_bytree': 0.8642396983313834, 'min_child_weight': 2.123396987707551, 'reg_lambda': 2.4896659973205026, 'reg_alpha': 0.0002860683145778128, 'gamma': 0.06589607190461733}. Best is trial 6 with value: 0.4324482267282993.
#
# ================================================================================
# [TRIAL 17] params:
# {
#   "objective": "binary:logistic",
#   "eval_metric": "logloss",
#   "tree_method": "hist",
#   "n_jobs": -1,
#   "random_state": 42,
#   "verbosity": 0,
#   "multi_strategy": "multi_output_tree",
#   "n_estimators": 773,
#   "max_depth": 8,
#   "learning_rate": 0.03533532674029352,
#   "subsample": 0.9072703694406211,
#   "colsample_bytree": 0.867196892261374,
#   "min_child_weight": 1.8464985413645072,
#   "reg_lambda": 3.169650254686986,
#   "reg_alpha": 0.0007499288911568007,
#   "gamma": 0.15935251762994246
# }
#     [FOLD 1] AUPRC=0.419815 | AUROC=0.864510 | Acc=0.943096 | P=0.513052 | R=0.267947 | Spec=0.970561
#     [FOLD 2] AUPRC=0.417162 | AUROC=0.872402 | Acc=0.943353 | P=0.530128 | R=0.236402 | Spec=0.973965
#     [FOLD 3] AUPRC=0.433158 | AUROC=0.862689 | Acc=0.946238 | P=0.588053 | R=0.306130 | Spec=0.972368
#     [FOLD 4] AUPRC=0.446969 | AUROC=0.868483 | Acc=0.943409 | P=0.633833 | R=0.282788 | Spec=0.970571
#     [FOLD 5] AUPRC=0.436398 | AUROC=0.863471 | Acc=0.945406 | P=0.518528 | R=0.273346 | Spec=0.971733
#
# [TRIAL 17] score(AUPRC_macro)=0.430700 | AUROC=0.866311 | Acc=0.944301 | P=0.556719 | R=0.273323 | Spec=0.971840
# [I 2026-07-02 01:10:46,670] Trial 17 finished with value: 0.4307002860556466 and parameters: {'n_estimators': 773, 'max_depth': 8, 'learning_rate': 0.03533532674029352, 'subsample': 0.9072703694406211, 'colsample_bytree': 0.867196892261374, 'min_child_weight': 1.8464985413645072, 'reg_lambda': 3.169650254686986, 'reg_alpha': 0.0007499288911568007, 'gamma': 0.15935251762994246}. Best is trial 6 with value: 0.4324482267282993.
#
# ================================================================================
# [TRIAL 18] params:
# {
#   "objective": "binary:logistic",
#   "eval_metric": "logloss",
#   "tree_method": "hist",
#   "n_jobs": -1,
#   "random_state": 42,
#   "verbosity": 0,
#   "multi_strategy": "multi_output_tree",
#   "n_estimators": 497,
#   "max_depth": 9,
#   "learning_rate": 0.015989779067515093,
#   "subsample": 0.7839944835498075,
#   "colsample_bytree": 0.8687980807316484,
#   "min_child_weight": 0.9306685431491606,
#   "reg_lambda": 0.0308564104040837,
#   "reg_alpha": 6.511399305332766e-05,
#   "gamma": 0.1251919157749406
# }
#     [FOLD 1] AUPRC=0.426342 | AUROC=0.866464 | Acc=0.942930 | P=0.487147 | R=0.276122 | Spec=0.971022
#     [FOLD 2] AUPRC=0.425780 | AUROC=0.869387 | Acc=0.942909 | P=0.555021 | R=0.245097 | Spec=0.974040
#     [FOLD 3] AUPRC=0.425444 | AUROC=0.855779 | Acc=0.945573 | P=0.574990 | R=0.287764 | Spec=0.973215
#     [FOLD 4] AUPRC=0.448134 | AUROC=0.864471 | Acc=0.943797 | P=0.725037 | R=0.291126 | Spec=0.970042
#     [FOLD 5] AUPRC=0.431252 | AUROC=0.859126 | Acc=0.945850 | P=0.524154 | R=0.282957 | Spec=0.972798
#
# [TRIAL 18] score(AUPRC_macro)=0.431391 | AUROC=0.863046 | Acc=0.944212 | P=0.573270 | R=0.276613 | Spec=0.972224
# [I 2026-07-02 01:27:39,775] Trial 18 finished with value: 0.43139051566562037 and parameters: {'n_estimators': 497, 'max_depth': 9, 'learning_rate': 0.015989779067515093, 'subsample': 0.7839944835498075, 'colsample_bytree': 0.8687980807316484, 'min_child_weight': 0.9306685431491606, 'reg_lambda': 0.0308564104040837, 'reg_alpha': 6.511399305332766e-05, 'gamma': 0.1251919157749406}. Best is trial 6 with value: 0.4324482267282993.
#
# ================================================================================
# [TRIAL 19] params:
# {
#   "objective": "binary:logistic",
#   "eval_metric": "logloss",
#   "tree_method": "hist",
#   "n_jobs": -1,
#   "random_state": 42,
#   "verbosity": 0,
#   "multi_strategy": "multi_output_tree",
#   "n_estimators": 489,
#   "max_depth": 6,
#   "learning_rate": 0.016201594287546243,
#   "subsample": 0.7727431143998708,
#   "colsample_bytree": 0.983328497388394,
#   "min_child_weight": 1.133648029939704,
#   "reg_lambda": 0.0177383064141609,
#   "reg_alpha": 3.0085461566924534e-05,
#   "gamma": 1.9022615672486707
# }
#     [FOLD 1] AUPRC=0.423949 | AUROC=0.870851 | Acc=0.944869 | P=0.671064 | R=0.237597 | Spec=0.975286
#     [FOLD 2] AUPRC=0.430577 | AUROC=0.871635 | Acc=0.943964 | P=0.595956 | R=0.221551 | Spec=0.977634
#     [FOLD 3] AUPRC=0.434560 | AUROC=0.860600 | Acc=0.946627 | P=0.628999 | R=0.260365 | Spec=0.975989
#     [FOLD 4] AUPRC=0.438148 | AUROC=0.869444 | Acc=0.943409 | P=0.684161 | R=0.252041 | Spec=0.974759
#     [FOLD 5] AUPRC=0.435039 | AUROC=0.865932 | Acc=0.946016 | P=0.609683 | R=0.252006 | Spec=0.975346
#
# [TRIAL 19] score(AUPRC_macro)=0.432455 | AUROC=0.867692 | Acc=0.944977 | P=0.637973 | R=0.244712 | Spec=0.975803
# [I 2026-07-02 01:32:20,661] Trial 19 finished with value: 0.4324547650044387 and parameters: {'n_estimators': 489, 'max_depth': 6, 'learning_rate': 0.016201594287546243, 'subsample': 0.7727431143998708, 'colsample_bytree': 0.983328497388394, 'min_child_weight': 1.133648029939704, 'reg_lambda': 0.0177383064141609, 'reg_alpha': 3.0085461566924534e-05, 'gamma': 1.9022615672486707}. Best is trial 19 with value: 0.4324547650044387.
#
# ================================================================================
# [TRIAL 20] params:
# {
#   "objective": "binary:logistic",
#   "eval_metric": "logloss",
#   "tree_method": "hist",
#   "n_jobs": -1,
#   "random_state": 42,
#   "verbosity": 0,
#   "multi_strategy": "multi_output_tree",
#   "n_estimators": 336,
#   "max_depth": 6,
#   "learning_rate": 0.015545025762510328,
#   "subsample": 0.6765700759525418,
#   "colsample_bytree": 0.9992710140945783,
#   "min_child_weight": 1.1448458782289705,
#   "reg_lambda": 0.0057488211852577565,
#   "reg_alpha": 1.3200803983542812e-06,
#   "gamma": 1.7897977241210181
# }
#     [FOLD 1] AUPRC=0.419810 | AUROC=0.872664 | Acc=0.944371 | P=0.735396 | R=0.223996 | Spec=0.976370
#     [FOLD 2] AUPRC=0.425152 | AUROC=0.875405 | Acc=0.942577 | P=0.663545 | R=0.211259 | Spec=0.977905
#     [FOLD 3] AUPRC=0.424796 | AUROC=0.858434 | Acc=0.945794 | P=0.676365 | R=0.238092 | Spec=0.977957
#     [FOLD 4] AUPRC=0.441189 | AUROC=0.866788 | Acc=0.942909 | P=0.747935 | R=0.233609 | Spec=0.975484
#     [FOLD 5] AUPRC=0.428839 | AUROC=0.861213 | Acc=0.945184 | P=0.677756 | R=0.222938 | Spec=0.975845
#
# [TRIAL 20] score(AUPRC_macro)=0.427958 | AUROC=0.866901 | Acc=0.944167 | P=0.700199 | R=0.225979 | Spec=0.976712
# [I 2026-07-02 01:35:37,729] Trial 20 finished with value: 0.42795754772967765 and parameters: {'n_estimators': 336, 'max_depth': 6, 'learning_rate': 0.015545025762510328, 'subsample': 0.6765700759525418, 'colsample_bytree': 0.9992710140945783, 'min_child_weight': 1.1448458782289705, 'reg_lambda': 0.0057488211852577565, 'reg_alpha': 1.3200803983542812e-06, 'gamma': 1.7897977241210181}. Best is trial 19 with value: 0.4324547650044387.
#
# ================================================================================
# [TRIAL 21] params:
# {
#   "objective": "binary:logistic",
#   "eval_metric": "logloss",
#   "tree_method": "hist",
#   "n_jobs": -1,
#   "random_state": 42,
#   "verbosity": 0,
#   "multi_strategy": "multi_output_tree",
#   "n_estimators": 476,
#   "max_depth": 7,
#   "learning_rate": 0.010403107916306832,
#   "subsample": 0.7715649748577397,
#   "colsample_bytree": 0.9345290940642033,
#   "min_child_weight": 0.9590597192047352,
#   "reg_lambda": 0.03182522435052595,
#   "reg_alpha": 2.5733038755665688e-05,
#   "gamma": 0.4784357857900971
# }
#     [FOLD 1] AUPRC=0.423633 | AUROC=0.870066 | Acc=0.944426 | P=0.741503 | R=0.235910 | Spec=0.976003
#     [FOLD 2] AUPRC=0.424915 | AUROC=0.874378 | Acc=0.943631 | P=0.558131 | R=0.218102 | Spec=0.977219
#     [FOLD 3] AUPRC=0.429650 | AUROC=0.857780 | Acc=0.945351 | P=0.595605 | R=0.246523 | Spec=0.975826
#     [FOLD 4] AUPRC=0.440711 | AUROC=0.865927 | Acc=0.942743 | P=0.730161 | R=0.250325 | Spec=0.973944
#     [FOLD 5] AUPRC=0.436554 | AUROC=0.861775 | Acc=0.945850 | P=0.592166 | R=0.249577 | Spec=0.975856
#
# [TRIAL 21] score(AUPRC_macro)=0.431092 | AUROC=0.865985 | Acc=0.944400 | P=0.643513 | R=0.240087 | Spec=0.975770
# [I 2026-07-02 01:42:23,618] Trial 21 finished with value: 0.43109243898266997 and parameters: {'n_estimators': 476, 'max_depth': 7, 'learning_rate': 0.010403107916306832, 'subsample': 0.7715649748577397, 'colsample_bytree': 0.9345290940642033, 'min_child_weight': 0.9590597192047352, 'reg_lambda': 0.03182522435052595, 'reg_alpha': 2.5733038755665688e-05, 'gamma': 0.4784357857900971}. Best is trial 19 with value: 0.4324547650044387.
#
# ================================================================================
# [TRIAL 22] params:
# {
#   "objective": "binary:logistic",
#   "eval_metric": "logloss",
#   "tree_method": "hist",
#   "n_jobs": -1,
#   "random_state": 42,
#   "verbosity": 0,
#   "multi_strategy": "multi_output_tree",
#   "n_estimators": 493,
#   "max_depth": 6,
#   "learning_rate": 0.016250099263264702,
#   "subsample": 0.7844582537066994,
#   "colsample_bytree": 0.9575509805586652,
#   "min_child_weight": 1.3890728197500464,
#   "reg_lambda": 0.03737299597922829,
#   "reg_alpha": 2.8585221086196457e-05,
#   "gamma": 1.8263597682153496
# }
#     [FOLD 1] AUPRC=0.421477 | AUROC=0.869883 | Acc=0.944703 | P=0.653418 | R=0.234643 | Spec=0.975606
#     [FOLD 2] AUPRC=0.423069 | AUROC=0.874527 | Acc=0.943131 | P=0.599505 | R=0.217266 | Spec=0.977225
#     [FOLD 3] AUPRC=0.431955 | AUROC=0.860954 | Acc=0.946793 | P=0.635550 | R=0.261209 | Spec=0.976439
#     [FOLD 4] AUPRC=0.440907 | AUROC=0.869837 | Acc=0.943353 | P=0.726319 | R=0.249107 | Spec=0.974624
#     [FOLD 5] AUPRC=0.428079 | AUROC=0.865382 | Acc=0.946627 | P=0.579984 | R=0.240067 | Spec=0.976566
#
# [TRIAL 22] score(AUPRC_macro)=0.429098 | AUROC=0.868117 | Acc=0.944922 | P=0.638955 | R=0.240458 | Spec=0.976092
# [I 2026-07-02 01:47:05,906] Trial 22 finished with value: 0.42909762048403427 and parameters: {'n_estimators': 493, 'max_depth': 6, 'learning_rate': 0.016250099263264702, 'subsample': 0.7844582537066994, 'colsample_bytree': 0.9575509805586652, 'min_child_weight': 1.3890728197500464, 'reg_lambda': 0.03737299597922829, 'reg_alpha': 2.8585221086196457e-05, 'gamma': 1.8263597682153496}. Best is trial 19 with value: 0.4324547650044387.
#
# ================================================================================
# [TRIAL 23] params:
# {
#   "objective": "binary:logistic",
#   "eval_metric": "logloss",
#   "tree_method": "hist",
#   "n_jobs": -1,
#   "random_state": 42,
#   "verbosity": 0,
#   "multi_strategy": "multi_output_tree",
#   "n_estimators": 396,
#   "max_depth": 9,
#   "learning_rate": 0.01786828057758642,
#   "subsample": 0.6073248792362046,
#   "colsample_bytree": 0.8535270660819744,
#   "min_child_weight": 1.0157988025493632,
#   "reg_lambda": 0.013745468311649887,
#   "reg_alpha": 0.00010274548940136535,
#   "gamma": 2.593721165044016
# }
#     [FOLD 1] AUPRC=0.417762 | AUROC=0.871032 | Acc=0.943927 | P=0.594736 | R=0.253305 | Spec=0.973504
#     [FOLD 2] AUPRC=0.423712 | AUROC=0.869188 | Acc=0.944407 | P=0.620276 | R=0.239393 | Spec=0.975633
#     [FOLD 3] AUPRC=0.428089 | AUROC=0.854673 | Acc=0.945517 | P=0.633079 | R=0.277145 | Spec=0.973291
#     [FOLD 4] AUPRC=0.450107 | AUROC=0.865114 | Acc=0.944241 | P=0.723215 | R=0.284090 | Spec=0.971448
#     [FOLD 5] AUPRC=0.433262 | AUROC=0.857308 | Acc=0.944962 | P=0.588776 | R=0.271638 | Spec=0.972932
#
# [TRIAL 23] score(AUPRC_macro)=0.430586 | AUROC=0.863463 | Acc=0.944611 | P=0.632016 | R=0.265114 | Spec=0.973362
# [I 2026-07-02 01:57:17,196] Trial 23 finished with value: 0.4305863773429853 and parameters: {'n_estimators': 396, 'max_depth': 9, 'learning_rate': 0.01786828057758642, 'subsample': 0.6073248792362046, 'colsample_bytree': 0.8535270660819744, 'min_child_weight': 1.0157988025493632, 'reg_lambda': 0.013745468311649887, 'reg_alpha': 0.00010274548940136535, 'gamma': 2.593721165044016}. Best is trial 19 with value: 0.4324547650044387.
#
# ================================================================================
# [TRIAL 24] params:
# {
#   "objective": "binary:logistic",
#   "eval_metric": "logloss",
#   "tree_method": "hist",
#   "n_jobs": -1,
#   "random_state": 42,
#   "verbosity": 0,
#   "multi_strategy": "multi_output_tree",
#   "n_estimators": 545,
#   "max_depth": 7,
#   "learning_rate": 0.013906503756700758,
#   "subsample": 0.7467320432990089,
#   "colsample_bytree": 0.9017511018096213,
#   "min_child_weight": 0.773696366679032,
#   "reg_lambda": 0.005490425592813812,
#   "reg_alpha": 0.004632994541292555,
#   "gamma": 1.343246617021208
# }
#     [FOLD 1] AUPRC=0.432788 | AUROC=0.871871 | Acc=0.944426 | P=0.618549 | R=0.262059 | Spec=0.973872
#     [FOLD 2] AUPRC=0.421339 | AUROC=0.874678 | Acc=0.943520 | P=0.553475 | R=0.230266 | Spec=0.976562
#     [FOLD 3] AUPRC=0.424694 | AUROC=0.858767 | Acc=0.945517 | P=0.598986 | R=0.257929 | Spec=0.974213
#     [FOLD 4] AUPRC=0.437495 | AUROC=0.867852 | Acc=0.943298 | P=0.666256 | R=0.254975 | Spec=0.972944
#     [FOLD 5] AUPRC=0.436125 | AUROC=0.861332 | Acc=0.946460 | P=0.579244 | R=0.267536 | Spec=0.974698
#
# [TRIAL 24] score(AUPRC_macro)=0.430488 | AUROC=0.866900 | Acc=0.944644 | P=0.603302 | R=0.254553 | Spec=0.974458
# [I 2026-07-02 02:04:22,929] Trial 24 finished with value: 0.43048802955763 and parameters: {'n_estimators': 545, 'max_depth': 7, 'learning_rate': 0.013906503756700758, 'subsample': 0.7467320432990089, 'colsample_bytree': 0.9017511018096213, 'min_child_weight': 0.773696366679032, 'reg_lambda': 0.005490425592813812, 'reg_alpha': 0.004632994541292555, 'gamma': 1.343246617021208}. Best is trial 19 with value: 0.4324547650044387.
#
# ================================================================================
# [TRIAL 25] params:
# {
#   "objective": "binary:logistic",
#   "eval_metric": "logloss",
#   "tree_method": "hist",
#   "n_jobs": -1,
#   "random_state": 42,
#   "verbosity": 0,
#   "multi_strategy": "multi_output_tree",
#   "n_estimators": 692,
#   "max_depth": 6,
#   "learning_rate": 0.03420384391336112,
#   "subsample": 0.7046182566978615,
#   "colsample_bytree": 0.9530035812485176,
#   "min_child_weight": 0.5015591759950515,
#   "reg_lambda": 0.07113970139263977,
#   "reg_alpha": 2.867999362862716e-06,
#   "gamma": 0.544158396836032
# }
#     [FOLD 1] AUPRC=0.432458 | AUROC=0.868415 | Acc=0.944038 | P=0.533201 | R=0.284501 | Spec=0.970952
#     [FOLD 2] AUPRC=0.393626 | AUROC=0.870071 | Acc=0.942077 | P=0.502249 | R=0.240807 | Spec=0.972916
#     [FOLD 3] AUPRC=0.430409 | AUROC=0.857406 | Acc=0.946072 | P=0.559747 | R=0.303365 | Spec=0.973288
#     [FOLD 4] AUPRC=0.427036 | AUROC=0.867894 | Acc=0.941689 | P=0.650581 | R=0.274046 | Spec=0.969905
#     [FOLD 5] AUPRC=0.420456 | AUROC=0.863319 | Acc=0.944629 | P=0.515585 | R=0.291439 | Spec=0.971630
#
# [TRIAL 25] score(AUPRC_macro)=0.420797 | AUROC=0.865421 | Acc=0.943701 | P=0.552272 | R=0.278831 | Spec=0.971738
# [I 2026-07-02 02:10:19,171] Trial 25 finished with value: 0.4207971123003443 and parameters: {'n_estimators': 692, 'max_depth': 6, 'learning_rate': 0.03420384391336112, 'subsample': 0.7046182566978615, 'colsample_bytree': 0.9530035812485176, 'min_child_weight': 0.5015591759950515, 'reg_lambda': 0.07113970139263977, 'reg_alpha': 2.867999362862716e-06, 'gamma': 0.544158396836032}. Best is trial 19 with value: 0.4324547650044387.
#
# ================================================================================
# [TRIAL 26] params:
# {
#   "objective": "binary:logistic",
#   "eval_metric": "logloss",
#   "tree_method": "hist",
#   "n_jobs": -1,
#   "random_state": 42,
#   "verbosity": 0,
#   "multi_strategy": "multi_output_tree",
#   "n_estimators": 415,
#   "max_depth": 4,
#   "learning_rate": 0.013168840601110473,
#   "subsample": 0.8644231577111164,
#   "colsample_bytree": 0.7629775773422901,
#   "min_child_weight": 1.6919334703527515,
#   "reg_lambda": 0.015654342938674536,
#   "reg_alpha": 3.09348395126308e-07,
#   "gamma": 4.821780046940351
# }
#     [FOLD 1] AUPRC=0.409793 | AUROC=0.871844 | Acc=0.942431 | P=0.791304 | R=0.185539 | Spec=0.978732
#     [FOLD 2] AUPRC=0.418897 | AUROC=0.876242 | Acc=0.941300 | P=0.686140 | R=0.169051 | Spec=0.980696
#     [FOLD 3] AUPRC=0.414136 | AUROC=0.858180 | Acc=0.944130 | P=0.718805 | R=0.187976 | Spec=0.980625
#     [FOLD 4] AUPRC=0.425206 | AUROC=0.860036 | Acc=0.940801 | P=0.848504 | R=0.181226 | Spec=0.978008
#     [FOLD 5] AUPRC=0.406596 | AUROC=0.857079 | Acc=0.942466 | P=0.840704 | R=0.181002 | Spec=0.977749
#
# [TRIAL 26] score(AUPRC_macro)=0.414926 | AUROC=0.864676 | Acc=0.942226 | P=0.777091 | R=0.180959 | Spec=0.979162
# [I 2026-07-02 02:12:48,535] Trial 26 finished with value: 0.41492557725129303 and parameters: {'n_estimators': 415, 'max_depth': 4, 'learning_rate': 0.013168840601110473, 'subsample': 0.8644231577111164, 'colsample_bytree': 0.7629775773422901, 'min_child_weight': 1.6919334703527515, 'reg_lambda': 0.015654342938674536, 'reg_alpha': 3.09348395126308e-07, 'gamma': 4.821780046940351}. Best is trial 19 with value: 0.4324547650044387.
#
# ================================================================================
# [TRIAL 27] params:
# {
#   "objective": "binary:logistic",
#   "eval_metric": "logloss",
#   "tree_method": "hist",
#   "n_jobs": -1,
#   "random_state": 42,
#   "verbosity": 0,
#   "multi_strategy": "multi_output_tree",
#   "n_estimators": 840,
#   "max_depth": 8,
#   "learning_rate": 0.020229020517777543,
#   "subsample": 0.8084420333436787,
#   "colsample_bytree": 0.60362662491687,
#   "min_child_weight": 1.231912099230854,
#   "reg_lambda": 0.1842870795910358,
#   "reg_alpha": 5.031769251910505e-06,
#   "gamma": 2.9452478851836514
# }
#     [FOLD 1] AUPRC=0.426221 | AUROC=0.865121 | Acc=0.943983 | P=0.581642 | R=0.289131 | Spec=0.971251
#     [FOLD 2] AUPRC=0.421174 | AUROC=0.867826 | Acc=0.943187 | P=0.517183 | R=0.251042 | Spec=0.973693
#     [FOLD 3] AUPRC=0.430538 | AUROC=0.858693 | Acc=0.945073 | P=0.552298 | R=0.295269 | Spec=0.971844
#     [FOLD 4] AUPRC=0.437786 | AUROC=0.865903 | Acc=0.943242 | P=0.683778 | R=0.283408 | Spec=0.970915
#     [FOLD 5] AUPRC=0.429823 | AUROC=0.862801 | Acc=0.945462 | P=0.549063 | R=0.280498 | Spec=0.972282
#
# [TRIAL 27] score(AUPRC_macro)=0.429108 | AUROC=0.864069 | Acc=0.944189 | P=0.576793 | R=0.279870 | Spec=0.971997
# [I 2026-07-02 02:24:17,465] Trial 27 finished with value: 0.429108402879821 and parameters: {'n_estimators': 840, 'max_depth': 8, 'learning_rate': 0.020229020517777543, 'subsample': 0.8084420333436787, 'colsample_bytree': 0.60362662491687, 'min_child_weight': 1.231912099230854, 'reg_lambda': 0.1842870795910358, 'reg_alpha': 5.031769251910505e-06, 'gamma': 2.9452478851836514}. Best is trial 19 with value: 0.4324547650044387.
#
# ================================================================================
# [TRIAL 28] params:
# {
#   "objective": "binary:logistic",
#   "eval_metric": "logloss",
#   "tree_method": "hist",
#   "n_jobs": -1,
#   "random_state": 42,
#   "verbosity": 0,
#   "multi_strategy": "multi_output_tree",
#   "n_estimators": 941,
#   "max_depth": 9,
#   "learning_rate": 0.010026094892975344,
#   "subsample": 0.752427162007906,
#   "colsample_bytree": 0.8852098043303755,
#   "min_child_weight": 0.7476137190979172,
#   "reg_lambda": 0.05170639510798298,
#   "reg_alpha": 0.008751628606675332,
#   "gamma": 2.1214162888011323
# }
#     [FOLD 1] AUPRC=0.431864 | AUROC=0.869438 | Acc=0.942598 | P=0.537487 | R=0.282361 | Spec=0.970752
#     [FOLD 2] AUPRC=0.416761 | AUROC=0.871675 | Acc=0.942688 | P=0.528916 | R=0.249085 | Spec=0.973414
#     [FOLD 3] AUPRC=0.429051 | AUROC=0.858547 | Acc=0.945573 | P=0.579806 | R=0.300331 | Spec=0.972390
#     [FOLD 4] AUPRC=0.440613 | AUROC=0.862404 | Acc=0.943575 | P=0.691368 | R=0.303887 | Spec=0.969772
#     [FOLD 5] AUPRC=0.431047 | AUROC=0.862939 | Acc=0.945739 | P=0.503268 | R=0.273400 | Spec=0.972395
#
# [TRIAL 28] score(AUPRC_macro)=0.429867 | AUROC=0.865000 | Acc=0.944034 | P=0.568169 | R=0.281813 | Spec=0.971745
# [I 2026-07-02 02:48:48,392] Trial 28 finished with value: 0.4298673497353535 and parameters: {'n_estimators': 941, 'max_depth': 9, 'learning_rate': 0.010026094892975344, 'subsample': 0.752427162007906, 'colsample_bytree': 0.8852098043303755, 'min_child_weight': 0.7476137190979172, 'reg_lambda': 0.05170639510798298, 'reg_alpha': 0.008751628606675332, 'gamma': 2.1214162888011323}. Best is trial 19 with value: 0.4324547650044387.
#
# ================================================================================
# [TRIAL 29] params:
# {
#   "objective": "binary:logistic",
#   "eval_metric": "logloss",
#   "tree_method": "hist",
#   "n_jobs": -1,
#   "random_state": 42,
#   "verbosity": 0,
#   "multi_strategy": "multi_output_tree",
#   "n_estimators": 664,
#   "max_depth": 10,
#   "learning_rate": 0.03731240609551797,
#   "subsample": 0.6383666666723251,
#   "colsample_bytree": 0.8369173205247173,
#   "min_child_weight": 1.0008204358226516,
#   "reg_lambda": 0.0033376132678291912,
#   "reg_alpha": 7.857534312692509e-05,
#   "gamma": 3.00120582375693
# }
#     [FOLD 1] AUPRC=0.423828 | AUROC=0.861369 | Acc=0.942598 | P=0.599102 | R=0.302611 | Spec=0.969007
#     [FOLD 2] AUPRC=0.395432 | AUROC=0.860946 | Acc=0.941633 | P=0.500062 | R=0.262446 | Spec=0.970924
#     [FOLD 3] AUPRC=0.413881 | AUROC=0.851451 | Acc=0.943575 | P=0.562104 | R=0.325591 | Spec=0.968758
#     [FOLD 4] AUPRC=0.421403 | AUROC=0.860175 | Acc=0.941911 | P=0.606200 | R=0.301176 | Spec=0.967688
#     [FOLD 5] AUPRC=0.414040 | AUROC=0.852627 | Acc=0.943797 | P=0.511910 | R=0.290838 | Spec=0.970135
#
# [TRIAL 29] score(AUPRC_macro)=0.413717 | AUROC=0.857314 | Acc=0.942703 | P=0.555875 | R=0.296532 | Spec=0.969302
# [I 2026-07-02 03:01:05,763] Trial 29 finished with value: 0.4137166359420427 and parameters: {'n_estimators': 664, 'max_depth': 10, 'learning_rate': 0.03731240609551797, 'subsample': 0.6383666666723251, 'colsample_bytree': 0.8369173205247173, 'min_child_weight': 1.0008204358226516, 'reg_lambda': 0.0033376132678291912, 'reg_alpha': 7.857534312692509e-05, 'gamma': 3.00120582375693}. Best is trial 19 with value: 0.4324547650044387.
#
# ================ BEST =================
# Best trial: 19
# Best AUPRC_macro: 0.4324547650044387
# Best params:
# {
#   "n_estimators": 489,
#   "max_depth": 6,
#   "learning_rate": 0.016201594287546243,
#   "subsample": 0.7727431143998708,
#   "colsample_bytree": 0.983328497388394,
#   "min_child_weight": 1.133648029939704,
#   "reg_lambda": 0.0177383064141609,
#   "reg_alpha": 3.0085461566924534e-05,
#   "gamma": 1.9022615672486707
# }
# [SAVED] ./optuna_singlemodel_XGB_30trials_5fold_results.csv
# [SAVED] ./used_label_columns_24.csv
# [SAVED] ./used_feature_columns.csv

# %%
# -*- coding: utf-8 -*-
import os
import glob
import json
import warnings
import numpy as np
import pandas as pd

import optuna
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import roc_auc_score, average_precision_score
from sklearn.multioutput import MultiOutputClassifier

# =========================
# 0) 全局：尽量屏蔽警告 + LightGBM 日志
# =========================
os.environ["PYTHONWARNINGS"] = "ignore"
warnings.filterwarnings("ignore", category=UserWarning)
warnings.filterwarnings("ignore", category=FutureWarning)
warnings.filterwarnings("ignore", category=RuntimeWarning)

try:
    import lightgbm as lgb
except Exception as e:
    raise RuntimeError(
        "未检测到 lightgbm。请先安装：pip install lightgbm\n"
        f"原始错误：{repr(e)}"
    )

# =========================
# 1) 配置
# =========================
RANDOM_SEED = 42
N_TRIALS = 30
N_SPLITS = 5
THRESH = 0.5

# 直接读取你已生成的特征文件
FEATURE_FILE_GLOB = "./Malodors_Rule&FG&Morgan_features.xlsx"

# 固定参数：Optuna 只搜索部分超参
BASE_LGB_PARAMS = dict(
    objective="binary",
    boosting_type="gbdt",
    n_jobs=-1,
    random_state=RANDOM_SEED,
    verbosity=-1,
)


# =========================
# 2) 读取特征文件 & 按固定列位置划分 SMILES / y / X
# =========================
def find_feature_file(pattern: str):
    cands = sorted(glob.glob(pattern))

    if not cands:
        raise FileNotFoundError(
            f"找不到特征文件：{pattern}\n"
            f"请确认 xlsx 文件名，或修改 FEATURE_FILE_GLOB。"
        )

    return cands[-1]


def load_Xy_from_feature_file(xlsx_path: str):
    """
    固定数据格式：
    第 1 列：SMILES
    第 2-25 列：24 个 y 标签
    第 26 列及之后：X 特征列

    说明：
    - 不再通过 0/1 自动判断 y 标签列；
    - 避免 Rule、FG、Morgan、StructKG 等 0/1 或数值特征被误识别为标签；
    - 适用于当前 24 标签任务。
    """
    df = pd.read_excel(xlsx_path)

    if df.shape[1] < 26:
        raise ValueError(
            f"当前文件列数为 {df.shape[1]}，不足以按“1列SMILES + 24列标签 + 特征列”划分。"
        )

    # 固定列位置
    smiles_col = df.columns[0]
    label_cols = list(df.columns[1:25])
    feature_cols = list(df.columns[25:])

    if len(label_cols) != 24:
        raise ValueError(
            f"标签列数量应为 24，但当前识别为 {len(label_cols)}。"
        )

    if len(feature_cols) == 0:
        raise ValueError(
            "未识别到特征列。请确认第 26 列之后为 X 特征。"
        )

    # y 标签转为 0/1 整数
    y_df = df[label_cols].copy()
    y_df = y_df.apply(pd.to_numeric, errors="coerce").fillna(0).astype(int)

    # 检查 y 标签是否为 0/1
    invalid_label_cols = []
    for c in label_cols:
        vals = set(pd.unique(y_df[c].dropna()))
        if not vals.issubset({0, 1}):
            invalid_label_cols.append(c)

    if invalid_label_cols:
        raise ValueError(
            "以下标签列不是标准 0/1 标签，请检查数据：\n"
            + "\n".join(map(str, invalid_label_cols))
        )

    # X 特征转为数值
    X_df = df[feature_cols].copy()
    X_df = X_df.apply(pd.to_numeric, errors="coerce").fillna(0)

    X = X_df.astype(np.float32).values
    y = y_df.values.astype(int)

    if X.shape[0] != y.shape[0]:
        raise ValueError("X 和 y 行数不一致，请检查文件。")

    print("[INFO] Column split mode: fixed-position")
    print(f"[INFO] SMILES column: {smiles_col}")
    print(f"[INFO] Label columns: columns 2-25, n={len(label_cols)}")
    print(f"[INFO] Feature columns: columns 26-end, n={len(feature_cols)}")

    print("\n[INFO] Label columns:")
    for i, c in enumerate(label_cols, start=1):
        print(f"  y{i:02d}: {c}")

    return X, y, feature_cols, label_cols, df


# =========================
# 3) 指标：macro
# =========================
def multilabel_macro_metrics(y_true, y_prob, thresh=0.5):
    y_true = np.asarray(y_true).astype(int)
    y_prob = np.asarray(y_prob).astype(float)
    y_pred = (y_prob >= thresh).astype(int)

    L = y_true.shape[1]
    accs, precs, recs, specs = [], [], [], []
    aurocs, auprcs = [], []

    for k in range(L):
        yt = y_true[:, k]
        yp = y_pred[:, k]
        ys = y_prob[:, k]

        tp = int(np.sum((yt == 1) & (yp == 1)))
        tn = int(np.sum((yt == 0) & (yp == 0)))
        fp = int(np.sum((yt == 0) & (yp == 1)))
        fn = int(np.sum((yt == 1) & (yp == 0)))
        n = len(yt)

        accs.append((tp + tn) / n if n else np.nan)
        precs.append(tp / (tp + fp) if (tp + fp) else np.nan)
        recs.append(tp / (tp + fn) if (tp + fn) else np.nan)
        specs.append(tn / (tn + fp) if (tn + fp) else np.nan)

        if len(np.unique(yt)) == 2:
            aurocs.append(roc_auc_score(yt, ys))
            auprcs.append(average_precision_score(yt, ys))
        else:
            aurocs.append(np.nan)
            auprcs.append(np.nan)

    def nanmean(x):
        return float(np.nanmean(np.asarray(x, dtype=float)))

    return {
        "Accuracy_macro": nanmean(accs),
        "Precision_macro": nanmean(precs),
        "Recall_macro": nanmean(recs),
        "Specificity_macro": nanmean(specs),
        "AUROC_macro": nanmean(aurocs),
        "AUPRC_macro": nanmean(auprcs),
        "AUROC_valid_labels": int(np.sum(~np.isnan(aurocs))),
        "AUPRC_valid_labels": int(np.sum(~np.isnan(auprcs))),
        "n_labels": int(L),
    }


def extract_positive_proba(p, n_labels: int):
    """
    MultiOutputClassifier.predict_proba 通常返回 list：
    list 长度 = 标签数，每个元素形状为 (n_samples, n_classes)。

    注意：
    - 若某个 fold 中某个标签训练集只有单类，LightGBM 可能只返回 1 列；
    - 这里做了兼容，避免 pi[:, 1] 越界。
    """
    if isinstance(p, list):
        out = np.zeros((p[0].shape[0], n_labels), dtype=np.float32)

        for k in range(n_labels):
            pk = p[k]

            if pk.ndim != 2:
                raise ValueError(f"predict_proba[{k}] 形状异常: {pk.shape}")

            if pk.shape[1] == 2:
                out[:, k] = pk[:, 1].astype(np.float32)
            elif pk.shape[1] == 1:
                # 无法从 predict_proba 本身判断该单类是 0 还是 1；
                # 这里兜底使用该列概率。通常极少发生。
                out[:, k] = pk[:, 0].astype(np.float32)
            else:
                raise ValueError(
                    f"predict_proba[{k}] 类别数异常: {pk.shape[1]}"
                )

        return out

    p = np.asarray(p)

    if p.ndim == 3 and p.shape[-1] == 2:
        return p[:, :, 1].astype(np.float32)

    if p.ndim == 2:
        if p.shape[1] == 2 and n_labels == 1:
            return p[:, 1:2].astype(np.float32)

        if p.shape[1] == n_labels:
            return p.astype(np.float32)

        raise ValueError(
            f"predict_proba 输出为二维，但列数 {p.shape[1]} 与标签数 {n_labels} 不一致。"
        )

    raise ValueError(f"无法解析 predict_proba 输出形状: {p.shape}")


# =========================
# 4) 近似分层 5 折：用 label cardinality 分层
# =========================
def make_stratify_target(y: np.ndarray, n_bins: int = 10):
    """
    多标签任务中没有直接的 StratifiedKFold。
    这里使用每个样本的标签数量 label cardinality 做近似分层。
    """
    card = y.sum(axis=1).astype(int)
    uniq = np.unique(card)

    if len(uniq) <= 15:
        return card

    r = pd.Series(card).rank(method="average").values
    bins = pd.qcut(
        r,
        q=min(n_bins, len(np.unique(r))),
        labels=False,
        duplicates="drop"
    )

    return np.asarray(bins, dtype=int)


def build_folds(X, y, n_splits=5, seed=42):
    strat_y = make_stratify_target(y)

    skf = StratifiedKFold(
        n_splits=n_splits,
        shuffle=True,
        random_state=seed
    )

    return list(skf.split(X, strat_y))


# =========================
# 5) 5 折 CV 评估：LightGBM + MultiOutput
# =========================
def cv_eval_one_paramset(X, y, folds, params, thresh=0.5):
    n_labels = y.shape[1]
    fold_metrics = []

    for fold_id, (tr_idx, va_idx) in enumerate(folds, start=1):
        X_tr, X_va = X[tr_idx], X[va_idx]
        y_tr, y_va = y[tr_idx], y[va_idx]

        base_est = lgb.LGBMClassifier(**params)

        # 每个标签一个 LGBM；
        # n_jobs=1 避免“外层并行 + 内层线程”导致线程过载
        clf = MultiOutputClassifier(base_est, n_jobs=1)

        clf.fit(X_tr, y_tr)

        p = clf.predict_proba(X_va)
        y_prob = extract_positive_proba(p, n_labels=n_labels)

        m = multilabel_macro_metrics(y_va, y_prob, thresh=thresh)
        fold_metrics.append(m)

        print(
            f"    [FOLD {fold_id}] "
            f"AUPRC={m['AUPRC_macro']:.6f} | "
            f"AUROC={m['AUROC_macro']:.6f} | "
            f"Acc={m['Accuracy_macro']:.6f} | "
            f"P={m['Precision_macro']:.6f} | "
            f"R={m['Recall_macro']:.6f} | "
            f"Spec={m['Specificity_macro']:.6f}"
        )

    keys = list(fold_metrics[0].keys())
    mean_metrics = {}

    for k in keys:
        vals = [fm[k] for fm in fold_metrics]

        if isinstance(vals[0], float):
            mean_metrics[k] = float(np.nanmean(vals))
        else:
            mean_metrics[k] = vals[-1]

    return mean_metrics


# =========================
# 6) Optuna 超参空间：LightGBM
# =========================
def build_trial_params(trial: optuna.Trial):
    params = dict(BASE_LGB_PARAMS)

    params.update({
        "n_estimators": trial.suggest_int("n_estimators", 300, 2000),
        "learning_rate": trial.suggest_float("learning_rate", 0.01, 0.2, log=True),

        "num_leaves": trial.suggest_int("num_leaves", 31, 255),
        "max_depth": trial.suggest_int("max_depth", -1, 20),
        "min_child_samples": trial.suggest_int("min_child_samples", 5, 80),

        "subsample": trial.suggest_float("subsample", 0.6, 1.0),
        "colsample_bytree": trial.suggest_float("colsample_bytree", 0.6, 1.0),

        "reg_lambda": trial.suggest_float("reg_lambda", 1e-3, 50.0, log=True),
        "reg_alpha": trial.suggest_float("reg_alpha", 1e-8, 10.0, log=True),

        "min_split_gain": trial.suggest_float("min_split_gain", 0.0, 5.0),
    })

    return params


# =========================
# 7) 主流程：读特征 -> 固定 folds -> Optuna -> 输出保存
# =========================
def main():
    feature_file = find_feature_file(FEATURE_FILE_GLOB)
    print("[INFO] Using feature file:", feature_file)

    X, y, feat_cols, label_cols, df_all = load_Xy_from_feature_file(feature_file)

    print(
        f"\n[INFO] X shape={X.shape} "
        f"(features={len(feat_cols)}) | "
        f"y shape={y.shape} "
        f"(labels={len(label_cols)})"
    )

    folds = build_folds(X, y, n_splits=N_SPLITS, seed=RANDOM_SEED)
    print(f"[INFO] Prepared fixed {N_SPLITS}-fold splits for all trials.")

    def objective(trial: optuna.Trial):
        params = build_trial_params(trial)

        print("\n" + "=" * 80)
        print(f"[TRIAL {trial.number:02d}] params:")
        print(json.dumps(params, indent=2, ensure_ascii=False, default=str))

        mean_metrics = cv_eval_one_paramset(
            X,
            y,
            folds,
            params,
            thresh=THRESH
        )

        score = mean_metrics["AUPRC_macro"]

        print(
            f"\n[TRIAL {trial.number:02d}] "
            f"score(AUPRC_macro)={score:.6f} | "
            f"AUROC={mean_metrics['AUROC_macro']:.6f} | "
            f"Acc={mean_metrics['Accuracy_macro']:.6f} | "
            f"P={mean_metrics['Precision_macro']:.6f} | "
            f"R={mean_metrics['Recall_macro']:.6f} | "
            f"Spec={mean_metrics['Specificity_macro']:.6f}"
        )

        for k, v in mean_metrics.items():
            trial.set_user_attr(k, v)

        return score

    study = optuna.create_study(
        direction="maximize",
        sampler=optuna.samplers.TPESampler(seed=RANDOM_SEED),
    )

    study.optimize(
        objective,
        n_trials=N_TRIALS,
        show_progress_bar=True
    )

    print("\n================ BEST =================")
    print("Best trial:", study.best_trial.number)
    print("Best AUPRC_macro:", study.best_value)
    print("Best params:")
    print(json.dumps(study.best_params, indent=2, ensure_ascii=False))

    rows = []

    for t in study.trials:
        if t.value is None:
            continue

        row = {
            "trial": t.number,
            "AUPRC_macro": t.value,
            **t.params
        }

        row.update({
            k: v for k, v in t.user_attrs.items()
            if k.endswith("_macro")
        })

        rows.append(row)

    res_df = pd.DataFrame(rows).sort_values(
        "AUPRC_macro",
        ascending=False
    )

    out_csv = "./optuna_singlemodel_LIGHTGBM_30trials_5fold_results.csv"
    res_df.to_csv(out_csv, index=False, encoding="utf-8-sig")
    print("[SAVED]", out_csv)

    # 额外保存标签列和特征列，便于核查
    label_out = "./used_label_columns_24.csv"
    feature_out = "./used_feature_columns.csv"

    pd.DataFrame({"label_col": label_cols}).to_csv(
        label_out,
        index=False,
        encoding="utf-8-sig"
    )

    pd.DataFrame({"feature_col": feat_cols}).to_csv(
        feature_out,
        index=False,
        encoding="utf-8-sig"
    )

    print("[SAVED]", label_out)
    print("[SAVED]", feature_out)


if __name__ == "__main__":
    main()
# Out:
# [INFO] Using feature file: ./Malodors_Rule&FG&Morgan_features.xlsx
# [I 2026-07-02 03:02:22,847] A new study created in memory with name: no-name-f0f55a51-b5c9-429b-bf03-87dc0a3826d2
# [INFO] Column split mode: fixed-position
# [INFO] SMILES column: Canonical_SMILES
# [INFO] Label columns: columns 2-25, n=24
# [INFO] Feature columns: columns 26-end, n=2427
#
# [INFO] Label columns:
#   y01: alcoholic
#   y02: aldehydic
#   y03: almond
#   y04: aromatic
#   y05: burnt
#   y06: cabbage
#   y07: cheesy
#   y08: cherry
#   y09: chocolate
#   y10: ethereal
#   y11: fishy
#   y12: fruity
#   y13: garlic
#   y14: grassy
#   y15: green
#   y16: ketonic
#   y17: musty
#   y18: pungent
#   y19: sharp
#   y20: solvent
#   y21: sour
#   y22: sulfurous
#   y23: sweaty
#   y24: sweet
#
# [INFO] X shape=(3756, 2427) (features=2427) | y shape=(3756, 24) (labels=24)
# [INFO] Prepared fixed 5-fold splits for all trials.
#   0%|          | 0/30 [00:00<?, ?it/s]
# ================================================================================
# [TRIAL 00] params:
# {
#   "objective": "binary",
#   "boosting_type": "gbdt",
#   "n_jobs": -1,
#   "random_state": 42,
#   "verbosity": -1,
#   "n_estimators": 937,
#   "learning_rate": 0.17254716573280354,
#   "num_leaves": 195,
#   "max_depth": 12,
#   "min_child_samples": 16,
#   "subsample": 0.662397808134481,
#   "colsample_bytree": 0.6232334448672797,
#   "reg_lambda": 11.752647960576219,
#   "reg_alpha": 0.002570603566117598,
#   "min_split_gain": 3.540362888980227
# }
#     [FOLD 1] AUPRC=0.341170 | AUROC=0.847004 | Acc=0.941988 | P=0.814209 | R=0.141314 | Spec=0.980447
#     [FOLD 2] AUPRC=0.341395 | AUROC=0.846058 | Acc=0.939802 | P=0.784505 | R=0.130675 | Spec=0.982247
#     [FOLD 3] AUPRC=0.327847 | AUROC=0.819392 | Acc=0.942077 | P=0.751889 | R=0.141597 | Spec=0.980767
#     [FOLD 4] AUPRC=0.336077 | AUROC=0.829155 | Acc=0.939414 | P=0.779002 | R=0.135899 | Spec=0.978669
#     [FOLD 5] AUPRC=0.326948 | AUROC=0.825264 | Acc=0.942188 | P=0.855822 | R=0.140963 | Spec=0.979076
#
# [TRIAL 00] score(AUPRC_macro)=0.334688 | AUROC=0.833374 | Acc=0.941094 | P=0.797085 | R=0.138090 | Spec=0.980241
# [I 2026-07-02 03:02:56,972] Trial 0 finished with value: 0.33468750542577597 and parameters: {'n_estimators': 937, 'learning_rate': 0.17254716573280354, 'num_leaves': 195, 'max_depth': 12, 'min_child_samples': 16, 'subsample': 0.662397808134481, 'colsample_bytree': 0.6232334448672797, 'reg_lambda': 11.752647960576219, 'reg_alpha': 0.002570603566117598, 'min_split_gain': 3.540362888980227}. Best is trial 0 with value: 0.33468750542577597.
#
# ================================================================================
# [TRIAL 01] params:
# {
#   "objective": "binary",
#   "boosting_type": "gbdt",
#   "n_jobs": -1,
#   "random_state": 42,
#   "verbosity": -1,
#   "n_estimators": 335,
#   "learning_rate": 0.18276027831785724,
#   "num_leaves": 218,
#   "max_depth": 3,
#   "min_child_samples": 18,
#   "subsample": 0.6733618039413735,
#   "colsample_bytree": 0.7216968971838151,
#   "reg_lambda": 0.2922905212920093,
#   "reg_alpha": 7.71800699380605e-05,
#   "min_split_gain": 1.4561457009902097
# }
#     [FOLD 1] AUPRC=0.397681 | AUROC=0.852486 | Acc=0.941933 | P=0.578215 | R=0.202498 | Spec=0.976890
#     [FOLD 2] AUPRC=0.389482 | AUROC=0.862395 | Acc=0.941079 | P=0.573384 | R=0.190322 | Spec=0.978306
#     [FOLD 3] AUPRC=0.400836 | AUROC=0.851209 | Acc=0.944907 | P=0.637834 | R=0.215553 | Spec=0.980037
#     [FOLD 4] AUPRC=0.398858 | AUROC=0.845011 | Acc=0.939858 | P=0.563581 | R=0.190073 | Spec=0.974636
#     [FOLD 5] AUPRC=0.371084 | AUROC=0.851887 | Acc=0.943409 | P=0.595273 | R=0.195818 | Spec=0.976910
#
# [TRIAL 01] score(AUPRC_macro)=0.391588 | AUROC=0.852598 | Acc=0.942237 | P=0.589657 | R=0.198853 | Spec=0.977356
# [I 2026-07-02 03:03:11,237] Trial 1 finished with value: 0.39158827822284314 and parameters: {'n_estimators': 335, 'learning_rate': 0.18276027831785724, 'num_leaves': 218, 'max_depth': 3, 'min_child_samples': 18, 'subsample': 0.6733618039413735, 'colsample_bytree': 0.7216968971838151, 'reg_lambda': 0.2922905212920093, 'reg_alpha': 7.71800699380605e-05, 'min_split_gain': 1.4561457009902097}. Best is trial 1 with value: 0.39158827822284314.
#
# ================================================================================
# [TRIAL 02] params:
# {
#   "objective": "binary",
#   "boosting_type": "gbdt",
#   "n_jobs": -1,
#   "random_state": 42,
#   "verbosity": -1,
#   "n_estimators": 1340,
#   "learning_rate": 0.01518747922672247,
#   "num_leaves": 96,
#   "max_depth": 7,
#   "min_child_samples": 39,
#   "subsample": 0.9140703845572055,
#   "colsample_bytree": 0.6798695128633439,
#   "reg_lambda": 0.2608388046560993,
#   "reg_alpha": 0.0021465011216654484,
#   "min_split_gain": 0.23225206359998862
# }
#     [FOLD 1] AUPRC=0.416730 | AUROC=0.862566 | Acc=0.942819 | P=0.614656 | R=0.263996 | Spec=0.973131
#     [FOLD 2] AUPRC=0.402234 | AUROC=0.864119 | Acc=0.942521 | P=0.554739 | R=0.231008 | Spec=0.975912
#     [FOLD 3] AUPRC=0.412669 | AUROC=0.855698 | Acc=0.944186 | P=0.510865 | R=0.269473 | Spec=0.974517
#     [FOLD 4] AUPRC=0.417130 | AUROC=0.850694 | Acc=0.941800 | P=0.624056 | R=0.260780 | Spec=0.972891
#     [FOLD 5] AUPRC=0.405397 | AUROC=0.853237 | Acc=0.942854 | P=0.541930 | R=0.254613 | Spec=0.971573
#
# [TRIAL 02] score(AUPRC_macro)=0.410832 | AUROC=0.857263 | Acc=0.942836 | P=0.569249 | R=0.255974 | Spec=0.973605
# [I 2026-07-02 03:04:02,725] Trial 2 finished with value: 0.41083200493222244 and parameters: {'n_estimators': 1340, 'learning_rate': 0.01518747922672247, 'num_leaves': 96, 'max_depth': 7, 'min_child_samples': 39, 'subsample': 0.9140703845572055, 'colsample_bytree': 0.6798695128633439, 'reg_lambda': 0.2608388046560993, 'reg_alpha': 0.0021465011216654484, 'min_split_gain': 0.23225206359998862}. Best is trial 2 with value: 0.41083200493222244.
#
# ================================================================================
# [TRIAL 03] params:
# {
#   "objective": "binary",
#   "boosting_type": "gbdt",
#   "n_jobs": -1,
#   "random_state": 42,
#   "verbosity": -1,
#   "n_estimators": 1333,
#   "learning_rate": 0.016666983286066417,
#   "num_leaves": 45,
#   "max_depth": 19,
#   "min_child_samples": 78,
#   "subsample": 0.9233589392465844,
#   "colsample_bytree": 0.7218455076693483,
#   "reg_lambda": 0.002877122371623787,
#   "reg_alpha": 0.014391207615728067,
#   "min_split_gain": 2.2007624686980067
# }
#     [FOLD 1] AUPRC=0.377574 | AUROC=0.858223 | Acc=0.942431 | P=0.725464 | R=0.168763 | Spec=0.977891
#     [FOLD 2] AUPRC=0.375377 | AUROC=0.857770 | Acc=0.940468 | P=0.668448 | R=0.146164 | Spec=0.980653
#     [FOLD 3] AUPRC=0.392019 | AUROC=0.849554 | Acc=0.942632 | P=0.770650 | R=0.167195 | Spec=0.979956
#     [FOLD 4] AUPRC=0.391153 | AUROC=0.840441 | Acc=0.939636 | P=0.781746 | R=0.171120 | Spec=0.976444
#     [FOLD 5] AUPRC=0.371000 | AUROC=0.846155 | Acc=0.941190 | P=0.787925 | R=0.150874 | Spec=0.977490
#
# [TRIAL 03] score(AUPRC_macro)=0.381425 | AUROC=0.850429 | Acc=0.941271 | P=0.746847 | R=0.160823 | Spec=0.978487
# [I 2026-07-02 03:04:25,210] Trial 3 finished with value: 0.38142462912473396 and parameters: {'n_estimators': 1333, 'learning_rate': 0.016666983286066417, 'num_leaves': 45, 'max_depth': 19, 'min_child_samples': 78, 'subsample': 0.9233589392465844, 'colsample_bytree': 0.7218455076693483, 'reg_lambda': 0.002877122371623787, 'reg_alpha': 0.014391207615728067, 'min_split_gain': 2.2007624686980067}. Best is trial 2 with value: 0.41083200493222244.
#
# ================================================================================
# [TRIAL 04] params:
# {
#   "objective": "binary",
#   "boosting_type": "gbdt",
#   "n_jobs": -1,
#   "random_state": 42,
#   "verbosity": -1,
#   "n_estimators": 507,
#   "learning_rate": 0.04407984038169244,
#   "num_leaves": 38,
#   "max_depth": 19,
#   "min_child_samples": 24,
#   "subsample": 0.8650089137415928,
#   "colsample_bytree": 0.7246844304357644,
#   "reg_lambda": 0.2778331300797557,
#   "reg_alpha": 0.0008325158565947976,
#   "min_split_gain": 0.9242722776276352
# }
#     [FOLD 1] AUPRC=0.415701 | AUROC=0.864800 | Acc=0.942819 | P=0.695962 | R=0.211893 | Spec=0.976401
#     [FOLD 2] AUPRC=0.408333 | AUROC=0.861560 | Acc=0.943242 | P=0.600602 | R=0.214301 | Spec=0.978061
#     [FOLD 3] AUPRC=0.418308 | AUROC=0.854698 | Acc=0.944907 | P=0.692982 | R=0.247179 | Spec=0.976781
#     [FOLD 4] AUPRC=0.419942 | AUROC=0.849169 | Acc=0.941411 | P=0.650378 | R=0.223853 | Spec=0.973720
#     [FOLD 5] AUPRC=0.407892 | AUROC=0.854118 | Acc=0.943964 | P=0.609435 | R=0.207284 | Spec=0.976207
#
# [TRIAL 04] score(AUPRC_macro)=0.414035 | AUROC=0.856869 | Acc=0.943269 | P=0.649872 | R=0.220902 | Spec=0.976234
# [I 2026-07-02 03:04:43,207] Trial 4 finished with value: 0.41403547015850234 and parameters: {'n_estimators': 507, 'learning_rate': 0.04407984038169244, 'num_leaves': 38, 'max_depth': 19, 'min_child_samples': 24, 'subsample': 0.8650089137415928, 'colsample_bytree': 0.7246844304357644, 'reg_lambda': 0.2778331300797557, 'reg_alpha': 0.0008325158565947976, 'min_split_gain': 0.9242722776276352}. Best is trial 4 with value: 0.41403547015850234.
#
# ================================================================================
# [TRIAL 05] params:
# {
#   "objective": "binary",
#   "boosting_type": "gbdt",
#   "n_jobs": -1,
#   "random_state": 42,
#   "verbosity": -1,
#   "n_estimators": 1949,
#   "learning_rate": 0.10196967939171485,
#   "num_leaves": 242,
#   "max_depth": 18,
#   "min_child_samples": 50,
#   "subsample": 0.9687496940092467,
#   "colsample_bytree": 0.6353970008207678,
#   "reg_lambda": 0.008335230071817131,
#   "reg_alpha": 2.5529693461039728e-08,
#   "min_split_gain": 1.6266516538163218
# }
#     [FOLD 1] AUPRC=0.385423 | AUROC=0.862256 | Acc=0.942154 | P=0.658738 | R=0.182317 | Spec=0.977384
#     [FOLD 2] AUPRC=0.385588 | AUROC=0.862847 | Acc=0.942077 | P=0.719008 | R=0.177858 | Spec=0.980486
#     [FOLD 3] AUPRC=0.410559 | AUROC=0.852332 | Acc=0.943242 | P=0.737528 | R=0.201475 | Spec=0.978588
#     [FOLD 4] AUPRC=0.405630 | AUROC=0.845223 | Acc=0.940801 | P=0.760795 | R=0.190200 | Spec=0.977689
#     [FOLD 5] AUPRC=0.382531 | AUROC=0.853819 | Acc=0.942188 | P=0.633219 | R=0.173458 | Spec=0.977193
#
# [TRIAL 05] score(AUPRC_macro)=0.393946 | AUROC=0.855296 | Acc=0.942093 | P=0.701857 | R=0.185062 | Spec=0.978268
# [I 2026-07-02 03:05:22,610] Trial 5 finished with value: 0.3939462696297332 and parameters: {'n_estimators': 1949, 'learning_rate': 0.10196967939171485, 'num_leaves': 242, 'max_depth': 18, 'min_child_samples': 50, 'subsample': 0.9687496940092467, 'colsample_bytree': 0.6353970008207678, 'reg_lambda': 0.008335230071817131, 'reg_alpha': 2.5529693461039728e-08, 'min_split_gain': 1.6266516538163218}. Best is trial 4 with value: 0.41403547015850234.
#
# ================================================================================
# [TRIAL 06] params:
# {
#   "objective": "binary",
#   "boosting_type": "gbdt",
#   "n_jobs": -1,
#   "random_state": 42,
#   "verbosity": -1,
#   "n_estimators": 961,
#   "learning_rate": 0.022544116997360492,
#   "num_leaves": 217,
#   "max_depth": 6,
#   "min_child_samples": 26,
#   "subsample": 0.8170784332632994,
#   "colsample_bytree": 0.6563696899899051,
#   "reg_lambda": 5.881655048861897,
#   "reg_alpha": 4.6876566400928895e-08,
#   "min_split_gain": 4.9344346830025865
# }
#     [FOLD 1] AUPRC=0.344319 | AUROC=0.845494 | Acc=0.941545 | P=0.821211 | R=0.130424 | Spec=0.982009
#     [FOLD 2] AUPRC=0.334660 | AUROC=0.841458 | Acc=0.939248 | P=0.727451 | R=0.124859 | Spec=0.982540
#     [FOLD 3] AUPRC=0.328049 | AUROC=0.816972 | Acc=0.941966 | P=0.796686 | R=0.128825 | Spec=0.982547
#     [FOLD 4] AUPRC=0.341174 | AUROC=0.830074 | Acc=0.938415 | P=0.690296 | R=0.123648 | Spec=0.979669
#     [FOLD 5] AUPRC=0.315029 | AUROC=0.823279 | Acc=0.940302 | P=0.813655 | R=0.122065 | Spec=0.979452
#
# [TRIAL 06] score(AUPRC_macro)=0.332646 | AUROC=0.831455 | Acc=0.940295 | P=0.769860 | R=0.125964 | Spec=0.981244
# [I 2026-07-02 03:05:44,301] Trial 6 finished with value: 0.3326462219541659 and parameters: {'n_estimators': 961, 'learning_rate': 0.022544116997360492, 'num_leaves': 217, 'max_depth': 6, 'min_child_samples': 26, 'subsample': 0.8170784332632994, 'colsample_bytree': 0.6563696899899051, 'reg_lambda': 5.881655048861897, 'reg_alpha': 4.6876566400928895e-08, 'min_split_gain': 4.9344346830025865}. Best is trial 4 with value: 0.41403547015850234.
#
# ================================================================================
# [TRIAL 07] params:
# {
#   "objective": "binary",
#   "boosting_type": "gbdt",
#   "n_jobs": -1,
#   "random_state": 42,
#   "verbosity": -1,
#   "n_estimators": 1613,
#   "learning_rate": 0.018135730867783396,
#   "num_leaves": 32,
#   "max_depth": 16,
#   "min_child_samples": 58,
#   "subsample": 0.8916028672163949,
#   "colsample_bytree": 0.9085081386743783,
#   "reg_lambda": 0.0022280944532589255,
#   "reg_alpha": 1.683416412018213e-05,
#   "min_split_gain": 0.5793452976256486
# }
#     [FOLD 1] AUPRC=0.408201 | AUROC=0.865104 | Acc=0.942320 | P=0.601317 | R=0.216350 | Spec=0.974338
#     [FOLD 2] AUPRC=0.381622 | AUROC=0.860416 | Acc=0.942355 | P=0.586327 | R=0.204605 | Spec=0.977196
#     [FOLD 3] AUPRC=0.409463 | AUROC=0.856263 | Acc=0.944851 | P=0.692729 | R=0.230591 | Spec=0.977306
#     [FOLD 4] AUPRC=0.419818 | AUROC=0.845901 | Acc=0.941578 | P=0.733508 | R=0.219796 | Spec=0.974356
#     [FOLD 5] AUPRC=0.396650 | AUROC=0.856095 | Acc=0.942854 | P=0.660564 | R=0.211582 | Spec=0.973790
#
# [TRIAL 07] score(AUPRC_macro)=0.403151 | AUROC=0.856756 | Acc=0.942792 | P=0.654889 | R=0.216585 | Spec=0.975397
# [I 2026-07-02 03:06:17,532] Trial 7 finished with value: 0.40315057253234443 and parameters: {'n_estimators': 1613, 'learning_rate': 0.018135730867783396, 'num_leaves': 32, 'max_depth': 16, 'min_child_samples': 58, 'subsample': 0.8916028672163949, 'colsample_bytree': 0.9085081386743783, 'reg_lambda': 0.0022280944532589255, 'reg_alpha': 1.683416412018213e-05, 'min_split_gain': 0.5793452976256486}. Best is trial 4 with value: 0.41403547015850234.
#
# ================================================================================
# [TRIAL 08] params:
# {
#   "objective": "binary",
#   "boosting_type": "gbdt",
#   "n_jobs": -1,
#   "random_state": 42,
#   "verbosity": -1,
#   "n_estimators": 1768,
#   "learning_rate": 0.06470376604234768,
#   "num_leaves": 105,
#   "max_depth": 0,
#   "min_child_samples": 28,
#   "subsample": 0.7300733288106989,
#   "colsample_bytree": 0.8918424713352255,
#   "reg_lambda": 0.9905204218383901,
#   "reg_alpha": 0.9658611176861268,
#   "min_split_gain": 2.3610746258097466
# }
#     [FOLD 1] AUPRC=0.374528 | AUROC=0.853683 | Acc=0.942043 | P=0.805694 | R=0.166866 | Spec=0.978269
#     [FOLD 2] AUPRC=0.373585 | AUROC=0.850795 | Acc=0.942022 | P=0.804570 | R=0.159571 | Spec=0.982569
#     [FOLD 3] AUPRC=0.378356 | AUROC=0.836665 | Acc=0.943076 | P=0.787086 | R=0.161236 | Spec=0.980733
#     [FOLD 4] AUPRC=0.383195 | AUROC=0.841208 | Acc=0.939969 | P=0.794684 | R=0.159222 | Spec=0.977298
#     [FOLD 5] AUPRC=0.357196 | AUROC=0.839394 | Acc=0.942299 | P=0.805311 | R=0.159925 | Spec=0.977945
#
# [TRIAL 08] score(AUPRC_macro)=0.373372 | AUROC=0.844349 | Acc=0.941882 | P=0.799469 | R=0.161364 | Spec=0.979363
# [I 2026-07-02 03:06:43,622] Trial 8 finished with value: 0.3733719579500496 and parameters: {'n_estimators': 1768, 'learning_rate': 0.06470376604234768, 'num_leaves': 105, 'max_depth': 0, 'min_child_samples': 28, 'subsample': 0.7300733288106989, 'colsample_bytree': 0.8918424713352255, 'reg_lambda': 0.9905204218383901, 'reg_alpha': 0.9658611176861268, 'min_split_gain': 2.3610746258097466}. Best is trial 4 with value: 0.41403547015850234.
#
# ================================================================================
# [TRIAL 09] params:
# {
#   "objective": "binary",
#   "boosting_type": "gbdt",
#   "n_jobs": -1,
#   "random_state": 42,
#   "verbosity": -1,
#   "n_estimators": 503,
#   "learning_rate": 0.08471354625326555,
#   "num_leaves": 202,
#   "max_depth": 11,
#   "min_child_samples": 63,
#   "subsample": 0.7975182385457563,
#   "colsample_bytree": 0.8090931317527976,
#   "reg_lambda": 0.10209451747520762,
#   "reg_alpha": 1.6934490731313353e-08,
#   "min_split_gain": 0.5394571349665223
# }
#     [FOLD 1] AUPRC=0.418660 | AUROC=0.863081 | Acc=0.941988 | P=0.623786 | R=0.213651 | Spec=0.973506
#     [FOLD 2] AUPRC=0.382174 | AUROC=0.860338 | Acc=0.941245 | P=0.517167 | R=0.195345 | Spec=0.976513
#     [FOLD 3] AUPRC=0.411973 | AUROC=0.854667 | Acc=0.945295 | P=0.672831 | R=0.235031 | Spec=0.977696
#     [FOLD 4] AUPRC=0.406641 | AUROC=0.847190 | Acc=0.940746 | P=0.670971 | R=0.219393 | Spec=0.973400
#     [FOLD 5] AUPRC=0.393872 | AUROC=0.856394 | Acc=0.942466 | P=0.660224 | R=0.208794 | Spec=0.974188
#
# [TRIAL 09] score(AUPRC_macro)=0.402664 | AUROC=0.856334 | Acc=0.942348 | P=0.628996 | R=0.214443 | Spec=0.975060
# [I 2026-07-02 03:06:56,939] Trial 9 finished with value: 0.4026641054463336 and parameters: {'n_estimators': 503, 'learning_rate': 0.08471354625326555, 'num_leaves': 202, 'max_depth': 11, 'min_child_samples': 63, 'subsample': 0.7975182385457563, 'colsample_bytree': 0.8090931317527976, 'reg_lambda': 0.10209451747520762, 'reg_alpha': 1.6934490731313353e-08, 'min_split_gain': 0.5394571349665223}. Best is trial 4 with value: 0.41403547015850234.
#
# ================================================================================
# [TRIAL 10] params:
# {
#   "objective": "binary",
#   "boosting_type": "gbdt",
#   "n_jobs": -1,
#   "random_state": 42,
#   "verbosity": -1,
#   "n_estimators": 653,
#   "learning_rate": 0.04128697297312279,
#   "num_leaves": 147,
#   "max_depth": 14,
#   "min_child_samples": 6,
#   "subsample": 0.8163775632702192,
#   "colsample_bytree": 0.983908298378168,
#   "reg_lambda": 0.03379534397108484,
#   "reg_alpha": 3.3316309468938505,
#   "min_split_gain": 3.6920277236251042
# }
#     [FOLD 1] AUPRC=0.333435 | AUROC=0.837483 | Acc=0.940991 | P=0.820761 | R=0.137739 | Spec=0.981229
#     [FOLD 2] AUPRC=0.325949 | AUROC=0.837309 | Acc=0.939470 | P=0.742779 | R=0.128110 | Spec=0.983116
#     [FOLD 3] AUPRC=0.316527 | AUROC=0.811206 | Acc=0.941356 | P=0.761676 | R=0.131646 | Spec=0.982550
#     [FOLD 4] AUPRC=0.333428 | AUROC=0.816769 | Acc=0.937750 | P=0.699541 | R=0.121180 | Spec=0.978796
#     [FOLD 5] AUPRC=0.309292 | AUROC=0.815438 | Acc=0.940912 | P=0.848268 | R=0.134268 | Spec=0.979193
#
# [TRIAL 10] score(AUPRC_macro)=0.323726 | AUROC=0.823641 | Acc=0.940096 | P=0.774605 | R=0.130589 | Spec=0.980977
# [I 2026-07-02 03:07:19,287] Trial 10 finished with value: 0.32372625629470736 and parameters: {'n_estimators': 653, 'learning_rate': 0.04128697297312279, 'num_leaves': 147, 'max_depth': 14, 'min_child_samples': 6, 'subsample': 0.8163775632702192, 'colsample_bytree': 0.983908298378168, 'reg_lambda': 0.03379534397108484, 'reg_alpha': 3.3316309468938505, 'min_split_gain': 3.6920277236251042}. Best is trial 4 with value: 0.41403547015850234.
#
# ================================================================================
# [TRIAL 11] params:
# {
#   "objective": "binary",
#   "boosting_type": "gbdt",
#   "n_jobs": -1,
#   "random_state": 42,
#   "verbosity": -1,
#   "n_estimators": 1264,
#   "learning_rate": 0.010272842363526024,
#   "num_leaves": 88,
#   "max_depth": 7,
#   "min_child_samples": 38,
#   "subsample": 0.88180962139586,
#   "colsample_bytree": 0.7389917503278137,
#   "reg_lambda": 1.507231417469703,
#   "reg_alpha": 0.027019779735714396,
#   "min_split_gain": 0.03670622408491764
# }
#     [FOLD 1] AUPRC=0.423824 | AUROC=0.864813 | Acc=0.942875 | P=0.561927 | R=0.277342 | Spec=0.972816
#     [FOLD 2] AUPRC=0.398949 | AUROC=0.862996 | Acc=0.943020 | P=0.502795 | R=0.263459 | Spec=0.976117
#     [FOLD 3] AUPRC=0.416402 | AUROC=0.857113 | Acc=0.944296 | P=0.572457 | R=0.291902 | Spec=0.974421
#     [FOLD 4] AUPRC=0.421188 | AUROC=0.853849 | Acc=0.942577 | P=0.636526 | R=0.285616 | Spec=0.972357
#     [FOLD 5] AUPRC=0.413183 | AUROC=0.858667 | Acc=0.942410 | P=0.500964 | R=0.253036 | Spec=0.971014
#
# [TRIAL 11] score(AUPRC_macro)=0.414709 | AUROC=0.859488 | Acc=0.943036 | P=0.554934 | R=0.274271 | Spec=0.973345
# [I 2026-07-02 03:08:40,637] Trial 11 finished with value: 0.41470910901782077 and parameters: {'n_estimators': 1264, 'learning_rate': 0.010272842363526024, 'num_leaves': 88, 'max_depth': 7, 'min_child_samples': 38, 'subsample': 0.88180962139586, 'colsample_bytree': 0.7389917503278137, 'reg_lambda': 1.507231417469703, 'reg_alpha': 0.027019779735714396, 'min_split_gain': 0.03670622408491764}. Best is trial 11 with value: 0.41470910901782077.
#
# ================================================================================
# [TRIAL 12] params:
# {
#   "objective": "binary",
#   "boosting_type": "gbdt",
#   "n_jobs": -1,
#   "random_state": 42,
#   "verbosity": -1,
#   "n_estimators": 858,
#   "learning_rate": 0.01038511485188037,
#   "num_leaves": 73,
#   "max_depth": 7,
#   "min_child_samples": 42,
#   "subsample": 0.9931791398704514,
#   "colsample_bytree": 0.7830926587418234,
#   "reg_lambda": 2.215962141079502,
#   "reg_alpha": 0.28705712109400183,
#   "min_split_gain": 0.016551504565429198
# }
#     [FOLD 1] AUPRC=0.423694 | AUROC=0.868980 | Acc=0.942819 | P=0.623540 | R=0.256284 | Spec=0.974145
#     [FOLD 2] AUPRC=0.411418 | AUROC=0.865467 | Acc=0.943187 | P=0.517973 | R=0.227406 | Spec=0.977191
#     [FOLD 3] AUPRC=0.419484 | AUROC=0.858715 | Acc=0.944463 | P=0.581209 | R=0.277872 | Spec=0.976144
#     [FOLD 4] AUPRC=0.422903 | AUROC=0.853986 | Acc=0.941800 | P=0.640748 | R=0.244349 | Spec=0.973476
#     [FOLD 5] AUPRC=0.412159 | AUROC=0.862417 | Acc=0.942854 | P=0.542083 | R=0.229855 | Spec=0.972986
#
# [TRIAL 12] score(AUPRC_macro)=0.417932 | AUROC=0.861913 | Acc=0.943025 | P=0.581111 | R=0.247153 | Spec=0.974789
# [I 2026-07-02 03:09:38,846] Trial 12 finished with value: 0.41793171404196033 and parameters: {'n_estimators': 858, 'learning_rate': 0.01038511485188037, 'num_leaves': 73, 'max_depth': 7, 'min_child_samples': 42, 'subsample': 0.9931791398704514, 'colsample_bytree': 0.7830926587418234, 'reg_lambda': 2.215962141079502, 'reg_alpha': 0.28705712109400183, 'min_split_gain': 0.016551504565429198}. Best is trial 12 with value: 0.41793171404196033.
#
# ================================================================================
# [TRIAL 13] params:
# {
#   "objective": "binary",
#   "boosting_type": "gbdt",
#   "n_jobs": -1,
#   "random_state": 42,
#   "verbosity": -1,
#   "n_estimators": 1045,
#   "learning_rate": 0.010136284547794212,
#   "num_leaves": 86,
#   "max_depth": 8,
#   "min_child_samples": 39,
#   "subsample": 0.999515774191902,
#   "colsample_bytree": 0.8184200828646883,
#   "reg_lambda": 2.344862431497,
#   "reg_alpha": 0.16036783824922757,
#   "min_split_gain": 0.008279365666262343
# }
#     [FOLD 1] AUPRC=0.430800 | AUROC=0.866846 | Acc=0.942764 | P=0.612385 | R=0.277491 | Spec=0.972689
#     [FOLD 2] AUPRC=0.409025 | AUROC=0.861363 | Acc=0.943520 | P=0.519204 | R=0.245628 | Spec=0.976875
#     [FOLD 3] AUPRC=0.422373 | AUROC=0.856510 | Acc=0.944740 | P=0.588448 | R=0.294301 | Spec=0.974521
#     [FOLD 4] AUPRC=0.430104 | AUROC=0.855158 | Acc=0.942909 | P=0.655077 | R=0.279685 | Spec=0.972102
#     [FOLD 5] AUPRC=0.414976 | AUROC=0.862393 | Acc=0.942743 | P=0.511132 | R=0.251652 | Spec=0.971651
#
# [TRIAL 13] score(AUPRC_macro)=0.421456 | AUROC=0.860454 | Acc=0.943335 | P=0.577249 | R=0.269751 | Spec=0.973568
# [I 2026-07-02 03:10:58,080] Trial 13 finished with value: 0.42145561695715583 and parameters: {'n_estimators': 1045, 'learning_rate': 0.010136284547794212, 'num_leaves': 86, 'max_depth': 8, 'min_child_samples': 39, 'subsample': 0.999515774191902, 'colsample_bytree': 0.8184200828646883, 'reg_lambda': 2.344862431497, 'reg_alpha': 0.16036783824922757, 'min_split_gain': 0.008279365666262343}. Best is trial 13 with value: 0.42145561695715583.
#
# ================================================================================
# [TRIAL 14] params:
# {
#   "objective": "binary",
#   "boosting_type": "gbdt",
#   "n_jobs": -1,
#   "random_state": 42,
#   "verbosity": -1,
#   "n_estimators": 923,
#   "learning_rate": 0.010615002992039876,
#   "num_leaves": 134,
#   "max_depth": 3,
#   "min_child_samples": 52,
#   "subsample": 0.9944583156059885,
#   "colsample_bytree": 0.8209966024533897,
#   "reg_lambda": 35.8566705453666,
#   "reg_alpha": 0.19878105820692568,
#   "min_split_gain": 1.3145482105778155
# }
#     [FOLD 1] AUPRC=0.347846 | AUROC=0.849269 | Acc=0.941102 | P=0.732585 | R=0.136069 | Spec=0.978268
#     [FOLD 2] AUPRC=0.341428 | AUROC=0.846974 | Acc=0.939913 | P=0.677770 | R=0.132867 | Spec=0.981567
#     [FOLD 3] AUPRC=0.344441 | AUROC=0.827926 | Acc=0.942299 | P=0.766936 | R=0.147233 | Spec=0.980948
#     [FOLD 4] AUPRC=0.350566 | AUROC=0.833193 | Acc=0.939192 | P=0.832199 | R=0.137240 | Spec=0.978747
#     [FOLD 5] AUPRC=0.340413 | AUROC=0.831345 | Acc=0.940524 | P=0.793882 | R=0.128764 | Spec=0.977811
#
# [TRIAL 14] score(AUPRC_macro)=0.344939 | AUROC=0.837741 | Acc=0.940606 | P=0.760674 | R=0.136435 | Spec=0.979468
# [I 2026-07-02 03:11:22,226] Trial 14 finished with value: 0.3449388827151131 and parameters: {'n_estimators': 923, 'learning_rate': 0.010615002992039876, 'num_leaves': 134, 'max_depth': 3, 'min_child_samples': 52, 'subsample': 0.9944583156059885, 'colsample_bytree': 0.8209966024533897, 'reg_lambda': 35.8566705453666, 'reg_alpha': 0.19878105820692568, 'min_split_gain': 1.3145482105778155}. Best is trial 13 with value: 0.42145561695715583.
#
# ================================================================================
# [TRIAL 15] params:
# {
#   "objective": "binary",
#   "boosting_type": "gbdt",
#   "n_jobs": -1,
#   "random_state": 42,
#   "verbosity": -1,
#   "n_estimators": 754,
#   "learning_rate": 0.02786387342808365,
#   "num_leaves": 63,
#   "max_depth": 9,
#   "min_child_samples": 42,
#   "subsample": 0.9631322351833054,
#   "colsample_bytree": 0.8598720487738334,
#   "reg_lambda": 2.0062266813796383,
#   "reg_alpha": 0.22966375910690154,
#   "min_split_gain": 0.056735346470968416
# }
#     [FOLD 1] AUPRC=0.421530 | AUROC=0.864857 | Acc=0.941933 | P=0.573766 | R=0.272669 | Spec=0.971075
#     [FOLD 2] AUPRC=0.401845 | AUROC=0.861574 | Acc=0.942577 | P=0.520096 | R=0.267899 | Spec=0.973150
#     [FOLD 3] AUPRC=0.412489 | AUROC=0.856091 | Acc=0.945295 | P=0.492320 | R=0.284467 | Spec=0.973407
#     [FOLD 4] AUPRC=0.415547 | AUROC=0.851495 | Acc=0.940968 | P=0.580024 | R=0.257908 | Spec=0.970277
#     [FOLD 5] AUPRC=0.408185 | AUROC=0.858322 | Acc=0.942244 | P=0.522351 | R=0.257030 | Spec=0.970968
#
# [TRIAL 15] score(AUPRC_macro)=0.411919 | AUROC=0.858468 | Acc=0.942603 | P=0.537712 | R=0.267995 | Spec=0.971775
# [I 2026-07-02 03:12:04,572] Trial 15 finished with value: 0.41191923435677785 and parameters: {'n_estimators': 754, 'learning_rate': 0.02786387342808365, 'num_leaves': 63, 'max_depth': 9, 'min_child_samples': 42, 'subsample': 0.9631322351833054, 'colsample_bytree': 0.8598720487738334, 'reg_lambda': 2.0062266813796383, 'reg_alpha': 0.22966375910690154, 'min_split_gain': 0.056735346470968416}. Best is trial 13 with value: 0.42145561695715583.
#
# ================================================================================
# [TRIAL 16] params:
# {
#   "objective": "binary",
#   "boosting_type": "gbdt",
#   "n_jobs": -1,
#   "random_state": 42,
#   "verbosity": -1,
#   "n_estimators": 1128,
#   "learning_rate": 0.030581042909244193,
#   "num_leaves": 136,
#   "max_depth": 4,
#   "min_child_samples": 71,
#   "subsample": 0.609478164602333,
#   "colsample_bytree": 0.7730852421324665,
#   "reg_lambda": 5.069430553224879,
#   "reg_alpha": 9.6018723897084,
#   "min_split_gain": 3.1370991330748375
# }
#     [FOLD 1] AUPRC=0.268013 | AUROC=0.782172 | Acc=0.939772 | P=0.732972 | R=0.102899 | Spec=0.982696
#     [FOLD 2] AUPRC=0.253922 | AUROC=0.781933 | Acc=0.937750 | P=0.734214 | R=0.095702 | Spec=0.983424
#     [FOLD 3] AUPRC=0.267455 | AUROC=0.768475 | Acc=0.938582 | P=0.730335 | R=0.101117 | Spec=0.981508
#     [FOLD 4] AUPRC=0.270553 | AUROC=0.768043 | Acc=0.935808 | P=0.682844 | R=0.103193 | Spec=0.978948
#     [FOLD 5] AUPRC=0.255244 | AUROC=0.755822 | Acc=0.938415 | P=0.707555 | R=0.097516 | Spec=0.979969
#
# [TRIAL 16] score(AUPRC_macro)=0.263037 | AUROC=0.771289 | Acc=0.938065 | P=0.717584 | R=0.100085 | Spec=0.981309
# [I 2026-07-02 03:12:21,446] Trial 16 finished with value: 0.2630374950240128 and parameters: {'n_estimators': 1128, 'learning_rate': 0.030581042909244193, 'num_leaves': 136, 'max_depth': 4, 'min_child_samples': 71, 'subsample': 0.609478164602333, 'colsample_bytree': 0.7730852421324665, 'reg_lambda': 5.069430553224879, 'reg_alpha': 9.6018723897084, 'min_split_gain': 3.1370991330748375}. Best is trial 13 with value: 0.42145561695715583.
#
# ================================================================================
# [TRIAL 17] params:
# {
#   "objective": "binary",
#   "boosting_type": "gbdt",
#   "n_jobs": -1,
#   "random_state": 42,
#   "verbosity": -1,
#   "n_estimators": 1469,
#   "learning_rate": 0.014449369873367413,
#   "num_leaves": 77,
#   "max_depth": 0,
#   "min_child_samples": 33,
#   "subsample": 0.9501144309604945,
#   "colsample_bytree": 0.8573491251665902,
#   "reg_lambda": 35.521809104890366,
#   "reg_alpha": 7.117072792005141e-06,
#   "min_split_gain": 1.1191178790888145
# }
#     [FOLD 1] AUPRC=0.372127 | AUROC=0.854422 | Acc=0.942099 | P=0.788978 | R=0.158016 | Spec=0.977426
#     [FOLD 2] AUPRC=0.361165 | AUROC=0.848751 | Acc=0.940912 | P=0.791117 | R=0.150277 | Spec=0.980217
#     [FOLD 3] AUPRC=0.368186 | AUROC=0.833287 | Acc=0.943187 | P=0.797520 | R=0.170612 | Spec=0.978694
#     [FOLD 4] AUPRC=0.363426 | AUROC=0.838315 | Acc=0.939470 | P=0.799161 | R=0.148379 | Spec=0.977144
#     [FOLD 5] AUPRC=0.361972 | AUROC=0.836812 | Acc=0.942133 | P=0.832447 | R=0.156477 | Spec=0.976595
#
# [TRIAL 17] score(AUPRC_macro)=0.365375 | AUROC=0.842318 | Acc=0.941560 | P=0.801845 | R=0.156752 | Spec=0.978015
# [I 2026-07-02 03:12:54,618] Trial 17 finished with value: 0.36537489902348574 and parameters: {'n_estimators': 1469, 'learning_rate': 0.014449369873367413, 'num_leaves': 77, 'max_depth': 0, 'min_child_samples': 33, 'subsample': 0.9501144309604945, 'colsample_bytree': 0.8573491251665902, 'reg_lambda': 35.521809104890366, 'reg_alpha': 7.117072792005141e-06, 'min_split_gain': 1.1191178790888145}. Best is trial 13 with value: 0.42145561695715583.
#
# ================================================================================
# [TRIAL 18] params:
# {
#   "objective": "binary",
#   "boosting_type": "gbdt",
#   "n_jobs": -1,
#   "random_state": 42,
#   "verbosity": -1,
#   "n_estimators": 1118,
#   "learning_rate": 0.010060927133553738,
#   "num_leaves": 116,
#   "max_depth": 9,
#   "min_child_samples": 49,
#   "subsample": 0.9956338445518763,
#   "colsample_bytree": 0.9623834668738909,
#   "reg_lambda": 0.9390987001523136,
#   "reg_alpha": 0.060116164837888966,
#   "min_split_gain": 1.7143164298881695
# }
#     [FOLD 1] AUPRC=0.387788 | AUROC=0.859311 | Acc=0.942265 | P=0.780804 | R=0.176576 | Spec=0.978061
#     [FOLD 2] AUPRC=0.396365 | AUROC=0.859766 | Acc=0.941300 | P=0.774072 | R=0.173019 | Spec=0.980159
#     [FOLD 3] AUPRC=0.404059 | AUROC=0.849768 | Acc=0.943242 | P=0.794245 | R=0.184135 | Spec=0.979030
#     [FOLD 4] AUPRC=0.395801 | AUROC=0.841234 | Acc=0.940912 | P=0.776510 | R=0.189430 | Spec=0.977341
#     [FOLD 5] AUPRC=0.377504 | AUROC=0.847695 | Acc=0.942133 | P=0.736119 | R=0.167876 | Spec=0.977487
#
# [TRIAL 18] score(AUPRC_macro)=0.392303 | AUROC=0.851555 | Acc=0.941971 | P=0.772350 | R=0.178207 | Spec=0.978416
# [I 2026-07-02 03:13:22,459] Trial 18 finished with value: 0.39230337781954666 and parameters: {'n_estimators': 1118, 'learning_rate': 0.010060927133553738, 'num_leaves': 116, 'max_depth': 9, 'min_child_samples': 49, 'subsample': 0.9956338445518763, 'colsample_bytree': 0.9623834668738909, 'reg_lambda': 0.9390987001523136, 'reg_alpha': 0.060116164837888966, 'min_split_gain': 1.7143164298881695}. Best is trial 13 with value: 0.42145561695715583.
#
# ================================================================================
# [TRIAL 19] params:
# {
#   "objective": "binary",
#   "boosting_type": "gbdt",
#   "n_jobs": -1,
#   "random_state": 42,
#   "verbosity": -1,
#   "n_estimators": 764,
#   "learning_rate": 0.02146724600348664,
#   "num_leaves": 157,
#   "max_depth": 12,
#   "min_child_samples": 63,
#   "subsample": 0.7636004284281295,
#   "colsample_bytree": 0.7736339750450786,
#   "reg_lambda": 0.05050657990214898,
#   "reg_alpha": 1.3461917355912045e-06,
#   "min_split_gain": 0.6896060497059809
# }
#     [FOLD 1] AUPRC=0.408938 | AUROC=0.863739 | Acc=0.942653 | P=0.731974 | R=0.204551 | Spec=0.975071
#     [FOLD 2] AUPRC=0.386618 | AUROC=0.860635 | Acc=0.940801 | P=0.552445 | R=0.190411 | Spec=0.977043
#     [FOLD 3] AUPRC=0.415621 | AUROC=0.854826 | Acc=0.944186 | P=0.719787 | R=0.218530 | Spec=0.977913
#     [FOLD 4] AUPRC=0.413520 | AUROC=0.846655 | Acc=0.941300 | P=0.731852 | R=0.214616 | Spec=0.974905
#     [FOLD 5] AUPRC=0.394208 | AUROC=0.858322 | Acc=0.942466 | P=0.651880 | R=0.200385 | Spec=0.974832
#
# [TRIAL 19] score(AUPRC_macro)=0.403781 | AUROC=0.856836 | Acc=0.942281 | P=0.677587 | R=0.205699 | Spec=0.975953
# [I 2026-07-02 03:13:45,930] Trial 19 finished with value: 0.403780801490344 and parameters: {'n_estimators': 764, 'learning_rate': 0.02146724600348664, 'num_leaves': 157, 'max_depth': 12, 'min_child_samples': 63, 'subsample': 0.7636004284281295, 'colsample_bytree': 0.7736339750450786, 'reg_lambda': 0.05050657990214898, 'reg_alpha': 1.3461917355912045e-06, 'min_split_gain': 0.6896060497059809}. Best is trial 13 with value: 0.42145561695715583.
#
# ================================================================================
# [TRIAL 20] params:
# {
#   "objective": "binary",
#   "boosting_type": "gbdt",
#   "n_jobs": -1,
#   "random_state": 42,
#   "verbosity": -1,
#   "n_estimators": 1053,
#   "learning_rate": 0.013612614564341284,
#   "num_leaves": 68,
#   "max_depth": 5,
#   "min_child_samples": 45,
#   "subsample": 0.8659374859368935,
#   "colsample_bytree": 0.9371210875505989,
#   "reg_lambda": 10.323029776044448,
#   "reg_alpha": 0.7931113995631545,
#   "min_split_gain": 4.848024319125552
# }
#     [FOLD 1] AUPRC=0.322826 | AUROC=0.825234 | Acc=0.939883 | P=0.702632 | R=0.104603 | Spec=0.982170
#     [FOLD 2] AUPRC=0.312421 | AUROC=0.838684 | Acc=0.938582 | P=0.710329 | R=0.102144 | Spec=0.982438
#     [FOLD 3] AUPRC=0.307174 | AUROC=0.807844 | Acc=0.940524 | P=0.773254 | R=0.113523 | Spec=0.982183
#     [FOLD 4] AUPRC=0.312419 | AUROC=0.816318 | Acc=0.937528 | P=0.708168 | R=0.102256 | Spec=0.979550
#     [FOLD 5] AUPRC=0.303964 | AUROC=0.812952 | Acc=0.939858 | P=0.732675 | R=0.106887 | Spec=0.979269
#
# [TRIAL 20] score(AUPRC_macro)=0.311761 | AUROC=0.820207 | Acc=0.939275 | P=0.725412 | R=0.105883 | Spec=0.981122
# [I 2026-07-02 03:14:06,005] Trial 20 finished with value: 0.31176060092155916 and parameters: {'n_estimators': 1053, 'learning_rate': 0.013612614564341284, 'num_leaves': 68, 'max_depth': 5, 'min_child_samples': 45, 'subsample': 0.8659374859368935, 'colsample_bytree': 0.9371210875505989, 'reg_lambda': 10.323029776044448, 'reg_alpha': 0.7931113995631545, 'min_split_gain': 4.848024319125552}. Best is trial 13 with value: 0.42145561695715583.
#
# ================================================================================
# [TRIAL 21] params:
# {
#   "objective": "binary",
#   "boosting_type": "gbdt",
#   "n_jobs": -1,
#   "random_state": 42,
#   "verbosity": -1,
#   "n_estimators": 1280,
#   "learning_rate": 0.011412521526555334,
#   "num_leaves": 91,
#   "max_depth": 8,
#   "min_child_samples": 32,
#   "subsample": 0.9411456428323135,
#   "colsample_bytree": 0.7629927359221791,
#   "reg_lambda": 1.9604130914948752,
#   "reg_alpha": 0.017279345936499442,
#   "min_split_gain": 0.04922174424631101
# }
#     [FOLD 1] AUPRC=0.421437 | AUROC=0.865451 | Acc=0.942875 | P=0.557070 | R=0.287587 | Spec=0.972139
#     [FOLD 2] AUPRC=0.407509 | AUROC=0.864041 | Acc=0.942632 | P=0.485580 | R=0.271939 | Spec=0.975009
#     [FOLD 3] AUPRC=0.418049 | AUROC=0.855023 | Acc=0.944629 | P=0.537796 | R=0.296088 | Spec=0.973320
#     [FOLD 4] AUPRC=0.421529 | AUROC=0.853352 | Acc=0.942188 | P=0.586236 | R=0.285554 | Spec=0.971871
#     [FOLD 5] AUPRC=0.408178 | AUROC=0.857884 | Acc=0.943187 | P=0.494967 | R=0.263198 | Spec=0.970934
#
# [TRIAL 21] score(AUPRC_macro)=0.415341 | AUROC=0.859150 | Acc=0.943102 | P=0.532330 | R=0.280873 | Spec=0.972655
# [I 2026-07-02 03:15:38,730] Trial 21 finished with value: 0.4153405232928674 and parameters: {'n_estimators': 1280, 'learning_rate': 0.011412521526555334, 'num_leaves': 91, 'max_depth': 8, 'min_child_samples': 32, 'subsample': 0.9411456428323135, 'colsample_bytree': 0.7629927359221791, 'reg_lambda': 1.9604130914948752, 'reg_alpha': 0.017279345936499442, 'min_split_gain': 0.04922174424631101}. Best is trial 13 with value: 0.42145561695715583.
#
# ================================================================================
# [TRIAL 22] params:
# {
#   "objective": "binary",
#   "boosting_type": "gbdt",
#   "n_jobs": -1,
#   "random_state": 42,
#   "verbosity": -1,
#   "n_estimators": 1478,
#   "learning_rate": 0.012933353718276879,
#   "num_leaves": 59,
#   "max_depth": 9,
#   "min_child_samples": 35,
#   "subsample": 0.943788410674838,
#   "colsample_bytree": 0.7848971170445036,
#   "reg_lambda": 3.7797714858084217,
#   "reg_alpha": 0.00977997326826024,
#   "min_split_gain": 0.481956958274695
# }
#     [FOLD 1] AUPRC=0.415298 | AUROC=0.866309 | Acc=0.943927 | P=0.699178 | R=0.213270 | Spec=0.975376
#     [FOLD 2] AUPRC=0.406638 | AUROC=0.862858 | Acc=0.942798 | P=0.660611 | R=0.208481 | Spec=0.978041
#     [FOLD 3] AUPRC=0.421300 | AUROC=0.856649 | Acc=0.944518 | P=0.657566 | R=0.221952 | Spec=0.975883
#     [FOLD 4] AUPRC=0.415600 | AUROC=0.853836 | Acc=0.941356 | P=0.628833 | R=0.206356 | Spec=0.974196
#     [FOLD 5] AUPRC=0.400939 | AUROC=0.857111 | Acc=0.943853 | P=0.654847 | R=0.203414 | Spec=0.975212
#
# [TRIAL 22] score(AUPRC_macro)=0.411955 | AUROC=0.859353 | Acc=0.943291 | P=0.660207 | R=0.210695 | Spec=0.975742
# [I 2026-07-02 03:16:21,864] Trial 22 finished with value: 0.41195512115093036 and parameters: {'n_estimators': 1478, 'learning_rate': 0.012933353718276879, 'num_leaves': 59, 'max_depth': 9, 'min_child_samples': 35, 'subsample': 0.943788410674838, 'colsample_bytree': 0.7848971170445036, 'reg_lambda': 3.7797714858084217, 'reg_alpha': 0.00977997326826024, 'min_split_gain': 0.481956958274695}. Best is trial 13 with value: 0.42145561695715583.
#
# ================================================================================
# [TRIAL 23] params:
# {
#   "objective": "binary",
#   "boosting_type": "gbdt",
#   "n_jobs": -1,
#   "random_state": 42,
#   "verbosity": -1,
#   "n_estimators": 827,
#   "learning_rate": 0.012329490074694109,
#   "num_leaves": 111,
#   "max_depth": 7,
#   "min_child_samples": 29,
#   "subsample": 0.999845346059305,
#   "colsample_bytree": 0.8383456106178822,
#   "reg_lambda": 0.6824434347841384,
#   "reg_alpha": 0.15776317831930173,
#   "min_split_gain": 0.9226919608387776
# }
#     [FOLD 1] AUPRC=0.408623 | AUROC=0.863879 | Acc=0.942598 | P=0.667710 | R=0.199691 | Spec=0.976118
#     [FOLD 2] AUPRC=0.394393 | AUROC=0.861316 | Acc=0.942521 | P=0.678982 | R=0.197305 | Spec=0.980098
#     [FOLD 3] AUPRC=0.419915 | AUROC=0.854279 | Acc=0.945628 | P=0.807592 | R=0.221629 | Spec=0.978785
#     [FOLD 4] AUPRC=0.419608 | AUROC=0.851534 | Acc=0.941190 | P=0.681723 | R=0.193052 | Spec=0.976631
#     [FOLD 5] AUPRC=0.404971 | AUROC=0.853939 | Acc=0.944019 | P=0.683138 | R=0.188013 | Spec=0.976865
#
# [TRIAL 23] score(AUPRC_macro)=0.409502 | AUROC=0.856990 | Acc=0.943191 | P=0.703829 | R=0.199938 | Spec=0.977700
# [I 2026-07-02 03:16:52,029] Trial 23 finished with value: 0.4095020112642693 and parameters: {'n_estimators': 827, 'learning_rate': 0.012329490074694109, 'num_leaves': 111, 'max_depth': 7, 'min_child_samples': 29, 'subsample': 0.999845346059305, 'colsample_bytree': 0.8383456106178822, 'reg_lambda': 0.6824434347841384, 'reg_alpha': 0.15776317831930173, 'min_split_gain': 0.9226919608387776}. Best is trial 13 with value: 0.42145561695715583.
#
# ================================================================================
# [TRIAL 24] params:
# {
#   "objective": "binary",
#   "boosting_type": "gbdt",
#   "n_jobs": -1,
#   "random_state": 42,
#   "verbosity": -1,
#   "n_estimators": 1148,
#   "learning_rate": 0.01975795584496128,
#   "num_leaves": 164,
#   "max_depth": 10,
#   "min_child_samples": 15,
#   "subsample": 0.9221283200116948,
#   "colsample_bytree": 0.755006879097736,
#   "reg_lambda": 2.9048375140092966,
#   "reg_alpha": 1.0094776466695152,
#   "min_split_gain": 1.9430917219093204
# }
#     [FOLD 1] AUPRC=0.383220 | AUROC=0.854256 | Acc=0.942376 | P=0.794571 | R=0.165477 | Spec=0.978466
#     [FOLD 2] AUPRC=0.372707 | AUROC=0.856440 | Acc=0.942188 | P=0.740027 | R=0.162782 | Spec=0.981860
#     [FOLD 3] AUPRC=0.375050 | AUROC=0.836631 | Acc=0.943686 | P=0.790185 | R=0.162678 | Spec=0.981020
#     [FOLD 4] AUPRC=0.383819 | AUROC=0.843721 | Acc=0.939525 | P=0.805089 | R=0.151409 | Spec=0.977641
#     [FOLD 5] AUPRC=0.357170 | AUROC=0.840001 | Acc=0.942965 | P=0.794560 | R=0.161600 | Spec=0.978856
#
# [TRIAL 24] score(AUPRC_macro)=0.374393 | AUROC=0.846210 | Acc=0.942148 | P=0.784887 | R=0.160789 | Spec=0.979568
# [I 2026-07-02 03:17:20,003] Trial 24 finished with value: 0.37439311951438997 and parameters: {'n_estimators': 1148, 'learning_rate': 0.01975795584496128, 'num_leaves': 164, 'max_depth': 10, 'min_child_samples': 15, 'subsample': 0.9221283200116948, 'colsample_bytree': 0.755006879097736, 'reg_lambda': 2.9048375140092966, 'reg_alpha': 1.0094776466695152, 'min_split_gain': 1.9430917219093204}. Best is trial 13 with value: 0.42145561695715583.
#
# ================================================================================
# [TRIAL 25] params:
# {
#   "objective": "binary",
#   "boosting_type": "gbdt",
#   "n_jobs": -1,
#   "random_state": 42,
#   "verbosity": -1,
#   "n_estimators": 1222,
#   "learning_rate": 0.028075509764709412,
#   "num_leaves": 85,
#   "max_depth": 14,
#   "min_child_samples": 45,
#   "subsample": 0.9686229691288716,
#   "colsample_bytree": 0.8058014085427238,
#   "reg_lambda": 17.048963947214926,
#   "reg_alpha": 0.0003198811498856527,
#   "min_split_gain": 2.76784375478582
# }
#     [FOLD 1] AUPRC=0.344091 | AUROC=0.844162 | Acc=0.941157 | P=0.788493 | R=0.134100 | Spec=0.978982
#     [FOLD 2] AUPRC=0.338613 | AUROC=0.843124 | Acc=0.939359 | P=0.714307 | R=0.128460 | Spec=0.980802
#     [FOLD 3] AUPRC=0.330419 | AUROC=0.822032 | Acc=0.941578 | P=0.744538 | R=0.135037 | Spec=0.980482
#     [FOLD 4] AUPRC=0.337902 | AUROC=0.827529 | Acc=0.938194 | P=0.717476 | R=0.131974 | Spec=0.978054
#     [FOLD 5] AUPRC=0.326784 | AUROC=0.827027 | Acc=0.940413 | P=0.770656 | R=0.119804 | Spec=0.977765
#
# [TRIAL 25] score(AUPRC_macro)=0.335562 | AUROC=0.832775 | Acc=0.940140 | P=0.747094 | R=0.129875 | Spec=0.979217
# [I 2026-07-02 03:17:41,115] Trial 25 finished with value: 0.33556187067797216 and parameters: {'n_estimators': 1222, 'learning_rate': 0.028075509764709412, 'num_leaves': 85, 'max_depth': 14, 'min_child_samples': 45, 'subsample': 0.9686229691288716, 'colsample_bytree': 0.8058014085427238, 'reg_lambda': 17.048963947214926, 'reg_alpha': 0.0003198811498856527, 'min_split_gain': 2.76784375478582}. Best is trial 13 with value: 0.42145561695715583.
#
# ================================================================================
# [TRIAL 26] params:
# {
#   "objective": "binary",
#   "boosting_type": "gbdt",
#   "n_jobs": -1,
#   "random_state": 42,
#   "verbosity": -1,
#   "n_estimators": 652,
#   "learning_rate": 0.01212825372213629,
#   "num_leaves": 126,
#   "max_depth": 1,
#   "min_child_samples": 56,
#   "subsample": 0.843308486040506,
#   "colsample_bytree": 0.6916618853509834,
#   "reg_lambda": 0.4540682236552071,
#   "reg_alpha": 0.0046299355562649264,
#   "min_split_gain": 0.32515683711008997
# }
#     [FOLD 1] AUPRC=0.350550 | AUROC=0.848477 | Acc=0.938165 | P=0.724814 | R=0.121275 | Spec=0.983016
#     [FOLD 2] AUPRC=0.346400 | AUROC=0.854455 | Acc=0.937084 | P=0.765842 | R=0.110395 | Spec=0.985221
#     [FOLD 3] AUPRC=0.360453 | AUROC=0.842470 | Acc=0.938582 | P=0.817508 | R=0.114108 | Spec=0.984604
#     [FOLD 4] AUPRC=0.350561 | AUROC=0.835128 | Acc=0.935919 | P=0.796252 | R=0.112604 | Spec=0.982670
#     [FOLD 5] AUPRC=0.343045 | AUROC=0.838412 | Acc=0.938693 | P=0.760423 | R=0.105894 | Spec=0.983439
#
# [TRIAL 26] score(AUPRC_macro)=0.350202 | AUROC=0.843788 | Acc=0.937688 | P=0.772968 | R=0.112855 | Spec=0.983790
# [I 2026-07-02 03:17:56,462] Trial 26 finished with value: 0.3502017742489324 and parameters: {'n_estimators': 652, 'learning_rate': 0.01212825372213629, 'num_leaves': 126, 'max_depth': 1, 'min_child_samples': 56, 'subsample': 0.843308486040506, 'colsample_bytree': 0.6916618853509834, 'reg_lambda': 0.4540682236552071, 'reg_alpha': 0.0046299355562649264, 'min_split_gain': 0.32515683711008997}. Best is trial 13 with value: 0.42145561695715583.
#
# ================================================================================
# [TRIAL 27] params:
# {
#   "objective": "binary",
#   "boosting_type": "gbdt",
#   "n_jobs": -1,
#   "random_state": 42,
#   "verbosity": -1,
#   "n_estimators": 1018,
#   "learning_rate": 0.03363057886731066,
#   "num_leaves": 56,
#   "max_depth": 8,
#   "min_child_samples": 33,
#   "subsample": 0.9320095314452297,
#   "colsample_bytree": 0.8853348979757797,
#   "reg_lambda": 0.1362617846438644,
#   "reg_alpha": 0.06235292437688871,
#   "min_split_gain": 0.02573950394957509
# }
#     [FOLD 1] AUPRC=0.412343 | AUROC=0.859173 | Acc=0.941212 | P=0.507323 | R=0.308476 | Spec=0.967550
#     [FOLD 2] AUPRC=0.374372 | AUROC=0.856966 | Acc=0.941079 | P=0.431912 | R=0.288647 | Spec=0.970451
#     [FOLD 3] AUPRC=0.397293 | AUROC=0.849830 | Acc=0.944075 | P=0.457613 | R=0.317686 | Spec=0.970354
#     [FOLD 4] AUPRC=0.401290 | AUROC=0.850294 | Acc=0.939969 | P=0.503139 | R=0.291108 | Spec=0.966814
#     [FOLD 5] AUPRC=0.393016 | AUROC=0.850532 | Acc=0.941689 | P=0.477485 | R=0.282146 | Spec=0.968845
#
# [TRIAL 27] score(AUPRC_macro)=0.395663 | AUROC=0.853359 | Acc=0.941605 | P=0.475495 | R=0.297613 | Spec=0.968803
# [I 2026-07-02 03:18:49,120] Trial 27 finished with value: 0.39566272530309526 and parameters: {'n_estimators': 1018, 'learning_rate': 0.03363057886731066, 'num_leaves': 56, 'max_depth': 8, 'min_child_samples': 33, 'subsample': 0.9320095314452297, 'colsample_bytree': 0.8853348979757797, 'reg_lambda': 0.1362617846438644, 'reg_alpha': 0.06235292437688871, 'min_split_gain': 0.02573950394957509}. Best is trial 13 with value: 0.42145561695715583.
#
# ================================================================================
# [TRIAL 28] params:
# {
#   "objective": "binary",
#   "boosting_type": "gbdt",
#   "n_jobs": -1,
#   "random_state": 42,
#   "verbosity": -1,
#   "n_estimators": 1457,
#   "learning_rate": 0.023163049846597634,
#   "num_leaves": 100,
#   "max_depth": 5,
#   "min_child_samples": 21,
#   "subsample": 0.8972106400934495,
#   "colsample_bytree": 0.8370935625192159,
#   "reg_lambda": 1.8547448928446602,
#   "reg_alpha": 4.230232700863344,
#   "min_split_gain": 0.8502281117378315
# }
#     [FOLD 1] AUPRC=0.353353 | AUROC=0.846162 | Acc=0.942542 | P=0.801497 | R=0.162801 | Spec=0.979226
#     [FOLD 2] AUPRC=0.345996 | AUROC=0.846196 | Acc=0.940468 | P=0.773025 | R=0.138722 | Spec=0.981511
#     [FOLD 3] AUPRC=0.341431 | AUROC=0.821207 | Acc=0.943187 | P=0.782009 | R=0.165207 | Spec=0.980880
#     [FOLD 4] AUPRC=0.352894 | AUROC=0.832502 | Acc=0.939581 | P=0.798019 | R=0.145726 | Spec=0.978153
#     [FOLD 5] AUPRC=0.329781 | AUROC=0.831035 | Acc=0.941245 | P=0.803443 | R=0.146326 | Spec=0.976953
#
# [TRIAL 28] score(AUPRC_macro)=0.344691 | AUROC=0.835421 | Acc=0.941405 | P=0.791599 | R=0.151756 | Spec=0.979345
# [I 2026-07-02 03:19:17,304] Trial 28 finished with value: 0.3446911418532214 and parameters: {'n_estimators': 1457, 'learning_rate': 0.023163049846597634, 'num_leaves': 100, 'max_depth': 5, 'min_child_samples': 21, 'subsample': 0.8972106400934495, 'colsample_bytree': 0.8370935625192159, 'reg_lambda': 1.8547448928446602, 'reg_alpha': 4.230232700863344, 'min_split_gain': 0.8502281117378315}. Best is trial 13 with value: 0.42145561695715583.
#
# ================================================================================
# [TRIAL 29] params:
# {
#   "objective": "binary",
#   "boosting_type": "gbdt",
#   "n_jobs": -1,
#   "random_state": 42,
#   "verbosity": -1,
#   "n_estimators": 890,
#   "learning_rate": 0.016312705162229293,
#   "num_leaves": 172,
#   "max_depth": 13,
#   "min_child_samples": 13,
#   "subsample": 0.9873802737883028,
#   "colsample_bytree": 0.6066353473015387,
#   "reg_lambda": 9.502168197542584,
#   "reg_alpha": 0.0024705224533247234,
#   "min_split_gain": 1.1452032307263516
# }
#     [FOLD 1] AUPRC=0.399986 | AUROC=0.860712 | Acc=0.943484 | P=0.805647 | R=0.182837 | Spec=0.977159
#     [FOLD 2] AUPRC=0.394513 | AUROC=0.862694 | Acc=0.942854 | P=0.704811 | R=0.169363 | Spec=0.980884
#     [FOLD 3] AUPRC=0.394971 | AUROC=0.846484 | Acc=0.944075 | P=0.793583 | R=0.190127 | Spec=0.978587
#     [FOLD 4] AUPRC=0.401927 | AUROC=0.848136 | Acc=0.940801 | P=0.803491 | R=0.173699 | Spec=0.976177
#     [FOLD 5] AUPRC=0.386134 | AUROC=0.849932 | Acc=0.943187 | P=0.762491 | R=0.172732 | Spec=0.977287
#
# [TRIAL 29] score(AUPRC_macro)=0.395506 | AUROC=0.853591 | Acc=0.942880 | P=0.774005 | R=0.177752 | Spec=0.978019
# [I 2026-07-02 03:20:03,985] Trial 29 finished with value: 0.3955062061979399 and parameters: {'n_estimators': 890, 'learning_rate': 0.016312705162229293, 'num_leaves': 172, 'max_depth': 13, 'min_child_samples': 13, 'subsample': 0.9873802737883028, 'colsample_bytree': 0.6066353473015387, 'reg_lambda': 9.502168197542584, 'reg_alpha': 0.0024705224533247234, 'min_split_gain': 1.1452032307263516}. Best is trial 13 with value: 0.42145561695715583.
#
# ================ BEST =================
# Best trial: 13
# Best AUPRC_macro: 0.42145561695715583
# Best params:
# {
#   "n_estimators": 1045,
#   "learning_rate": 0.010136284547794212,
#   "num_leaves": 86,
#   "max_depth": 8,
#   "min_child_samples": 39,
#   "subsample": 0.999515774191902,
#   "colsample_bytree": 0.8184200828646883,
#   "reg_lambda": 2.344862431497,
#   "reg_alpha": 0.16036783824922757,
#   "min_split_gain": 0.008279365666262343
# }
# [SAVED] ./optuna_singlemodel_LIGHTGBM_30trials_5fold_results.csv
# [SAVED] ./used_label_columns_24.csv
# [SAVED] ./used_feature_columns.csv

# %%
# -*- coding: utf-8 -*-
import os
import glob
import json
import warnings
import numpy as np
import pandas as pd

import optuna
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import roc_auc_score, average_precision_score
from sklearn.ensemble import RandomForestClassifier

# =========================
# 0) 配置 & 尽量屏蔽警告
# =========================
RANDOM_SEED = 42
N_TRIALS = 30
N_SPLITS = 5
THRESH = 0.5

os.environ["PYTHONWARNINGS"] = "ignore"
warnings.filterwarnings("ignore", category=UserWarning)
warnings.filterwarnings("ignore", category=FutureWarning)
warnings.filterwarnings("ignore", category=RuntimeWarning)

# 读取特征文件
FEATURE_FILE_GLOB = "./Malodors_Rule&FG&Morgan_features.xlsx"

# RandomForest 固定参数，Optuna 只搜索部分超参
BASE_RF_PARAMS = dict(
    n_jobs=-1,
    random_state=RANDOM_SEED,
)


# =========================
# 1) 读取特征文件 & 按固定列位置划分 SMILES / y / X
# =========================
def find_feature_file(pattern: str):
    cands = sorted(glob.glob(pattern))
    if not cands:
        raise FileNotFoundError(
            f"找不到特征文件：{pattern}\n"
            f"请确认 xlsx 文件名，或修改 FEATURE_FILE_GLOB。"
        )
    return cands[-1]


def load_Xy_from_feature_file(xlsx_path: str):
    """
    固定数据格式：
    第 1 列：SMILES
    第 2-25 列：24 个 y 标签
    第 26 列及之后：X 特征列

    说明：
    - 不再通过 0/1 自动判断 y 标签列；
    - 避免 Morgan bit、Rule、FG 等 0/1 特征被误识别为标签；
    - 适用于当前 24 标签任务。
    """
    df = pd.read_excel(xlsx_path)

    if df.shape[1] < 26:
        raise ValueError(
            f"当前文件列数为 {df.shape[1]}，不足以按“1列SMILES + 24列标签 + 特征列”划分。"
        )

    # 固定列位置
    smiles_col = df.columns[0]
    label_cols = list(df.columns[1:25])
    feature_cols = list(df.columns[25:])

    if len(label_cols) != 24:
        raise ValueError(f"标签列数量应为 24，但当前识别为 {len(label_cols)}。")

    if len(feature_cols) == 0:
        raise ValueError("未识别到特征列。请确认第 26 列之后为 X 特征。")

    # y 标签转为 0/1 整数
    y_df = df[label_cols].copy()
    y_df = y_df.apply(pd.to_numeric, errors="coerce").fillna(0).astype(int)

    # 检查 y 标签是否为 0/1
    invalid_label_cols = []
    for c in label_cols:
        vals = set(pd.unique(y_df[c].dropna()))
        if not vals.issubset({0, 1}):
            invalid_label_cols.append(c)

    if invalid_label_cols:
        raise ValueError(
            "以下标签列不是标准 0/1 标签，请检查数据：\n"
            + "\n".join(map(str, invalid_label_cols))
        )

    # X 特征转为数值
    X_df = df[feature_cols].copy()
    X_df = X_df.apply(pd.to_numeric, errors="coerce").fillna(0)

    X = X_df.astype(np.float32).values
    y = y_df.values.astype(int)

    if X.shape[0] != y.shape[0]:
        raise ValueError("X 和 y 行数不一致，请检查文件。")

    print("[INFO] Column split mode: fixed-position")
    print(f"[INFO] SMILES column: {smiles_col}")
    print(f"[INFO] Label columns: columns 2-25, n={len(label_cols)}")
    print(f"[INFO] Feature columns: columns 26-end, n={len(feature_cols)}")

    print("\n[INFO] Label columns:")
    for i, c in enumerate(label_cols, start=1):
        print(f"  y{i:02d}: {c}")

    return X, y, feature_cols, label_cols, df


# =========================
# 2) 指标：macro
# =========================
def multilabel_macro_metrics(y_true, y_prob, thresh=0.5):
    y_true = np.asarray(y_true).astype(int)
    y_prob = np.asarray(y_prob).astype(float)
    y_pred = (y_prob >= thresh).astype(int)

    L = y_true.shape[1]
    accs, precs, recs, specs = [], [], [], []
    aurocs, auprcs = [], []

    for k in range(L):
        yt = y_true[:, k]
        yp = y_pred[:, k]
        ys = y_prob[:, k]

        tp = int(np.sum((yt == 1) & (yp == 1)))
        tn = int(np.sum((yt == 0) & (yp == 0)))
        fp = int(np.sum((yt == 0) & (yp == 1)))
        fn = int(np.sum((yt == 1) & (yp == 0)))
        n = len(yt)

        accs.append((tp + tn) / n if n else np.nan)
        precs.append(tp / (tp + fp) if (tp + fp) else np.nan)
        recs.append(tp / (tp + fn) if (tp + fn) else np.nan)
        specs.append(tn / (tn + fp) if (tn + fp) else np.nan)

        if len(np.unique(yt)) == 2:
            aurocs.append(roc_auc_score(yt, ys))
            auprcs.append(average_precision_score(yt, ys))
        else:
            aurocs.append(np.nan)
            auprcs.append(np.nan)

    def nanmean(x):
        return float(np.nanmean(np.asarray(x, dtype=float)))

    return {
        "Accuracy_macro": nanmean(accs),
        "Precision_macro": nanmean(precs),
        "Recall_macro": nanmean(recs),
        "Specificity_macro": nanmean(specs),
        "AUROC_macro": nanmean(aurocs),
        "AUPRC_macro": nanmean(auprcs),
        "AUROC_valid_labels": int(np.sum(~np.isnan(aurocs))),
        "AUPRC_valid_labels": int(np.sum(~np.isnan(auprcs))),
        "n_labels": int(L),
    }


def extract_positive_proba(p, n_labels: int, classes_list=None):
    """
    兼容：
    - multi-output RF 的 predict_proba: list，长度=labels，每个元素形状为 (n, n_classes_k)
    - 某标签在该 fold 训练集里只有单类时，predict_proba 可能为 (n, 1)
    """
    if isinstance(p, list):
        out = np.zeros((p[0].shape[0], n_labels), dtype=np.float32)

        for k in range(n_labels):
            pk = p[k]

            if pk.ndim != 2:
                raise ValueError(f"predict_proba[{k}] 形状异常: {pk.shape}")

            if pk.shape[1] == 2:
                # 优先按 classes_ 找 class == 1 对应的概率列
                if classes_list is not None and len(classes_list) == n_labels:
                    cls = list(classes_list[k])
                    if 1 in cls:
                        j = cls.index(1)
                        out[:, k] = pk[:, j].astype(np.float32)
                    else:
                        out[:, k] = 0.0
                else:
                    out[:, k] = pk[:, 1].astype(np.float32)

            elif pk.shape[1] == 1:
                # 只有单一类别：若该类别是 1，则概率恒为 1；若是 0，则概率恒为 0
                if classes_list is not None and len(classes_list) == n_labels:
                    only_cls = int(list(classes_list[k])[0])
                    out[:, k] = 1.0 if only_cls == 1 else 0.0
                else:
                    out[:, k] = 0.0

            else:
                raise ValueError(f"predict_proba[{k}] 类别数异常: {pk.shape[1]}")

        return out

    # 非 list 情况，一般不会出现在 multi-output RF
    p = np.asarray(p)

    if p.ndim == 3 and p.shape[-1] == 2:
        return p[:, :, 1].astype(np.float32)

    if p.ndim == 2:
        if p.shape[1] == 2 and n_labels == 1:
            return p[:, 1:2].astype(np.float32)
        return p.astype(np.float32)

    raise ValueError(f"无法解析 predict_proba 输出形状: {p.shape}")


# =========================
# 3) 近似分层 5 折：用 label cardinality 分层
# =========================
def make_stratify_target(y: np.ndarray, n_bins: int = 10):
    """
    多标签任务中没有直接的 StratifiedKFold。
    这里使用每个样本的标签数量 label cardinality 做近似分层。
    """
    card = y.sum(axis=1).astype(int)
    uniq = np.unique(card)

    if len(uniq) <= 15:
        return card

    r = pd.Series(card).rank(method="average").values
    bins = pd.qcut(
        r,
        q=min(n_bins, len(np.unique(r))),
        labels=False,
        duplicates="drop"
    )

    return np.asarray(bins, dtype=int)


def build_folds(X, y, n_splits=5, seed=42):
    strat_y = make_stratify_target(y)
    skf = StratifiedKFold(
        n_splits=n_splits,
        shuffle=True,
        random_state=seed
    )
    return list(skf.split(X, strat_y))


# =========================
# 4) 5 折 CV 评估：RF
# =========================
def cv_eval_one_paramset(X, y, folds, params, thresh=0.5):
    n_labels = y.shape[1]
    fold_metrics = []

    for fold_id, (tr_idx, va_idx) in enumerate(folds, start=1):
        X_tr, X_va = X[tr_idx], X[va_idx]
        y_tr, y_va = y[tr_idx], y[va_idx]

        clf = RandomForestClassifier(**params)
        clf.fit(X_tr, y_tr)

        p = clf.predict_proba(X_va)
        y_prob = extract_positive_proba(
            p,
            n_labels=n_labels,
            classes_list=getattr(clf, "classes_", None)
        )

        m = multilabel_macro_metrics(y_va, y_prob, thresh=thresh)
        fold_metrics.append(m)

        print(
            f"    [FOLD {fold_id}] "
            f"AUPRC={m['AUPRC_macro']:.6f} | "
            f"AUROC={m['AUROC_macro']:.6f} | "
            f"Acc={m['Accuracy_macro']:.6f} | "
            f"P={m['Precision_macro']:.6f} | "
            f"R={m['Recall_macro']:.6f} | "
            f"Spec={m['Specificity_macro']:.6f}"
        )

    keys = list(fold_metrics[0].keys())
    mean_metrics = {}

    for k in keys:
        vals = [fm[k] for fm in fold_metrics]
        if isinstance(vals[0], float):
            mean_metrics[k] = float(np.nanmean(vals))
        else:
            mean_metrics[k] = vals[-1]

    return mean_metrics


# =========================
# 5) Optuna 超参空间：RF
# =========================
def build_trial_params(trial: optuna.Trial):
    params = dict(BASE_RF_PARAMS)

    max_depth_raw = trial.suggest_int("max_depth", 0, 40)
    max_depth = None if max_depth_raw == 0 else max_depth_raw

    params.update({
        "n_estimators": trial.suggest_int("n_estimators", 300, 1500),
        "max_depth": max_depth,
        "max_features": trial.suggest_categorical(
            "max_features",
            ["sqrt", "log2", 0.3, 0.5, 0.8, 1.0]
        ),
        "min_samples_split": trial.suggest_int("min_samples_split", 2, 20),
        "min_samples_leaf": trial.suggest_int("min_samples_leaf", 1, 10),
        "bootstrap": trial.suggest_categorical("bootstrap", [True, False]),
        "criterion": trial.suggest_categorical(
            "criterion",
            ["gini", "entropy", "log_loss"]
        ),
    })

    return params


# =========================
# 6) 主流程：读特征 -> 固定 folds -> Optuna -> 输出保存
# =========================
def main():
    feature_file = find_feature_file(FEATURE_FILE_GLOB)
    print("[INFO] Using feature file:", feature_file)

    X, y, feat_cols, label_cols, df_all = load_Xy_from_feature_file(feature_file)

    print(
        f"\n[INFO] X shape={X.shape} "
        f"(features={len(feat_cols)}) | "
        f"y shape={y.shape} "
        f"(labels={len(label_cols)})"
    )

    folds = build_folds(X, y, n_splits=N_SPLITS, seed=RANDOM_SEED)
    print(f"[INFO] Prepared fixed {N_SPLITS}-fold splits for all trials.")

    def objective(trial: optuna.Trial):
        params = build_trial_params(trial)

        print("\n" + "=" * 80)
        print(f"[TRIAL {trial.number:02d}] params:")
        print(json.dumps(params, indent=2, ensure_ascii=False, default=str))

        mean_metrics = cv_eval_one_paramset(
            X,
            y,
            folds,
            params,
            thresh=THRESH
        )

        score = mean_metrics["AUPRC_macro"]

        print(
            f"\n[TRIAL {trial.number:02d}] "
            f"score(AUPRC_macro)={score:.6f} | "
            f"AUROC={mean_metrics['AUROC_macro']:.6f} | "
            f"Acc={mean_metrics['Accuracy_macro']:.6f} | "
            f"P={mean_metrics['Precision_macro']:.6f} | "
            f"R={mean_metrics['Recall_macro']:.6f} | "
            f"Spec={mean_metrics['Specificity_macro']:.6f}"
        )

        for k, v in mean_metrics.items():
            trial.set_user_attr(k, v)

        return score

    study = optuna.create_study(
        direction="maximize",
        sampler=optuna.samplers.TPESampler(seed=RANDOM_SEED),
    )

    study.optimize(
        objective,
        n_trials=N_TRIALS,
        show_progress_bar=True
    )

    print("\n================ BEST =================")
    print("Best trial:", study.best_trial.number)
    print("Best AUPRC_macro:", study.best_value)
    print("Best params:")
    print(json.dumps(study.best_params, indent=2, ensure_ascii=False))

    rows = []
    for t in study.trials:
        if t.value is None:
            continue

        row = {
            "trial": t.number,
            "AUPRC_macro": t.value,
            **t.params
        }

        row.update({
            k: v for k, v in t.user_attrs.items()
            if k.endswith("_macro")
        })

        rows.append(row)

    res_df = pd.DataFrame(rows).sort_values(
        "AUPRC_macro",
        ascending=False
    )

    out_csv = "./optuna_singlemodel_RF_30trials_5fold_results.csv"
    res_df.to_csv(out_csv, index=False, encoding="utf-8-sig")
    print("[SAVED]", out_csv)

    # 额外保存标签列和特征列，便于后续核查
    label_out = "./used_label_columns_24.csv"
    feature_out = "./used_feature_columns.csv"

    pd.DataFrame({"label_col": label_cols}).to_csv(
        label_out,
        index=False,
        encoding="utf-8-sig"
    )

    pd.DataFrame({"feature_col": feat_cols}).to_csv(
        feature_out,
        index=False,
        encoding="utf-8-sig"
    )

    print("[SAVED]", label_out)
    print("[SAVED]", feature_out)


if __name__ == "__main__":
    main()
# Out:
# [INFO] Using feature file: ./Malodors_Rule&FG&Morgan_features.xlsx
# [I 2026-07-02 03:21:22,810] A new study created in memory with name: no-name-c19d184d-c246-4121-97f2-4f802a286f20
# [INFO] Column split mode: fixed-position
# [INFO] SMILES column: Canonical_SMILES
# [INFO] Label columns: columns 2-25, n=24
# [INFO] Feature columns: columns 26-end, n=2427
#
# [INFO] Label columns:
#   y01: alcoholic
#   y02: aldehydic
#   y03: almond
#   y04: aromatic
#   y05: burnt
#   y06: cabbage
#   y07: cheesy
#   y08: cherry
#   y09: chocolate
#   y10: ethereal
#   y11: fishy
#   y12: fruity
#   y13: garlic
#   y14: grassy
#   y15: green
#   y16: ketonic
#   y17: musty
#   y18: pungent
#   y19: sharp
#   y20: solvent
#   y21: sour
#   y22: sulfurous
#   y23: sweaty
#   y24: sweet
#
# [INFO] X shape=(3756, 2427) (features=2427) | y shape=(3756, 24) (labels=24)
# [INFO] Prepared fixed 5-fold splits for all trials.
#   0%|          | 0/30 [00:00<?, ?it/s]
# ================================================================================
# [TRIAL 00] params:
# {
#   "n_jobs": -1,
#   "random_state": 42,
#   "n_estimators": 1441,
#   "max_depth": 15,
#   "max_features": 1.0,
#   "min_samples_split": 13,
#   "min_samples_leaf": 8,
#   "bootstrap": false,
#   "criterion": "gini"
# }
#     [FOLD 1] AUPRC=0.335831 | AUROC=0.774476 | Acc=0.938553 | P=0.538927 | R=0.267143 | Spec=0.965591
#     [FOLD 2] AUPRC=0.316145 | AUROC=0.790040 | Acc=0.936917 | P=0.540504 | R=0.231252 | Spec=0.967488
#     [FOLD 3] AUPRC=0.317656 | AUROC=0.755743 | Acc=0.937861 | P=0.495208 | R=0.263085 | Spec=0.962409
#     [FOLD 4] AUPRC=0.322083 | AUROC=0.760912 | Acc=0.936696 | P=0.550335 | R=0.248214 | Spec=0.960752
#     [FOLD 5] AUPRC=0.328077 | AUROC=0.778894 | Acc=0.937028 | P=0.453405 | R=0.260234 | Spec=0.962044
#
# [TRIAL 00] score(AUPRC_macro)=0.323959 | AUROC=0.772013 | Acc=0.937411 | P=0.515676 | R=0.253985 | Spec=0.963657
# [I 2026-07-02 03:23:43,186] Trial 0 finished with value: 0.3239585461875586 and parameters: {'max_depth': 15, 'n_estimators': 1441, 'max_features': 1.0, 'min_samples_split': 13, 'min_samples_leaf': 8, 'bootstrap': False, 'criterion': 'gini'}. Best is trial 0 with value: 0.3239585461875586.
#
# ================================================================================
# [TRIAL 01] params:
# {
#   "n_jobs": -1,
#   "random_state": 42,
#   "n_estimators": 665,
#   "max_depth": 7,
#   "max_features": 0.5,
#   "min_samples_split": 8,
#   "min_samples_leaf": 5,
#   "bootstrap": true,
#   "criterion": "entropy"
# }
#     [FOLD 1] AUPRC=0.391617 | AUROC=0.864456 | Acc=0.940381 | P=0.745594 | R=0.159196 | Spec=0.977710
#     [FOLD 2] AUPRC=0.374051 | AUROC=0.863743 | Acc=0.940579 | P=0.730446 | R=0.154352 | Spec=0.981356
#     [FOLD 3] AUPRC=0.376330 | AUROC=0.848581 | Acc=0.942022 | P=0.770935 | R=0.150102 | Spec=0.981095
#     [FOLD 4] AUPRC=0.390540 | AUROC=0.845805 | Acc=0.938415 | P=0.742959 | R=0.157965 | Spec=0.976296
#     [FOLD 5] AUPRC=0.400142 | AUROC=0.854752 | Acc=0.941023 | P=0.835525 | R=0.161799 | Spec=0.978431
#
# [TRIAL 01] score(AUPRC_macro)=0.386536 | AUROC=0.855467 | Acc=0.940484 | P=0.765092 | R=0.156683 | Spec=0.978978
# [I 2026-07-02 03:24:12,596] Trial 1 finished with value: 0.38653597384676075 and parameters: {'max_depth': 7, 'n_estimators': 665, 'max_features': 0.5, 'min_samples_split': 8, 'min_samples_leaf': 5, 'bootstrap': True, 'criterion': 'entropy'}. Best is trial 1 with value: 0.38653597384676075.
#
# ================================================================================
# [TRIAL 02] params:
# {
#   "n_jobs": -1,
#   "random_state": 42,
#   "n_estimators": 504,
#   "max_depth": 24,
#   "max_features": 0.3,
#   "min_samples_split": 15,
#   "min_samples_leaf": 5,
#   "bootstrap": false,
#   "criterion": "entropy"
# }
#     [FOLD 1] AUPRC=0.413404 | AUROC=0.873075 | Acc=0.941323 | P=0.689731 | R=0.213112 | Spec=0.973754
#     [FOLD 2] AUPRC=0.397622 | AUROC=0.872138 | Acc=0.942909 | P=0.625237 | R=0.214537 | Spec=0.976386
#     [FOLD 3] AUPRC=0.401556 | AUROC=0.847120 | Acc=0.945573 | P=0.683878 | R=0.231480 | Spec=0.976894
#     [FOLD 4] AUPRC=0.431755 | AUROC=0.854971 | Acc=0.942632 | P=0.762450 | R=0.217204 | Spec=0.973804
#     [FOLD 5] AUPRC=0.416897 | AUROC=0.858345 | Acc=0.943686 | P=0.634991 | R=0.218664 | Spec=0.973685
#
# [TRIAL 02] score(AUPRC_macro)=0.412247 | AUROC=0.861130 | Acc=0.943225 | P=0.679258 | R=0.218999 | Spec=0.974904
# [I 2026-07-02 03:24:38,361] Trial 2 finished with value: 0.41224659295630783 and parameters: {'max_depth': 24, 'n_estimators': 504, 'max_features': 0.3, 'min_samples_split': 15, 'min_samples_leaf': 5, 'bootstrap': False, 'criterion': 'entropy'}. Best is trial 2 with value: 0.41224659295630783.
#
# ================================================================================
# [TRIAL 03] params:
# {
#   "n_jobs": -1,
#   "random_state": 42,
#   "n_estimators": 674,
#   "max_depth": 27,
#   "max_features": 0.5,
#   "min_samples_split": 19,
#   "min_samples_leaf": 6,
#   "bootstrap": true,
#   "criterion": "log_loss"
# }
#     [FOLD 1] AUPRC=0.404053 | AUROC=0.875169 | Acc=0.941711 | P=0.760727 | R=0.195993 | Spec=0.973924
#     [FOLD 2] AUPRC=0.404301 | AUROC=0.876031 | Acc=0.942188 | P=0.682950 | R=0.193158 | Spec=0.976954
#     [FOLD 3] AUPRC=0.396548 | AUROC=0.853715 | Acc=0.944574 | P=0.767237 | R=0.195900 | Spec=0.977427
#     [FOLD 4] AUPRC=0.433925 | AUROC=0.857023 | Acc=0.941190 | P=0.788977 | R=0.190525 | Spec=0.974854
#     [FOLD 5] AUPRC=0.411563 | AUROC=0.860440 | Acc=0.943742 | P=0.779611 | R=0.208222 | Spec=0.975443
#
# [TRIAL 03] score(AUPRC_macro)=0.410078 | AUROC=0.864476 | Acc=0.942681 | P=0.755901 | R=0.196760 | Spec=0.975720
# [I 2026-07-02 03:25:10,512] Trial 3 finished with value: 0.41007788964059355 and parameters: {'max_depth': 27, 'n_estimators': 674, 'max_features': 0.5, 'min_samples_split': 19, 'min_samples_leaf': 6, 'bootstrap': True, 'criterion': 'log_loss'}. Best is trial 2 with value: 0.41224659295630783.
#
# ================================================================================
# [TRIAL 04] params:
# {
#   "n_jobs": -1,
#   "random_state": 42,
#   "n_estimators": 625,
#   "max_depth": 15,
#   "max_features": "sqrt",
#   "min_samples_split": 3,
#   "min_samples_leaf": 10,
#   "bootstrap": true,
#   "criterion": "entropy"
# }
#     [FOLD 1] AUPRC=0.385970 | AUROC=0.870193 | Acc=0.938996 | P=0.783178 | R=0.086785 | Spec=0.985898
#     [FOLD 2] AUPRC=0.380636 | AUROC=0.868973 | Acc=0.938138 | P=0.785024 | R=0.083347 | Spec=0.987622
#     [FOLD 3] AUPRC=0.394188 | AUROC=0.853107 | Acc=0.938915 | P=0.790854 | R=0.087896 | Spec=0.985143
#     [FOLD 4] AUPRC=0.391754 | AUROC=0.851388 | Acc=0.936363 | P=0.759049 | R=0.080344 | Spec=0.984661
#     [FOLD 5] AUPRC=0.384166 | AUROC=0.852847 | Acc=0.937750 | P=0.746900 | R=0.080377 | Spec=0.984395
#
# [TRIAL 04] score(AUPRC_macro)=0.387343 | AUROC=0.859302 | Acc=0.938032 | P=0.773001 | R=0.083750 | Spec=0.985544
# [I 2026-07-02 03:26:20,888] Trial 4 finished with value: 0.3873429587123747 and parameters: {'max_depth': 15, 'n_estimators': 625, 'max_features': 'sqrt', 'min_samples_split': 3, 'min_samples_leaf': 10, 'bootstrap': True, 'criterion': 'entropy'}. Best is trial 2 with value: 0.41224659295630783.
#
# ================================================================================
# [TRIAL 05] params:
# {
#   "n_jobs": -1,
#   "random_state": 42,
#   "n_estimators": 1226,
#   "max_depth": 29,
#   "max_features": 0.5,
#   "min_samples_split": 3,
#   "min_samples_leaf": 4,
#   "bootstrap": false,
#   "criterion": "entropy"
# }
#     [FOLD 1] AUPRC=0.403260 | AUROC=0.866141 | Acc=0.940547 | P=0.533118 | R=0.239517 | Spec=0.970152
#     [FOLD 2] AUPRC=0.383071 | AUROC=0.865326 | Acc=0.942355 | P=0.620190 | R=0.247094 | Spec=0.973610
#     [FOLD 3] AUPRC=0.397535 | AUROC=0.843059 | Acc=0.944186 | P=0.509409 | R=0.244867 | Spec=0.972508
#     [FOLD 4] AUPRC=0.421770 | AUROC=0.842181 | Acc=0.942521 | P=0.664912 | R=0.252969 | Spec=0.970784
#     [FOLD 5] AUPRC=0.415293 | AUROC=0.852436 | Acc=0.944019 | P=0.646062 | R=0.255926 | Spec=0.972576
#
# [TRIAL 05] score(AUPRC_macro)=0.404186 | AUROC=0.853829 | Acc=0.942726 | P=0.594738 | R=0.248075 | Spec=0.971926
# [I 2026-07-02 03:27:43,491] Trial 5 finished with value: 0.4041859309391677 and parameters: {'max_depth': 29, 'n_estimators': 1226, 'max_features': 0.5, 'min_samples_split': 3, 'min_samples_leaf': 4, 'bootstrap': False, 'criterion': 'entropy'}. Best is trial 2 with value: 0.41224659295630783.
#
# ================================================================================
# [TRIAL 06] params:
# {
#   "n_jobs": -1,
#   "random_state": 42,
#   "n_estimators": 1156,
#   "max_depth": 4,
#   "max_features": 0.3,
#   "min_samples_split": 2,
#   "min_samples_leaf": 2,
#   "bootstrap": false,
#   "criterion": "log_loss"
# }
#     [FOLD 1] AUPRC=0.330342 | AUROC=0.836883 | Acc=0.936946 | P=0.763993 | R=0.100939 | Spec=0.979701
#     [FOLD 2] AUPRC=0.305032 | AUROC=0.826649 | Acc=0.935308 | P=0.773363 | R=0.091098 | Spec=0.985123
#     [FOLD 3] AUPRC=0.313326 | AUROC=0.823878 | Acc=0.935752 | P=0.812251 | R=0.088760 | Spec=0.985797
#     [FOLD 4] AUPRC=0.321568 | AUROC=0.809655 | Acc=0.932923 | P=0.673385 | R=0.091840 | Spec=0.980316
#     [FOLD 5] AUPRC=0.325101 | AUROC=0.812122 | Acc=0.936363 | P=0.747174 | R=0.098910 | Spec=0.978946
#
# [TRIAL 06] score(AUPRC_macro)=0.319074 | AUROC=0.821837 | Acc=0.935458 | P=0.754033 | R=0.094309 | Spec=0.981976
# [I 2026-07-02 03:28:59,009] Trial 6 finished with value: 0.3190737988165342 and parameters: {'max_depth': 4, 'n_estimators': 1156, 'max_features': 0.3, 'min_samples_split': 2, 'min_samples_leaf': 2, 'bootstrap': False, 'criterion': 'log_loss'}. Best is trial 2 with value: 0.41224659295630783.
#
# ================================================================================
# [TRIAL 07] params:
# {
#   "n_jobs": -1,
#   "random_state": 42,
#   "n_estimators": 792,
#   "max_depth": 10,
#   "max_features": 1.0,
#   "min_samples_split": 17,
#   "min_samples_leaf": 7,
#   "bootstrap": true,
#   "criterion": "entropy"
# }
#     [FOLD 1] AUPRC=0.397566 | AUROC=0.870604 | Acc=0.941766 | P=0.785714 | R=0.196073 | Spec=0.974191
#     [FOLD 2] AUPRC=0.398978 | AUROC=0.871920 | Acc=0.941855 | P=0.678140 | R=0.192549 | Spec=0.977072
#     [FOLD 3] AUPRC=0.397493 | AUROC=0.850824 | Acc=0.943742 | P=0.749420 | R=0.186444 | Spec=0.977757
#     [FOLD 4] AUPRC=0.429833 | AUROC=0.852801 | Acc=0.940302 | P=0.743334 | R=0.183144 | Spec=0.974529
#     [FOLD 5] AUPRC=0.403369 | AUROC=0.859828 | Acc=0.944075 | P=0.795137 | R=0.202865 | Spec=0.976330
#
# [TRIAL 07] score(AUPRC_macro)=0.405448 | AUROC=0.861195 | Acc=0.942348 | P=0.750349 | R=0.192215 | Spec=0.975976
# [I 2026-07-02 03:29:49,284] Trial 7 finished with value: 0.40544798776586893 and parameters: {'max_depth': 10, 'n_estimators': 792, 'max_features': 1.0, 'min_samples_split': 17, 'min_samples_leaf': 7, 'bootstrap': True, 'criterion': 'entropy'}. Best is trial 2 with value: 0.41224659295630783.
#
# ================================================================================
# [TRIAL 08] params:
# {
#   "n_jobs": -1,
#   "random_state": 42,
#   "n_estimators": 1376,
#   "max_depth": 33,
#   "max_features": 1.0,
#   "min_samples_split": 2,
#   "min_samples_leaf": 6,
#   "bootstrap": true,
#   "criterion": "log_loss"
# }
#     [FOLD 1] AUPRC=0.406532 | AUROC=0.871230 | Acc=0.941877 | P=0.755058 | R=0.208668 | Spec=0.972776
#     [FOLD 2] AUPRC=0.398275 | AUROC=0.872919 | Acc=0.942244 | P=0.591375 | R=0.207809 | Spec=0.976038
#     [FOLD 3] AUPRC=0.398114 | AUROC=0.852664 | Acc=0.944685 | P=0.722927 | R=0.218355 | Spec=0.976059
#     [FOLD 4] AUPRC=0.429807 | AUROC=0.851648 | Acc=0.941023 | P=0.687625 | R=0.201028 | Spec=0.973146
#     [FOLD 5] AUPRC=0.408854 | AUROC=0.859890 | Acc=0.944851 | P=0.730315 | R=0.218720 | Spec=0.975034
#
# [TRIAL 08] score(AUPRC_macro)=0.408317 | AUROC=0.861670 | Acc=0.942936 | P=0.697460 | R=0.210916 | Spec=0.974610
# [I 2026-07-02 03:31:15,682] Trial 8 finished with value: 0.4083165051876345 and parameters: {'max_depth': 33, 'n_estimators': 1376, 'max_features': 1.0, 'min_samples_split': 2, 'min_samples_leaf': 6, 'bootstrap': True, 'criterion': 'log_loss'}. Best is trial 2 with value: 0.41224659295630783.
#
# ================================================================================
# [TRIAL 09] params:
# {
#   "n_jobs": -1,
#   "random_state": 42,
#   "n_estimators": 923,
#   "max_depth": 13,
#   "max_features": 0.3,
#   "min_samples_split": 7,
#   "min_samples_leaf": 3,
#   "bootstrap": false,
#   "criterion": "gini"
# }
#     [FOLD 1] AUPRC=0.408415 | AUROC=0.868764 | Acc=0.941822 | P=0.654867 | R=0.219226 | Spec=0.974637
#     [FOLD 2] AUPRC=0.392258 | AUROC=0.865662 | Acc=0.942244 | P=0.626167 | R=0.206980 | Spec=0.976835
#     [FOLD 3] AUPRC=0.395147 | AUROC=0.846099 | Acc=0.944352 | P=0.626165 | R=0.220552 | Spec=0.976346
#     [FOLD 4] AUPRC=0.415917 | AUROC=0.852060 | Acc=0.941578 | P=0.691811 | R=0.221036 | Spec=0.973707
#     [FOLD 5] AUPRC=0.427899 | AUROC=0.862974 | Acc=0.945295 | P=0.661659 | R=0.255299 | Spec=0.975046
#
# [TRIAL 09] score(AUPRC_macro)=0.407927 | AUROC=0.859112 | Acc=0.943058 | P=0.652134 | R=0.224619 | Spec=0.975314
# [I 2026-07-02 03:32:00,123] Trial 9 finished with value: 0.4079274515800588 and parameters: {'max_depth': 13, 'n_estimators': 923, 'max_features': 0.3, 'min_samples_split': 7, 'min_samples_leaf': 3, 'bootstrap': False, 'criterion': 'gini'}. Best is trial 2 with value: 0.41224659295630783.
#
# ================================================================================
# [TRIAL 10] params:
# {
#   "n_jobs": -1,
#   "random_state": 42,
#   "n_estimators": 307,
#   "max_depth": 39,
#   "max_features": 0.8,
#   "min_samples_split": 14,
#   "min_samples_leaf": 1,
#   "bootstrap": false,
#   "criterion": "entropy"
# }
#     [FOLD 1] AUPRC=0.383848 | AUROC=0.850527 | Acc=0.939051 | P=0.490891 | R=0.249510 | Spec=0.967820
#     [FOLD 2] AUPRC=0.361221 | AUROC=0.843187 | Acc=0.940080 | P=0.446614 | R=0.248243 | Spec=0.970170
#     [FOLD 3] AUPRC=0.372852 | AUROC=0.817708 | Acc=0.941800 | P=0.525991 | R=0.263597 | Spec=0.968740
#     [FOLD 4] AUPRC=0.388805 | AUROC=0.825372 | Acc=0.939248 | P=0.547583 | R=0.263786 | Spec=0.965487
#     [FOLD 5] AUPRC=0.377405 | AUROC=0.833329 | Acc=0.940302 | P=0.524544 | R=0.276233 | Spec=0.967463
#
# [TRIAL 10] score(AUPRC_macro)=0.376826 | AUROC=0.834024 | Acc=0.940096 | P=0.507124 | R=0.260274 | Spec=0.967936
# [I 2026-07-02 03:32:38,455] Trial 10 finished with value: 0.37682617616880193 and parameters: {'max_depth': 39, 'n_estimators': 307, 'max_features': 0.8, 'min_samples_split': 14, 'min_samples_leaf': 1, 'bootstrap': False, 'criterion': 'entropy'}. Best is trial 2 with value: 0.41224659295630783.
#
# ================================================================================
# [TRIAL 11] params:
# {
#   "n_jobs": -1,
#   "random_state": 42,
#   "n_estimators": 416,
#   "max_depth": 25,
#   "max_features": "log2",
#   "min_samples_split": 20,
#   "min_samples_leaf": 8,
#   "bootstrap": true,
#   "criterion": "log_loss"
# }
#     [FOLD 1] AUPRC=0.362008 | AUROC=0.864187 | Acc=0.932236 | P=0.851642 | R=0.038944 | Spec=0.990661
#     [FOLD 2] AUPRC=0.379868 | AUROC=0.867999 | Acc=0.931813 | P=0.846276 | R=0.038117 | Spec=0.991681
#     [FOLD 3] AUPRC=0.380442 | AUROC=0.851465 | Acc=0.930093 | P=0.784234 | R=0.036892 | Spec=0.988571
#     [FOLD 4] AUPRC=0.376580 | AUROC=0.847130 | Acc=0.929372 | P=0.765941 | R=0.037847 | Spec=0.988069
#     [FOLD 5] AUPRC=0.356372 | AUROC=0.852055 | Acc=0.932479 | P=0.793119 | R=0.035828 | Spec=0.990774
#
# [TRIAL 11] score(AUPRC_macro)=0.371054 | AUROC=0.856567 | Acc=0.931199 | P=0.808242 | R=0.037526 | Spec=0.989951
# [I 2026-07-02 03:33:17,393] Trial 11 finished with value: 0.37105407667275714 and parameters: {'max_depth': 25, 'n_estimators': 416, 'max_features': 'log2', 'min_samples_split': 20, 'min_samples_leaf': 8, 'bootstrap': True, 'criterion': 'log_loss'}. Best is trial 2 with value: 0.41224659295630783.
#
# ================================================================================
# [TRIAL 12] params:
# {
#   "n_jobs": -1,
#   "random_state": 42,
#   "n_estimators": 531,
#   "max_depth": 21,
#   "max_features": 0.3,
#   "min_samples_split": 20,
#   "min_samples_leaf": 5,
#   "bootstrap": true,
#   "criterion": "log_loss"
# }
#     [FOLD 1] AUPRC=0.409265 | AUROC=0.877032 | Acc=0.942043 | P=0.766150 | R=0.192715 | Spec=0.974948
#     [FOLD 2] AUPRC=0.402109 | AUROC=0.875786 | Acc=0.942022 | P=0.720649 | R=0.187723 | Spec=0.977532
#     [FOLD 3] AUPRC=0.398035 | AUROC=0.855783 | Acc=0.944296 | P=0.794403 | R=0.192474 | Spec=0.977819
#     [FOLD 4] AUPRC=0.433516 | AUROC=0.858015 | Acc=0.941190 | P=0.773014 | R=0.185571 | Spec=0.975355
#     [FOLD 5] AUPRC=0.414261 | AUROC=0.860564 | Acc=0.943520 | P=0.808328 | R=0.206198 | Spec=0.975683
#
# [TRIAL 12] score(AUPRC_macro)=0.411437 | AUROC=0.865436 | Acc=0.942614 | P=0.772509 | R=0.192936 | Spec=0.976267
# [I 2026-07-02 03:34:02,350] Trial 12 finished with value: 0.4114372619756928 and parameters: {'max_depth': 21, 'n_estimators': 531, 'max_features': 0.3, 'min_samples_split': 20, 'min_samples_leaf': 5, 'bootstrap': True, 'criterion': 'log_loss'}. Best is trial 2 with value: 0.41224659295630783.
#
# ================================================================================
# [TRIAL 13] params:
# {
#   "n_jobs": -1,
#   "random_state": 42,
#   "n_estimators": 444,
#   "max_depth": 21,
#   "max_features": 0.3,
#   "min_samples_split": 16,
#   "min_samples_leaf": 4,
#   "bootstrap": false,
#   "criterion": "log_loss"
# }
#     [FOLD 1] AUPRC=0.415561 | AUROC=0.871737 | Acc=0.941711 | P=0.647296 | R=0.212858 | Spec=0.973844
#     [FOLD 2] AUPRC=0.398564 | AUROC=0.872911 | Acc=0.942688 | P=0.607565 | R=0.216706 | Spec=0.975854
#     [FOLD 3] AUPRC=0.407744 | AUROC=0.847649 | Acc=0.944241 | P=0.669771 | R=0.226200 | Spec=0.975336
#     [FOLD 4] AUPRC=0.429569 | AUROC=0.850605 | Acc=0.942077 | P=0.721118 | R=0.216268 | Spec=0.973367
#     [FOLD 5] AUPRC=0.420361 | AUROC=0.863351 | Acc=0.944907 | P=0.588973 | R=0.226456 | Spec=0.974398
#
# [TRIAL 13] score(AUPRC_macro)=0.414360 | AUROC=0.861251 | Acc=0.943125 | P=0.646945 | R=0.219698 | Spec=0.974560
# [I 2026-07-02 03:34:26,904] Trial 13 finished with value: 0.4143599029392144 and parameters: {'max_depth': 21, 'n_estimators': 444, 'max_features': 0.3, 'min_samples_split': 16, 'min_samples_leaf': 4, 'bootstrap': False, 'criterion': 'log_loss'}. Best is trial 13 with value: 0.4143599029392144.
#
# ================================================================================
# [TRIAL 14] params:
# {
#   "n_jobs": -1,
#   "random_state": 42,
#   "n_estimators": 918,
#   "max_depth": 20,
#   "max_features": 0.3,
#   "min_samples_split": 16,
#   "min_samples_leaf": 3,
#   "bootstrap": false,
#   "criterion": "gini"
# }
#     [FOLD 1] AUPRC=0.414541 | AUROC=0.868832 | Acc=0.942930 | P=0.709060 | R=0.227181 | Spec=0.973493
#     [FOLD 2] AUPRC=0.396101 | AUROC=0.868264 | Acc=0.942632 | P=0.644793 | R=0.213818 | Spec=0.975893
#     [FOLD 3] AUPRC=0.398741 | AUROC=0.846901 | Acc=0.944851 | P=0.681670 | R=0.225743 | Spec=0.976173
#     [FOLD 4] AUPRC=0.420226 | AUROC=0.852490 | Acc=0.942022 | P=0.674601 | R=0.223533 | Spec=0.972505
#     [FOLD 5] AUPRC=0.424221 | AUROC=0.862383 | Acc=0.946016 | P=0.560444 | R=0.230370 | Spec=0.974849
#
# [TRIAL 14] score(AUPRC_macro)=0.410766 | AUROC=0.859774 | Acc=0.943690 | P=0.654114 | R=0.224129 | Spec=0.974582
# [I 2026-07-02 03:35:12,075] Trial 14 finished with value: 0.41076587710292783 and parameters: {'max_depth': 20, 'n_estimators': 918, 'max_features': 0.3, 'min_samples_split': 16, 'min_samples_leaf': 3, 'bootstrap': False, 'criterion': 'gini'}. Best is trial 13 with value: 0.4143599029392144.
#
# ================================================================================
# [TRIAL 15] params:
# {
#   "n_jobs": -1,
#   "random_state": 42,
#   "n_estimators": 429,
#   "max_depth": 19,
#   "max_features": 0.3,
#   "min_samples_split": 11,
#   "min_samples_leaf": 4,
#   "bootstrap": false,
#   "criterion": "entropy"
# }
#     [FOLD 1] AUPRC=0.413092 | AUROC=0.870607 | Acc=0.941600 | P=0.637668 | R=0.228188 | Spec=0.973146
#     [FOLD 2] AUPRC=0.390899 | AUROC=0.869983 | Acc=0.943464 | P=0.627516 | R=0.227096 | Spec=0.975670
#     [FOLD 3] AUPRC=0.405396 | AUROC=0.844898 | Acc=0.945240 | P=0.602273 | R=0.235904 | Spec=0.975450
#     [FOLD 4] AUPRC=0.431420 | AUROC=0.850651 | Acc=0.942410 | P=0.683369 | R=0.231771 | Spec=0.972537
#     [FOLD 5] AUPRC=0.425192 | AUROC=0.857281 | Acc=0.944463 | P=0.619267 | R=0.234555 | Spec=0.973594
#
# [TRIAL 15] score(AUPRC_macro)=0.413200 | AUROC=0.858684 | Acc=0.943435 | P=0.634019 | R=0.231503 | Spec=0.974079
# [I 2026-07-02 03:35:34,927] Trial 15 finished with value: 0.41319979441539323 and parameters: {'max_depth': 19, 'n_estimators': 429, 'max_features': 0.3, 'min_samples_split': 11, 'min_samples_leaf': 4, 'bootstrap': False, 'criterion': 'entropy'}. Best is trial 13 with value: 0.4143599029392144.
#
# ================================================================================
# [TRIAL 16] params:
# {
#   "n_jobs": -1,
#   "random_state": 42,
#   "n_estimators": 401,
#   "max_depth": 19,
#   "max_features": 0.8,
#   "min_samples_split": 10,
#   "min_samples_leaf": 3,
#   "bootstrap": false,
#   "criterion": "log_loss"
# }
#     [FOLD 1] AUPRC=0.379674 | AUROC=0.847191 | Acc=0.938774 | P=0.476822 | R=0.247950 | Spec=0.967805
#     [FOLD 2] AUPRC=0.362396 | AUROC=0.846475 | Acc=0.940246 | P=0.494254 | R=0.253600 | Spec=0.970408
#     [FOLD 3] AUPRC=0.369695 | AUROC=0.826232 | Acc=0.941467 | P=0.506720 | R=0.253097 | Spec=0.970179
#     [FOLD 4] AUPRC=0.388573 | AUROC=0.822776 | Acc=0.940468 | P=0.600268 | R=0.274081 | Spec=0.967671
#     [FOLD 5] AUPRC=0.380855 | AUROC=0.828869 | Acc=0.941966 | P=0.509041 | R=0.269105 | Spec=0.970196
#
# [TRIAL 16] score(AUPRC_macro)=0.376239 | AUROC=0.834308 | Acc=0.940584 | P=0.517421 | R=0.259567 | Spec=0.969252
# [I 2026-07-02 03:36:15,786] Trial 16 finished with value: 0.37623874734110785 and parameters: {'max_depth': 19, 'n_estimators': 401, 'max_features': 0.8, 'min_samples_split': 10, 'min_samples_leaf': 3, 'bootstrap': False, 'criterion': 'log_loss'}. Best is trial 13 with value: 0.4143599029392144.
#
# ================================================================================
# [TRIAL 17] params:
# {
#   "n_jobs": -1,
#   "random_state": 42,
#   "n_estimators": 796,
#   "max_depth": 33,
#   "max_features": "log2",
#   "min_samples_split": 13,
#   "min_samples_leaf": 1,
#   "bootstrap": false,
#   "criterion": "log_loss"
# }
#     [FOLD 1] AUPRC=0.403934 | AUROC=0.876410 | Acc=0.941711 | P=0.819045 | R=0.130763 | Spec=0.981775
#     [FOLD 2] AUPRC=0.397780 | AUROC=0.878361 | Acc=0.940746 | P=0.868101 | R=0.118564 | Spec=0.984222
#     [FOLD 3] AUPRC=0.405452 | AUROC=0.863671 | Acc=0.942466 | P=0.774435 | R=0.125752 | Spec=0.982235
#     [FOLD 4] AUPRC=0.407019 | AUROC=0.862170 | Acc=0.939581 | P=0.898389 | R=0.127333 | Spec=0.980874
#     [FOLD 5] AUPRC=0.425568 | AUROC=0.863895 | Acc=0.943131 | P=0.891080 | R=0.127927 | Spec=0.981922
#
# [TRIAL 17] score(AUPRC_macro)=0.407951 | AUROC=0.868901 | Acc=0.941527 | P=0.850210 | R=0.126068 | Spec=0.982206
# [I 2026-07-02 03:37:23,544] Trial 17 finished with value: 0.40795063969997586 and parameters: {'max_depth': 33, 'n_estimators': 796, 'max_features': 'log2', 'min_samples_split': 13, 'min_samples_leaf': 1, 'bootstrap': False, 'criterion': 'log_loss'}. Best is trial 13 with value: 0.4143599029392144.
#
# ================================================================================
# [TRIAL 18] params:
# {
#   "n_jobs": -1,
#   "random_state": 42,
#   "n_estimators": 304,
#   "max_depth": null,
#   "max_features": "sqrt",
#   "min_samples_split": 11,
#   "min_samples_leaf": 4,
#   "bootstrap": false,
#   "criterion": "entropy"
# }
#     [FOLD 1] AUPRC=0.416443 | AUROC=0.879411 | Acc=0.941212 | P=0.744788 | R=0.126199 | Spec=0.980780
#     [FOLD 2] AUPRC=0.405140 | AUROC=0.877387 | Acc=0.940468 | P=0.765485 | R=0.126648 | Spec=0.983061
#     [FOLD 3] AUPRC=0.409284 | AUROC=0.860718 | Acc=0.942022 | P=0.736277 | R=0.132127 | Spec=0.981610
#     [FOLD 4] AUPRC=0.426689 | AUROC=0.859578 | Acc=0.939525 | P=0.822405 | R=0.130700 | Spec=0.980676
#     [FOLD 5] AUPRC=0.424232 | AUROC=0.863581 | Acc=0.943187 | P=0.900955 | R=0.140432 | Spec=0.981603
#
# [TRIAL 18] score(AUPRC_macro)=0.416358 | AUROC=0.868135 | Acc=0.941283 | P=0.793982 | R=0.131222 | Spec=0.981546
# [I 2026-07-02 03:37:56,104] Trial 18 finished with value: 0.41635769404386486 and parameters: {'max_depth': 0, 'n_estimators': 304, 'max_features': 'sqrt', 'min_samples_split': 11, 'min_samples_leaf': 4, 'bootstrap': False, 'criterion': 'entropy'}. Best is trial 18 with value: 0.41635769404386486.
#
# ================================================================================
# [TRIAL 19] params:
# {
#   "n_jobs": -1,
#   "random_state": 42,
#   "n_estimators": 303,
#   "max_depth": 2,
#   "max_features": "sqrt",
#   "min_samples_split": 7,
#   "min_samples_leaf": 4,
#   "bootstrap": false,
#   "criterion": "gini"
# }
#     [FOLD 1] AUPRC=0.319238 | AUROC=0.844831 | Acc=0.928579 | P=0.786834 | R=0.027522 | Spec=0.992384
#     [FOLD 2] AUPRC=0.330033 | AUROC=0.847208 | Acc=0.928817 | P=0.805825 | R=0.028270 | Spec=0.993490
#     [FOLD 3] AUPRC=0.319780 | AUROC=0.822648 | Acc=0.929039 | P=0.894659 | R=0.029470 | Spec=0.992069
#     [FOLD 4] AUPRC=0.311074 | AUROC=0.813745 | Acc=0.927097 | P=0.734694 | R=0.029086 | Spec=0.990278
#     [FOLD 5] AUPRC=0.316395 | AUROC=0.815026 | Acc=0.929927 | P=0.821317 | R=0.026497 | Spec=0.992994
#
# [TRIAL 19] score(AUPRC_macro)=0.319304 | AUROC=0.828691 | Acc=0.928692 | P=0.808666 | R=0.028169 | Spec=0.992243
# [I 2026-07-02 03:38:29,356] Trial 19 finished with value: 0.3193041050735712 and parameters: {'max_depth': 2, 'n_estimators': 303, 'max_features': 'sqrt', 'min_samples_split': 7, 'min_samples_leaf': 4, 'bootstrap': False, 'criterion': 'gini'}. Best is trial 18 with value: 0.41635769404386486.
#
# ================================================================================
# [TRIAL 20] params:
# {
#   "n_jobs": -1,
#   "random_state": 42,
#   "n_estimators": 1106,
#   "max_depth": 1,
#   "max_features": "sqrt",
#   "min_samples_split": 11,
#   "min_samples_leaf": 2,
#   "bootstrap": false,
#   "criterion": "log_loss"
# }
#     [FOLD 1] AUPRC=0.313779 | AUROC=0.844777 | Acc=0.928856 | P=0.779762 | R=0.028728 | Spec=0.991711
#     [FOLD 2] AUPRC=0.320468 | AUROC=0.843085 | Acc=0.928540 | P=0.770588 | R=0.029746 | Spec=0.991536
#     [FOLD 3] AUPRC=0.323378 | AUROC=0.821820 | Acc=0.928984 | P=0.777778 | R=0.030093 | Spec=0.991287
#     [FOLD 4] AUPRC=0.314192 | AUROC=0.815339 | Acc=0.926931 | P=0.713514 | R=0.030471 | Spec=0.988675
#     [FOLD 5] AUPRC=0.308297 | AUROC=0.818186 | Acc=0.929816 | P=0.826367 | R=0.025991 | Spec=0.993363
#
# [TRIAL 20] score(AUPRC_macro)=0.316023 | AUROC=0.828641 | Acc=0.928625 | P=0.773602 | R=0.029006 | Spec=0.991315
# [I 2026-07-02 03:40:26,458] Trial 20 finished with value: 0.3160229952538215 and parameters: {'max_depth': 1, 'n_estimators': 1106, 'max_features': 'sqrt', 'min_samples_split': 11, 'min_samples_leaf': 2, 'bootstrap': False, 'criterion': 'log_loss'}. Best is trial 18 with value: 0.41635769404386486.
#
# ================================================================================
# [TRIAL 21] params:
# {
#   "n_jobs": -1,
#   "random_state": 42,
#   "n_estimators": 452,
#   "max_depth": 9,
#   "max_features": "sqrt",
#   "min_samples_split": 9,
#   "min_samples_leaf": 4,
#   "bootstrap": false,
#   "criterion": "entropy"
# }
#     [FOLD 1] AUPRC=0.387759 | AUROC=0.871852 | Acc=0.938497 | P=0.825423 | R=0.085357 | Spec=0.986836
#     [FOLD 2] AUPRC=0.382580 | AUROC=0.871725 | Acc=0.938304 | P=0.837724 | R=0.085247 | Spec=0.988307
#     [FOLD 3] AUPRC=0.393693 | AUROC=0.854639 | Acc=0.939525 | P=0.808398 | R=0.087780 | Spec=0.986620
#     [FOLD 4] AUPRC=0.399407 | AUROC=0.850287 | Acc=0.936751 | P=0.770485 | R=0.082289 | Spec=0.985327
#     [FOLD 5] AUPRC=0.386446 | AUROC=0.853736 | Acc=0.937861 | P=0.803690 | R=0.082514 | Spec=0.985259
#
# [TRIAL 21] score(AUPRC_macro)=0.389977 | AUROC=0.860448 | Acc=0.938188 | P=0.809144 | R=0.084637 | Spec=0.986470
# [I 2026-07-02 03:41:14,048] Trial 21 finished with value: 0.3899770713757427 and parameters: {'max_depth': 9, 'n_estimators': 452, 'max_features': 'sqrt', 'min_samples_split': 9, 'min_samples_leaf': 4, 'bootstrap': False, 'criterion': 'entropy'}. Best is trial 18 with value: 0.41635769404386486.
#
# ================================================================================
# [TRIAL 22] params:
# {
#   "n_jobs": -1,
#   "random_state": 42,
#   "n_estimators": 540,
#   "max_depth": 17,
#   "max_features": 0.3,
#   "min_samples_split": 12,
#   "min_samples_leaf": 4,
#   "bootstrap": false,
#   "criterion": "entropy"
# }
#     [FOLD 1] AUPRC=0.412163 | AUROC=0.873456 | Acc=0.941379 | P=0.655425 | R=0.223539 | Spec=0.973235
#     [FOLD 2] AUPRC=0.394871 | AUROC=0.873917 | Acc=0.943575 | P=0.608487 | R=0.219718 | Spec=0.976044
#     [FOLD 3] AUPRC=0.406922 | AUROC=0.847250 | Acc=0.945628 | P=0.619139 | R=0.235818 | Spec=0.976039
#     [FOLD 4] AUPRC=0.428728 | AUROC=0.851987 | Acc=0.942022 | P=0.717873 | R=0.226220 | Spec=0.972489
#     [FOLD 5] AUPRC=0.428175 | AUROC=0.861790 | Acc=0.944685 | P=0.624280 | R=0.233969 | Spec=0.973938
#
# [TRIAL 22] score(AUPRC_macro)=0.414172 | AUROC=0.861680 | Acc=0.943458 | P=0.645041 | R=0.227853 | Spec=0.974349
# [I 2026-07-02 03:41:45,517] Trial 22 finished with value: 0.41417187561784863 and parameters: {'max_depth': 17, 'n_estimators': 540, 'max_features': 0.3, 'min_samples_split': 12, 'min_samples_leaf': 4, 'bootstrap': False, 'criterion': 'entropy'}. Best is trial 18 with value: 0.41635769404386486.
#
# ================================================================================
# [TRIAL 23] params:
# {
#   "n_jobs": -1,
#   "random_state": 42,
#   "n_estimators": 567,
#   "max_depth": 6,
#   "max_features": 0.3,
#   "min_samples_split": 17,
#   "min_samples_leaf": 2,
#   "bootstrap": false,
#   "criterion": "entropy"
# }
#     [FOLD 1] AUPRC=0.369349 | AUROC=0.855537 | Acc=0.938996 | P=0.779991 | R=0.116312 | Spec=0.981801
#     [FOLD 2] AUPRC=0.348527 | AUROC=0.850012 | Acc=0.938083 | P=0.672813 | R=0.125018 | Spec=0.981696
#     [FOLD 3] AUPRC=0.357625 | AUROC=0.840817 | Acc=0.940468 | P=0.804743 | R=0.128192 | Spec=0.982175
#     [FOLD 4] AUPRC=0.372892 | AUROC=0.835375 | Acc=0.937028 | P=0.755421 | R=0.128082 | Spec=0.978466
#     [FOLD 5] AUPRC=0.388535 | AUROC=0.843465 | Acc=0.939081 | P=0.850273 | R=0.136013 | Spec=0.978799
#
# [TRIAL 23] score(AUPRC_macro)=0.367386 | AUROC=0.845041 | Acc=0.938731 | P=0.772648 | R=0.126723 | Spec=0.980587
# [I 2026-07-02 03:42:09,912] Trial 23 finished with value: 0.3673855238511684 and parameters: {'max_depth': 6, 'n_estimators': 567, 'max_features': 0.3, 'min_samples_split': 17, 'min_samples_leaf': 2, 'bootstrap': False, 'criterion': 'entropy'}. Best is trial 18 with value: 0.41635769404386486.
#
# ================================================================================
# [TRIAL 24] params:
# {
#   "n_jobs": -1,
#   "random_state": 42,
#   "n_estimators": 300,
#   "max_depth": 14,
#   "max_features": "sqrt",
#   "min_samples_split": 12,
#   "min_samples_leaf": 3,
#   "bootstrap": false,
#   "criterion": "entropy"
# }
#     [FOLD 1] AUPRC=0.407888 | AUROC=0.878017 | Acc=0.941212 | P=0.753255 | R=0.113904 | Spec=0.983473
#     [FOLD 2] AUPRC=0.396708 | AUROC=0.876652 | Acc=0.940246 | P=0.850978 | R=0.113060 | Spec=0.984978
#     [FOLD 3] AUPRC=0.400927 | AUROC=0.860210 | Acc=0.941800 | P=0.774694 | R=0.114757 | Spec=0.983583
#     [FOLD 4] AUPRC=0.417442 | AUROC=0.857504 | Acc=0.938304 | P=0.862601 | R=0.115979 | Spec=0.981637
#     [FOLD 5] AUPRC=0.413927 | AUROC=0.862017 | Acc=0.940524 | P=0.830965 | R=0.108283 | Spec=0.982823
#
# [TRIAL 24] score(AUPRC_macro)=0.407378 | AUROC=0.866880 | Acc=0.940417 | P=0.814499 | R=0.113197 | Spec=0.983299
# [I 2026-07-02 03:42:26,693] Trial 24 finished with value: 0.4073784091148115 and parameters: {'max_depth': 14, 'n_estimators': 300, 'max_features': 'sqrt', 'min_samples_split': 12, 'min_samples_leaf': 3, 'bootstrap': False, 'criterion': 'entropy'}. Best is trial 18 with value: 0.41635769404386486.
#
# ================================================================================
# [TRIAL 25] params:
# {
#   "n_jobs": -1,
#   "random_state": 42,
#   "n_estimators": 758,
#   "max_depth": 31,
#   "max_features": 0.3,
#   "min_samples_split": 5,
#   "min_samples_leaf": 6,
#   "bootstrap": false,
#   "criterion": "entropy"
# }
#     [FOLD 1] AUPRC=0.411936 | AUROC=0.872216 | Acc=0.941434 | P=0.682701 | R=0.213214 | Spec=0.974136
#     [FOLD 2] AUPRC=0.396355 | AUROC=0.873821 | Acc=0.942909 | P=0.595014 | R=0.212154 | Spec=0.976572
#     [FOLD 3] AUPRC=0.399076 | AUROC=0.850263 | Acc=0.945628 | P=0.712294 | R=0.231546 | Spec=0.976760
#     [FOLD 4] AUPRC=0.432623 | AUROC=0.850534 | Acc=0.942188 | P=0.781312 | R=0.215790 | Spec=0.973965
#     [FOLD 5] AUPRC=0.420657 | AUROC=0.861952 | Acc=0.943742 | P=0.608732 | R=0.221265 | Spec=0.973026
#
# [TRIAL 25] score(AUPRC_macro)=0.412129 | AUROC=0.861757 | Acc=0.943180 | P=0.676011 | R=0.218794 | Spec=0.974892
# [I 2026-07-02 03:43:04,144] Trial 25 finished with value: 0.4121293569434633 and parameters: {'max_depth': 31, 'n_estimators': 758, 'max_features': 0.3, 'min_samples_split': 5, 'min_samples_leaf': 6, 'bootstrap': False, 'criterion': 'entropy'}. Best is trial 18 with value: 0.41635769404386486.
#
# ================================================================================
# [TRIAL 26] params:
# {
#   "n_jobs": -1,
#   "random_state": 42,
#   "n_estimators": 562,
#   "max_depth": 39,
#   "max_features": 0.8,
#   "min_samples_split": 15,
#   "min_samples_leaf": 7,
#   "bootstrap": false,
#   "criterion": "entropy"
# }
#     [FOLD 1] AUPRC=0.385328 | AUROC=0.848023 | Acc=0.940104 | P=0.540782 | R=0.223340 | Spec=0.971726
#     [FOLD 2] AUPRC=0.370930 | AUROC=0.855051 | Acc=0.941079 | P=0.592884 | R=0.236662 | Spec=0.971942
#     [FOLD 3] AUPRC=0.367812 | AUROC=0.831132 | Acc=0.941689 | P=0.491510 | R=0.224360 | Spec=0.972276
#     [FOLD 4] AUPRC=0.411776 | AUROC=0.829226 | Acc=0.940080 | P=0.699557 | R=0.222672 | Spec=0.969460
#     [FOLD 5] AUPRC=0.384034 | AUROC=0.849426 | Acc=0.941855 | P=0.541634 | R=0.218689 | Spec=0.971788
#
# [TRIAL 26] score(AUPRC_macro)=0.383976 | AUROC=0.842572 | Acc=0.940961 | P=0.573274 | R=0.225145 | Spec=0.971439
# [I 2026-07-02 03:43:53,320] Trial 26 finished with value: 0.383976039633793 and parameters: {'max_depth': 39, 'n_estimators': 562, 'max_features': 0.8, 'min_samples_split': 15, 'min_samples_leaf': 7, 'bootstrap': False, 'criterion': 'entropy'}. Best is trial 18 with value: 0.41635769404386486.
#
# ================================================================================
# [TRIAL 27] params:
# {
#   "n_jobs": -1,
#   "random_state": 42,
#   "n_estimators": 382,
#   "max_depth": 23,
#   "max_features": "log2",
#   "min_samples_split": 12,
#   "min_samples_leaf": 5,
#   "bootstrap": false,
#   "criterion": "entropy"
# }
#     [FOLD 1] AUPRC=0.380565 | AUROC=0.872452 | Acc=0.935062 | P=0.797269 | R=0.050748 | Spec=0.988638
#     [FOLD 2] AUPRC=0.402222 | AUROC=0.871692 | Acc=0.934754 | P=0.810700 | R=0.053930 | Spec=0.989384
#     [FOLD 3] AUPRC=0.391675 | AUROC=0.855237 | Acc=0.934310 | P=0.804751 | R=0.053785 | Spec=0.986381
#     [FOLD 4] AUPRC=0.396149 | AUROC=0.854766 | Acc=0.933089 | P=0.771633 | R=0.054939 | Spec=0.986480
#     [FOLD 5] AUPRC=0.380193 | AUROC=0.856420 | Acc=0.935863 | P=0.767620 | R=0.050369 | Spec=0.988779
#
# [TRIAL 27] score(AUPRC_macro)=0.390161 | AUROC=0.862113 | Acc=0.934616 | P=0.790395 | R=0.052754 | Spec=0.987932
# [I 2026-07-02 03:44:28,699] Trial 27 finished with value: 0.39016066610112105 and parameters: {'max_depth': 23, 'n_estimators': 382, 'max_features': 'log2', 'min_samples_split': 12, 'min_samples_leaf': 5, 'bootstrap': False, 'criterion': 'entropy'}. Best is trial 18 with value: 0.41635769404386486.
#
# ================================================================================
# [TRIAL 28] params:
# {
#   "n_jobs": -1,
#   "random_state": 42,
#   "n_estimators": 1009,
#   "max_depth": null,
#   "max_features": "sqrt",
#   "min_samples_split": 18,
#   "min_samples_leaf": 4,
#   "bootstrap": false,
#   "criterion": "gini"
# }
#     [FOLD 1] AUPRC=0.412395 | AUROC=0.878423 | Acc=0.941323 | P=0.765132 | R=0.135154 | Spec=0.979969
#     [FOLD 2] AUPRC=0.405386 | AUROC=0.876473 | Acc=0.940746 | P=0.780189 | R=0.129949 | Spec=0.982670
#     [FOLD 3] AUPRC=0.406777 | AUROC=0.860242 | Acc=0.942688 | P=0.724695 | R=0.136501 | Spec=0.981325
#     [FOLD 4] AUPRC=0.430704 | AUROC=0.859349 | Acc=0.939802 | P=0.820827 | R=0.131123 | Spec=0.980360
#     [FOLD 5] AUPRC=0.410482 | AUROC=0.864176 | Acc=0.942798 | P=0.896741 | R=0.137707 | Spec=0.981087
#
# [TRIAL 28] score(AUPRC_macro)=0.413149 | AUROC=0.867732 | Acc=0.941471 | P=0.797517 | R=0.134087 | Spec=0.981082
# [I 2026-07-02 03:46:14,524] Trial 28 finished with value: 0.4131488504365001 and parameters: {'max_depth': 0, 'n_estimators': 1009, 'max_features': 'sqrt', 'min_samples_split': 18, 'min_samples_leaf': 4, 'bootstrap': False, 'criterion': 'gini'}. Best is trial 18 with value: 0.41635769404386486.
#
# ================================================================================
# [TRIAL 29] params:
# {
#   "n_jobs": -1,
#   "random_state": 42,
#   "n_estimators": 494,
#   "max_depth": 11,
#   "max_features": 1.0,
#   "min_samples_split": 14,
#   "min_samples_leaf": 7,
#   "bootstrap": false,
#   "criterion": "log_loss"
# }
#     [FOLD 1] AUPRC=0.324622 | AUROC=0.779946 | Acc=0.937389 | P=0.483580 | R=0.251638 | Spec=0.967557
#     [FOLD 2] AUPRC=0.313463 | AUROC=0.766675 | Acc=0.938415 | P=0.508248 | R=0.259275 | Spec=0.966274
#     [FOLD 3] AUPRC=0.310154 | AUROC=0.755947 | Acc=0.937195 | P=0.457428 | R=0.231934 | Spec=0.965661
#     [FOLD 4] AUPRC=0.337303 | AUROC=0.768580 | Acc=0.936973 | P=0.598085 | R=0.260128 | Spec=0.964165
#     [FOLD 5] AUPRC=0.327911 | AUROC=0.769959 | Acc=0.937528 | P=0.484930 | R=0.238245 | Spec=0.965827
#
# [TRIAL 29] score(AUPRC_macro)=0.322691 | AUROC=0.768221 | Acc=0.937500 | P=0.506454 | R=0.248244 | Spec=0.965897
# [I 2026-07-02 03:47:07,423] Trial 29 finished with value: 0.3226907363612864 and parameters: {'max_depth': 11, 'n_estimators': 494, 'max_features': 1.0, 'min_samples_split': 14, 'min_samples_leaf': 7, 'bootstrap': False, 'criterion': 'log_loss'}. Best is trial 18 with value: 0.41635769404386486.
#
# ================ BEST =================
# Best trial: 18
# Best AUPRC_macro: 0.41635769404386486
# Best params:
# {
#   "max_depth": 0,
#   "n_estimators": 304,
#   "max_features": "sqrt",
#   "min_samples_split": 11,
#   "min_samples_leaf": 4,
#   "bootstrap": false,
#   "criterion": "entropy"
# }
# [SAVED] ./optuna_singlemodel_RF_30trials_5fold_results.csv
# [SAVED] ./used_label_columns_24.csv
# [SAVED] ./used_feature_columns.csv
